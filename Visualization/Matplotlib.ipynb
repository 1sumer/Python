# %% [markdown]
# ## **MatPlotLib**

# %% [markdown]
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK. There is also a procedural "pylab" interface based on a state machine (like OpenGL), designed to closely resemble that of MATLAB, though its use is discouraged. SciPy makes use of Matplotlib.
#
# Matplotlib was originally written by John D. Hunter.
#
# Matplotlib supports various types of 2 dimensional and 3 dimensional plots. The support for two dimensional plots is robust. The support for three dimensional plots was added later and while it is good, it is not as robust as 2 dimensional plots.

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

# %%
#pip install matplotlib, numpy, scipy

# %%
x = np.arange(-3, 3, 0.1)
print(x)
print("-----------------------------------------------------------------------")
y = norm.pdf(x)
print(y)
# Out:
# [-3.00000000e+00 -2.90000000e+00 -2.80000000e+00 -2.70000000e+00
#  -2.60000000e+00 -2.50000000e+00 -2.40000000e+00 -2.30000000e+00
#  -2.20000000e+00 -2.10000000e+00 -2.00000000e+00 -1.90000000e+00
#  -1.80000000e+00 -1.70000000e+00 -1.60000000e+00 -1.50000000e+00
#  -1.40000000e+00 -1.30000000e+00 -1.20000000e+00 -1.10000000e+00
#  -1.00000000e+00 -9.00000000e-01 -8.00000000e-01 -7.00000000e-01
#  -6.00000000e-01 -5.00000000e-01 -4.00000000e-01 -3.00000000e-01
#  -2.00000000e-01 -1.00000000e-01  2.66453526e-15  1.00000000e-01
#   2.00000000e-01  3.00000000e-01  4.00000000e-01  5.00000000e-01
#   6.00000000e-01  7.00000000e-01  8.00000000e-01  9.00000000e-01
#   1.00000000e+00  1.10000000e+00  1.20000000e+00  1.30000000e+00
#   1.40000000e+00  1.50000000e+00  1.60000000e+00  1.70000000e+00
#   1.80000000e+00  1.90000000e+00  2.00000000e+00  2.10000000e+00
#   2.20000000e+00  2.30000000e+00  2.40000000e+00  2.50000000e+00
# ...

# %%
plt.scatter(x,y) #Scatter Plot
plt.title("Normal Distribution")
plt.show() # Displaying Plot

# %%
plt.plot(x,y) #Line Plot
plt.show()

# %% [markdown]
# ### **Mutiple Plots on One Graph**

# %%
plt.scatter(x, y) # Scaytter plot
plt.plot(x, norm.pdf(x, 1, 0.5)) # line Plot
plt.show() # Show the plot

# %% [markdown]
# ## **Save it to a File**

# %%
plt.scatter(x, y, color='c') # color representation c, b, k, r, y, g, m, gray, glod, silver, brown, darkblue, orange, violet, #72BF78
plt.plot(x, norm.pdf(x, 1.0, 0.5), color='g') 
plt.savefig(r"D:\Python\Visualization\plot.png", format='png')

# %% [markdown]
# ### **Adjust the Axes**

# %%
plt.style.use('ggplot') #fivethirtyeight, bmh, seaborn, ggplots, grayscale, grayscale

# %%
# adjusting Axis
plt.plot(x, norm.pdf(x))
plt.plot(x, x**2)

plt.xlim([-4, 4]) # adjusting x axis value range
plt.ylim([0, 1.2]) # adjusting y axis value range

plt.show()

# %%
#Specifically assigning the axis values
plt.scatter(x, y, color='m') # Scaytter plot
plt.plot(x, norm.pdf(x, 1, 0.25), 'c') # line Plot

plt.xticks([-2,-1.5, 0,1.5,2]) # Specifically assigning the x axis values
plt.yticks([0,0.4,0.8]) # Specifically assigning the y axis values

plt.xticks(rotation=90) # Rotates the x axis labels 90 degrees

plt.show()

# %% [markdown]
# ### **Add a Grid**

# %%
plt.plot(x, norm.pdf(x), color='c')                            
plt.plot(x, norm.pdf(x, 1.0, 0.5), color='m')

plt.grid(axis='both',color='k', linestyle=':', linewidth=1.0) # adding grid to the plot for x axis 'x', 'y', linewidth,  # liinestyle = -', '--', '-.', ':', ''
plt.show()

# %% [markdown]
# ### **Change Line Types and Colors**

# %%
plt.plot(x, norm.pdf(x), 'y--',linewidth=1.5) # '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'
plt.plot(x, norm.pdf(x, 1.0, 0.5),color='red', linestyle=':',linewidth=1)
plt.grid(axis='both', color='k', linestyle=':',linewidth=1)
plt.show()

# %%
x=np.arange(-3,3,0.1)

plt.plot(x, norm.pdf(x), 'b+', marker='^', markersize=8) # marker '.', 'o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X'
plt.plot(x, norm.pdf(x, 1.0, 0.5),color='red', marker='+', markersize=8)

plt.grid(axis='both', color='k', linestyle=':',linewidth=1)

plt.xlabel('event1', size=10, color='c', fontweight='bold')
plt.ylabel('event2')

plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2288\1662699054.py:3: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "b+" (-> marker='+'). The keyword argument will take precedence.
#   plt.plot(x, norm.pdf(x), 'b+', marker='^', markersize=8) # marker '.', 'o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X'

# %% [markdown]
# ### **Labeling Axes and Adding a Legend**

# %%
plt.plot(x, x**2, color='blue', linestyle=':')
plt.plot(x, norm.pdf(x), color='yellow', marker='*')
plt.plot(x, norm.pdf(x,1.0,0.5), 'g+')

plt.xlim([-4, 4]) # adjusting x axis value range
plt.ylim([0, 2.0]) # adjusting y axis value range

plt.grid(axis='both', color='k', linestyle=':',linewidth=1)

plt.xlabel('Event1')
plt.ylabel('Event2')

plt.title('line Graph',fontsize=15, color='b', loc='center', fontweight='bold')

plt.legend(['Fun A', 'Fun B', 'Fun C'], loc='best') #, 'best', 'upper left', 'upper right', 'lower left', 'lower right', 1, 2, 4

plt.show()

# %% [markdown]
# ### **Customizing Line plot**

# %%
plt.figure(figsize=(8,6)) # Ajusting the figure size

plt.plot(x,x**2, color='blue', linestyle=':')
plt.plot(x, norm.pdf(x), color='yellow', marker='*')
plt.plot(x, norm.pdf(x,1.0,0.5), 'g+')

plt.xlim([-4, 4]) # adjusting x axis value range
plt.ylim([0, 2.0]) # adjusting y axis value range

plt.grid(axis='both', color='k', linestyle=':',linewidth=1)

plt.xlabel('Event1')
plt.ylabel('Event2')

plt.title('line Graph',fontsize=15, color='b', loc='left', fontweight='bold')

plt.legend(['Fun A', 'Fun B', 'Fun C'], loc='best') #, 'best', 'upper left', 'upper right', 'lower left', 'lower right', 1, 2, 4

plt.show()

# %% [markdown]
# ### **Customizing Scatter plot**

# %%
plt.scatter(x,y, color='b', marker='*') #Scatter Plot
plt.scatter(x, norm.pdf(x,1.0,0.5), marker='o', cmap='viridis', edgecolors='black', alpha=1) #Scatter Plot with PDF

plt.grid(axis='both',color='k', linestyle='--', linewidth=1, alpha=0.5)

plt.xlabel('X')
plt.ylabel('Y')

plt.title('Scatter Plot', color='r', fontsize=16, loc='center', pad=20, fontweight='bold')

plt.legend(['mark','marko'],title='type', loc='best')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2288\1448457926.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, norm.pdf(x,1.0,0.5), marker='o', cmap='viridis', edgecolors='black', alpha=1) #Scatter Plot with PDF

# %% [markdown]
# ### **Pie Chart**

# %%
values = [12, 30, 4, 32, 14]

colors = ['r', 'g', 'b', 'c', 'm']

explode = [0.2, 0, 0.5, 0, 0]

labels = ['India', 'United States', 'Russia', 'China', 'Europe']

plt.pie(values, radius=2, colors= colors, labels=labels, explode=explode, autopct='%1.f%%',frame=False)
plt.axis('equal')

plt.legend(title='country', loc='best') #loc=4
plt.title('Student Locations')

plt.tight_layout() # Adjust the plot to fit the figure area

plt.show()

# %% [markdown]
# ### **Bar Chart**

# %%
import seaborn as sns
sns.color_palette('Set2')
# Out:
# [(0.4, 0.7607843137254902, 0.6470588235294118),
#  (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
#  (0.5529411764705883, 0.6274509803921569, 0.796078431372549),
#  (0.9058823529411765, 0.5411764705882353, 0.7647058823529411),
#  (0.6509803921568628, 0.8470588235294118, 0.32941176470588235),
#  (1.0, 0.8509803921568627, 0.1843137254901961),
#  (0.8980392156862745, 0.7686274509803922, 0.5803921568627451),
#  (0.7019607843137254, 0.7019607843137254, 0.7019607843137254)]

# %%
import seaborn as sns
x = [1, 5, 6, 7, 8]

y = [12, 55, 4, 32, 14]

#colors = ['r', 'g', 'b', 'c', 'm']

# Plotting the bar chart
bars = plt.bar(x, y, color=sns.color_palette('Set2'), edgecolor='k', align='center')
plt.plot(x,y, marker='o', color='r')

# Adding labels
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')

# Adding a title
plt.title('Bar Chart Example')

# Adding a legend
plt.legend(bars, ['Bar 1', 'Bar 2', 'Bar 3', 'Bar 4', 'Bar 5'])

# Add bar labels with vertical rotation and 2 decimal places
plt.bar_label(bars, label_type='center', rotation=90, fmt='%.f') #label_type = edge, fmt is displaying 2 decimal values

# Adding a grid
plt.grid(axis='both', color='k',linestyle='--', linewidth=0.5)

plt.savefig(r"D:\Python\Visualization\Plot.png", format='png')

# %%
x = [1, 5, 8, 6, 7]

y = [12, 55, 4, 32, 14]

# Plotting the bar chart
bars = plt.barh(x, y, color=sns.color_palette('Set2'), edgecolor='k', align='center')

# Adding labels
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')

# Adding a title
plt.title('Bar Chart Example')

# Adding a legend
plt.legend(bars, ['Bar 1', 'Bar 2', 'Bar 3', 'Bar 4', 'Bar 5'])
plt.bar_label(bars, label_type='center') #edge

# Set the y-axis to plain numerical format (no scientific notation)
plt.ticklabel_format(style='plain', axis='y')

# Adding a grid
plt.grid(axis='both', color='k',linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# ### **Histogram**

# %%
data = np.random.randn(1000)
plt.hist(data, bins=10, alpha=0.5, edgecolor='black', histtype='bar', color='blue', orientation='vertical') #histtype: bar, step, stepfilled, orientation: vertical , horizontal

plt.ylabel('Value')
plt.xlabel('Frequency')
plt.title('Histogram')

plt.grid(axis='both', linestyle='--', color='k', alpha=0.5)
plt.show()

# %%
# Generate some random data
data = np.random.randn(1000)

# Create a histogram
plt.hist(data, bins=30, color='skyblue', edgecolor='black', alpha=0.7)

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')

# Add a grid
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ### **Box & Whisker Plot**
#
# Useful for visualizing the spread & skew of data.
#
# The red line represents the median of the data, and the box represents the bounds of the 1st and 3rd quartiles.
#
# So, half of the data exists within the box.
#
# The dotted-line "whiskers" indicate the range of the data - except for outliers, which are plotted outside the whiskers. Outliers are 1.5X or more the interquartile range.
#
# This example below creates uniformly distributed random numbers between -40 and 60, plus a few outliers above 100 and below -100:

# %% [markdown]
# <pre><code>     Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
#                   |-----:-----|
#   o      |--------|     :     |--------|    o  o
#                   |-----:-----|
# flier             <----------->            fliers
#                        IQR</code></pre>

# %%
import pandas as pd
uniformSkewed = np.random.rand(100) * 100 - 40
high_outliers = np.random.rand(10) * 50 + 100
low_outliers = np.random.rand(10) * -50 - 100
data = np.concatenate((uniformSkewed, high_outliers, low_outliers))
df = pd.DataFrame({'data': data}, columns=['data'])
print(df)
df.describe()
# Out:
#            data
# 0     -8.615938
# 1     11.418232
# 2    -10.373981
# 3     -3.953566
# 4    -24.345117
# ..          ...
# 115 -145.575135
# 116 -138.410650
# 117 -143.514765
# 118 -125.337221
# 119 -132.011101
#
# [120 rows x 1 columns]
#              data
# count  120.000000
# mean     8.237439
# std     60.309247
# min   -145.903128
# 25%    -16.769450
# 50%     11.881305
# 75%     36.298715
# max    149.454132

# %%
plt.boxplot(df['data'],labels=df.columns, vert=True, showfliers=True, meanline=True)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2288\926092274.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(df['data'],labels=df.columns, vert=True, showfliers=True, meanline=True)

# %% [markdown]
# ### **Subplots**

# %%
x=np.arange(-3,3,0.1)
data = np.random.randn(1000)

plt.figure(figsize=(8,6)) 

plt.subplot(221)  # This is to create a 2x2 plot 1st position
plt.plot(x,x**2, color='blue', linestyle='--')
plt.xlabel('Event1')
plt.ylabel('Event2')
plt.title('Fun A')

plt.subplot(2, 2, 2)
plt.scatter(x, norm.pdf(x), color='yellow', marker='*')
plt.xlabel('Event1')
plt.ylabel('Event2')
plt.title('Fun B')

plt.subplot(2, 2, 3)
plt.hist(data, bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Event1')
plt.ylabel('Event2')
plt.title('Fun C')

plt.subplot(2, 2, 4)
plt.boxplot(data, vert=False, patch_artist=True)
plt.xlabel('Event1')
plt.title('Fun D')

plt.tight_layout() # Adjust the plot to fit the figure area

plt.show()

# %% [markdown]
# ## **Seaborn**
# seaborn is a Python data visualization library based on Matplotlib that provides a high-level interface for creating informative and attractive statistical graphics.
