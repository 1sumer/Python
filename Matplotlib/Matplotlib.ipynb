# %% [markdown]
# ## **MatPlotLib**

# %% [markdown]
# ### **Normal Distribution:**
#
# The normal distribution, also known as the Gaussian distribution, is a continuous probability distribution that is symmetric around its mean, which is also its median and mode. It is characterized by its bell-shaped curve. The distribution is completely determined by two parameters: the mean (μ) and the standard deviation (σ).
#
# ### **Probability Density Function (pdf):**
#
# The probability density function is a function that describes the likelihood of a continuous random variable falling within a particular range.
#
# For the normal distribution
#
# Here:
#
# `x` is the variable.
#
# `μ` is the mean.
#
# `σ` is the standard deviation.
#
# The integral of the pdf over the entire range of possible values is equal to 1, indicating that the total probability of all possible outcomes is 1.

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

# %%
np.arange.__doc__
# Out:
# 'arange([start,] stop[, step,], dtype=None, *, like=None)\n\n    Return evenly spaced values within a given interval.\n\n    ``arange`` can be called with a varying number of positional arguments:\n\n    * ``arange(stop)``: Values are generated within the half-open interval\n      ``[0, stop)`` (in other words, the interval including `start` but\n      excluding `stop`).\n    * ``arange(start, stop)``: Values are generated within the half-open\n      interval ``[start, stop)``.\n    * ``arange(start, stop, step)`` Values are generated within the half-open\n      interval ``[start, stop)``, with spacing between values given by\n      ``step``.\n\n    For integer arguments the function is roughly equivalent to the Python\n    built-in :py:class:`range`, but returns an ndarray rather than a ``range``\n    instance.\n\n    When using a non-integer step, such as 0.1, it is often better to use\n    `numpy.linspace`.\n\n    See the Warning sections below for more information.\n\n    Paramet
# ...

# %%
x = np.arange(-3, 3, 0.1)
print(x)
y = norm.pdf(x)
print(y)
# Out:
# [-3.00000000e+00 -2.90000000e+00 -2.80000000e+00 -2.70000000e+00
#  -2.60000000e+00 -2.50000000e+00 -2.40000000e+00 -2.30000000e+00
#  -2.20000000e+00 -2.10000000e+00 -2.00000000e+00 -1.90000000e+00
#  -1.80000000e+00 -1.70000000e+00 -1.60000000e+00 -1.50000000e+00
#  -1.40000000e+00 -1.30000000e+00 -1.20000000e+00 -1.10000000e+00
#  -1.00000000e+00 -9.00000000e-01 -8.00000000e-01 -7.00000000e-01
#  -6.00000000e-01 -5.00000000e-01 -4.00000000e-01 -3.00000000e-01
#  -2.00000000e-01 -1.00000000e-01  2.66453526e-15  1.00000000e-01
#   2.00000000e-01  3.00000000e-01  4.00000000e-01  5.00000000e-01
#   6.00000000e-01  7.00000000e-01  8.00000000e-01  9.00000000e-01
#   1.00000000e+00  1.10000000e+00  1.20000000e+00  1.30000000e+00
#   1.40000000e+00  1.50000000e+00  1.60000000e+00  1.70000000e+00
#   1.80000000e+00  1.90000000e+00  2.00000000e+00  2.10000000e+00
#   2.20000000e+00  2.30000000e+00  2.40000000e+00  2.50000000e+00
# ...

# %%
plt.scatter(x,y) #Scatter Plot
plt.title("Normal Distribution ")
plt.show() # Displaying Plot

# %%
plt.plot(x,y) #Line Plot
plt.show()

# %% [markdown]
# ### **Mutiple Plots on One Graph**

# %%
plt.scatter(x, y) # Scaytter plot
plt.plot(x, norm.pdf(x, 1, 0.25)) # line Plot
plt.show() # Show the plot

# %% [markdown]
# ## **Save it to a File**

# %%
plt.scatter(x, y, color='#72BF78') # color representation c, b, k, r, y, g, m, gray, glod, silver, brown, darkblue, orange, violet, #72BF78
plt.plot(x, norm.pdf(x, 1.0, 0.5), color='r') 
plt.savefig(r"D:\Python\Matplotlib\Plot.png", format='png')

# %% [markdown]
# ### **Adjust the Axes**

# %%
plt.style.use('ggplot') #fivethirtyeight, bmh, seaborn, ggplots, grayscale, grayscale

# %%
# adjusting Axis
plt.plot(x, norm.pdf(x))
plt.plot(x, x**2)

plt.xlim([-4, 3]) # adjusting x axis value range
plt.ylim([0, 1.2]) # adjusting y axis value range

plt.show()

# %%
#Specifically assigning the axis values
plt.scatter(x, y, color='m') # Scaytter plot
plt.plot(x, norm.pdf(x, 1, 0.25), 'c') # line Plot

plt.xticks([-2,-1.5, 0,1.5,2]) # Specifically assigning the x axis values
plt.yticks([0,0.4,0.8]) # Specifically assigning the y axis values

plt.xticks(rotation=90) # Rotates the x axis labels 90 degrees

plt.show()

# %% [markdown]
# ### **Add a Grid**

# %%
plt.plot(x, norm.pdf(x), color='c')                            
plt.plot(x, norm.pdf(x, 1.0, 0.5), color='m')

plt.grid(axis='both',color='k', linestyle=':', linewidth=1.5) # adding grid to the plot for x axis 'x', 'y', linewidth,  # liinestyle = -', '--', '-.', ':', ''
plt.show()

# %% [markdown]
# ### **Change Line Types and Colors**

# %%
plt.plot(x, norm.pdf(x), 'y--',linewidth=2) # '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'
plt.plot(x, norm.pdf(x, 1.0, 0.5),color='red', linestyle=':',linewidth=2)
plt.grid(axis='both', color='k', linestyle=':',linewidth=1)
plt.show()

# %%
x=np.arange(-3,3,0.1)

plt.plot(x, norm.pdf(x), 'b+', marker='^', markersize=8) # marker '.', 'o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X'
plt.plot(x, norm.pdf(x, 1.0, 0.5),color='red', marker='+', markersize=8)

plt.grid(axis='both', color='k', linestyle=':',linewidth=1)

plt.xlabel('event1', size=10, color='gray', fontweight='bold')
plt.ylabel('event2')

plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1828\1697738556.py:3: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "b+" (-> marker='+'). The keyword argument will take precedence.
#   plt.plot(x, norm.pdf(x), 'b+', marker='^', markersize=8) # marker '.', 'o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X'

# %% [markdown]
# ### **Labeling Axes and Adding a Legend**

# %%
plt.plot(x,x**2, color='blue', linestyle=':')
plt.plot(x, norm.pdf(x), color='yellow', marker='*')
plt.plot(x, norm.pdf(x,1.0,0.5), 'g+')

plt.xlim([-4, 4]) # adjusting x axis value range
plt.ylim([0, 2.0]) # adjusting y axis value range

plt.grid(axis='both', color='k', linestyle=':',linewidth=1)

plt.xlabel('Event1')
plt.ylabel('Event2')

plt.title('line Graph',fontsize=15, color='b', loc='left', fontweight='bold')

plt.legend(['Fun A', 'Fun B', 'Fun C'], loc='best') #, 'best', 'upper left', 'upper right', 'lower left', 'lower right', 1, 2, 4

plt.show()

# %% [markdown]
# ### **Customizing Lie plot**

# %%
plt.figure(figsize=(8,6)) # Ajusting the figure size

plt.plot(x,x**2, color='blue', linestyle=':')
plt.plot(x, norm.pdf(x), color='yellow', marker='*')
plt.plot(x, norm.pdf(x,1.0,0.5), 'g+')

plt.xlim([-4, 4]) # adjusting x axis value range
plt.ylim([0, 2.0]) # adjusting y axis value range

plt.grid(axis='both', color='k', linestyle=':',linewidth=1)

plt.xlabel('Event1')
plt.ylabel('Event2')

plt.title('line Graph',fontsize=15, color='b', loc='left', fontweight='bold')

plt.legend(['Fun A', 'Fun B', 'Fun C'], loc='best') #, 'best', 'upper left', 'upper right', 'lower left', 'lower right', 1, 2, 4

plt.show()

# %% [markdown]
# ### **Customizing Scatter plot**

# %%
plt.scatter(x,y, color='b', marker='*') #Scatter Plot
plt.scatter(x, norm.pdf(x,1.0,0.5), marker='o', cmap='viridis', edgecolors='black', alpha=0.5) #Scatter Plot with PDF

plt.grid(axis='both',color='k', linestyle='--', linewidth=1, alpha=0.5)

plt.xlabel('X')
plt.ylabel('Y')

plt.title('Scatter Plot', color='r', fontsize=16, loc='center', pad=20, fontweight='bold')

plt.legend(['mark','marko'],title='type', loc='best')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1828\2972121499.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, norm.pdf(x,1.0,0.5), marker='o', cmap='viridis', edgecolors='black', alpha=0.5) #Scatter Plot with PDF

# %% [markdown]
# ### **Pie Chart**

# %%
values = [12, 30, 4, 32, 14]

colors = ['r', 'g', 'b', 'c', 'm']

explode = [0.2, 0, 0.5, 0, 0]

labels = ['India', 'United States', 'Russia', 'China', 'Europe']

plt.pie(values, radius=2, colors= colors, labels=labels, explode=explode, autopct='%1.1f%%',frame=False)
plt.axis('equal')

plt.legend(title='country', loc='best') #loc=4
plt.title('Student Locations')
plt.tight_layout()

plt.show()

# %% [markdown]
# ### **Bar Chart**

# %%
import seaborn as sns
x = [1, 5, 6, 7, 8]

y = [12, 55, 4, 32, 14]

#colors = ['r', 'g', 'b', 'c', 'm']

# Plotting the bar chart
bars = plt.bar(x, y, color=sns.color_palette('Set2'), edgecolor='k', align='center')
plt.plot(x,y, marker='o', color='r')

# Adding labels
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')

# Adding a title
plt.title('Bar Chart Example')

# Adding a legend
plt.legend(bars, ['Bar 1', 'Bar 2', 'Bar 3', 'Bar 4', 'Bar 5'])
plt.bar_label(bars, label_type='center') #edge

# Adding a grid
plt.grid(axis='both', color='k',linestyle='--', linewidth=0.5)

plt.savefig(r"D:\Python\Matplotlib\Plot.png", format='png')

# %%
x = [1, 5, 8, 6, 7]

y = [12, 55, 4, 32, 14]

# Plotting the bar chart
bars = plt.barh(x, y, color=sns.color_palette('Set2'), edgecolor='k', align='center')

# Adding labels
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')

# Adding a title
plt.title('Bar Chart Example')

# Adding a legend
plt.legend(bars, ['Bar 1', 'Bar 2', 'Bar 3', 'Bar 4', 'Bar 5'])
plt.bar_label(bars, label_type='center') #edge

# Adding a grid
plt.grid(axis='both', color='k',linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# ### **Histogram**

# %%
data = np.random.randn(1000)
plt.hist(data, bins=10, alpha=0.5, edgecolor='red', histtype='barstacked', color='blue', orientation='horizontal') #histtype: bar, step, stepfilled, orientation: Verticle

plt.ylabel('Value')
plt.xlabel('Frequency')
plt.title('Histogram')

plt.grid(axis='both', linestyle='--', color='k', alpha=0.5)
plt.show()

# %%
# Generate some random data
data = np.random.randn(1000)

# Create a histogram
plt.hist(data, bins=30, color='skyblue', edgecolor='black', alpha=0.7)

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')

# Add a grid
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ### **Box & Whisker Plot**
#
# Useful for visualizing the spread & skew of data.
#
# The red line represents the median of the data, and the box represents the bounds of the 1st and 3rd quartiles.
#
# So, half of the data exists within the box.
#
# The dotted-line "whiskers" indicate the range of the data - except for outliers, which are plotted outside the whiskers. Outliers are 1.5X or more the interquartile range.
#
# This example below creates uniformly distributed random numbers between -40 and 60, plus a few outliers above 100 and below -100:

# %% [markdown]
# <pre><code>     Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
#                   |-----:-----|
#   o      |--------|     :     |--------|    o  o
#                   |-----:-----|
# flier             <----------->            fliers
#                        IQR</code></pre>

# %%
import pandas as pd
uniformSkewed = np.random.rand(100) * 100 - 40
high_outliers = np.random.rand(10) * 50 + 100
low_outliers = np.random.rand(10) * -50 - 100
data = np.concatenate((uniformSkewed, high_outliers, low_outliers))
df = pd.DataFrame({'data': data}, columns=['data'])
print(df)
df.describe()
# Out:
#            data
# 0     -4.859998
# 1    -18.475663
# 2    -28.310519
# 3    -37.172704
# 4     26.202446
# ..          ...
# 115 -111.786590
# 116 -125.218683
# 117 -129.803095
# 118 -106.248779
# 119 -132.670299
#
# [120 rows x 1 columns]
#              data
# count  120.000000
# mean     5.033665
# std     57.502522
# min   -146.804769
# 25%    -19.974949
# 50%      4.346879
# 75%     37.155363
# max    146.662612

# %%
plt.boxplot(df,labels=df.columns, vert=False, showfliers=True, meanline=True)
plt.show()

# %% [markdown]
# ### **Subplots**

# %%
x=np.arange(-3,3,0.1)
data = np.random.randn(1000)

plt.figure(figsize=(8,6)) 

plt.subplot(2, 2, 1)  # This is to create a 2x2 plot 1st position
plt.plot(x,x**2, color='blue', linestyle='--')
plt.xlabel('Event1')
plt.ylabel('Event2')
plt.grid()
plt.title('Fun A')

plt.subplot(2, 2, 2)
plt.scatter(x, norm.pdf(x), color='yellow', marker='*')
plt.xlabel('Event1')
plt.ylabel('Event2')
plt.title('Fun B')

plt.subplot(2, 2, 3)
plt.hist(data, bins=10, color='green', density=True)
plt.xlabel('Event1')
plt.ylabel('Event2')
plt.title('Fun C')

plt.tight_layout()  # This is to make the plot look nice
plt.show()

# %% [markdown]
# ## **Seaborn**
# seaborn is a Python data visualization library based on Matplotlib that provides a high-level interface for creating informative and attractive statistical graphics.

# %% [markdown]
# **palatte**
#
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,4,6,8,10]

sns.lineplot(x=x,y=y,palette='Greens',linestyle=':', label=True)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('linechart')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15664\713457337.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x=x,y=y,palette='Greens',linestyle=':', label=True)

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]
sns.scatterplot(x=x,y=y,color='green', marker='o')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('scatter plot')
plt.show()

# %%
cat = ['a','b','c','d']
value = [3,8,5,12]
sns.barplot(x=cat,y=value,palette='summer_r')
plt.grid(True)
plt.xlabel('Category')
plt.ylabel('Value')
plt.title('Barplot')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15664\535312054.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cat,y=value,palette='summer_r')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
categories = ['Category A', 'Category B', 'Category C']
values_1 = [3, 8, 5]
values_2 = [5, 2, 7]

# Creating a dataframe for Seaborn
data = {'Categories': categories, 'Group 1': values_1, 'Group 2': values_2}
df = pd.DataFrame(data)
df
# Out:
#    Categories  Group 1  Group 2
# 0  Category A        3        5
# 1  Category B        8        2
# 2  Category C        5        7

# %%
sns.lineplot(x='Group 1', y=df['Group 2'], data=df, palette='Set1', linestyle=':')
plt.grid(True)
plt.xlabel("Value 1")
plt.ylabel("Value 2")
plt.title('lineplot')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15664\438019314.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x='Group 1', y=df['Group 2'], data=df, palette='Set1', linestyle=':')

# %%
# Plotting bar graphs using Seaborn
sns.barplot(x='Categories', y='Group 1', data=df, color='blue', label='Group 1')
sns.barplot(x='Categories', y='Group 2', data=df, color='orange', bottom=values_1, label='Group 2')

# Adding labels, title, and legend
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Seaborn Stacked Bar Graph with Legend')
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %%
data = [-5,1,2,3,2,3,3,3,4,4,5,8]
sns.boxplot(y=data,palette='Set1') #orient=v or h
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15664\3825226788.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=data,palette='Set1') #orient=v or h

# %%
# Sample data
x = ['A', 'B', 'C', 'A', 'B', 'C']
y = [3, 8, 5, 12, 6, 9]

# Create a Seaborn violin plot
sns.violinplot(x=x, y=y, palette='Set2', inner='box', fill=True)
#A violinplot is a statistical plot used in data visualization.
#the palette='Set2' argument specifies the use of the Set2 color palette. You can replace 'Set2' with other Seaborn palettes like 'deep', 'muted', 'viridis', etc., or you can provide your own list of colors.

# Adding labels and title (optional)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Seaborn Violin Plot')

# Display the plot
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15664\2926470918.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=x, y=y, palette='Set2', inner='box', fill=True)

# %%
# Sample data
data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
#data is a 2D array representing the values you want to visualize.
#annot=True adds numerical annotations to each cell.
#cmap='viridis' specifies the color map (you can choose other colormaps like 'coolwarm', 'YlGnBu', etc.).

df = pd.DataFrame(data)
print(df)
# Create a Seaborn heatmap
sns.heatmap(df.corr(), annot=True, cmap='Blues')

# Adding title (optional)
plt.title('Seaborn Heatmap')

# Display the plot
plt.show()
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  

# Sample data
data = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
print(data)
#creates a pair plot where each scatterplot shows the relationship between a pair of features, and the points are colored by the species of the iris flower.

# Create a Seaborn pair plot
sns.pairplot(data)

# Display the plot
plt.show()
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
categories = ['A', 'B', 'A', 'A', 'C', 'B', 'C', 'A']
df = pd.DataFrame({'categories': categories})   

print(df['categories'].unique())
print(df['categories'].value_counts())
#creates a count plot where each bar represents the count of observations for each day in the dataset.
# Create a Seaborn count plot
sns.countplot(x=df['categories'], palette='pastel')#"husl","Blues"

# Adding title (optional)
plt.title('Seaborn Count Plot', loc='center') #loc='right', 'center', left

# Display the plot
plt.show()
# Out:
# ['A' 'B' 'C']
# categories
# A    4
# B    2
# C    2
# Name: count, dtype: int64
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15664\1415258313.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['categories'], palette='pastel')#"husl","Blues"

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5] # weeks
y = [2, 4, 5, 4, 5] # sales thousands

# creates a regression plot, showing the linear relationship between the two variables.
#A linear relationship refers to a straight-line relationship between two variables.
#it means that as one variable changes, the other variable changes by a constant amount per unit change in the first variable
# y = mx+c
# Create a Seaborn regression plot
sns.regplot(x=x, y=y, color='blue')

# Adding labels and title (optional)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Seaborn Regression Plot')

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 20, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a Seaborn scatter plot
sns.scatterplot(x=x, y=y, label='Data Points', color='red')

# Customizations
plt.xlim(0, 22)  # Set x-axis limits
plt.ylim(0, 12)  # Set y-axis limits
#plt.xticks([1, 2, 3, 4, 5, 6])  # Set x-axis tick locations
#plt.yticks([0, 2, 4, 6, 8, 10, 12])  # Set y-axis tick locations

plt.xlabel('X-axis')  # Label for the x-axis
plt.ylabel('Y-axis')  # Label for the y-axis
plt.title('Customized Scatter Plot')  # Title of the plot
plt.legend()  # Display legend

# Display the plot
plt.show()

# %% [markdown]
# ## Activity

# %% [markdown]
# Try creating a scatter plot representing random data on corona virus data.
