# %%
# Importing the Necessory libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from warnings import filterwarnings
filterwarnings('ignore')

# %%
# various forms to load the data
#df = pd.read_csv(r"D:\Python\EDA\Euromart\EuroMart_Stores.csv")
#df1 = pd.read_excel(r"D:\Python\EDA\Euromart\EuroMart_Stores_RETAIL_DATA.xlsx")
#df2 = pd.read_sql(conn, query)
#df2 = pd.read_sql_table(table_name, conn)
#df3 = pd.read_json(r"D:\Python\EDA\Euromart\Euromart_Stores.json")

# %%
# Loading the data using Seaborn
df = sns.load_dataset('titanic')

# %%
# to Save file
#df.to_excel(r'D:\Python\Pandas\data.xlsx')

# %%
# Top Most rows from the Data
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Bottom Most Rows from the dataframe
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
# Dimensions of the Dataframe
df.shape
# Out:
# (891, 15)

# %%
# Data Type of each column
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# Column Names
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# Whole information about the Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# Stastical description about the Dataset
df.describe().T
# df.describe(include='object').T
# df.describe(include='all').T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
# Data cleaning 
# missing values
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# finding the dupliactes in dataset
df.duplicated().sum()
# Out:
# 107

# %%
# finding the duplicate rows
df[df.duplicated()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 47          1       3  female   NaN      0      0   7.7500        Q   Third
# 76          0       3    male   NaN      0      0   7.8958        S   Third
# 77          0       3    male   NaN      0      0   8.0500        S   Third
# 87          0       3    male   NaN      0      0   8.0500        S   Third
# 95          0       3    male   NaN      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# handling the missing values in the dataset
df.dropna(inplace=False) # droping the all null value rows
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Imputation - Reapacing or filling the nan values  with determine values
# categorical = median or mode
# numarical values  = mean, meadian or mode
# mean - values are contineous varable

# %%
# Imputation of missing values
df['age'].fillna(round(df['age'].mean()), inplace = True)
df['embark_town'].fillna(df['embark_town'].mode()[0], inplace = True)

# %%
# Data Reduction
columns = ['deck', 'alive', 'pclass', 'embarked']
df.drop(columns, axis=1, inplace=True)

# %%
# How handle th duplicates
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum() # isna, notnull, notna
# Out:
# survived       0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alone          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[['survived']] # accesing one columns
# Out:
#      survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 885         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [773 rows x 1 columns]

# %%
df[['sex', 'age']] # axceing multiple columns
# Out:
#         sex   age
# 0      male  22.0
# 1    female  38.0
# 2    female  26.0
# 3    female  35.0
# 4      male  35.0
# ..      ...   ...
# 885  female  39.0
# 887  female  19.0
# 888  female  30.0
# 889    male  26.0
# 890    male  32.0
#
# [773 rows x 2 columns]

# %%
df['age'][0]
# Out:
# 22.0

# %%
df.columns
# Out:
# Index(['survived', 'sex', 'age', 'sibsp', 'parch', 'fare', 'class', 'who',
#        'adult_male', 'embark_town', 'alone'],
#       dtype='object')

# %%
df.loc[0:5, 'age':'class'] # categorical accessing
# Out:
#     age  sibsp  parch     fare  class
# 0  22.0      1      0   7.2500  Third
# 1  38.0      1      0  71.2833  First
# 2  26.0      0      0   7.9250  Third
# 3  35.0      1      0  53.1000  First
# 4  35.0      0      0   8.0500  Third
# 5  30.0      0      0   8.4583  Third

# %%
df.loc[0:5:2, 'age':'class'] # select only rows, only columns or both.
# Out:
#     age  sibsp  parch   fare  class
# 0  22.0      1      0  7.250  Third
# 2  26.0      0      0  7.925  Third
# 4  35.0      0      0  8.050  Third

# %%
df.iloc[-3:-1, -4:-1]
# Out:
#        who  adult_male  embark_town
# 888  woman       False  Southampton
# 889    man        True    Cherbourg

# %%
df.iloc[0:5,0:4] # Numaricl Accessing
# Out:
#    survived     sex   age  sibsp
# 0         0    male  22.0      1
# 1         1  female  38.0      1
# 2         1  female  26.0      0
# 3         1  female  35.0      1
# 4         0    male  35.0      0

# %%
df.iloc[:, [1, 2, 5]] # Select columns in positions 1, 2 and 5 (first column is 0)
# Out:
#         sex   age     fare
# 0      male  22.0   7.2500
# 1    female  38.0  71.2833
# 2    female  26.0   7.9250
# 3    female  35.0  53.1000
# 4      male  35.0   8.0500
# ..      ...   ...      ...
# 885  female  39.0  29.1250
# 887  female  19.0  30.0000
# 888  female  30.0  23.4500
# 889    male  26.0  30.0000
# 890    male  32.0   7.7500
#
# [773 rows x 3 columns]

# %%
df.iloc[0:5:2,0:4:2]
# Out:
#    survived   age
# 0         0  22.0
# 2         1  26.0
# 4         0  35.0

# %%
df.iloc[0:7]
# Out:
#    survived     sex   age  sibsp  parch     fare  class    who  adult_male  \
# 0         0    male  22.0      1      0   7.2500  Third    man        True
# 1         1  female  38.0      1      0  71.2833  First  woman       False
# 2         1  female  26.0      0      0   7.9250  Third  woman       False
# 3         1  female  35.0      1      0  53.1000  First  woman       False
# 4         0    male  35.0      0      0   8.0500  Third    man        True
# 5         0    male  30.0      0      0   8.4583  Third    man        True
# 6         0    male  54.0      0      0  51.8625  First    man        True
#
#    embark_town  alone
# 0  Southampton  False
# 1    Cherbourg  False
# 2  Southampton   True
# 3  Southampton  False
# 4  Southampton   True
# 5   Queenstown   True
# 6  Southampton   True

# %%
df.iloc[:]
# Out:
#      survived     sex   age  sibsp  parch     fare  class    who  adult_male  \
# 0           0    male  22.0      1      0   7.2500  Third    man        True
# 1           1  female  38.0      1      0  71.2833  First  woman       False
# 2           1  female  26.0      0      0   7.9250  Third  woman       False
# 3           1  female  35.0      1      0  53.1000  First  woman       False
# 4           0    male  35.0      0      0   8.0500  Third    man        True
# ..        ...     ...   ...    ...    ...      ...    ...    ...         ...
# 885         0  female  39.0      0      5  29.1250  Third  woman       False
# 887         1  female  19.0      0      0  30.0000  First  woman       False
# 888         0  female  30.0      1      2  23.4500  Third  woman       False
# 889         1    male  26.0      0      0  30.0000  First    man        True
# 890         0    male  32.0      0      0   7.7500  Third    man        True
#
#      embark_town  alone
# ...

# %%
#df[df['method'].str.endswith('g')]
df[df['embark_town'].str.startswith('S')]
# Out:
#      survived     sex  Age  sibsp  parch     fare   class    who  adult_male  \
# 0           0    male   22      1      0   7.2500   Third    man           1
# 2           1  female   26      0      0   7.9250   Third  woman           0
# 3           1  female   35      1      0  53.1000   First  woman           0
# 4           0    male   35      0      0   8.0500   Third    man           1
# 6           0    male   54      0      0  51.8625   First    man           1
# ..        ...     ...  ...    ...    ...      ...     ...    ...         ...
# 881         0    male   33      0      0   7.8958   Third    man           1
# 882         0  female   22      0      0  10.5167   Third  woman           0
# 883         0    male   28      0      0  10.5000  Second    man           1
# 887         1  female   19      0      0  30.0000   First  woman           0
# 888         0  female   30      1      2  23.4500   Third  woman           0
#
#      embark_town  alone  alone_n
# ...

# %%
df[df['who'].str.contains('child')]
# Out:
#      survived     sex  Age  sibsp  parch     fare   class    who  adult_male  \
# 7           0    male    2      3      1  21.0750   Third  child           0
# 9           1  female   14      1      0  30.0708  Second  child           0
# 10          1  female    4      1      1  16.7000   Third  child           0
# 14          0  female   14      0      0   7.8542   Third  child           0
# 16          0    male    2      4      1  29.1250   Third  child           0
# ..        ...     ...  ...    ...    ...      ...     ...    ...         ...
# 831         1    male    0      1      1  18.7500  Second  child           0
# 850         0    male    4      4      2  31.2750   Third  child           0
# 852         0  female    9      1      1  15.2458   Third  child           0
# 869         1    male    4      1      1  11.1333   Third  child           0
# 875         1  female   15      0      0   7.2250   Third  child           0
#
#      embark_town  alone  alone_n
# ...

# %% [markdown]
# change Data Type

# %%
# Changing the Data type of a column
df['age'] = df['age'].astype('int') # float, str

# %% [markdown]
# Adding a new rows

# %%
df.loc[891] = {'survived':1, 'sex':'male', 'age':24, 'sibsp':2,'parch':0, 'fare':20.000, 'class':'First', 'who':'man', 'adult_male':True, 'embark_town':'Queenstown', 'alone':False}

# %%
df.loc[892] = [1,'female',24,2,0,21.0000,'First','man',False,'Cherbourg', False]

# %%
df.tail()
# Out:
#      survived     sex  age  sibsp  parch   fare  class    who  adult_male  \
# 888         0  female   30      1      2  23.45  Third  woman       False
# 889         1    male   26      0      0  30.00  First    man        True
# 890         0    male   32      0      0   7.75  Third    man        True
# 891         1    male   24      2      0  20.00  First    man        True
# 892         1  female   24      2      0  21.00  First    man       False
#
#      embark_town  alone
# 888  Southampton  False
# 889    Cherbourg   True
# 890   Queenstown   True
# 891   Queenstown  False
# 892    Cherbourg  False

# %% [markdown]
# Adding a new column

# %%
df['Rank'] = df['age'].rank(ascending=False)

# %%
df.drop(['Rank'], axis=1, inplace=True) # removing a column or droping a column

# %%
df.drop(892, inplace=True) # drop the row with index 15

# %%
df.rename(columns={'age':'Age'}, inplace=True)

# %%
df['adult_male'].replace({True:1, False:0}, inplace=True)

# %%
print(df['Age'].mean())
print(df['Age'].mode())
print(df['Age'].median())
print(df['Age'].std())
print(df['Age'].var())
print(df['Age'].sum())
print(df['Age'].min())
print(df['Age'].max())
print(len(df))
# Out:
# 29.811369509043928
# 0    30
# Name: Age, dtype: int64
# 30.0
# 13.77148843999577
# 189.65389385293713
# 23074
# 0
# 80
# 774

# %%
num = df.select_dtypes(include=np.number).columns.tolist()
df[num].quantile([0.25,0.5,0.75])
# Out:
#       survived   Age  sibsp  parch    fare
# 0.25       0.0  21.0    0.0    0.0   8.050
# 0.50       0.0  30.0    0.0    0.0  16.100
# 0.75       1.0  36.0    1.0    1.0  34.375

# %%
df['Age'].idxmax() # highest value index no
# Out:
# 630

# %%
df.loc[df['Age'].idxmin()] #  lowest Value index no
# Out:
# survived                 1
# sex                   male
# Age                      0
# sibsp                    0
# parch                    2
# fare                  29.0
# class               Second
# who                  child
# adult_male           False
# embark_town    Southampton
# alone                False
# Name: 78, dtype: object

# %%
print(df['fare'].nlargest(1))
print(df['fare'].nsmallest(1))
# Out:
# 258    512.3292
# Name: fare, dtype: float64
# 179    0.0
# Name: fare, dtype: float64

# %%
df['embark_town'].unique() # finding unique value from the colun
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown'], dtype=object)

# %%
df['embark_town'].nunique() # count of distinct values
# Out:
# 3

# %% [markdown]
# Appling condition for the data

# %%
df['Age'] > 30
df[df['Age'] > 30]
# Out:
#      survived     sex  Age  sibsp  parch     fare  class    who  adult_male  \
# 1           1  female   38      1      0  71.2833  First  woman       False
# 3           1  female   35      1      0  53.1000  First  woman       False
# 4           0    male   35      0      0   8.0500  Third    man        True
# 6           0    male   54      0      0  51.8625  First    man        True
# 11          1  female   58      0      0  26.5500  First  woman       False
# ..        ...     ...  ...    ...    ...      ...    ...    ...         ...
# 873         0    male   47      0      0   9.0000  Third    man        True
# 879         1  female   56      0      1  83.1583  First  woman       False
# 881         0    male   33      0      0   7.8958  Third    man        True
# 885         0  female   39      0      5  29.1250  Third  woman       False
# 890         0    male   32      0      0   7.7500  Third    man        True
#
#      embark_town  alone
# 1      Cherbourg  False
# ...

# %%
df['Age'][1] = 39

# %%
df[df['embark_town'] == 'Queenstown']
# Out:
#      survived     sex  Age  sibsp  parch     fare   class    who  adult_male  \
# 5           0    male   30      0      0   8.4583   Third    man        True
# 16          0    male    2      4      1  29.1250   Third  child       False
# 22          1  female   15      0      0   8.0292   Third  child       False
# 28          1  female   30      0      0   7.8792   Third  woman       False
# 32          1  female   30      0      0   7.7500   Third  woman       False
# 44          1  female   19      0      0   7.8792   Third  woman       False
# 46          0    male   30      1      0  15.5000   Third    man        True
# 82          1  female   30      0      0   7.7875   Third  woman       False
# 109         1  female   30      1      0  24.1500   Third  woman       False
# 116         0    male   70      0      0   7.7500   Third    man        True
# 126         0    male   30      0      0   7.7500   Third    man        True
# ...

# %%
df[df['embark_town'].isin(['New York', 'Cherbourg', 'Chicago', 'Houston', 'Phoenix','Paris'])]
# Out:
#      survived     sex  Age  sibsp  parch     fare   class    who  adult_male  \
# 1           1  female   38      1      0  71.2833   First  woman       False
# 9           1  female   14      1      0  30.0708  Second  child       False
# 19          1  female   30      0      0   7.2250   Third  woman       False
# 26          0    male   30      0      0   7.2250   Third    man        True
# 30          0    male   40      0      0  27.7208   First    man        True
# ..        ...     ...  ...    ...    ...      ...     ...    ...         ...
# 866         1  female   27      1      0  13.8583  Second  woman       False
# 874         1  female   28      1      0  24.0000  Second  woman       False
# 875         1  female   15      0      0   7.2250   Third  child       False
# 879         1  female   56      0      1  83.1583   First  woman       False
# 889         1    male   26      0      0  30.0000   First    man        True
#
#     embark_town  alone
# ...

# %%
df.query('fare > 50')
# Out:
#      survived     sex  Age  sibsp  parch      fare  class    who  adult_male  \
# 1           1  female   38      1      0   71.2833  First  woman       False
# 3           1  female   35      1      0   53.1000  First  woman       False
# 6           0    male   54      0      0   51.8625  First    man        True
# 27          0    male   19      3      2  263.0000  First    man        True
# 31          1  female   30      1      0  146.5208  First  woman       False
# ..        ...     ...  ...    ...    ...       ...    ...    ...         ...
# 849         1  female   30      1      0   89.1042  First  woman       False
# 856         1  female   45      1      1  164.8667  First  woman       False
# 867         0    male   31      0      0   50.4958  First    man        True
# 871         1  female   47      1      1   52.5542  First  woman       False
# 879         1  female   56      0      1   83.1583  First  woman       False
#
#      embark_town  alone
# ...

# %%
df.query('who == "man"')
# Out:
#      survived   sex  Age  sibsp  parch     fare   class  who  adult_male  \
# 0           0  male   22      1      0   7.2500   Third  man        True
# 4           0  male   35      0      0   8.0500   Third  man        True
# 5           0  male   30      0      0   8.4583   Third  man        True
# 6           0  male   54      0      0  51.8625   First  man        True
# 12          0  male   20      0      0   8.0500   Third  man        True
# ..        ...   ...  ...    ...    ...      ...     ...  ...         ...
# 881         0  male   33      0      0   7.8958   Third  man        True
# 883         0  male   28      0      0  10.5000  Second  man        True
# 889         1  male   26      0      0  30.0000   First  man        True
# 890         0  male   32      0      0   7.7500   Third  man        True
# 891         1  male   24      2      0  20.0000   First  man        True
#
#      embark_town  alone
# 0    Southampton  False
# 4    Southampton   True
# ...

# %%
for col in df.columns:
    print(f"Name of the column {col}, Unique Value {df[col].unique()}")
# Out:
# Name of the column survived, Unique Value [0 1]
# Name of the column sex, Unique Value ['male' 'female']
# Name of the column Age, Unique Value [22 38 26 35 30 54  2 27 14  4 58 20 39 55 31 34 15 28  8 19 40 66 42 21
#  18  3  7 49 29 65  5 11 45 17 32 16 25  0 33 23 24 46 59 71 37 47 70 12
#   9 36 51 44  1 61 56 50 62 41 52 63 43 60 10 64 13 48 53 57 80  6 74]
# Name of the column sibsp, Unique Value [1 0 3 4 2 5 8]
# Name of the column parch, Unique Value [0 1 2 5 3 4 6]
# Name of the column fare, Unique Value [  7.25    71.2833   7.925   53.1      8.05     8.4583  51.8625  21.075
#   11.1333  30.0708  16.7     26.55    31.275    7.8542  16.      29.125
#   13.      18.       7.225   26.       8.0292  35.5     31.3875 263.
#    7.8792   7.8958  27.7208 146.5208   7.75    10.5     82.1708  52.
#    7.2292  11.2417   9.475   21.      41.5792  15.5     21.6792  17.8
#   39.6875   7.8     76.7292  61.9792  27.75    46.9     80.      83.475
# ...

# %%
df['embark_town'].value_counts() # find the sum of unique values in the column
# Out:
# embark_town
# Southampton    563
# Cherbourg      153
# Queenstown      58
# Name: count, dtype: int64

# %%
df.Age.sort_values() # sort by age in ascending order
# Out:
# 803     0
# 469     0
# 755     0
# 78      0
# 831     0
#        ..
# 672    70
# 493    71
# 96     71
# 851    74
# 630    80
# Name: Age, Length: 774, dtype: int64

# %%
df.Age.sort_values(ascending=False) # sort by age in descending order
# Out:
# 630    80
# 851    74
# 96     71
# 493    71
# 745    70
#        ..
# 803     0
# 755     0
# 305     0
# 78      0
# 469     0
# Name: Age, Length: 774, dtype: int64

# %%
df.groupby('embark_town').count() # group by city and get the mean of the age
# Out:
#              survived  sex  Age  sibsp  parch  fare  class  who  adult_male  \
# embark_town
# Cherbourg         153  153  153    153    153   153    153  153         153
# Queenstown         58   58   58     58     58    58     58   58          58
# Southampton       563  563  563    563    563   563    563  563         563
#
#              alone
# embark_town
# Cherbourg      153
# Queenstown      58
# Southampton    563

# %%
df.columns
# Out:
# Index(['survived', 'sex', 'Age', 'sibsp', 'parch', 'fare', 'class', 'who',
#        'adult_male', 'embark_town', 'alone'],
#       dtype='object')

# %%
df.groupby('class')['adult_male'].sum() # sum of Salary for each name
# Out:
# class
# First     117
# Second     83
# Third     243
# Name: adult_male, dtype: int64

# %%
df.groupby(['sex','adult_male']).count()
# Out:
#                    survived  Age  sibsp  parch  fare  class  who  embark_town  \
# sex    adult_male
# female False            291  291    291    291   291    291  291          291
# male   False             40   40     40     40    40     40   40           40
#        True             443  443    443    443   443    443  443          443
#
#                    alone
# sex    adult_male
# female False         291
# male   False          40
#        True          443

# %%
# Calculate multiple aggregations simultaneously
df.groupby('class').agg({'sex': 'first', 'adult_male': 'sum'})
# Out:
#            sex  adult_male
# class
# First   female         117
# Second  female          83
# Third     male         243

# %%
# Sorting data
df.sort_values(by='Age', ascending=False)
# Out:
#      survived     sex  Age  sibsp  parch      fare   class    who  adult_male  \
# 630         1    male   80      0      0   30.0000   First    man        True
# 851         0    male   74      0      0    7.7750   Third    man        True
# 96          0    male   71      0      0   34.6542   First    man        True
# 493         0    male   71      0      0   49.5042   First    man        True
# 745         0    male   70      1      1   71.0000   First    man        True
# ..        ...     ...  ...    ...    ...       ...     ...    ...         ...
# 803         1    male    0      0      1    8.5167   Third  child       False
# 755         1    male    0      1      1   14.5000  Second  child       False
# 305         1    male    0      1      2  151.5500   First  child       False
# 78          1    male    0      0      2   29.0000  Second  child       False
# 469         1  female    0      2      1   19.2583   Third  child       False
#
#      embark_town  alone
# ...

# %% [markdown]
# Appling Function on column

# %%
# Define a function to double the value of each element
def category(x):
    if x == True:
        return 1
    elif x == False:
        return 0

# %%
# Apply the function to the DataFrame, column-wise (default behavior)
df['alone_n'] = df['alone'].apply(category)

# %%
df.head(1)
# Out:
#    survived   sex  Age  sibsp  parch  fare  class  who  adult_male  \
# 0         0  male   22      1      0  7.25  Third  man        True
#
#    embark_town  alone  alone_n
# 0  Southampton  False        0

# %%
left_data = {
    'ID': [1, 2, 3, 4, 5],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 35, 28, 24],
}

left_df = pd.DataFrame(left_data)

# Sample data for right DataFrame
right_data = {
    'ID': [1, 2, 4, 5, 6],
    'City': ['New York', 'London', 'Paris', 'Berlin', 'Tokyo'],
    'Salary': [60000, 75000, 62000, 57000, 80000],
}

right_df = pd.DataFrame(right_data)

# %%
# Joining DataFrames based on the index
# Inner join on 'ID' column
result_inner = pd.merge(left_df, right_df, on='ID', how='inner')
print(result_inner)

# Left join on 'ID' column
result_left = pd.merge(left_df, right_df, on='ID', how='left')
print(result_left)

# Right join on 'ID' column
result_right = pd.merge(left_df, right_df, on='ID', how='right')
print(result_right)

# Outer join on 'ID' column
result_outer = pd.merge(left_df, right_df, on='ID', how='outer')
print(result_outer)
# Out:
#    ID   Name  Age      City  Salary
# 0   1  Alice   25  New York   60000
# 1   2    Bob   30    London   75000
# 2   4  David   28     Paris   62000
# 3   5    Eva   24    Berlin   57000
#    ID     Name  Age      City   Salary
# 0   1    Alice   25  New York  60000.0
# 1   2      Bob   30    London  75000.0
# 2   3  Charlie   35       NaN      NaN
# 3   4    David   28     Paris  62000.0
# 4   5      Eva   24    Berlin  57000.0
#    ID   Name   Age      City  Salary
# 0   1  Alice  25.0  New York   60000
# 1   2    Bob  30.0    London   75000
# 2   4  David  28.0     Paris   62000
# 3   5    Eva  24.0    Berlin   57000
# 4   6    NaN   NaN     Tokyo   80000
#    ID     Name   Age      City   Salary
# 0   1    Alice  25.0  New York  60000.0
# 1   2      Bob  30.0    London  75000.0
# 2   3  Charlie  35.0       NaN      NaN
# 3   4    David  28.0     Paris  62000.0
# 4   5      Eva  24.0    Berlin  57000.0
# 5   6      NaN   NaN     Tokyo  80000.0

# %% [markdown]
# #### **Pivot Table**

# %%
df.pivot_table(index='embark_town', columns='who', values='Age', aggfunc='count')
# Out:
# who          child  man  woman
# embark_town
# Cherbourg       17   77     59
# Queenstown       5   29     24
# Southampton     60  337    166

# %%
cross_tab = pd.crosstab(df['embark_town'], df['class'])
cross_tab
# Out:
# class        First  Second  Third
# embark_town
# Cherbourg       83      17     53
# Queenstown       3       2     53
# Southampton    127     144    292
