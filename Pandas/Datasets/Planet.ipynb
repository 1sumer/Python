# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# df = pd.read_csv(pathe of the file)
# df = pd.read_excel(path of the file)

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df1 = sns.load_dataset('penguins')
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df = sns.load_dataset("planets")

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1        3.941507   NaN     172.0  2006
# 1031  Transit       1        2.615864   NaN     148.0  2007
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
df.shape
# Out:
# (1035, 6)

# %%
df.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df.describe().T
# Out:
#                  count         mean           std          min         25%  \
# number          1035.0     1.785507      1.240976     1.000000     1.00000
# orbital_period   992.0  2002.917596  26014.728304     0.090706     5.44254
# mass             513.0     2.638161      3.818617     0.003600     0.22900
# distance         808.0   264.069282    733.116493     1.350000    32.56000
# year            1035.0  2009.070531      3.972567  1989.000000  2007.00000
#
#                       50%       75%       max
# number             1.0000     2.000       7.0
# orbital_period    39.9795   526.005  730000.0
# mass               1.2600     3.040      25.0
# distance          55.2500   178.500    8500.0
# year            2010.0000  2012.000    2014.0

# %%
df.year.nlargest().head(1)
# Out:
# 112    2014
# Name: year, dtype: int64

# %%
df.year.nsmallest().head(1)
# Out:
# 441    1989
# Name: year, dtype: int64

# %%
df['method'].unique()
# Out:
# array(['Radial Velocity', 'Imaging', 'Eclipse Timing Variations',
#        'Transit', 'Astrometry', 'Transit Timing Variations',
#        'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing',
#        'Pulsation Timing Variations'], dtype=object)

# %%
df['number'].unique()
# Out:
# array([1, 2, 3, 5, 4, 6, 7], dtype=int64)

# %%
df['method'].nunique()
# Out:
# 10

# %%
df[df['method'].str.endswith('g')]
#df[df['method'].str.startswith('R')]
# Out:
#        method  number  orbital_period  mass  distance  year
# 29    Imaging       1             NaN   NaN     45.52  2005
# 30    Imaging       1             NaN   NaN    165.00  2007
# 31    Imaging       1             NaN   NaN    140.00  2004
# 33    Imaging       1             NaN   NaN       NaN  2008
# 34    Imaging       1             NaN   NaN    145.00  2013
# ...       ...     ...             ...   ...       ...   ...
# 949   Imaging       1             NaN   NaN    120.00  2013
# 950   Imaging       1             NaN   NaN       NaN  2010
# 957   Imaging       1             NaN   NaN       NaN  2008
# 1027  Imaging       1             NaN   NaN     19.20  2011
# 1029  Imaging       1             NaN   NaN     10.10  2012
#
# [66 rows x 6 columns]

# %%
df[df['method'].str.contains('Radial Velocity')].count()
# Out:
# method            553
# number            553
# orbital_period    553
# mass              510
# distance          530
# year              553
# dtype: int64

# %%
df['number'].value_counts()
# Out:
# number
# 1    595
# 2    259
# 3     88
# 4     32
# 5     30
# 6     24
# 7      7
# Name: count, dtype: int64

# %%
df['method'].value_counts()
# Out:
# method
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: count, dtype: int64

# %%
year = df['year'].value_counts()
Year = year.reset_index()

# %%
Year[Year['count']>=30]
# Out:
#     year  count
# 0   2011    185
# 1   2012    140
# 2   2013    118
# 3   2010    102
# 4   2009     98
# 5   2008     74
# 6   2007     53
# 7   2014     52
# 8   2005     39
# 9   2002     32
# 10  2006     31

# %%
df.groupby('method')['orbital_period'].sum()
# Out:
# method
# Astrometry                       1.262360e+03
# Eclipse Timing Variations        4.276480e+04
# Imaging                          1.418973e+06
# Microlensing                     2.207500e+04
# Orbital Brightness Modulation    2.127920e+00
# Pulsar Timing                    3.671511e+04
# Pulsation Timing Variations      1.170000e+03
# Radial Velocity                  4.553151e+05
# Transit                          8.377523e+03
# Transit Timing Variations        2.393505e+02
# Name: orbital_period, dtype: float64

# %%
df.groupby(['method', 'year']).agg({'distance':'mean'})
# Out:
#                                 distance
# method                    year
# Astrometry                2010     14.98
#                           2013     20.77
# Eclipse Timing Variations 2008    130.72
#                           2009       NaN
#                           2010    500.00
# ...                                  ...
# Transit                   2014    517.50
# Transit Timing Variations 2011   2119.00
#                           2012    855.00
#                           2013    339.00
#                           2014       NaN
#
# [69 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df.iloc[:,2:5]
# Out:
#       orbital_period   mass  distance
# 0         269.300000   7.10     77.40
# 1         874.774000   2.21     56.95
# 2         763.000000   2.60     19.84
# 3         326.030000  19.40    110.62
# 4         516.220000  10.50    119.47
# ...              ...    ...       ...
# 1030        3.941507    NaN    172.00
# 1031        2.615864    NaN    148.00
# 1032        3.191524    NaN    174.00
# 1033        4.125083    NaN    293.00
# 1034        4.187757    NaN    260.00
#
# [1035 rows x 3 columns]

# %%
df.isna().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# method            1035
# number            1035
# orbital_period     992
# mass               513
# distance           808
# year              1035
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df.drop(['mass'], axis=1, inplace = True)

# %%
df.orbital_period.mean()
# Out:
# 2002.9175960947582

# %%
df['orbital_period'].fillna(df.orbital_period.mean(),inplace=True)
df['distance'].fillna(df.distance.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# method            0
# number            0
# orbital_period    0
# distance          0
# year              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1031, 5)

# %%
plt.scatter(x=df['year'], y=df['orbital_period'], marker='*')
plt.grid(True)
plt.xlabel('Year')
plt.ylabel('orbital_period')
plt.title('orbital_period by year')
plt.show()

# %%
sns.scatterplot(x='year', y='orbital_period',data=df, marker='p', palette='Set1')
plt.show()

# %%
#plt.boxplot(df['orbital_period'])
sns.boxplot(y=df['orbital_period'])
plt.show()

# %%
#plt.hist(df['distance'], alpha=0.5, bins=10, edgecolor='blue', color='red')
sns.distplot(df['distance'])
plt.show()

# %%
x = df['method']
y = df['orbital_period']

plt.bar(x,y, color='red',width=0.5, align='center', alpha=0.5, label='Orbital Period', edgecolor='black')
plt.xlabel('method')
plt.ylabel('orbital_period')
plt.xticks(rotation=90)
plt.title('Orbital Period')
plt.legend()
plt.show()

# %%
sns.barplot(x='method', y='distance',data=df, palette='summer')
plt.xlabel('method')
plt.ylabel('distance')
plt.xticks(rotation=90)
plt.legend(loc='upper left')
plt.title('bar plot')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.countplot(x='number', data=df, palette='Greens_r')
plt.show()

# %%
number = df['number'].value_counts()
number
# Out:
# number
# 1    592
# 2    258
# 3     88
# 4     32
# 5     30
# 6     24
# 7      7
# Name: count, dtype: int64

# %%
plt.pie(number, labels=number.index, autopct='%1.1f%%',explode=[0.1, 0,0,0,0,0,0], colors=sns.color_palette('Set1'))
plt.title('distribution of number')
plt.show()

# %%
plt.plot(x, y, color='blue',linestyle='--', marker='o', markerfacecolor='red', markersize=10)
plt.grid()
plt.xticks(rotation=90)
plt.title('line chart', fontsize=15)
plt.show()

# %%
sns.lineplot(x='method', y='distance',data=df, palette='Greens', linestyle='-.',label='distance')
plt.xlabel('method')
plt.xticks(rotation=90)
plt.ylabel('distance')
plt.title('linechart')
plt.show()

# %%
df.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'distance', 'year'], dtype='object')

# %%
sns.pairplot(df)
plt.show()

# %%
Co = df.drop(['method'], axis=1).corr()
sns.heatmap(Co, annot=True, cmap='Blues')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.pie(number, labels=number.index, autopct='%1.1f%%',explode=[0.1, 0,0,0,0,0,0], colors=sns.color_palette('Set1'))
plt.title('distribution of number')

plt.subplot(2,2,2)
sns.countplot(x='number', data=df, palette='Greens_r')

plt.subplot(2,2,3)
sns.lineplot(x='method', y='distance',data=df, palette='Greens', linestyle='-.',label='distance')
plt.xlabel('method')
plt.xticks(rotation=90)
plt.ylabel('distance')
plt.title('linechart')

plt.subplot(2,2,4)
sns.distplot(df['distance'])

plt.tight_layout()
plt.show()
