# %% [markdown]
# ### **Import Necessary Libraries**
# - The code imports necessary libraries for data analysis and visualization, including pandas, numpy, matplotlib, and seaborn.
# - Pandas is commonly used for data manipulation and analysis.
# - NumPy is used for numerical computations.
# - Matplotlib and Seaborn are popular libraries for data visualization.

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt     
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### **Loading the Data**

# %%
order = pd.read_excel(r"D:\Python\EDA\Global_Store\global_superstore_2016.xlsx", sheet_name='Orders')

# %%
Return = pd.read_excel(r"D:\Python\EDA\Global_Store\global_superstore_2016.xlsx", sheet_name='Returns')

# %%
People = pd.read_excel(r"D:\Python\EDA\Global_Store\global_superstore_2016.xlsx", sheet_name='People')

# %%
order.shape
# Out:
# (51290, 24)

# %% [markdown]
# The dataset contains 51,290 rows and 24 columns.

# %%
Return.shape
# Out:
# (1079, 3)

# %% [markdown]
# The dataset contains 1079 rows and 3 columns.

# %%
order.iloc[:6, :12]
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
# 5   22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01  Second Class
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
# 5     JM-156557       Jim Mitchum    Corporate          NaN         Sydney
#
#              State        Country
# 0         Oklahoma  United States
# 1  New South Wales      Australia
# 2       Queensland      Australia
# 3           Berlin        Germany
# 4            Dakar        Senegal
# 5  New South Wales      Australia

# %%
order.iloc[:6, 12:]
# Out:
#            Region        Market   Product ID    Category Sub-Category  \
# 0      Central US          USCA  TEC-PH-5816  Technology       Phones
# 1         Oceania  Asia Pacific  FUR-CH-5379   Furniture       Chairs
# 2         Oceania  Asia Pacific  TEC-PH-5356  Technology       Phones
# 3  Western Europe        Europe  TEC-PH-5267  Technology       Phones
# 4  Western Africa        Africa  TEC-CO-6011  Technology      Copiers
# 5         Oceania  Asia Pacific  TEC-PH-5842  Technology       Phones
#
#                                 Product Name     Sales  Quantity  Discount  \
# 0                           Samsung Convoy 3   221.980         2       0.0
# 1  Novimex Executive Leather Armchair, Black  3709.395         9       0.1
# 2          Nokia Smart Phone, with Caller ID  5175.171         9       0.1
# 3             Motorola Smart Phone, Cordless  2892.510         5       0.1
# 4             Sharp Wireless Fax, High-Speed  2832.960         8       0.0
# 5        Samsung Smart Phone, with Caller ID  2862.675         5       0.1
#
#      Profit  Shipping Cost Order Priority
# 0   62.1544          40.77           High
# 1 -288.7650         923.63       Critical
# 2  919.9710         915.49         Medium
# 3  -96.5400         910.16         Medium
# 4  311.5200         903.04       Critical
# 5  763.2750         897.35       Critical

# %% [markdown]
# filters the 'order' DataFrame based on the condition where the 'Order ID' column contains the string 'IN-2012-PB19210127-41259'

# %%
order[order['Order ID'].str.contains('IN-2012-PB19210127-41259')].iloc[:1, :12]
# Out:
#     Row ID                  Order ID Order Date  Ship Date    Ship Mode  \
# 26   30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19  First Class
#
#     Customer ID   Customer Name    Segment  Postal Code    City        State  \
# 26  PB-19210127  Phillip Breyer  Corporate          NaN  Taipei  Taipei City
#
#    Country
# 26  Taiwan

# %%
order[order['Order ID'].str.contains('ES-2014-JF15295120-41924')].iloc[:, 12:]
# Out:
#               Region  Market   Product ID    Category Sub-Category  \
# 178  Southern Europe  Europe  TEC-AC-4185  Technology  Accessories
#
#                   Product Name    Sales  Quantity  Discount  Profit  \
# 178  Enermax Router, Bluetooth  1549.98         6       0.0  139.32
#
#      Shipping Cost Order Priority
# 178         443.92       Critical

# %%
Return.head()
# Out:
#   Returned                  Order ID        Region
# 0      Yes  CA-2012-SA20830140-41210    Central US
# 1      Yes  IN-2012-PB19210127-41259  Eastern Asia
# 2      Yes  CA-2012-SC20095140-41174    Central US
# 3      Yes    IN-2015-JH158207-42140       Oceania
# 4      Yes    IN-2014-LC168857-41747       Oceania

# %%
People.head()
# Out:
#               Person           Region
# 0  Marilène Rousseau        Caribbean
# 1   Andile Ihejirika   Central Africa
# 2  Nicodemo Bautista  Central America
# 3     Cansu Peynirci     Central Asia
# 4         Lon Bonher       Central US

# %% [markdown]
# ! Final Data

# %% [markdown]
# Merges two Table, 'order' and 'Return', based on the columns 'Order ID' and 'Region'.

# %%
Gsma = pd.merge(order, Return, on=['Order ID','Region'], how = 'left')

# %%
Gsma.shape
# Out:
# (51290, 25)

# %% [markdown]
# The dataset contains 51290 rows and 25 columns.

# %%
Gsma.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...    Category Sub-Category                               Product Name  \
# 0  ...  Technology       Phones                           Samsung Convoy 3
# 1  ...   Furniture       Chairs  Novimex Executive Leather Armchair, Black
# 2  ...  Technology       Phones          Nokia Smart Phone, with Caller ID
# 3  ...  Technology       Phones             Motorola Smart Phone, Cordless
# 4  ...  Technology      Copiers             Sharp Wireless Fax, High-Speed
#
#       Sales Quantity Discount    Profit Shipping Cost  Order Priority  \
# 0   221.980        2      0.0   62.1544         40.77            High
# 1  3709.395        9      0.1 -288.7650        923.63        Critical
# 2  5175.171        9      0.1  919.9710        915.49          Medium
# 3  2892.510        5      0.1  -96.5400        910.16          Medium
# 4  2832.960        8      0.0  311.5200        903.04        Critical
#
#    Returned
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 25 columns]

# %%
Gsma[['Sales','Quantity','Discount','Profit','Shipping Cost']].head()
# Out:
#       Sales  Quantity  Discount    Profit  Shipping Cost
# 0   221.980         2       0.0   62.1544          40.77
# 1  3709.395         9       0.1 -288.7650         923.63
# 2  5175.171         9       0.1  919.9710         915.49
# 3  2892.510         5       0.1  -96.5400         910.16
# 4  2832.960         8       0.0  311.5200         903.04

# %%
Gsma.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority', 'Returned'],
#       dtype='object')

# %%
Gsma.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
#  17  Product Name    51290 non-null  object
#  18  Sales           51290 non-null  float64
#  19  Quantity        51290 non-null  int64
#  20  Discount        51290 non-null  float64
#  21  Profit          51290 non-null  float64
#  22  Shipping Cost   51290 non-null  float64
#  23  Order Priority  51290 non-null  object
#  24  Returned        2202 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(2), object(16)
# memory usage: 9.8+ MB

# %% [markdown]
# **DataFrame Information:**
# - The DataFrame 'Gsma' contains 51,290 entries across 25 columns.
# - Column names and their respective data types are displayed.
# - Several columns contain non-null values, while others have missing values (e.g., 'Postal Code' and 'Returned').
# - 'Order Date' and 'Ship Date' columns are datetime objects, likely representing the date and time of order and shipment.
# - Numeric columns include 'Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit', and 'Shipping Cost'.
# - Object type columns include 'Order ID', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country', 'Region', 'Market', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Order Priority', and 'Returned'.

# %%
Gsma.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# Returned          49088
# dtype: int64

# %% [markdown]
# - It appears that the 'Postal Code' column has a significant number of missing values, and the 'Returned' column also has a considerable number of missing values.
# - If the 'Postal Code' column is not essential for your analysis, you may choose to drop it altogether.
# - Replace missing values with a specific category like 'No' if orders were not returned.

# %%
Gsma.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### **Data Reduction**
# Removes several columns from the 'Gsma' DataFrame

# %%
Gsma.drop(['Row ID', 'Order ID', 'Ship Date', 'Customer ID', 'Postal Code', 'Product Name'], axis=1, inplace = True)

# %% [markdown]
# Fills missing values in the 'Returned' column of the 'Gsma' DataFrame with the string 'No'

# %%
Gsma['Returned'].fillna('No', inplace=True)

# %%
Gsma.isnull().sum()
# Out:
# Order Date        0
# Ship Mode         0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Region            0
# Market            0
# Product ID        0
# Category          0
# Sub-Category      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# Returned          0
# dtype: int64

# %% [markdown]
# ### **Fearture Engineering**
# - Adds several new columns to the 'Gsma' DataFrame:
#     - 'Year': Extracted from the 'Order Date' column, representing the year of the order.
#     - 'Month': Extracted from the 'Order Date' column, representing the month of the order.
#     - 'Cost': Calculated as the difference between 'Sales' and 'Profit', representing the cost incurred.
#     - 'Total Amount': Calculated as the sum of 'Sales' and 'Shipping Cost', representing the total amount including shipping cost.

# %%
# New column
Gsma['Year'] = Gsma['Order Date'].dt.year
Gsma['Month'] = Gsma['Order Date'].dt.month

# %%
# The total revenue generated from sales.
Gsma['Total Sales'] = Gsma['Sales'] * Gsma['Quantity']

# The total profit generated from sales.
Gsma['Total Profit'] = Gsma['Profit'] * Gsma['Quantity']

# The total cost incurred for shipping.
Gsma['Total Shipping Cost'] = Gsma['Shipping Cost'] * Gsma['Quantity']

# %%
Gsma.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order Date           51290 non-null  datetime64[ns]
#  1   Ship Mode            51290 non-null  object
#  2   Customer Name        51290 non-null  object
#  3   Segment              51290 non-null  object
#  4   City                 51290 non-null  object
#  5   State                51290 non-null  object
#  6   Country              51290 non-null  object
#  7   Region               51290 non-null  object
#  8   Market               51290 non-null  object
#  9   Product ID           51290 non-null  object
#  10  Category             51290 non-null  object
#  11  Sub-Category         51290 non-null  object
#  12  Sales                51290 non-null  float64
#  13  Quantity             51290 non-null  int64
#  14  Discount             51290 non-null  float64
#  15  Profit               51290 non-null  float64
#  16  Shipping Cost        51290 non-null  float64
#  17  Order Priority       51290 non-null  object
#  18  Returned             51290 non-null  object
#  19  Year                 51290 non-null  int32
#  20  Month                51290 non-null  int32
#  21  Total Sales          51290 non-null  float64
#  22  Total Profit         51290 non-null  float64
#  23  Total Shipping Cost  51290 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int32(2), int64(1), object(13)
# memory usage: 9.0+ MB

# %%
Gsma.describe().T
# Out:
#                        count                           mean  \
# Order Date             51290  2014-05-11 21:26:49.155780608
# Sales                51290.0                     246.490581
# Quantity             51290.0                       3.476545
# Discount             51290.0                       0.142908
# Profit               51290.0                      28.610982
# Shipping Cost        51290.0                      26.478567
# Year                 51290.0                    2013.777208
# Month                51290.0                       7.516027
# Total Sales          51290.0                    1205.327987
# Total Profit         51290.0                     140.928945
# Total Shipping Cost  51290.0                     127.513488
#
#                                      min                  25%  \
# Order Date           2012-01-01 00:00:00  2013-06-19 00:00:00
# Sales                              0.444            30.758625
# Quantity                             1.0                  2.0
# Discount                             0.0                  0.0
# Profit                         -6599.978                  0.0
# Shipping Cost                      1.002                 2.61
# Year                              2012.0               2013.0
# Month                                1.0                  5.0
# Total Sales                        0.444                66.93
# Total Profit                  -49060.512                  0.0
# Total Shipping Cost                 1.01                  6.2
#
#                                      50%                  75%  \
# Order Date           2014-07-08 00:00:00  2015-05-22 00:00:00
# Sales                             85.053             251.0532
# Quantity                             3.0                  5.0
# Discount                             0.0                  0.2
# Profit                              9.24                36.81
# Shipping Cost                       7.79                24.45
# Year                              2014.0               2015.0
# Month                                8.0                 10.0
# Total Sales                      245.772              904.875
# Total Profit                     22.6515               123.12
# Total Shipping Cost                22.64              87.3575
#
#                                      max          std
# Order Date           2015-12-31 00:00:00          NaN
# Sales                           22638.48   487.565361
# Quantity                            14.0     2.278766
# Discount                            0.85      0.21228
# Profit                          8399.976   174.340972
# Shipping Cost                     933.57    57.251373
# Year                              2015.0     1.098931
# Month                               12.0     3.300526
# Total Sales                    135830.88  3452.079528
# Total Profit                    64302.81  1204.325089
# Total Shipping Cost             11254.62   385.804489

# %% [markdown]
# **Summary Statistics:**
#
# - The earliest order date is in 2012, and the latest is in 2015.
# - The average sales amount is approximately $246.49, with a minimum of $0.44 and a maximum of $22,638.48.
# - On average, around 3.48 items are sold per order, with a minimum of 1 and a maximum of 14.
# - The average discount offered is about 14.29%, ranging from 0% to 85%.
# - The average profit per order is $28.61, with values ranging from a loss of $6,599.98 to a profit of $8,399.98.
# - The average shipping cost is approximately $26.48, with a minimum of $1.00 and a maximum of $933.57.
# - Orders span from the year 2012 to 2015, with most orders concentrated around 2013 and 2014.
# - Most orders are placed in July, with the highest median.
# - The average cost (sales minus profit) is approximately $217.88.
# - The average total amount (sales plus shipping cost) is approximately $272.97.

# %% [markdown]
# ### **Data Visualization**

# %%
cat_col = Gsma.select_dtypes(include='object').columns.tolist()
num_col = Gsma.select_dtypes(include=np.number).columns.tolist()

print(cat_col)
print(num_col)
# Out:
# ['Ship Mode', 'Customer Name', 'Segment', 'City', 'State', 'Country', 'Region', 'Market', 'Product ID', 'Category', 'Sub-Category', 'Order Priority', 'Returned']
# ['Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost', 'Year', 'Month', 'Total Sales', 'Total Profit', 'Total Shipping Cost']

# %%
for col in num_col:
    plt.subplot(1,1,1)
    Gsma[col].hist(bins=20, alpha=0.5, grid=False)
    plt.ylabel('Frequency')
    plt.title(col)
    plt.show()

# %% [markdown]
# - Most orders consist of 1 to 5 items, with 2 being the most common quantity.
# - Discounts of 20%, 10%, 40%, and 60% are among the most common.
# - Profits vary widely, ranging from significant profits to losses. A considerable number of orders result in zero profit.
# - Most common shipping costs include $1.35, $1.97, $1.79, $1.80, and $1.62
# - Orders are distributed across the years 2012 to 2015, with 2015 having the highest number of orders
# - Orders are spread across different months, with November and December having the highest number of orders.

# %%
for col in cat_col:
    plt.figure()  # Adjust the figsize as needed
    sns.countplot(x=col, data=Gsma, order=Gsma[col].value_counts().head(10).index, palette='Set1')
    plt.xticks(rotation=90)
    plt.title(col)
    plt.show()

# %% [markdown]
# - The provided series of value counts represents the distribution of various categorical variables in the dataset.
# - Most orders are shipped using "Standard Class" (30,775 orders), followed by "Second Class" (10,309 orders), "First Class" (7,505 orders), and "Same Day" (2,701 orders).
# - The majority of orders are from the "Consumer" segment (26,518 orders), followed by "Corporate" (15,429 orders), and "Home Office" (9,343 orders).
# - The dataset includes orders from different countries, with the majority from the "United States" (9,994 orders).
# - Orders are from different states, with "California" having the highest number of orders (2,001 orders).
# - Orders are distributed across different regions, with "Western Europe" having the highest number of orders (5,883 orders).
# - The market is segmented into different regions, with "Asia Pacific" having the highest number of orders (14,302 orders).
# - Most orders are for "Office Supplies" (31,289 orders), followed by "Technology" (10,141 orders), and "Furniture" (9,860 orders).

# %% [markdown]
# ### **Analysis**

# %%
# Set the display format for floating point numbers
pd.options.display.float_format = '{:,.2f}'.format

# %%
print(f'Net Sales {Gsma['Sales'].sum()}')
# Out:
# Net Sales 12642501.90988

# %%
print(f'Net Profit {Gsma['Profit'].sum()}')
# Out:
# Net Profit 1467457.2912799998

# %%
print(f'Gross Sales {Gsma['Total Sales'].sum()}')
# Out:
# Gross Sales 61821272.47008

# %%
print(f'Gross Profit {Gsma['Total Profit'].sum()}')
# Out:
# Gross Profit 7228245.59588

# %%
print(f'Profit Margin {round(Gsma['Total Profit'].sum()/Gsma['Total Sales'].sum() * 100)} %')
# Out:
# Profit Margin 12 %

# %%
print(f'Total Cost {Gsma['Total Sales'].sum() - Gsma['Total Profit'].sum() - Gsma['Total Shipping Cost'].sum()}')
# Out:
# Total Cost 48052860.08724

# %%
print(f'Net Profit {Gsma['Total Profit'].sum() - Gsma['Total Shipping Cost'].sum()}')
# Out:
# Net Profit 688078.8089199997

# %%
# Group data by month and calculate sum
year_analysis = Gsma.groupby('Year').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).reset_index()

# %%
year_analysis
# Out:
#    Year        Sales     Profit  Quantity
# 0  2012 2,259,450.90 248,940.81     31443
# 1  2013 2,677,438.69 307,415.28     38111
# 2  2014 3,405,746.45 406,935.23     48136
# 3  2015 4,299,865.87 504,165.97     60622

# %%
# Plotting
plt.figure(figsize=(12, 6))


# Sales plot
plt.subplot(2, 2, 1)
plt.bar(year_analysis['Year'], year_analysis['Sales'], color=sns.color_palette('Set1'))
plt.xticks([2012,2013,2014,2015])
plt.title('Total Sales by Year')
plt.xlabel('Month')
plt.ylabel('Total Sales')

# Profit plot
plt.subplot(2, 2, 2)
plt.bar(year_analysis['Year'], year_analysis['Profit'], color=sns.color_palette('Set2'))
plt.xticks([2012,2013,2014,2015])
plt.title('Total Profit by Year')
plt.xlabel('Month')
plt.ylabel('Total Profit')

# Quantity plot
plt.subplot(2, 2, 3)
plt.bar(year_analysis['Year'], year_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.xticks([2012,2013,2014,2015])
plt.title('Total Quantity Sold by Year')
plt.xlabel('Month')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# - Sales and profit show an increasing trend over the years, indicating positive growth in business.
# - The most significant growth is observed between 2014 and 2015, with both sales and profit substantially increasing.

# %%
# Group data by month and calculate sum
monthly_data = Gsma.groupby('Month').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).style.background_gradient(cmap='BrBG')

# %%
monthly_data
# Out:
# <style type="text/css">
# #T_8cc7f_row0_col0, #T_8cc7f_row1_col1, #T_8cc7f_row1_col2 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_8cc7f_row0_col1 {
#   background-color: #015b52;
#   color: #f1f1f1;
# }
# #T_8cc7f_row0_col2 {
#   background-color: #004135;
#   color: #f1f1f1;
# }
# #T_8cc7f_row1_col0 {
#   background-color: #004439;
#   color: #f1f1f1;
# }
# #T_8cc7f_row2_col0 {
#   background-color: #12766e;
#   color: #f1f1f1;
# }
# #T_8cc7f_row2_col1 {
#   background-color: #01554b;
#   color: #f1f1f1;
# }
# #T_8cc7f_row2_col2 {
#   background-color: #0e726a;
#   color: #f1f1f1;
# }
# #T_8cc7f_row3_col0 {
#   background-color: #67bbb0;
#   color: #000000;
# }
# #T_8cc7f_row3_col1 {
#   background-color: #3b9b93;
#   color: #f1f1f1;
# }
# #T_8cc7f_row3_col2 {
#   background-color: #8dd2c7;
#   color: #000000;
# }
# #T_8cc7f_row4_col0, #T_8cc7f_row4_col1 {
#   background-color: #81cec2;
#   color: #000000;
# }
# #T_8cc7f_row4_col2 {
#   background-color: #79c8bc;
#   color: #000000;
# }
# #T_8cc7f_row5_col0 {
#   background-color: #b6e3dd;
#   color: #000000;
# }
# #T_8cc7f_row5_col1 {
#   background-color: #23867e;
#   color: #f1f1f1;
# }
# #T_8cc7f_row5_col2 {
#   background-color: #cbebe6;
#   color: #000000;
# }
# #T_8cc7f_row6_col0 {
#   background-color: #ecd8a5;
#   color: #000000;
# }
# #T_8cc7f_row6_col1 {
#   background-color: #e6cd92;
#   color: #000000;
# }
# #T_8cc7f_row6_col2 {
#   background-color: #f2e2b8;
#   color: #000000;
# }
# #T_8cc7f_row7_col0, #T_8cc7f_row9_col2 {
#   background-color: #c08430;
#   color: #f1f1f1;
# }
# #T_8cc7f_row7_col1 {
#   background-color: #b77928;
#   color: #f1f1f1;
# }
# #T_8cc7f_row7_col2 {
#   background-color: #bd7f2c;
#   color: #f1f1f1;
# }
# #T_8cc7f_row8_col0 {
#   background-color: #bb7d2a;
#   color: #f1f1f1;
# }
# #T_8cc7f_row8_col1 {
#   background-color: #663a07;
#   color: #f1f1f1;
# }
# #T_8cc7f_row8_col2 {
#   background-color: #cc9a4c;
#   color: #f1f1f1;
# }
# #T_8cc7f_row9_col0 {
#   background-color: #9f6317;
#   color: #f1f1f1;
# }
# #T_8cc7f_row9_col1 {
#   background-color: #583305;
#   color: #f1f1f1;
# }
# #T_8cc7f_row10_col0 {
#   background-color: #955910;
#   color: #f1f1f1;
# }
# #T_8cc7f_row10_col1 {
#   background-color: #563105;
#   color: #f1f1f1;
# }
# #T_8cc7f_row10_col2 {
#   background-color: #894f0a;
#   color: #f1f1f1;
# }
# #T_8cc7f_row11_col0, #T_8cc7f_row11_col1, #T_8cc7f_row11_col2 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8cc7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8cc7f_level0_col0" class="col_heading level0 col0" >Sales</th>
#       <th id="T_8cc7f_level0_col1" class="col_heading level0 col1" >Profit</th>
#       <th id="T_8cc7f_level0_col2" class="col_heading level0 col2" >Quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8cc7f_level0_row0" class="row_heading level0 row0" >12</th>
#       <td id="T_8cc7f_row0_col0" class="data row0 col0" >1566662.447500</td>
#       <td id="T_8cc7f_row0_col1" class="data row0 col1" >168101.707100</td>
#       <td id="T_8cc7f_row0_col2" class="data row0 col2" >22147</td>
#     </tr>
#     <tr>
#       <th id="T_8cc7f_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_8cc7f_row1_col0" class="data row1 col0" >1546728.156160</td>
#       <td id="T_8cc7f_row1_col1" class="data row1 col1" >175983.189460</td>
#       <td id="T_8cc7f_row1_col2" class="data row1 col2" >22379</td>
#     </tr>
#     <tr>
#       <th id="T_8cc7f_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_8cc7f_row2_col0" class="data row2 col0" >1431753.403480</td>
#       <td id="T_8cc7f_row2_col1" class="data row2 col1" >169705.822080</td>
#       <td id="T_8cc7f_row2_col2" class="data row2 col2" >20479</td>
#     </tr>
#     <tr>
#       <th id="T_8cc7f_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_8cc7f_row3_col0" class="data row3 col0" >1294314.957820</td>
#       <td id="T_8cc7f_row3_col1" class="data row3 col1" >154593.439420</td>
#       <td id="T_8cc7f_row3_col2" class="data row3 col2" >17596</td>
#     </tr>
#     <tr>
#       <th id="T_8cc7f_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_8cc7f_row4_col0" class="data row4 col0" >1262080.916940</td>
#       <td id="T_8cc7f_row4_col1" class="data row4 col1" >144604.768440</td>
#       <td id="T_8cc7f_row4_col2" class="data row4 col2" >18009</td>
#     </tr>
#     <tr>
#       <th id="T_8cc7f_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_8cc7f_row5_col0" class="data row5 col0" >1185227.689720</td>
#       <td id="T_8cc7f_row5_col1" class="data row5 col1" >158903.895920</td>
#       <td id="T_8cc7f_row5_col2" class="data row5 col2" >16303</td>
#     </tr>
#     <tr>
#       <th id="T_8cc7f_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_8cc7f_row6_col0" class="data row6 col0" >915492.830880</td>
#       <td id="T_8cc7f_row6_col1" class="data row6 col1" >106970.037880</td>
#       <td id="T_8cc7f_row6_col2" class="data row6 col2" >13196</td>
#     </tr>
#     <tr>
#       <th id="T_8cc7f_level0_row7" class="row_heading level0 row7" >3</th>
#       <td id="T_8cc7f_row7_col0" class="data row7 col0" >760517.975960</td>
#       <td id="T_8cc7f_row7_col1" class="data row7 col1" >91873.579660</td>
#       <td id="T_8cc7f_row7_col2" class="data row7 col2" >10390</td>
#     </tr>
#     <tr>
#       <th id="T_8cc7f_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_8cc7f_row8_col0" class="data row8 col0" >752306.302220</td>
#       <td id="T_8cc7f_row8_col1" class="data row8 col1" >76525.695020</td>
#       <td id="T_8cc7f_row8_col2" class="data row8 col2" >11046</td>
#     </tr>
#     <tr>
#       <th id="T_8cc7f_level0_row9" class="row_heading level0 row9" >4</th>
#       <td id="T_8cc7f_row9_col0" class="data row9 col0" >695978.410840</td>
#       <td id="T_8cc7f_row9_col1" class="data row9 col1" >73822.418640</td>
#       <td id="T_8cc7f_row9_col2" class="data row9 col2" >10466</td>
#     </tr>
#     <tr>
#       <th id="T_8cc7f_level0_row10" class="row_heading level0 row10" >1</th>
#       <td id="T_8cc7f_row10_col0" class="data row10 col0" >676788.927040</td>
#       <td id="T_8cc7f_row10_col1" class="data row10 col1" >73440.459440</td>
#       <td id="T_8cc7f_row10_col2" class="data row10 col2" >8872</td>
#     </tr>
#     <tr>
#       <th id="T_8cc7f_level0_row11" class="row_heading level0 row11" >2</th>
#       <td id="T_8cc7f_row11_col0" class="data row11 col0" >554649.891320</td>
#       <td id="T_8cc7f_row11_col1" class="data row11 col1" >72932.278220</td>
#       <td id="T_8cc7f_row11_col2" class="data row11 col2" >7429</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plotting
plt.figure(figsize=(12, 6))

# Sales plot
plt.subplot(2, 2, 1)
plt.plot(monthly_data['Month'], monthly_data['Sales'], marker='o')
plt.title('Total Sales by Month')
plt.xlabel('Month')
plt.ylabel('Total Sales')

# Profit plot
plt.subplot(2, 2, 2)
plt.plot(monthly_data['Month'], monthly_data['Profit'], marker='o')
plt.title('Total Profit by Month')
plt.xlabel('Month')
plt.ylabel('Total Profit')

# Quantity plot
plt.subplot(2, 2, 3)
plt.plot(monthly_data['Month'], monthly_data['Quantity'], marker='o')
plt.title('Total Quantity Sold by Month')
plt.xlabel('Month')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %%
# Group data by month and calculate sum
Ship_Mode_analysis = Gsma.groupby('Ship Mode').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).style.background_gradient(cmap='BrBG')

# %%
Ship_Mode_analysis
# Out:
# <style type="text/css">
# #T_54556_row0_col0, #T_54556_row0_col1, #T_54556_row0_col2 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_54556_row1_col0 {
#   background-color: #d7b169;
#   color: #000000;
# }
# #T_54556_row1_col1 {
#   background-color: #d4ac62;
#   color: #000000;
# }
# #T_54556_row1_col2 {
#   background-color: #d6af65;
#   color: #000000;
# }
# #T_54556_row2_col0, #T_54556_row2_col2 {
#   background-color: #af7222;
#   color: #f1f1f1;
# }
# #T_54556_row2_col1 {
#   background-color: #ab6e1f;
#   color: #f1f1f1;
# }
# #T_54556_row3_col0, #T_54556_row3_col1, #T_54556_row3_col2 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_54556">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54556_level0_col0" class="col_heading level0 col0" >Sales</th>
#       <th id="T_54556_level0_col1" class="col_heading level0 col1" >Profit</th>
#       <th id="T_54556_level0_col2" class="col_heading level0 col2" >Quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ship Mode</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54556_level0_row0" class="row_heading level0 row0" >Standard Class</th>
#       <td id="T_54556_row0_col0" class="data row0 col0" >7578652.106700</td>
#       <td id="T_54556_row0_col1" class="data row0 col1" >890596.021200</td>
#       <td id="T_54556_row0_col2" class="data row0 col2" >107319</td>
#     </tr>
#     <tr>
#       <th id="T_54556_level0_row1" class="row_heading level0 row1" >Second Class</th>
#       <td id="T_54556_row1_col0" class="data row1 col0" >2565671.681080</td>
#       <td id="T_54556_row1_col1" class="data row1 col1" >292583.527080</td>
#       <td id="T_54556_row1_col2" class="data row1 col2" >35724</td>
#     </tr>
#     <tr>
#       <th id="T_54556_level0_row2" class="row_heading level0 row2" >First Class</th>
#       <td id="T_54556_row2_col0" class="data row2 col0" >1830976.138200</td>
#       <td id="T_54556_row2_col1" class="data row2 col1" >208104.675200</td>
#       <td id="T_54556_row2_col2" class="data row2 col2" >26039</td>
#     </tr>
#     <tr>
#       <th id="T_54556_level0_row3" class="row_heading level0 row3" >Same Day</th>
#       <td id="T_54556_row3_col0" class="data row3 col0" >667201.983900</td>
#       <td id="T_54556_row3_col1" class="data row3 col1" >76173.067800</td>
#       <td id="T_54556_row3_col2" class="data row3 col2" >9230</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plotting
plt.figure(figsize=(12, 8))


# Sales plot
plt.subplot(2, 2, 1)
plt.bar(Ship_Mode_analysis['Ship Mode'], Ship_Mode_analysis['Sales'], color=sns.color_palette('Set1'))
plt.title('Total Sales by Ship Mode')
plt.xlabel('Month')
plt.ylabel('Total Sales')

# Profit plot
plt.subplot(2, 2, 2)
plt.bar(Ship_Mode_analysis['Ship Mode'], Ship_Mode_analysis['Profit'], color=sns.color_palette('Set2'))
plt.title('Total Profit by Ship Mode')
plt.xlabel('Month')
plt.ylabel('Total Profit')

# Quantity plot
plt.subplot(2, 2, 3)
plt.bar(Ship_Mode_analysis['Ship Mode'], Ship_Mode_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.title('Total Quantity by Ship Mode')
plt.xlabel('Month')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %%
Gsma.columns
# Out:
# Index(['Order Date', 'Ship Mode', 'Customer Name', 'Segment', 'City', 'State',
#        'Country', 'Region', 'Market', 'Product ID', 'Category', 'Sub-Category',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost',
#        'Order Priority', 'Returned', 'Year', 'Month', 'Total Sales',
#        'Total Profit', 'Total Shipping Cost'],
#       dtype='object')

# %%
# Group data by month and calculate sum
Segment_analysis = Gsma.groupby('Segment').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales',ascending=False).style.background_gradient(cmap='BrBG')

# %%
Segment_analysis
# Out:
# <style type="text/css">
# #T_4f38f_row0_col0, #T_4f38f_row0_col1, #T_4f38f_row0_col2 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_4f38f_row1_col0 {
#   background-color: #edd9a8;
#   color: #000000;
# }
# #T_4f38f_row1_col1 {
#   background-color: #ead59f;
#   color: #000000;
# }
# #T_4f38f_row1_col2 {
#   background-color: #ebd6a2;
#   color: #000000;
# }
# #T_4f38f_row2_col0, #T_4f38f_row2_col1, #T_4f38f_row2_col2 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4f38f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f38f_level0_col0" class="col_heading level0 col0" >Sales</th>
#       <th id="T_4f38f_level0_col1" class="col_heading level0 col1" >Profit</th>
#       <th id="T_4f38f_level0_col2" class="col_heading level0 col2" >Quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Segment</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f38f_level0_row0" class="row_heading level0 row0" >Consumer</th>
#       <td id="T_4f38f_row0_col0" class="data row0 col0" >6507949.417860</td>
#       <td id="T_4f38f_row0_col1" class="data row0 col1" >749239.782060</td>
#       <td id="T_4f38f_row0_col2" class="data row0 col2" >92157</td>
#     </tr>
#     <tr>
#       <th id="T_4f38f_level0_row1" class="row_heading level0 row1" >Corporate</th>
#       <td id="T_4f38f_row1_col0" class="data row1 col0" >3824697.521460</td>
#       <td id="T_4f38f_row1_col1" class="data row1 col1" >441208.328660</td>
#       <td id="T_4f38f_row1_col2" class="data row1 col2" >53565</td>
#     </tr>
#     <tr>
#       <th id="T_4f38f_level0_row2" class="row_heading level0 row2" >Home Office</th>
#       <td id="T_4f38f_row2_col0" class="data row2 col0" >2309854.970560</td>
#       <td id="T_4f38f_row2_col1" class="data row2 col1" >277009.180560</td>
#       <td id="T_4f38f_row2_col2" class="data row2 col2" >32590</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Group data by month and calculate sum
City_analysis = Gsma.groupby('City').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False)

# %%
City_analysis.head(10)
# Out:
#                    Sales     Profit  Quantity
# City
# New York City 256,368.16  62,036.98      3417
# Los Angeles   175,851.34  30,440.76      2879
# Manila        120,886.95 -11,158.56      1661
# Seattle       119,540.74  29,156.10      1590
# San Francisco 112,669.09  17,507.39      1935
# Philadelphia  109,077.01 -13,837.77      1981
# Sydney        101,945.52  16,002.81       975
# Jakarta        94,321.32   3,826.98      1226
# London         86,945.81  17,378.72      1033
# Mexico City    85,700.25  13,335.59      1138

# %%
# Group data by month and calculate sum
State_analysis = Gsma.groupby('State').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).head(10).style.background_gradient(cmap='BrBG')

# %%
State_analysis
# Out:
# <style type="text/css">
# #T_78485_row0_col0, #T_78485_row0_col1, #T_78485_row1_col2 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_78485_row0_col2 {
#   background-color: #b1e1da;
#   color: #000000;
# }
# #T_78485_row1_col0 {
#   background-color: #015f56;
#   color: #f1f1f1;
# }
# #T_78485_row1_col1 {
#   background-color: #2d8f87;
#   color: #f1f1f1;
# }
# #T_78485_row2_col0 {
#   background-color: #f5f5f4;
#   color: #000000;
# }
# #T_78485_row2_col1 {
#   background-color: #dbefec;
#   color: #000000;
# }
# #T_78485_row2_col2 {
#   background-color: #ddbe78;
#   color: #000000;
# }
# #T_78485_row3_col0 {
#   background-color: #f5f2ea;
#   color: #000000;
# }
# #T_78485_row3_col1 {
#   background-color: #389991;
#   color: #f1f1f1;
# }
# #T_78485_row3_col2 {
#   background-color: #eedbaa;
#   color: #000000;
# }
# #T_78485_row4_col0 {
#   background-color: #ebd6a2;
#   color: #000000;
# }
# #T_78485_row4_col1 {
#   background-color: #ddefed;
#   color: #000000;
# }
# #T_78485_row4_col2 {
#   background-color: #995d13;
#   color: #f1f1f1;
# }
# #T_78485_row5_col0 {
#   background-color: #d2a75c;
#   color: #000000;
# }
# #T_78485_row5_col1 {
#   background-color: #f1dfb3;
#   color: #000000;
# }
# #T_78485_row5_col2, #T_78485_row6_col2 {
#   background-color: #804a09;
#   color: #f1f1f1;
# }
# #T_78485_row6_col0 {
#   background-color: #bb7d2a;
#   color: #f1f1f1;
# }
# #T_78485_row6_col1 {
#   background-color: #e2f0ee;
#   color: #000000;
# }
# #T_78485_row7_col0 {
#   background-color: #714108;
#   color: #f1f1f1;
# }
# #T_78485_row7_col1, #T_78485_row9_col0, #T_78485_row9_col2 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_78485_row7_col2 {
#   background-color: #d7b169;
#   color: #000000;
# }
# #T_78485_row8_col0, #T_78485_row8_col2 {
#   background-color: #563105;
#   color: #f1f1f1;
# }
# #T_78485_row8_col1 {
#   background-color: #f5f4f0;
#   color: #000000;
# }
# #T_78485_row9_col1 {
#   background-color: #8b500a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_78485">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78485_level0_col0" class="col_heading level0 col0" >Sales</th>
#       <th id="T_78485_level0_col1" class="col_heading level0 col1" >Profit</th>
#       <th id="T_78485_level0_col2" class="col_heading level0 col2" >Quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >State</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78485_level0_row0" class="row_heading level0 row0" >England</th>
#       <td id="T_78485_row0_col0" class="data row0 col0" >485170.971000</td>
#       <td id="T_78485_row0_col1" class="data row0 col1" >99907.731000</td>
#       <td id="T_78485_row0_col2" class="data row0 col2" >5656</td>
#     </tr>
#     <tr>
#       <th id="T_78485_level0_row1" class="row_heading level0 row1" >California</th>
#       <td id="T_78485_row1_col0" class="data row1 col0" >457687.631500</td>
#       <td id="T_78485_row1_col1" class="data row1 col1" >76381.387100</td>
#       <td id="T_78485_row1_col2" class="data row1 col2" >7667</td>
#     </tr>
#     <tr>
#       <th id="T_78485_level0_row2" class="row_heading level0 row2" >Ile-de-France</th>
#       <td id="T_78485_row2_col0" class="data row2 col0" >317822.544000</td>
#       <td id="T_78485_row2_col1" class="data row2 col1" >44055.924000</td>
#       <td id="T_78485_row2_col2" class="data row2 col2" >3839</td>
#     </tr>
#     <tr>
#       <th id="T_78485_level0_row3" class="row_heading level0 row3" >New York</th>
#       <td id="T_78485_row3_col0" class="data row3 col0" >310876.271000</td>
#       <td id="T_78485_row3_col1" class="data row3 col1" >74038.548600</td>
#       <td id="T_78485_row3_col2" class="data row3 col2" >4224</td>
#     </tr>
#     <tr>
#       <th id="T_78485_level0_row4" class="row_heading level0 row4" >New South Wales</th>
#       <td id="T_78485_row4_col0" class="data row4 col0" >270487.104000</td>
#       <td id="T_78485_row4_col1" class="data row4 col1" >43695.984000</td>
#       <td id="T_78485_row4_col2" class="data row4 col2" >2921</td>
#     </tr>
#     <tr>
#       <th id="T_78485_level0_row5" class="row_heading level0 row5" >Queensland</th>
#       <td id="T_78485_row5_col0" class="data row5 col0" >238312.734000</td>
#       <td id="T_78485_row5_col1" class="data row5 col1" >21608.754000</td>
#       <td id="T_78485_row5_col2" class="data row5 col2" >2665</td>
#     </tr>
#     <tr>
#       <th id="T_78485_level0_row6" class="row_heading level0 row6" >North Rhine-Westphalia</th>
#       <td id="T_78485_row6_col0" class="data row6 col0" >216451.851000</td>
#       <td id="T_78485_row6_col1" class="data row6 col1" >42347.871000</td>
#       <td id="T_78485_row6_col2" class="data row6 col2" >2660</td>
#     </tr>
#     <tr>
#       <th id="T_78485_level0_row7" class="row_heading level0 row7" >Texas</th>
#       <td id="T_78485_row7_col0" class="data row7 col0" >170188.045800</td>
#       <td id="T_78485_row7_col1" class="data row7 col1" >-25729.356300</td>
#       <td id="T_78485_row7_col2" class="data row7 col2" >3724</td>
#     </tr>
#     <tr>
#       <th id="T_78485_level0_row8" class="row_heading level0 row8" >San Salvador</th>
#       <td id="T_78485_row8_col0" class="data row8 col0" >153639.397000</td>
#       <td id="T_78485_row8_col1" class="data row8 col1" >35883.377000</td>
#       <td id="T_78485_row8_col2" class="data row8 col2" >2273</td>
#     </tr>
#     <tr>
#       <th id="T_78485_level0_row9" class="row_heading level0 row9" >National Capital</th>
#       <td id="T_78485_row9_col0" class="data row9 col0" >152175.355500</td>
#       <td id="T_78485_row9_col1" class="data row9 col1" >-13066.084500</td>
#       <td id="T_78485_row9_col2" class="data row9 col2" >2231</td>
#     </tr>
#   </tbody>
# </table>

# %%
Country_analysis = Gsma.groupby('Country').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).head(10).style.background_gradient(cmap='BrBG')

# %%
Country_analysis
# Out:
# <style type="text/css">
# #T_7d199_row0_col0, #T_7d199_row0_col1, #T_7d199_row0_col2 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_7d199_row1_col0 {
#   background-color: #dcbc75;
#   color: #000000;
# }
# #T_7d199_row1_col1 {
#   background-color: #e5cc8f;
#   color: #000000;
# }
# #T_7d199_row1_col2 {
#   background-color: #ad7021;
#   color: #f1f1f1;
# }
# #T_7d199_row2_col0 {
#   background-color: #d1a559;
#   color: #000000;
# }
# #T_7d199_row2_col1 {
#   background-color: #e9d39d;
#   color: #000000;
# }
# #T_7d199_row2_col2 {
#   background-color: #af7222;
#   color: #f1f1f1;
# }
# #T_7d199_row3_col0 {
#   background-color: #b37625;
#   color: #f1f1f1;
# }
# #T_7d199_row3_col1 {
#   background-color: #f5f5f4;
#   color: #000000;
# }
# #T_7d199_row3_col2 {
#   background-color: #734208;
#   color: #f1f1f1;
# }
# #T_7d199_row4_col0 {
#   background-color: #9f6317;
#   color: #f1f1f1;
# }
# #T_7d199_row4_col1 {
#   background-color: #e8d097;
#   color: #000000;
# }
# #T_7d199_row4_col2 {
#   background-color: #7e4909;
#   color: #f1f1f1;
# }
# #T_7d199_row5_col0 {
#   background-color: #9d6116;
#   color: #f1f1f1;
# }
# #T_7d199_row5_col1 {
#   background-color: #e4ca8c;
#   color: #000000;
# }
# #T_7d199_row5_col2 {
#   background-color: #a3671a;
#   color: #f1f1f1;
# }
# #T_7d199_row6_col0 {
#   background-color: #955910;
#   color: #f1f1f1;
# }
# #T_7d199_row6_col1 {
#   background-color: #f6ebcd;
#   color: #000000;
# }
# #T_7d199_row6_col2 {
#   background-color: #5d3506;
#   color: #f1f1f1;
# }
# #T_7d199_row7_col0 {
#   background-color: #844c09;
#   color: #f1f1f1;
# }
# #T_7d199_row7_col1 {
#   background-color: #ecd8a5;
#   color: #000000;
# }
# #T_7d199_row7_col2 {
#   background-color: #633906;
#   color: #f1f1f1;
# }
# #T_7d199_row8_col0 {
#   background-color: #5f3606;
#   color: #f1f1f1;
# }
# #T_7d199_row8_col1, #T_7d199_row8_col2, #T_7d199_row9_col0 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_7d199_row9_col1 {
#   background-color: #714108;
#   color: #f1f1f1;
# }
# #T_7d199_row9_col2 {
#   background-color: #613806;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7d199">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d199_level0_col0" class="col_heading level0 col0" >Sales</th>
#       <th id="T_7d199_level0_col1" class="col_heading level0 col1" >Profit</th>
#       <th id="T_7d199_level0_col2" class="col_heading level0 col2" >Quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d199_level0_row0" class="row_heading level0 row0" >United States</th>
#       <td id="T_7d199_row0_col0" class="data row0 col0" >2297200.860300</td>
#       <td id="T_7d199_row0_col1" class="data row0 col1" >286397.021700</td>
#       <td id="T_7d199_row0_col2" class="data row0 col2" >37873</td>
#     </tr>
#     <tr>
#       <th id="T_7d199_level0_row1" class="row_heading level0 row1" >Australia</th>
#       <td id="T_7d199_row1_col0" class="data row1 col0" >925235.853000</td>
#       <td id="T_7d199_row1_col1" class="data row1 col1" >103907.433000</td>
#       <td id="T_7d199_row1_col2" class="data row1 col2" >10673</td>
#     </tr>
#     <tr>
#       <th id="T_7d199_level0_row2" class="row_heading level0 row2" >France</th>
#       <td id="T_7d199_row2_col0" class="data row2 col0" >858931.083000</td>
#       <td id="T_7d199_row2_col1" class="data row2 col1" >109029.003000</td>
#       <td id="T_7d199_row2_col2" class="data row2 col2" >10804</td>
#     </tr>
#     <tr>
#       <th id="T_7d199_level0_row3" class="row_heading level0 row3" >China</th>
#       <td id="T_7d199_row3_col0" class="data row3 col0" >700562.025000</td>
#       <td id="T_7d199_row3_col1" class="data row3 col1" >150683.085000</td>
#       <td id="T_7d199_row3_col2" class="data row3 col2" >7081</td>
#     </tr>
#     <tr>
#       <th id="T_7d199_level0_row4" class="row_heading level0 row4" >Germany</th>
#       <td id="T_7d199_row4_col0" class="data row4 col0" >628136.185500</td>
#       <td id="T_7d199_row4_col1" class="data row4 col1" >107190.325500</td>
#       <td id="T_7d199_row4_col2" class="data row4 col2" >7739</td>
#     </tr>
#     <tr>
#       <th id="T_7d199_level0_row5" class="row_heading level0 row5" >Mexico</th>
#       <td id="T_7d199_row5_col0" class="data row5 col0" >621552.645520</td>
#       <td id="T_7d199_row5_col1" class="data row5 col1" >102453.585520</td>
#       <td id="T_7d199_row5_col2" class="data row5 col2" >9972</td>
#     </tr>
#     <tr>
#       <th id="T_7d199_level0_row6" class="row_heading level0 row6" >India</th>
#       <td id="T_7d199_row6_col0" class="data row6 col0" >589486.035000</td>
#       <td id="T_7d199_row6_col1" class="data row6 col1" >129050.595000</td>
#       <td id="T_7d199_row6_col2" class="data row6 col2" >5755</td>
#     </tr>
#     <tr>
#       <th id="T_7d199_level0_row7" class="row_heading level0 row7" >United Kingdom</th>
#       <td id="T_7d199_row7_col0" class="data row7 col0" >528576.300000</td>
#       <td id="T_7d199_row7_col1" class="data row7 col1" >111900.150000</td>
#       <td id="T_7d199_row7_col2" class="data row7 col2" >6161</td>
#     </tr>
#     <tr>
#       <th id="T_7d199_level0_row8" class="row_heading level0 row8" >Indonesia</th>
#       <td id="T_7d199_row8_col0" class="data row8 col0" >404887.497900</td>
#       <td id="T_7d199_row8_col1" class="data row8 col1" >15608.677900</td>
#       <td id="T_7d199_row8_col2" class="data row8 col2" >5237</td>
#     </tr>
#     <tr>
#       <th id="T_7d199_level0_row9" class="row_heading level0 row9" >Brazil</th>
#       <td id="T_7d199_row9_col0" class="data row9 col0" >359924.858960</td>
#       <td id="T_7d199_row9_col1" class="data row9 col1" >29686.898960</td>
#       <td id="T_7d199_row9_col2" class="data row9 col2" >6123</td>
#     </tr>
#   </tbody>
# </table>

# %%
Market_analysis = Gsma.groupby('Market').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).style.background_gradient(cmap='BrBG')

# %%
Market_analysis
# Out:
# <style type="text/css">
# #T_2e6f9_row0_col0, #T_2e6f9_row0_col2, #T_2e6f9_row1_col1 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_2e6f9_row0_col1 {
#   background-color: #0e726a;
#   color: #f1f1f1;
# }
# #T_2e6f9_row1_col0 {
#   background-color: #4da89f;
#   color: #f1f1f1;
# }
# #T_2e6f9_row1_col2 {
#   background-color: #278a82;
#   color: #f1f1f1;
# }
# #T_2e6f9_row2_col0 {
#   background-color: #f5f3ee;
#   color: #000000;
# }
# #T_2e6f9_row2_col1 {
#   background-color: #c9eae6;
#   color: #000000;
# }
# #T_2e6f9_row2_col2 {
#   background-color: #61b7ac;
#   color: #f1f1f1;
# }
# #T_2e6f9_row3_col0 {
#   background-color: #f6ebcf;
#   color: #000000;
# }
# #T_2e6f9_row3_col1 {
#   background-color: #efdcad;
#   color: #000000;
# }
# #T_2e6f9_row3_col2 {
#   background-color: #64b9ae;
#   color: #f1f1f1;
# }
# #T_2e6f9_row4_col0, #T_2e6f9_row4_col1, #T_2e6f9_row4_col2 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2e6f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e6f9_level0_col0" class="col_heading level0 col0" >Sales</th>
#       <th id="T_2e6f9_level0_col1" class="col_heading level0 col1" >Profit</th>
#       <th id="T_2e6f9_level0_col2" class="col_heading level0 col2" >Quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Market</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e6f9_level0_row0" class="row_heading level0 row0" >Asia Pacific</th>
#       <td id="T_2e6f9_row0_col0" class="data row0 col0" >4042658.268000</td>
#       <td id="T_2e6f9_row0_col1" class="data row0 col1" >403176.038000</td>
#       <td id="T_2e6f9_row0_col2" class="data row0 col2" >48597</td>
#     </tr>
#     <tr>
#       <th id="T_2e6f9_level0_row1" class="row_heading level0 row1" >Europe</th>
#       <td id="T_2e6f9_row1_col0" class="data row1 col0" >3287336.233500</td>
#       <td id="T_2e6f9_row1_col1" class="data row1 col1" >449551.723500</td>
#       <td id="T_2e6f9_row1_col2" class="data row1 col2" >41919</td>
#     </tr>
#     <tr>
#       <th id="T_2e6f9_level0_row2" class="row_heading level0 row2" >USCA</th>
#       <td id="T_2e6f9_row2_col0" class="data row2 col0" >2364129.030300</td>
#       <td id="T_2e6f9_row2_col1" class="data row2 col1" >304214.411700</td>
#       <td id="T_2e6f9_row2_col2" class="data row2 col2" >38706</td>
#     </tr>
#     <tr>
#       <th id="T_2e6f9_level0_row3" class="row_heading level0 row3" >LATAM</th>
#       <td id="T_2e6f9_row3_col0" class="data row3 col0" >2164605.167080</td>
#       <td id="T_2e6f9_row3_col1" class="data row3 col1" >221643.487080</td>
#       <td id="T_2e6f9_row3_col2" class="data row3 col2" >38526</td>
#     </tr>
#     <tr>
#       <th id="T_2e6f9_level0_row4" class="row_heading level0 row4" >Africa</th>
#       <td id="T_2e6f9_row4_col0" class="data row4 col0" >783773.211000</td>
#       <td id="T_2e6f9_row4_col1" class="data row4 col1" >88871.631000</td>
#       <td id="T_2e6f9_row4_col2" class="data row4 col2" >10564</td>
#     </tr>
#   </tbody>
# </table>

# %%
Product_analysis = Gsma.groupby('Product ID').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False)

# %%
Product_analysis.head(10).style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_7ff65_row0_col0, #T_7ff65_row0_col2, #T_7ff65_row4_col1 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_7ff65_row0_col1 {
#   background-color: #cc9a4c;
#   color: #f1f1f1;
# }
# #T_7ff65_row1_col0 {
#   background-color: #67bbb0;
#   color: #000000;
# }
# #T_7ff65_row1_col1 {
#   background-color: #8ad1c6;
#   color: #000000;
# }
# #T_7ff65_row1_col2 {
#   background-color: #3e9d95;
#   color: #f1f1f1;
# }
# #T_7ff65_row2_col0 {
#   background-color: #a6dcd4;
#   color: #000000;
# }
# #T_7ff65_row2_col1 {
#   background-color: #8fd3c9;
#   color: #000000;
# }
# #T_7ff65_row2_col2 {
#   background-color: #55aea5;
#   color: #f1f1f1;
# }
# #T_7ff65_row3_col0 {
#   background-color: #bce5df;
#   color: #000000;
# }
# #T_7ff65_row3_col1 {
#   background-color: #f6e8c3;
#   color: #000000;
# }
# #T_7ff65_row3_col2 {
#   background-color: #1f827a;
#   color: #f1f1f1;
# }
# #T_7ff65_row4_col0 {
#   background-color: #ead59f;
#   color: #000000;
# }
# #T_7ff65_row4_col2, #T_7ff65_row8_col1, #T_7ff65_row9_col0 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_7ff65_row5_col0 {
#   background-color: #d3aa5f;
#   color: #000000;
# }
# #T_7ff65_row5_col1 {
#   background-color: #cd9d50;
#   color: #f1f1f1;
# }
# #T_7ff65_row5_col2 {
#   background-color: #004135;
#   color: #f1f1f1;
# }
# #T_7ff65_row6_col0 {
#   background-color: #7c4709;
#   color: #f1f1f1;
# }
# #T_7ff65_row6_col1 {
#   background-color: #bb7d2a;
#   color: #f1f1f1;
# }
# #T_7ff65_row6_col2 {
#   background-color: #33958d;
#   color: #f1f1f1;
# }
# #T_7ff65_row7_col0 {
#   background-color: #734208;
#   color: #f1f1f1;
# }
# #T_7ff65_row7_col1 {
#   background-color: #f6ebcd;
#   color: #000000;
# }
# #T_7ff65_row7_col2 {
#   background-color: #31938b;
#   color: #f1f1f1;
# }
# #T_7ff65_row8_col0 {
#   background-color: #5f3606;
#   color: #f1f1f1;
# }
# #T_7ff65_row8_col2 {
#   background-color: #ceece8;
#   color: #000000;
# }
# #T_7ff65_row9_col1 {
#   background-color: #f1e1b5;
#   color: #000000;
# }
# #T_7ff65_row9_col2 {
#   background-color: #f4f5f5;
#   color: #000000;
# }
# </style>
# <table id="T_7ff65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ff65_level0_col0" class="col_heading level0 col0" >Sales</th>
#       <th id="T_7ff65_level0_col1" class="col_heading level0 col1" >Profit</th>
#       <th id="T_7ff65_level0_col2" class="col_heading level0 col2" >Quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Product ID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ff65_level0_row0" class="row_heading level0 row0" >TEC-PH-3148</th>
#       <td id="T_7ff65_row0_col0" class="data row0 col0" >86935.778600</td>
#       <td id="T_7ff65_row0_col1" class="data row0 col1" >5921.578600</td>
#       <td id="T_7ff65_row0_col2" class="data row0 col2" >171</td>
#     </tr>
#     <tr>
#       <th id="T_7ff65_level0_row1" class="row_heading level0 row1" >TEC-PH-3806</th>
#       <td id="T_7ff65_row1_col0" class="data row1 col0" >76441.530600</td>
#       <td id="T_7ff65_row1_col1" class="data row1 col1" >17238.520600</td>
#       <td id="T_7ff65_row1_col2" class="data row1 col2" >139</td>
#     </tr>
#     <tr>
#       <th id="T_7ff65_level0_row2" class="row_heading level0 row2" >TEC-PH-5268</th>
#       <td id="T_7ff65_row2_col0" class="data row2 col0" >73156.303000</td>
#       <td id="T_7ff65_row2_col1" class="data row2 col1" >17027.113000</td>
#       <td id="T_7ff65_row2_col2" class="data row2 col2" >134</td>
#     </tr>
#     <tr>
#       <th id="T_7ff65_level0_row3" class="row_heading level0 row3" >TEC-PH-5355</th>
#       <td id="T_7ff65_row3_col0" class="data row3 col0" >71904.555500</td>
#       <td id="T_7ff65_row3_col1" class="data row3 col1" >9938.195500</td>
#       <td id="T_7ff65_row3_col2" class="data row3 col2" >147</td>
#     </tr>
#     <tr>
#       <th id="T_7ff65_level0_row4" class="row_heading level0 row4" >TEC-CO-3691</th>
#       <td id="T_7ff65_row4_col0" class="data row4 col0" >61599.824000</td>
#       <td id="T_7ff65_row4_col1" class="data row4 col1" >25199.928000</td>
#       <td id="T_7ff65_row4_col2" class="data row4 col2" >20</td>
#     </tr>
#     <tr>
#       <th id="T_7ff65_level0_row5" class="row_heading level0 row5" >FUR-CH-4654</th>
#       <td id="T_7ff65_row5_col0" class="data row5 col0" >58193.484100</td>
#       <td id="T_7ff65_row5_col1" class="data row5 col1" >5997.254100</td>
#       <td id="T_7ff65_row5_col2" class="data row5 col2" >169</td>
#     </tr>
#     <tr>
#       <th id="T_7ff65_level0_row6" class="row_heading level0 row6" >FUR-CH-5441</th>
#       <td id="T_7ff65_row6_col0" class="data row6 col0" >50661.684000</td>
#       <td id="T_7ff65_row6_col1" class="data row6 col1" >4710.984000</td>
#       <td id="T_7ff65_row6_col2" class="data row6 col2" >141</td>
#     </tr>
#     <tr>
#       <th id="T_7ff65_level0_row7" class="row_heading level0 row7" >FUR-CH-4530</th>
#       <td id="T_7ff65_row7_col0" class="data row7 col0" >50121.516000</td>
#       <td id="T_7ff65_row7_col1" class="data row7 col1" >10427.326000</td>
#       <td id="T_7ff65_row7_col2" class="data row7 col2" >142</td>
#     </tr>
#     <tr>
#       <th id="T_7ff65_level0_row8" class="row_heading level0 row8" >TEC-PH-5839</th>
#       <td id="T_7ff65_row8_col0" class="data row8 col0" >48653.460000</td>
#       <td id="T_7ff65_row8_col1" class="data row8 col1" >-198.090000</td>
#       <td id="T_7ff65_row8_col2" class="data row8 col2" >108</td>
#     </tr>
#     <tr>
#       <th id="T_7ff65_level0_row9" class="row_heading level0 row9" >TEC-PH-5356</th>
#       <td id="T_7ff65_row9_col0" class="data row9 col0" >47877.785700</td>
#       <td id="T_7ff65_row9_col1" class="data row9 col1" >9465.325700</td>
#       <td id="T_7ff65_row9_col2" class="data row9 col2" >96</td>
#     </tr>
#   </tbody>
# </table>

# %%
Product_analysis.query('Quantity == Quantity.max()')
# Out:
#                Sales   Profit  Quantity
# Product ID
# OFF-FA-6129 7,008.20 2,611.07       876

# %%
Category_analysis = Gsma.groupby('Category').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).style.background_gradient(cmap='BrBG')

# %%
Category_analysis
# Out:
# <style type="text/css">
# #T_bc73f_row0_col0, #T_bc73f_row0_col1, #T_bc73f_row2_col2 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_bc73f_row0_col2, #T_bc73f_row1_col1, #T_bc73f_row1_col2, #T_bc73f_row2_col0 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_bc73f_row1_col0 {
#   background-color: #e8d097;
#   color: #000000;
# }
# #T_bc73f_row2_col1 {
#   background-color: #bce5df;
#   color: #000000;
# }
# </style>
# <table id="T_bc73f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc73f_level0_col0" class="col_heading level0 col0" >Sales</th>
#       <th id="T_bc73f_level0_col1" class="col_heading level0 col1" >Profit</th>
#       <th id="T_bc73f_level0_col2" class="col_heading level0 col2" >Quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc73f_level0_row0" class="row_heading level0 row0" >Technology</th>
#       <td id="T_bc73f_row0_col0" class="data row0 col0" >4744557.498080</td>
#       <td id="T_bc73f_row0_col1" class="data row0 col1" >663778.733180</td>
#       <td id="T_bc73f_row0_col2" class="data row0 col2" >35176</td>
#     </tr>
#     <tr>
#       <th id="T_bc73f_level0_row1" class="row_heading level0 row1" >Furniture</th>
#       <td id="T_bc73f_row1_col0" class="data row1 col0" >4110451.898300</td>
#       <td id="T_bc73f_row1_col1" class="data row1 col1" >285082.730200</td>
#       <td id="T_bc73f_row1_col2" class="data row1 col2" >34892</td>
#     </tr>
#     <tr>
#       <th id="T_bc73f_level0_row2" class="row_heading level0 row2" >Office Supplies</th>
#       <td id="T_bc73f_row2_col0" class="data row2 col0" >3787492.513500</td>
#       <td id="T_bc73f_row2_col1" class="data row2 col1" >518595.827900</td>
#       <td id="T_bc73f_row2_col2" class="data row2 col2" >108244</td>
#     </tr>
#   </tbody>
# </table>

# %%
Sub_Category_analysis = Gsma.groupby('Sub-Category').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False)

# %%
Sub_Category_analysis.style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_5785b_row0_col0, #T_5785b_row1_col1, #T_5785b_row9_col2 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_5785b_row0_col1 {
#   background-color: #10746c;
#   color: #f1f1f1;
# }
# #T_5785b_row0_col2 {
#   background-color: #f5f2ea;
#   color: #000000;
# }
# #T_5785b_row1_col0 {
#   background-color: #0a6f67;
#   color: #f1f1f1;
# }
# #T_5785b_row1_col2, #T_5785b_row15_col1 {
#   background-color: #cc9a4c;
#   color: #f1f1f1;
# }
# #T_5785b_row2_col0 {
#   background-color: #0e726a;
#   color: #f1f1f1;
# }
# #T_5785b_row2_col1 {
#   background-color: #aee0d8;
#   color: #000000;
# }
# #T_5785b_row2_col2 {
#   background-color: #f2f4f4;
#   color: #000000;
# }
# #T_5785b_row3_col0 {
#   background-color: #187c74;
#   color: #f1f1f1;
# }
# #T_5785b_row3_col1 {
#   background-color: #7fccc0;
#   color: #000000;
# }
# #T_5785b_row3_col2, #T_5785b_row14_col1 {
#   background-color: #dbb972;
#   color: #000000;
# }
# #T_5785b_row4_col0 {
#   background-color: #a6dcd4;
#   color: #000000;
# }
# #T_5785b_row4_col1 {
#   background-color: #e6f1f0;
#   color: #000000;
# }
# #T_5785b_row4_col2 {
#   background-color: #58b0a7;
#   color: #f1f1f1;
# }
# #T_5785b_row5_col0 {
#   background-color: #d4ede9;
#   color: #000000;
# }
# #T_5785b_row5_col1 {
#   background-color: #abdfd7;
#   color: #000000;
# }
# #T_5785b_row5_col2 {
#   background-color: #ab6e1f;
#   color: #f1f1f1;
# }
# #T_5785b_row6_col0 {
#   background-color: #f6ecd3;
#   color: #000000;
# }
# #T_5785b_row6_col1 {
#   background-color: #f1e1b5;
#   color: #000000;
# }
# #T_5785b_row6_col2 {
#   background-color: #8b500a;
#   color: #f1f1f1;
# }
# #T_5785b_row7_col0 {
#   background-color: #f6ebcd;
#   color: #000000;
# }
# #T_5785b_row7_col1, #T_5785b_row7_col2, #T_5785b_row16_col0 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_5785b_row8_col0 {
#   background-color: #f6eac9;
#   color: #000000;
# }
# #T_5785b_row8_col1 {
#   background-color: #c7eae5;
#   color: #000000;
# }
# #T_5785b_row8_col2 {
#   background-color: #f6ecd1;
#   color: #000000;
# }
# #T_5785b_row9_col0 {
#   background-color: #ca9849;
#   color: #f1f1f1;
# }
# #T_5785b_row9_col1 {
#   background-color: #f6ebcf;
#   color: #000000;
# }
# #T_5785b_row10_col0 {
#   background-color: #b97b29;
#   color: #f1f1f1;
# }
# #T_5785b_row10_col1 {
#   background-color: #e9d39d;
#   color: #000000;
# }
# #T_5785b_row10_col2 {
#   background-color: #f6edd7;
#   color: #000000;
# }
# #T_5785b_row11_col0 {
#   background-color: #b57826;
#   color: #f1f1f1;
# }
# #T_5785b_row11_col1, #T_5785b_row13_col1 {
#   background-color: #f1dfb3;
#   color: #000000;
# }
# #T_5785b_row11_col2 {
#   background-color: #73c3b8;
#   color: #000000;
# }
# #T_5785b_row12_col0, #T_5785b_row13_col0 {
#   background-color: #8d520b;
#   color: #f1f1f1;
# }
# #T_5785b_row12_col1 {
#   background-color: #d4ac62;
#   color: #000000;
# }
# #T_5785b_row12_col2 {
#   background-color: #ddbe78;
#   color: #000000;
# }
# #T_5785b_row13_col2 {
#   background-color: #ebf3f2;
#   color: #000000;
# }
# #T_5785b_row14_col0 {
#   background-color: #754308;
#   color: #f1f1f1;
# }
# #T_5785b_row14_col2 {
#   background-color: #d8b46c;
#   color: #000000;
# }
# #T_5785b_row15_col0 {
#   background-color: #583305;
#   color: #f1f1f1;
# }
# #T_5785b_row15_col2 {
#   background-color: #e5cc8f;
#   color: #000000;
# }
# #T_5785b_row16_col1 {
#   background-color: #cd9d50;
#   color: #f1f1f1;
# }
# #T_5785b_row16_col2 {
#   background-color: #e8d097;
#   color: #000000;
# }
# </style>
# <table id="T_5785b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5785b_level0_col0" class="col_heading level0 col0" >Sales</th>
#       <th id="T_5785b_level0_col1" class="col_heading level0 col1" >Profit</th>
#       <th id="T_5785b_level0_col2" class="col_heading level0 col2" >Quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sub-Category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5785b_level0_row0" class="row_heading level0 row0" >Phones</th>
#       <td id="T_5785b_row0_col0" class="data row0 col0" >1706824.139200</td>
#       <td id="T_5785b_row0_col1" class="data row0 col1" >216717.005800</td>
#       <td id="T_5785b_row0_col2" class="data row0 col2" >11870</td>
#     </tr>
#     <tr>
#       <th id="T_5785b_level0_row1" class="row_heading level0 row1" >Copiers</th>
#       <td id="T_5785b_row1_col0" class="data row1 col0" >1509436.273280</td>
#       <td id="T_5785b_row1_col1" class="data row1 col1" >258567.548180</td>
#       <td id="T_5785b_row1_col2" class="data row1 col2" >7454</td>
#     </tr>
#     <tr>
#       <th id="T_5785b_level0_row2" class="row_heading level0 row2" >Chairs</th>
#       <td id="T_5785b_row2_col0" class="data row2 col0" >1501681.764200</td>
#       <td id="T_5785b_row2_col1" class="data row2 col1" >140396.267500</td>
#       <td id="T_5785b_row2_col2" class="data row2 col2" >12336</td>
#     </tr>
#     <tr>
#       <th id="T_5785b_level0_row3" class="row_heading level0 row3" >Bookcases</th>
#       <td id="T_5785b_row3_col0" class="data row3 col0" >1466572.241800</td>
#       <td id="T_5785b_row3_col1" class="data row3 col1" >161924.419500</td>
#       <td id="T_5785b_row3_col2" class="data row3 col2" >8310</td>
#     </tr>
#     <tr>
#       <th id="T_5785b_level0_row4" class="row_heading level0 row4" >Storage</th>
#       <td id="T_5785b_row4_col0" class="data row4 col0" >1126812.969400</td>
#       <td id="T_5785b_row4_col1" class="data row4 col1" >108416.680600</td>
#       <td id="T_5785b_row4_col2" class="data row4 col2" >16884</td>
#     </tr>
#     <tr>
#       <th id="T_5785b_level0_row5" class="row_heading level0 row5" >Appliances</th>
#       <td id="T_5785b_row5_col0" class="data row5 col0" >1010535.525000</td>
#       <td id="T_5785b_row5_col1" class="data row5 col1" >141562.587700</td>
#       <td id="T_5785b_row5_col2" class="data row5 col2" >6026</td>
#     </tr>
#     <tr>
#       <th id="T_5785b_level0_row6" class="row_heading level0 row6" >Machines</th>
#       <td id="T_5785b_row6_col0" class="data row6 col0" >779060.067100</td>
#       <td id="T_5785b_row6_col1" class="data row6 col1" >58867.873000</td>
#       <td id="T_5785b_row6_col2" class="data row6 col2" >4906</td>
#     </tr>
#     <tr>
#       <th id="T_5785b_level0_row7" class="row_heading level0 row7" >Tables</th>
#       <td id="T_5785b_row7_col0" class="data row7 col0" >757041.924400</td>
#       <td id="T_5785b_row7_col1" class="data row7 col1" >-64083.388700</td>
#       <td id="T_5785b_row7_col2" class="data row7 col2" >3083</td>
#     </tr>
#     <tr>
#       <th id="T_5785b_level0_row8" class="row_heading level0 row8" >Accessories</th>
#       <td id="T_5785b_row8_col0" class="data row8 col0" >749237.018500</td>
#       <td id="T_5785b_row8_col1" class="data row8 col1" >129626.306200</td>
#       <td id="T_5785b_row8_col2" class="data row8 col2" >10946</td>
#     </tr>
#     <tr>
#       <th id="T_5785b_level0_row9" class="row_heading level0 row9" >Binders</th>
#       <td id="T_5785b_row9_col0" class="data row9 col0" >461869.393700</td>
#       <td id="T_5785b_row9_col1" class="data row9 col1" >72433.151600</td>
#       <td id="T_5785b_row9_col2" class="data row9 col2" >21403</td>
#     </tr>
#     <tr>
#       <th id="T_5785b_level0_row10" class="row_heading level0 row10" >Furnishings</th>
#       <td id="T_5785b_row10_col0" class="data row10 col0" >385155.967900</td>
#       <td id="T_5785b_row10_col1" class="data row10 col1" >46845.431900</td>
#       <td id="T_5785b_row10_col2" class="data row10 col2" >11163</td>
#     </tr>
#     <tr>
#       <th id="T_5785b_level0_row11" class="row_heading level0 row11" >Art</th>
#       <td id="T_5785b_row11_col0" class="data row11 col0" >371613.153900</td>
#       <td id="T_5785b_row11_col1" class="data row11 col1" >57829.859300</td>
#       <td id="T_5785b_row11_col2" class="data row11 col2" >16215</td>
#     </tr>
#     <tr>
#       <th id="T_5785b_level0_row12" class="row_heading level0 row12" >Supplies</th>
#       <td id="T_5785b_row12_col0" class="data row12 col0" >242811.132600</td>
#       <td id="T_5785b_row12_col1" class="data row12 col1" >22559.195300</td>
#       <td id="T_5785b_row12_col2" class="data row12 col2" >8482</td>
#     </tr>
#     <tr>
#       <th id="T_5785b_le

# %%
Sub_Category_analysis.query('Quantity == Quantity.max()')
# Out:
#                   Sales    Profit  Quantity
# Sub-Category
# Binders      461,869.39 72,433.15     21403

# %%
Return_analysis = Gsma.groupby('Product ID').agg({
    'Returned': 'count',
}).sort_values(by='Returned', ascending=False)

# %%
Return_analysis.head(10).style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_9bbf3_row0_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_9bbf3_row1_col0 {
#   background-color: #955910;
#   color: #f1f1f1;
# }
# #T_9bbf3_row2_col0 {
#   background-color: #8d520b;
#   color: #f1f1f1;
# }
# #T_9bbf3_row3_col0 {
#   background-color: #774508;
#   color: #f1f1f1;
# }
# #T_9bbf3_row4_col0 {
#   background-color: #754308;
#   color: #f1f1f1;
# }
# #T_9bbf3_row5_col0 {
#   background-color: #6a3d07;
#   color: #f1f1f1;
# }
# #T_9bbf3_row6_col0 {
#   background-color: #5f3606;
#   color: #f1f1f1;
# }
# #T_9bbf3_row7_col0, #T_9bbf3_row8_col0 {
#   background-color: #563105;
#   color: #f1f1f1;
# }
# #T_9bbf3_row9_col0 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9bbf3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bbf3_level0_col0" class="col_heading level0 col0" >Returned</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Product ID</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bbf3_level0_row0" class="row_heading level0 row0" >OFF-FA-6129</th>
#       <td id="T_9bbf3_row0_col0" class="data row0 col0" >227</td>
#     </tr>
#     <tr>
#       <th id="T_9bbf3_level0_row1" class="row_heading level0 row1" >OFF-BI-3737</th>
#       <td id="T_9bbf3_row1_col0" class="data row1 col0" >92</td>
#     </tr>
#     <tr>
#       <th id="T_9bbf3_level0_row2" class="row_heading level0 row2" >OFF-ST-4057</th>
#       <td id="T_9bbf3_row2_col0" class="data row2 col0" >90</td>
#     </tr>
#     <tr>
#       <th id="T_9bbf3_level0_row3" class="row_heading level0 row3" >OFF-ST-5693</th>
#       <td id="T_9bbf3_row3_col0" class="data row3 col0" >84</td>
#     </tr>
#     <tr>
#       <th id="T_9bbf3_level0_row4" class="row_heading level0 row4" >OFF-BI-4828</th>
#       <td id="T_9bbf3_row4_col0" class="data row4 col0" >83</td>
#     </tr>
#     <tr>
#       <th id="T_9bbf3_level0_row5" class="row_heading level0 row5" >OFF-AR-5923</th>
#       <td id="T_9bbf3_row5_col0" class="data row5 col0" >80</td>
#     </tr>
#     <tr>
#       <th id="T_9bbf3_level0_row6" class="row_heading level0 row6" >OFF-ST-6033</th>
#       <td id="T_9bbf3_row6_col0" class="data row6 col0" >77</td>
#     </tr>
#     <tr>
#       <th id="T_9bbf3_level0_row7" class="row_heading level0 row7" >OFF-BI-2917</th>
#       <td id="T_9bbf3_row7_col0" class="data row7 col0" >75</td>
#     </tr>
#     <tr>
#       <th id="T_9bbf3_level0_row8" class="row_heading level0 row8" >OFF-AR-6120</th>
#       <td id="T_9bbf3_row8_col0" class="data row8 col0" >75</td>
#     </tr>
#     <tr>
#       <th id="T_9bbf3_level0_row9" class="row_heading level0 row9" >OFF-BI-3293</th>
#       <td id="T_9bbf3_row9_col0" class="data row9 col0" >74</td>
#     </tr>
#   </tbody>
# </table>

# %%
Gsma[['Category','Sub-Category']][Gsma['Product ID'].isin(['OFF-FA-6129'])]
# Out:
#               Category Sub-Category
# 28     Office Supplies    Fasteners
# 138    Office Supplies    Fasteners
# 337    Office Supplies    Fasteners
# 778    Office Supplies    Fasteners
# 942    Office Supplies    Fasteners
# ...                ...          ...
# 50258  Office Supplies    Fasteners
# 50445  Office Supplies    Fasteners
# 50907  Office Supplies    Fasteners
# 50909  Office Supplies    Fasteners
# 51249  Office Supplies    Fasteners
#
# [227 rows x 2 columns]
