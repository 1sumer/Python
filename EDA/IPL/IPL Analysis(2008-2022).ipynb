# %% [markdown]
# # Detailed Analysis of IPL data (2008-2022)

# %% [markdown]
# The Indian Premier League (IPL) is a professional Twenty20 cricket league in India usually contested between March and May of every year by eight teams representing eight different cities or states in India. The league was founded by the Board of Control for Cricket in India (BCCI) in 2007. The IPL is the most-attended cricket league in the world and the brand value of the IPL in 2019 was ₹475 billion (US$6.7 billion) in 2023 (US$15.4 billion)

# %% [markdown]
# ![ipl-auction-scaled.jpg](attachment:ipl-auction-scaled.jpg)

# %% [markdown]
# #### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ##### Let us import the data sets called IPL Matches 2008-2020 and IPL Ball-by-Ball 2008-2020 into python environment

# %%
deliveries_data = pd.read_csv(r'D:\Python\EDA\IPL\IPL_Ball_by_Ball_2008_2022.csv')
match_data=pd.read_csv(r"D:\Python\EDA\IPL\IPL_Matches_2008_2022.csv")
print("Data ready for exploration")
# Out:
# Data ready for exploration

# %% [markdown]
# ##### Basic data exploration

# %%
#looking at the top 5 rows
print('Below are the first 5 rows of the IPL Matches 2008-2020 dataset')
match_data.head()
# Out:
# Below are the first 5 rows of the IPL Matches 2008-2020 dataset
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
#match_data[['Team1','Team2', 'TossWinner','WinningTeam']].replace('Rising Pune Supergiant', 'Rising Pune Supergiants')

# %%
match_data['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
#looking at the top 5 rows
print('Below are the first 5 rows of the IPL Ball-by-Ball 2008-2020 dataset')
deliveries_data.tail()
# Out:
# Below are the first 5 rows of the IPL Ball-by-Ball 2008-2020 dataset
#             ID  innings  overs  ballnumber    batter     bowler non-striker  \
# 225949  335982        2     14           5   P Kumar   I Sharma    SB Joshi
# 225950  335982        2     14           6  SB Joshi   I Sharma     P Kumar
# 225951  335982        2     14           7   P Kumar   I Sharma    SB Joshi
# 225952  335982        2     15           1  SB Joshi  LR Shukla     P Kumar
# 225953  335982        2     15           2  SB Joshi  LR Shukla     P Kumar
#
#        extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 225949    legbyes            0           1          1             0
# 225950        NaN            1           0          1             0
# 225951        NaN            0           0          0             0
# 225952      wides            0           1          1             0
# 225953        NaN            0           0          0             0
#
#         isWicketDelivery player_out    kind fielders_involved  \
# 225949                 0        NaN     NaN               NaN
# 225950                 0        NaN     NaN               NaN
# 225951                 0        NaN     NaN               NaN
# 225952                 0        NaN     NaN               NaN
# 225953                 1   SB Joshi  caught       BB McCullum
#
#                         BattingTeam
# 225949  Royal Challengers Bangalore
# 225950  Royal Challengers Bangalore
# 225951  Royal Challengers Bangalore
# 225952  Royal Challengers Bangalore
# 225953  Royal Challengers Bangalore

# %%
#looking at bottom 5 rows
print('Below are the bottom 5 rows of the dataset')
match_data.tail()
# Out:
# Below are the bottom 5 rows of the dataset
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 945          bat         N        Kolkata Knight Riders  Wickets     5.0
# 946          bat         N  Royal Challengers Bangalore  Wickets     5.0
# 947          bat         N             Delhi Daredevils  Wickets     9.0
# 948          bat         N          Chennai Super Kings     Runs    33.0
# 949        field         N        Kolkata Knight Riders     Runs   140.0
#
#     method Player_of_Match                                       Team1Players  \
# 945    NaN       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946    NaN      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947    NaN     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948    NaN      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949    NaN     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players    Umpire1  \
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...  BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...   SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...  Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...  MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  Asad Rauf
#
#             Umpire2
# 945     K Hariharan
# 946       DJ Harper
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen

# %%
#Checking for null values in each column`
match_data.isnull().sum().to_frame().T
# Out:
#    ID  City  Date  Season  MatchNumber  Team1  Team2  Venue  TossWinner  \
# 0   0    51     0       0            0      0      0      0           0
#
#    TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0             0          4            4      0      18     931
#
#    Player_of_Match  Team1Players  Team2Players  Umpire1  Umpire2
# 0                4             0             0        0        0

# %%
#checking number of rows and columns
print(match_data.shape)
print(deliveries_data.shape)
# Out:
# (950, 20)
# (225954, 17)

# %%
#checking the which are the columns
match_data.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
deliveries_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 225954 non-null  int64
#  1   innings            225954 non-null  int64
#  2   overs              225954 non-null  int64
#  3   ballnumber         225954 non-null  int64
#  4   batter             225954 non-null  object
#  5   bowler             225954 non-null  object
#  6   non-striker        225954 non-null  object
#  7   extra_type         12049 non-null   object
#  8   batsman_run        225954 non-null  int64
#  9   extras_run         225954 non-null  int64
#  10  total_run          225954 non-null  int64
#  11  non_boundary       225954 non-null  int64
#  12  isWicketDelivery   225954 non-null  int64
#  13  player_out         11151 non-null   object
#  14  kind               11151 non-null   object
#  15  fielders_involved  7988 non-null    object
#  16  BattingTeam        225954 non-null  object
# dtypes: int64(9), object(8)
# memory usage: 29.3+ MB

# %%
match_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
#  16  Team1Players     950 non-null    object
#  17  Team2Players     950 non-null    object
#  18  Umpire1          950 non-null    object
#  19  Umpire2          950 non-null    object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 148.6+ KB

# %%
deliveries_data.isnull().sum()
# Out:
# ID                        0
# innings                   0
# overs                     0
# ballnumber                0
# batter                    0
# bowler                    0
# non-striker               0
# extra_type           213905
# batsman_run               0
# extras_run                0
# total_run                 0
# non_boundary              0
# isWicketDelivery          0
# player_out           214803
# kind                 214803
# fielders_involved    217966
# BattingTeam               0
# dtype: int64

# %%
match_data.isna().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
match_data.method.unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
deliveries_data.duplicated().sum()
# Out:
# 0

# %%
match_data.duplicated().sum()
# Out:
# 0

# %%
deliveries_data.describe().T
# Out:
#                      count           mean            std       min       25%  \
# ID                225954.0  832047.003257  337954.245970  335982.0  501262.0
# innings           225954.0       1.483868       0.503104       1.0       1.0
# overs             225954.0       9.185679       5.681797       0.0       4.0
# ballnumber        225954.0       3.619750       1.810633       1.0       2.0
# batsman_run       225954.0       1.243523       1.618166       0.0       0.0
# extras_run        225954.0       0.066907       0.341470       0.0       0.0
# total_run         225954.0       1.310430       1.606050       0.0       0.0
# non_boundary      225954.0       0.000093       0.009640       0.0       0.0
# isWicketDelivery  225954.0       0.049351       0.216600       0.0       0.0
#
#                        50%        75%        max
# ID                829737.0  1178395.0  1312200.0
# innings                1.0        2.0        6.0
# overs                  9.0       14.0       19.0
# ballnumber             4.0        5.0       10.0
# batsman_run            1.0        1.0        6.0
# extras_run             0.0        0.0        7.0
# total_run              1.0        1.0        7.0
# non_boundary           0.0        0.0        1.0
# isWicketDelivery       0.0        0.0        1.0

# %%
deliveries_data.describe(include='object').T
# Out:
#                     count unique             top   freq
# batter             225954    605         V Kohli   5266
# bowler             225954    472        R Ashwin   4024
# non-striker        225954    595        S Dhawan   5526
# extra_type          12049      5           wides   7025
# player_out          11151    573       RG Sharma    194
# kind                11151     10          caught   6837
# fielders_involved    7988    535        MS Dhoni    196
# BattingTeam        225954     18  Mumbai Indians  27826

# %%
match_data.describe().T
# Out:
#         count           mean            std       min        25%       50%  \
# ID      950.0  830485.247368  337567.829494  335982.0  501261.25  829738.0
# Margin  932.0      17.056867      21.633109       1.0       6.00       8.0
#
#                75%        max
# ID      1175371.75  1312200.0
# Margin       19.00      146.0

# %%
match_data.describe(include='object').T
# Out:
#                 count unique  \
# City              899     33
# Date              950    706
# Season            950     15
# MatchNumber       950     80
# Team1             950     18
# Team2             950     18
# Venue             950     49
# TossWinner        950     18
# TossDecision      950      2
# SuperOver         946      2
# WinningTeam       946     18
# WonBy             950      4
# method             19      1
# Player_of_Match   946    262
# Team1Players      950    932
# Team2Players      950    937
# Umpire1           950     58
# Umpire2           950     60
#
#                                                                top freq
# City                                                        Mumbai  159
# Date                                                    2014-05-10    2
# Season                                                        2013   76
# MatchNumber                                                  Final   15
# Team1                                  Royal Challengers Bangalore  126
# Team2                                               Mumbai Indians  119
# Venue                                                 Eden Gardens   77
# TossWinner                                          Mumbai Indians  123
# TossDecision                                                 field  599
# SuperOver                                                        N  932
# WinningTeam                                         Mumbai Indians  131
# WonBy                                                      Wickets  509
# method                                                         D/L   19
# Player_of_Match                                     AB de Villiers   25
# Team1Players     ['RD Gaikwad', 'F du Plessis', 'MM Ali', 'SK R...    2
# Team2Players     ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'SA Y...    2
# Umpire1                                               AK Chaudhary   95
# Umpire2                                                     S Ravi   83

# %%
print('Total Matches Played:',match_data.shape[0])
# Out:
# Total Matches Played: 950

# %%
print('Venues Played At:',match_data['City'].unique())
# Out:
# Venues Played At: ['Ahmedabad' 'Kolkata' 'Mumbai' 'Navi Mumbai' 'Pune' 'Dubai' 'Sharjah'
#  'Abu Dhabi' 'Delhi' 'Chennai' nan 'Hyderabad' 'Visakhapatnam'
#  'Chandigarh' 'Bengaluru' 'Jaipur' 'Indore' 'Bangalore' 'Kanpur' 'Rajkot'
#  'Raipur' 'Ranchi' 'Cuttack' 'Dharamsala' 'Kochi' 'Nagpur' 'Johannesburg'
#  'Centurion' 'Durban' 'Bloemfontein' 'Port Elizabeth' 'Kimberley'
#  'East London' 'Cape Town']

# %%
print('Teams : ',match_data['Team1'].unique())
# Out:
# Teams :  ['Rajasthan Royals' 'Royal Challengers Bangalore' 'Sunrisers Hyderabad'
#  'Delhi Capitals' 'Chennai Super Kings' 'Gujarat Titans'
#  'Lucknow Super Giants' 'Kolkata Knight Riders' 'Punjab Kings'
#  'Mumbai Indians' 'Kings XI Punjab' 'Delhi Daredevils'
#  'Rising Pune Supergiant' 'Gujarat Lions' 'Rising Pune Supergiants'
#  'Pune Warriors' 'Deccan Chargers' 'Kochi Tuskers Kerala']

# %% [markdown]
# ### 1) What is the count of matches played in each season?

# %% [markdown]
# Number of matches played in various seasons :

# %%
match_data['Season'] = pd.DatetimeIndex(match_data['Date']).year
match_data.head()
# Out:
#         ID       City        Date  Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29    2022        Final
# 1  1312199  Ahmedabad  2022-05-27    2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25    2022   Eliminator
# 3  1312197    Kolkata  2022-05-24    2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22    2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
match_data.groupby(['Season'])['ID'].count()
match_data.groupby(['Season'])['ID'].count().reset_index()
match_data.groupby(['Season'])['ID'].count().reset_index().rename(columns={'ID':'Matches'})
# Out:
#     Season  Matches
# 0     2008       58
# 1     2009       57
# 2     2010       60
# 3     2011       73
# 4     2012       74
# 5     2013       76
# 6     2014       60
# 7     2015       59
# 8     2016       60
# 9     2017       59
# 10    2018       60
# 11    2019       60
# 12    2020       60
# 13    2021       60
# 14    2022       74

# %%
match_per_season = match_data.groupby(['Season'])['ID'].count().reset_index().rename(columns={'ID':'matches'})
print(match_per_season)
print(match_per_season.nsmallest(1,'matches'))
print(match_per_season.nlargest(1,'matches'))
# Out:
#     Season  matches
# 0     2008       58
# 1     2009       57
# 2     2010       60
# 3     2011       73
# 4     2012       74
# 5     2013       76
# 6     2014       60
# 7     2015       59
# 8     2016       60
# 9     2017       59
# 10    2018       60
# 11    2019       60
# 12    2020       60
# 13    2021       60
# 14    2022       74
#    Season  matches
# 1    2009       57
#    Season  matches
# 5    2013       76

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x="Season", y="matches", data=match_per_season, palette="rocket_r")
plt.xlabel("Seasons",fontsize=14)
plt.ylabel("matches",fontsize=14)
plt.title("Number of matches played in various seasons ",fontsize= 20, fontweight="bold")
plt.show()

# %% [markdown]
# The number of games played per season is close to 60. But between 2011, 2013 & 2022, we are seaing slite increase in the number of matches. it is because there are now 10 teams, thanks to the addition of two new teams, the Pune Warriors and Kochi Tuskers Kerala.

# %% [markdown]
# ### 2) How many runs were scored in each season?

# %% [markdown]
# Total number of runs scored across seasons

# %%
season_data = match_data[['ID','Season']].merge(deliveries_data, left_on = 'ID', right_on = 'ID', how = 'left').drop('ID', axis = 1)
season_data.head()
# Out:
#    Season  innings  overs  ballnumber       batter          bowler  \
# 0    2022        1      0           1  YBK Jaiswal  Mohammed Shami
# 1    2022        1      0           2  YBK Jaiswal  Mohammed Shami
# 2    2022        1      0           3   JC Buttler  Mohammed Shami
# 3    2022        1      0           4  YBK Jaiswal  Mohammed Shami
# 4    2022        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
season = season_data.groupby(['Season'])['total_run'].sum().reset_index()
print(season)
print(season.nsmallest(1,'total_run'))
print(season.nlargest(1,'total_run'))
# Out:
#     Season  total_run
# 0     2008      17937
# 1     2009      16353
# 2     2010      18883
# 3     2011      21154
# 4     2012      22453
# 5     2013      22602
# 6     2014      18931
# 7     2015      18353
# 8     2016      18862
# 9     2017      18786
# 10    2018      19901
# 11    2019      19434
# 12    2020      19416
# 13    2021      18637
# 14    2022      24395
#    Season  total_run
# 1    2009      16353
#     Season  total_run
# 14    2022      24395

# %% [markdown]
# ### 3) What were the total number of matches played and the total runs scored in each season?

# %%
runs_per_season=pd.concat([match_per_season,season.loc[:,'total_run']],axis=1)
print(runs_per_season)
# Out:
#     Season  matches  total_run
# 0     2008       58      17937
# 1     2009       57      16353
# 2     2010       60      18883
# 3     2011       73      21154
# 4     2012       74      22453
# 5     2013       76      22602
# 6     2014       60      18931
# 7     2015       59      18353
# 8     2016       60      18862
# 9     2017       59      18786
# 10    2018       60      19901
# 11    2019       60      19434
# 12    2020       60      19416
# 13    2021       60      18637
# 14    2022       74      24395

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(runs_per_season['Season'], runs_per_season['total_run'], marker='o', linestyle='-', color='green')
plt.title('Total Runs Scored per Season')
plt.xlabel('Season')
plt.ylabel('Total Runs')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# - IN Season 2022 the highest scoring season is (24,395 runs),
# - IN Season 2009 the lowest scoring season is (16,353 runs).

# %% [markdown]
# # MATCH DATA

# %% [markdown]
# #### 4) Who has umpired the most?

# %% [markdown]
# Count of matches by umpires

# %%
ump=pd.concat([match_data['Umpire1'],match_data['Umpire2']])
ump=ump.value_counts()
umps=ump.to_frame().reset_index()
umps.head(10)
# Out:
#                    index  count
# 0                 S Ravi    131
# 1           AK Chaudhary    111
# 2        HDPK Dharmasena     94
# 3          C Shamshuddin     88
# 4            Nitin Menon     83
# 5            CB Gaffaney     69
# 6              M Erasmus     67
# 7              CK Nandan     59
# 8           BNJ Oxenford     57
# 9  KN Ananthapadmanabhan     56

# %% [markdown]
# S Ravi is  umpired in 131 matches, followed by AK Chaudhary who is umpired in 111 matches.

# %% [markdown]
# #### 5) Which team has won the most tosses?

# %% [markdown]
# Number of tosses won by teams

# %%
match_data.head(1)
# Out:
#         ID       City        Date  Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29    2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
toss=match_data['TossWinner'].value_counts()
toss
# Out:
# TossWinner
# Mumbai Indians                 123
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Sunrisers Hyderabad             74
# Deccan Chargers                 43
# Delhi Capitals                  36
# Pune Warriors                   20
# Gujarat Lions                   15
# Gujarat Titans                  10
# Punjab Kings                     9
# Kochi Tuskers Kerala             8
# Lucknow Super Giants             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
plt.bar(toss.index, toss, color=sns.color_palette('Set1'))
plt.title("No. of tosses won by each team",fontsize=16)
plt.xlabel("Team",fontsize=14)
plt.ylabel("Tosses won",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Mumbai Indians have won the most tosses, followed by Kolkata Knight Riders.

# %% [markdown]
# #### 6) What does the team decide after winning the toss?

# %% [markdown]
# Decision made after winning the toss

# %%
temp_series = match_data.TossDecision.value_counts()
temp_series
# Out:
# TossDecision
# field    599
# bat      351
# Name: count, dtype: int64

# %%
labels = temp_series.index
values = (temp_series / temp_series.sum()) * 100
plt.figure(figsize=(8, 6))
plt.pie(values, labels=labels, autopct='%1.1f%%', textprops={'fontsize': 14}, radius=0.7)
plt.title("Toss decision percentage", fontsize=20)
plt.show()

# %% [markdown]
# After winning the toss, team take to field first

# %% [markdown]
# #### 7) How toss decision varies across seasons?

# %% [markdown]
# Toss decision across seasons

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=match_data, x='Season', hue='TossDecision', multiple='stack')
plt.title("Toss decision in different seasons", fontsize=20)
plt.xlabel("Season", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.show()

# %% [markdown]
# In 2020 most of the teams are choosing field first,
# In 2008,2009 most of the teams are choosing bat first,
# In 2016 to 2018 most of the teams are choosing field first

# %% [markdown]
# #### 8) Does winning the toss implies winning the game?

# %%
match_data['toss_win_game_win'] = np.where((match_data.TossWinner == match_data.WinningTeam),'Yes','No')
match_data.head()
# Out:
#         ID       City        Date  Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29    2022        Final
# 1  1312199  Ahmedabad  2022-05-27    2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25    2022   Eliminator
# 3  1312197    Kolkata  2022-05-24    2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22    2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# 3             Eden Gardens, Kolkata        Gujarat Titans        field  ...
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat  ...
#
#                    WinningTeam    WonBy Margin  method Player_of_Match  \
# 0               Gujarat Titans  Wickets    7.0     NaN       HH Pandya
# 1             Rajasthan Royals  Wickets    7.0     NaN      JC Buttler
# 2  Royal Challengers Bangalore     Runs   14.0     NaN      RM Patidar
# 3               Gujarat Titans  Wickets    7.0     NaN       DA Miller
# 4                 Punjab Kings  Wickets    5.0     NaN   Harpreet Brar
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2 toss_win_game_win
# 0    Nitin Menon                No
# 1    Nitin Menon               Yes
# 2       MA Gough                No
# 3      VK Sharma               Yes
# 4  NA Patwardhan                No
#
# [5 rows x 21 columns]

# %%
match_data.groupby('TossWinner')['toss_win_game_win'].value_counts()
# Out:
# TossWinner                   toss_win_game_win
# Chennai Super Kings          Yes                  68
#                              No                   41
# Deccan Chargers              No                   24
#                              Yes                  19
# Delhi Capitals               Yes                  21
#                              No                   15
# Delhi Daredevils             No                   45
#                              Yes                  35
# Gujarat Lions                Yes                  10
#                              No                    5
# Gujarat Titans               Yes                   7
#                              No                    3
# Kings XI Punjab              No                   49
#                              Yes                  36
# Kochi Tuskers Kerala         No                    4
#                              Yes                   4
# Kolkata Knight Riders        Yes                  64
#                              No                   50
# Lucknow Super Giants         Yes                   4
#                              No                    3
# Mumbai Indians               Yes                  70
#                              No                   53
# Pune Warriors                No                   17
#                              Yes                   3
# Punjab Kings                 No                    5
#                              Yes                   4
# Rajasthan Royals             No                   50
#                              Yes                  49
# Rising Pune Supergiant       Yes                   5
#                              No                    1
# Rising Pune Supergiants      No                    4
#                              Yes                   3
# Royal Challengers Bangalore  Yes                  53
#                              No                   52
# Sunrisers Hyderabad          No                   40
#                              Yes                  34
# Name: count, dtype: int64

# %%
values = match_data["toss_win_game_win"].value_counts()
values
# Out:
# toss_win_game_win
# Yes    489
# No     461
# Name: count, dtype: int64

# %%
labels = ["Yes", "No"]
values = match_data["toss_win_game_win"].value_counts()
plt.figure(figsize=(10, 8))
plt.title("Winning toss implies winning matches?", fontsize=20)
plt.pie(values, labels=labels, autopct="%1.1f%%")
plt.legend(title="Toss win = Game win", loc="best")
plt.show()

# %% [markdown]
# Winning the toss may be beneficial, but it does not always determine the outcome of the game.

# %% [markdown]
# #### 9) How many times chasing team has won the match?

# %% [markdown]
# Match win result

# %%
match_data.head(1)
# Out:
#         ID       City        Date  Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29    2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision  ...     WinningTeam    WonBy Margin  method Player_of_Match  \
# 0          bat  ...  Gujarat Titans  Wickets    7.0     NaN       HH Pandya
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney
#
#        Umpire2 toss_win_game_win
# 0  Nitin Menon                No
#
# [1 rows x 21 columns]

# %%
match_data['WonBy'].value_counts()
# Out:
# WonBy
# Wickets      509
# Runs         423
# SuperOver     14
# NoResults      4
# Name: count, dtype: int64

# %% [markdown]
# #### 10) Which team has won the tournament the most number of times?

# %% [markdown]
# Number of times team have won the tournament

# %%
winners_of_IPL = match_data.groupby('Season').agg({'WinningTeam': 'first'})
winners_of_IPL
# Out:
#                   WinningTeam
# Season
# 2008         Rajasthan Royals
# 2009          Deccan Chargers
# 2010      Chennai Super Kings
# 2011      Chennai Super Kings
# 2012    Kolkata Knight Riders
# 2013           Mumbai Indians
# 2014    Kolkata Knight Riders
# 2015           Mumbai Indians
# 2016      Sunrisers Hyderabad
# 2017           Mumbai Indians
# 2018      Chennai Super Kings
# 2019           Mumbai Indians
# 2020           Mumbai Indians
# 2021      Chennai Super Kings
# 2022           Gujarat Titans

# %%
winners_of_IPL.value_counts()
# Out:
# WinningTeam
# Mumbai Indians           5
# Chennai Super Kings      4
# Kolkata Knight Riders    2
# Deccan Chargers          1
# Gujarat Titans           1
# Rajasthan Royals         1
# Sunrisers Hyderabad      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=winners_of_IPL['WinningTeam'].value_counts().index, y=winners_of_IPL['WinningTeam'].value_counts(), palette='Set2')
plt.title("Winners of IPL", fontsize=26)
plt.xlabel("Team Name",fontsize=14)
plt.ylabel("Count",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  Mumbai Indians had won the IPL 5 times while Chennai Super Kings had won it 4 times.

# %% [markdown]
# #### 11) Which team has played the most number of matches?

# %%
teams = pd.concat([match_data['Team1'], match_data['Team2']]).value_counts().reset_index()
teams.columns = ['Team Name', 'Total Matches played']
teams.style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_6e958_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_6e958_row1_col1 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_6e958_row2_col1 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_6e958_row3_col1 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_6e958_row4_col1 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_6e958_row5_col1 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_6e958_row6_col1 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_6e958_row7_col1 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_6e958_row8_col1 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_6e958_row9_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_6e958_row10_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_6e958_row11_col1 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_6e958_row12_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_6e958_row13_col1, #T_6e958_row14_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_6e958_row15_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_6e958_row16_col1, #T_6e958_row17_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_6e958">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e958_level0_col0" class="col_heading level0 col0" >Team Name</th>
#       <th id="T_6e958_level0_col1" class="col_heading level0 col1" >Total Matches played</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e958_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e958_row0_col0" class="data row0 col0" >Mumbai Indians</td>
#       <td id="T_6e958_row0_col1" class="data row0 col1" >231</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e958_row1_col0" class="data row1 col0" >Royal Challengers Bangalore</td>
#       <td id="T_6e958_row1_col1" class="data row1 col1" >226</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6e958_row2_col0" class="data row2 col0" >Kolkata Knight Riders</td>
#       <td id="T_6e958_row2_col1" class="data row2 col1" >223</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6e958_row3_col0" class="data row3 col0" >Chennai Super Kings</td>
#       <td id="T_6e958_row3_col1" class="data row3 col1" >208</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6e958_row4_col0" class="data row4 col0" >Rajasthan Royals</td>
#       <td id="T_6e958_row4_col1" class="data row4 col1" >192</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6e958_row5_col0" class="data row5 col0" >Kings XI Punjab</td>
#       <td id="T_6e958_row5_col1" class="data row5 col1" >190</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6e958_row6_col0" class="data row6 col0" >Delhi Daredevils</td>
#       <td id="T_6e958_row6_col1" class="data row6 col1" >161</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6e958_row7_col0" class="data row7 col0" >Sunrisers Hyderabad</td>
#       <td id="T_6e958_row7_col1" class="data row7 col1" >152</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6e958_row8_col0" class="data row8 col0" >Deccan Chargers</td>
#       <td id="T_6e958_row8_col1" class="data row8 col1" >75</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6e958_row9_col0" class="data row9 col0" >Delhi Capitals</td>
#       <td id="T_6e958_row9_col1" class="data row9 col1" >63</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6e958_row10_col0" class="data row10 col0" >Pune Warriors</td>
#       <td id="T_6e958_row10_col1" class="data row10 col1" >46</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6e958_row11_col0" class="data row11 col0" >Gujarat Lions</td>
#       <td id="T_6e958_row11_col1" class="data row11 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6e958_row12_col0" class="data row12 col0" >Punjab Kings</td>
#       <td id="T_6e958_row12_col1" class="data row12 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6e958_row13_col0" class="data row13 col0" >Gujarat Titans</td>
#       <td id="T_6e958_row13_col1" class="data row13 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6e958_row14_col0" class="data row14 col0" >Rising Pune Supergiant</td>
#       <td id="T_6e958_row14_col1" class="data row14 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6e958_row15_col0" class="data row15 col0" >Lucknow Super Giants</td>
#       <td id="T_6e958_row15_col1" class="data row15 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6e958_row16_col0" class="data row16 col0" >Rising Pune Supergiants</td>
#       <td id="T_6e958_row16_col1" class="data row16 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_6e958_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6e958_row17_col0" class="data row17 col0" >Kochi Tuskers Kerala</td>
#       <td id="T_6e958_row17_col1" class="data row17 col1" >14</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.subplots(figsize=(10,6))
sns.barplot(x="Team Name", y="Total Matches played", data=teams.sort_values(by='Total Matches played', ascending=False), palette='Set1')
plt.title("Total number of matches played", fontsize=26)
plt.xlabel("Team Name",fontsize=14)
plt.ylabel("Count",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Mumbai Indians have played the most matches(231), followed by Royal Challengers Bangalore (226)

# %% [markdown]
# #### 12) Which team has won the most number of times?

# %%
wins=pd.DataFrame(match_data['WinningTeam'].value_counts()).reset_index()
wins.columns=['Team Name','Wins']
wins.style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_5e2b1_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5e2b1_row1_col1 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_5e2b1_row2_col1 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_5e2b1_row3_col1 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_5e2b1_row4_col1 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_5e2b1_row5_col1 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_5e2b1_row6_col1 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_5e2b1_row7_col1 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_5e2b1_row8_col1 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_5e2b1_row9_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_5e2b1_row10_col1, #T_5e2b1_row11_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_5e2b1_row12_col1, #T_5e2b1_row13_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_5e2b1_row14_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_5e2b1_row15_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_5e2b1_row16_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_5e2b1_row17_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_5e2b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e2b1_level0_col0" class="col_heading level0 col0" >Team Name</th>
#       <th id="T_5e2b1_level0_col1" class="col_heading level0 col1" >Wins</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e2b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e2b1_row0_col0" class="data row0 col0" >Mumbai Indians</td>
#       <td id="T_5e2b1_row0_col1" class="data row0 col1" >131</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e2b1_row1_col0" class="data row1 col0" >Chennai Super Kings</td>
#       <td id="T_5e2b1_row1_col1" class="data row1 col1" >121</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5e2b1_row2_col0" class="data row2 col0" >Kolkata Knight Riders</td>
#       <td id="T_5e2b1_row2_col1" class="data row2 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5e2b1_row3_col0" class="data row3 col0" >Royal Challengers Bangalore</td>
#       <td id="T_5e2b1_row3_col1" class="data row3 col1" >109</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5e2b1_row4_col0" class="data row4 col0" >Rajasthan Royals</td>
#       <td id="T_5e2b1_row4_col1" class="data row4 col1" >96</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5e2b1_row5_col0" class="data row5 col0" >Kings XI Punjab</td>
#       <td id="T_5e2b1_row5_col1" class="data row5 col1" >88</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5e2b1_row6_col0" class="data row6 col0" >Sunrisers Hyderabad</td>
#       <td id="T_5e2b1_row6_col1" class="data row6 col1" >75</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5e2b1_row7_col0" class="data row7 col0" >Delhi Daredevils</td>
#       <td id="T_5e2b1_row7_col1" class="data row7 col1" >67</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5e2b1_row8_col0" class="data row8 col0" >Delhi Capitals</td>
#       <td id="T_5e2b1_row8_col1" class="data row8 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5e2b1_row9_col0" class="data row9 col0" >Deccan Chargers</td>
#       <td id="T_5e2b1_row9_col1" class="data row9 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5e2b1_row10_col0" class="data row10 col0" >Gujarat Lions</td>
#       <td id="T_5e2b1_row10_col1" class="data row10 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5e2b1_row11_col0" class="data row11 col0" >Punjab Kings</td>
#       <td id="T_5e2b1_row11_col1" class="data row11 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5e2b1_row12_col0" class="data row12 col0" >Pune Warriors</td>
#       <td id="T_5e2b1_row12_col1" class="data row12 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5e2b1_row13_col0" class="data row13 col0" >Gujarat Titans</td>
#       <td id="T_5e2b1_row13_col1" class="data row13 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5e2b1_row14_col0" class="data row14 col0" >Rising Pune Supergiant</td>
#       <td id="T_5e2b1_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5e2b1_row15_col0" class="data row15 col0" >Lucknow Super Giants</td>
#       <td id="T_5e2b1_row15_col1" class="data row15 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5e2b1_row16_col0" class="data row16 col0" >Kochi Tuskers Kerala</td>
#       <td id="T_5e2b1_row16_col1" class="data row16 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_5e2b1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5e2b1_row17_col0" class="data row17 col0" >Rising Pune Supergiants</td>
#       <td id="T_5e2b1_row17_col1" class="data row17 col1" >5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Most number of wins

# %%
plt.subplots(figsize=(10,6))
sns.barplot(x="Team Name", y="Wins", data=wins.sort_values(by='Wins', ascending=False), palette='Set2')
plt.title("Total Win by teams", fontsize=26)
plt.xlabel("Team Name",fontsize=14)
plt.ylabel("Count",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Mumbai Indians had won the most matches(131), followed by Chennai Super Kings (121)

# %% [markdown]
# #### 13) Which team has the highest winning percentage?

# %%
played=teams.merge(wins,left_on='Team Name',right_on='Team Name',how='inner')
played['% Win']=(played['Wins']/played['Total Matches played'])*100 # total win / no of played match * 100
played.sort_values(by=['% Win'],ascending=False).reset_index().drop('index',axis=1).style.background_gradient(cmap='PuBu',subset=['% Win'])
# Out:
# <style type="text/css">
# #T_ab44f_row0_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ab44f_row1_col3 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_ab44f_row2_col3 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_ab44f_row3_col3 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_ab44f_row4_col3 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_ab44f_row5_col3 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_ab44f_row6_col3 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_ab44f_row7_col3 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_ab44f_row8_col3 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_ab44f_row9_col3 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_ab44f_row10_col3 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_ab44f_row11_col3 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_ab44f_row12_col3 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_ab44f_row13_col3 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_ab44f_row14_col3 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_ab44f_row15_col3 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_ab44f_row16_col3 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_ab44f_row17_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_ab44f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab44f_level0_col0" class="col_heading level0 col0" >Team Name</th>
#       <th id="T_ab44f_level0_col1" class="col_heading level0 col1" >Total Matches played</th>
#       <th id="T_ab44f_level0_col2" class="col_heading level0 col2" >Wins</th>
#       <th id="T_ab44f_level0_col3" class="col_heading level0 col3" >% Win</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab44f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ab44f_row0_col0" class="data row0 col0" >Gujarat Titans</td>
#       <td id="T_ab44f_row0_col1" class="data row0 col1" >16</td>
#       <td id="T_ab44f_row0_col2" class="data row0 col2" >12</td>
#       <td id="T_ab44f_row0_col3" class="data row0 col3" >75.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ab44f_row1_col0" class="data row1 col0" >Rising Pune Supergiant</td>
#       <td id="T_ab44f_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_ab44f_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_ab44f_row1_col3" class="data row1 col3" >62.500000</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ab44f_row2_col0" class="data row2 col0" >Lucknow Super Giants</td>
#       <td id="T_ab44f_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_ab44f_row2_col2" class="data row2 col2" >9</td>
#       <td id="T_ab44f_row2_col3" class="data row2 col3" >60.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ab44f_row3_col0" class="data row3 col0" >Chennai Super Kings</td>
#       <td id="T_ab44f_row3_col1" class="data row3 col1" >208</td>
#       <td id="T_ab44f_row3_col2" class="data row3 col2" >121</td>
#       <td id="T_ab44f_row3_col3" class="data row3 col3" >58.173077</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ab44f_row4_col0" class="data row4 col0" >Delhi Capitals</td>
#       <td id="T_ab44f_row4_col1" class="data row4 col1" >63</td>
#       <td id="T_ab44f_row4_col2" class="data row4 col2" >36</td>
#       <td id="T_ab44f_row4_col3" class="data row4 col3" >57.142857</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ab44f_row5_col0" class="data row5 col0" >Mumbai Indians</td>
#       <td id="T_ab44f_row5_col1" class="data row5 col1" >231</td>
#       <td id="T_ab44f_row5_col2" class="data row5 col2" >131</td>
#       <td id="T_ab44f_row5_col3" class="data row5 col3" >56.709957</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ab44f_row6_col0" class="data row6 col0" >Kolkata Knight Riders</td>
#       <td id="T_ab44f_row6_col1" class="data row6 col1" >223</td>
#       <td id="T_ab44f_row6_col2" class="data row6 col2" >114</td>
#       <td id="T_ab44f_row6_col3" class="data row6 col3" >51.121076</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ab44f_row7_col0" class="data row7 col0" >Rajasthan Royals</td>
#       <td id="T_ab44f_row7_col1" class="data row7 col1" >192</td>
#       <td id="T_ab44f_row7_col2" class="data row7 col2" >96</td>
#       <td id="T_ab44f_row7_col3" class="data row7 col3" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ab44f_row8_col0" class="data row8 col0" >Sunrisers Hyderabad</td>
#       <td id="T_ab44f_row8_col1" class="data row8 col1" >152</td>
#       <td id="T_ab44f_row8_col2" class="data row8 col2" >75</td>
#       <td id="T_ab44f_row8_col3" class="data row8 col3" >49.342105</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ab44f_row9_col0" class="data row9 col0" >Royal Challengers Bangalore</td>
#       <td id="T_ab44f_row9_col1" class="data row9 col1" >226</td>
#       <td id="T_ab44f_row9_col2" class="data row9 col2" >109</td>
#       <td id="T_ab44f_row9_col3" class="data row9 col3" >48.230088</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ab44f_row10_col0" class="data row10 col0" >Punjab Kings</td>
#       <td id="T_ab44f_row10_col1" class="data row10 col1" >28</td>
#       <td id="T_ab44f_row10_col2" class="data row10 col2" >13</td>
#       <td id="T_ab44f_row10_col3" class="data row10 col3" >46.428571</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ab44f_row11_col0" class="data row11 col0" >Kings XI Punjab</td>
#       <td id="T_ab44f_row11_col1" class="data row11 col1" >190</td>
#       <td id="T_ab44f_row11_col2" class="data row11 col2" >88</td>
#       <td id="T_ab44f_row11_col3" class="data row11 col3" >46.315789</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ab44f_row12_col0" class="data row12 col0" >Gujarat Lions</td>
#       <td id="T_ab44f_row12_col1" class="data row12 col1" >30</td>
#       <td id="T_ab44f_row12_col2" class="data row12 col2" >13</td>
#       <td id="T_ab44f_row12_col3" class="data row12 col3" >43.333333</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ab44f_row13_col0" class="data row13 col0" >Kochi Tuskers Kerala</td>
#       <td id="T_ab44f_row13_col1" class="data row13 col1" >14</td>
#       <td id="T_ab44f_row13_col2" class="data row13 col2" >6</td>
#       <td id="T_ab44f_row13_col3" class="data row13 col3" >42.857143</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ab44f_row14_col0" class="data row14 col0" >Delhi Daredevils</td>
#       <td id="T_ab44f_row14_col1" class="data row14 col1" >161</td>
#       <td id="T_ab44f_row14_col2" class="data row14 col2" >67</td>
#       <td id="T_ab44f_row14_col3" class="data row14 col3" >41.614907</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ab44f_row15_col0" class="data row15 col0" >Deccan Chargers</td>
#       <td id="T_ab44f_row15_col1" class="data row15 col1" >75</td>
#       <td id="T_ab44f_row15_col2" class="data row15 col2" >29</td>
#       <td id="T_ab44f_row15_col3" class="data row15 col3" >38.666667</td>
#     </tr>
#     <tr>
#       <th id="T_ab44f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ab44f_row16_col0" class="data row16 col0" >Rising

# %% [markdown]
# Win % by teams

# %%
plt.subplots(figsize=(10,6))
sns.barplot(x='Team Name', y='% Win',data=played.sort_values(by='% Win', ascending=False), palette='Set3' )
plt.title("Win % by teams", fontsize=26)
plt.xlabel("Team Name",fontsize=14)
plt.ylabel("Count",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The Gujarat Titans have the highest win % of 75.00

# %% [markdown]
# #### 14) Is there any lucky venue for a particular team?

# %% [markdown]
# Lucky Venues for a team

# %%
def lucky(match_data,team_name):
    return match_data[match_data['WinningTeam']==team_name]['Venue'].value_counts().nlargest(10)

# %%
mi = lucky(match_data, 'Royal Challengers Bangalore')
mi
# Out:
# Venue
# M Chinnaswamy Stadium                       29
# Dubai International Cricket Stadium          8
# M.Chinnaswamy Stadium                        8
# Feroz Shah Kotla                             5
# Wankhede Stadium, Mumbai                     5
# Eden Gardens                                 4
# New Wanderers Stadium                        3
# Sharjah Cricket Stadium                      3
# Kingsmead                                    3
# MA Chidambaram Stadium, Chepauk, Chennai     3
# Name: count, dtype: int64

# %%
mi = lucky(match_data, 'Royal Challengers Bangalore')
values = mi
labels = mi.index
fig, ax = plt.subplots(figsize=(10, 6))
wedges, texts, autotexts = ax.pie(values, labels=labels, autopct='%1.1f%%', pctdistance=0.85,textprops=dict(color="w"), wedgeprops=dict(width=0.6, edgecolor='w'))

for w in wedges:
    w.set_edgecolor('w')
ax.legend(wedges, labels, title="Venues", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
ax.set_title('Wins at different Venues for RCB', fontsize=30)
plt.show()

# %% [markdown]
# #### 15) Which is the biggest win in terms of run margin?

# %%
match_data[match_data['Margin']==match_data['Margin'].max()]
# Out:
#           ID   City        Date  Season MatchNumber             Team1  \
# 329  1082635  Delhi  2017-05-06    2017          45  Delhi Daredevils
#
#               Team2             Venue        TossWinner TossDecision  ...  \
# 329  Mumbai Indians  Feroz Shah Kotla  Delhi Daredevils        field  ...
#
#         WinningTeam WonBy Margin  method Player_of_Match  \
# 329  Mumbai Indians  Runs  146.0     NaN     LMP Simmons
#
#                                           Team1Players  \
# 329  ['SV Samson', 'KK Nair', 'SS Iyer', 'RR Pant',...
#
#                                           Team2Players      Umpire1  \
# 329  ['LMP Simmons', 'PA Patel', 'KA Pollard', 'RG ...  Nitin Menon
#
#        Umpire2 toss_win_game_win
# 329  CK Nandan                No
#
# [1 rows x 21 columns]

# %% [markdown]
# #### 16) What is the count of runs scored from boundaries in each season?

# %% [markdown]
#  Total runs scored from boundaries in each season

# %%
fours_list = deliveries_data[deliveries_data['batsman_run'] == 4].groupby(deliveries_data['ID'].map(match_data.set_index('ID')['Season'])).size()
sixes_list = deliveries_data[deliveries_data['batsman_run'] == 6].groupby(deliveries_data['ID'].map(match_data.set_index('ID')['Season'])).size()

# %%
runs4=np.dot(fours_list,4)
runs6=np.dot(sixes_list,6)

# %%
k = runs4 + runs6
Y = match_data['Season'].unique()
colors = ['turquoise'] * 14
colors[5] = 'crimson'
sns.set_style('whitegrid')
plt.figure(figsize=(12, 8))
sns.barplot(x=Y, y=k, palette=colors)
plt.title('Total number of runs scored from boundaries in each season', fontsize=22)
plt.xlabel('Season', fontsize=16)
plt.ylabel('Total runs', fontsize=16)
plt.show()

# %% [markdown]
# #### 17) Which stadium has hosted the most number of matches?

# %% [markdown]
#  Total count of matches played in differnt stadiums

# %%
match_data['Venue'].value_counts()[:10]
# Out:
# Venue
# Eden Gardens                                  77
# Wankhede Stadium                              73
# M Chinnaswamy Stadium                         65
# Feroz Shah Kotla                              60
# Rajiv Gandhi International Stadium, Uppal     49
# MA Chidambaram Stadium, Chepauk               48
# Sawai Mansingh Stadium                        47
# Dubai International Cricket Stadium           46
# Punjab Cricket Association Stadium, Mohali    35
# Wankhede Stadium, Mumbai                      31
# Name: count, dtype: int64

# %%
sns.barplot(x=match_data['Venue'].value_counts()[:10].index, y=match_data['Venue'].value_counts()[:10], palette='Set1')
plt.title("Matches played at different stadiums", fontsize=20)
plt.xlabel("Venue",fontsize=14)
plt.ylabel("Match count",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Eden Gardens has hosted most number of matches.

# %% [markdown]
# #### 18) Who has won the most MOM awards?

# %% [markdown]
# Man of the Match award

# %%
match_data.Player_of_Match.value_counts()[:10]
# Out:
# Player_of_Match
# AB de Villiers    25
# CH Gayle          22
# DA Warner         18
# RG Sharma         18
# MS Dhoni          17
# YK Pathan         16
# SR Watson         16
# KA Pollard        14
# SK Raina          14
# V Kohli           14
# Name: count, dtype: int64

# %%
sns.barplot(x=match_data.Player_of_Match.value_counts()[:10].index, y=match_data.Player_of_Match.value_counts()[:10], palette='Set3')
plt.title("Top 10 MOM awardee", fontsize=20)
plt.xlabel("Players",fontsize=14)
plt.ylabel("Count",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# AB de Villiers (23) had won the most MOM awards, followed by Chris Gayle (22)

# %% [markdown]
# Total run scored from boundaries is lowest in season 2009 and highest in season 2013.

# %% [markdown]
# # Deliveries Data

# %% [markdown]
# #### 19) Particular Batsmen analysis

# %% [markdown]
# Lets see some stats of highest run scorer of IPL : Virat Kohli

# %%
filt=(deliveries_data['batter']=='V Kohli')
df_kohli=deliveries_data[filt]
df_kohli.head()
# Out:
#           ID  innings  overs  ballnumber   batter    bowler   non-striker  \
# 233  1312199        1      0           1  V Kohli  TA Boult  F du Plessis
# 234  1312199        1      0           2  V Kohli  TA Boult  F du Plessis
# 236  1312199        1      0           4  V Kohli  TA Boult  F du Plessis
# 237  1312199        1      0           5  V Kohli  TA Boult  F du Plessis
# 238  1312199        1      0           6  V Kohli  TA Boult  F du Plessis
#
#     extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 233        NaN            0           0          0             0
# 234        NaN            1           0          1             0
# 236        NaN            0           0          0             0
# 237        NaN            0           0          0             0
# 238        NaN            6           0          6             0
#
#      isWicketDelivery player_out kind fielders_involved  \
# 233                 0        NaN  NaN               NaN
# 234                 0        NaN  NaN               NaN
# 236                 0        NaN  NaN               NaN
# 237                 0        NaN  NaN               NaN
# 238                 0        NaN  NaN               NaN
#
#                      BattingTeam
# 233  Royal Challengers Bangalore
# 234  Royal Challengers Bangalore
# 236  Royal Challengers Bangalore
# 237  Royal Challengers Bangalore
# 238  Royal Challengers Bangalore

# %%
df_kohli['total_run'].sum()
# Out:
# 6876

# %%
# how many sixs
len(df_kohli[df_kohli['batsman_run']==6])
# Out:
# 219

# %%
# Grouping data by innings and summing up the runs
runs_by_position = df_kohli.groupby('innings')['batsman_run'].sum()

print(runs_by_position)
# Out:
# innings
# 1    3554
# 2    3070
# 4      10
# Name: batsman_run, dtype: int64

# %%
# how many fours
len(df_kohli[df_kohli['batsman_run']==4])
# Out:
# 581

# %%
# Get the value counts of runs scored
runs_counts = df_kohli['batsman_run'].value_counts()
print(runs_counts)

# Plotting the pie chart
plt.pie(runs_counts, labels=runs_counts.index, autopct='%1.1f%%')
plt.title('Virat Kohli total runs contribution', fontsize=20)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# batsman_run
# 1    2183
# 0    1886
# 4     581
# 2     378
# 6     219
# 3      19
# Name: count, dtype: int64

# %% [markdown]
#  Interesting fact is that Virat Kohli has scored more runs by taking singles than by hitting 6

# %%
plt.figure(figsize=(10, 6))

values = df_kohli['kind'].value_counts()
colors = ['turquoise', 'crimson', 'lime', 'orange', 'blue', 'green']

plt.pie(values, labels=values.index, colors=colors, autopct='%1.1f%%', pctdistance=0.85,textprops=dict(color="w"), wedgeprops=dict(width=0.6, edgecolor='w'))

plt.title('Dismissal Type', fontsize=30)
plt.legend(title="Dismissal Type", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# #### 20) Innings wise comparison between teams

# %% [markdown]
# Innings wise comparision

# %%
runs=deliveries_data.groupby(['ID','innings','BattingTeam'])[['total_run']].sum().reset_index()
runs.drop('ID',axis=1,inplace=True)
runs.head()
# Out:
#    innings                  BattingTeam  total_run
# 0        1        Kolkata Knight Riders        222
# 1        2  Royal Challengers Bangalore         82
# 2        1          Chennai Super Kings        240
# 3        2              Kings XI Punjab        207
# 4        1             Rajasthan Royals        129

# %%
inning1=runs[runs['innings']==1]
inning2=runs[runs['innings']==2]
inning1
# Out:
#       innings                  BattingTeam  total_run
# 0           1        Kolkata Knight Riders        222
# 2           1          Chennai Super Kings        240
# 4           1             Rajasthan Royals        129
# 6           1               Mumbai Indians        165
# 8           1              Deccan Chargers        110
# ...       ...                          ...        ...
# 1918        1          Sunrisers Hyderabad        157
# 1920        1             Rajasthan Royals        188
# 1922        1  Royal Challengers Bangalore        207
# 1924        1  Royal Challengers Bangalore        157
# 1926        1             Rajasthan Royals        130
#
# [950 rows x 3 columns]

# %% [markdown]
# ## Batting first :

# %%
# Plotting the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='BattingTeam', y='total_run', data=inning1.sort_values(by='total_run', ascending=False), palette='PuBu')
plt.title('Batting First', fontsize=26)
plt.xlabel('Batting Team', fontsize=14)
plt.ylabel('Total Runs', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Royal Challengers Bangalore and Mumbai Indians median value is better than other teams while batting first.
# Royal Challengers Bangalore had scored 250+ in a single match and is the only team to achieve that feat.

# %% [markdown]
# ## Batting second :

# %%
# Plotting the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='BattingTeam', y='total_run', data=inning2.sort_values(by='total_run', ascending=False), palette='dark')
plt.title('Total Runs scored by each Batting Team', fontsize=16)
plt.xlabel('Batting Team', fontsize=14)
plt.ylabel('Total Runs', fontsize=14)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 21) Which batsmen have played the most number of balls?

# %% [markdown]
#  Most balls played by a batsman

# %%
balls_played=deliveries_data.groupby(['batter'])['ballnumber'].count().reset_index()
balls_played.sort_values(by='ballnumber',ascending=False).head(10).style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_a3d93_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a3d93_row1_col1 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_a3d93_row2_col1 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_a3d93_row3_col1 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_a3d93_row4_col1 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_a3d93_row5_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_a3d93_row6_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_a3d93_row7_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_a3d93_row8_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a3d93_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_a3d93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3d93_level0_col0" class="col_heading level0 col0" >batter</th>
#       <th id="T_a3d93_level0_col1" class="col_heading level0 col1" >ballnumber</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3d93_level0_row0" class="row_heading level0 row0" >569</th>
#       <td id="T_a3d93_row0_col0" class="data row0 col0" >V Kohli</td>
#       <td id="T_a3d93_row0_col1" class="data row0 col1" >5266</td>
#     </tr>
#     <tr>
#       <th id="T_a3d93_level0_row1" class="row_heading level0 row1" >462</th>
#       <td id="T_a3d93_row1_col0" class="data row1 col0" >S Dhawan</td>
#       <td id="T_a3d93_row1_col1" class="data row1 col1" >5083</td>
#     </tr>
#     <tr>
#       <th id="T_a3d93_level0_row2" class="row_heading level0 row2" >430</th>
#       <td id="T_a3d93_row2_col0" class="data row2 col0" >RG Sharma</td>
#       <td id="T_a3d93_row2_col1" class="data row2 col1" >4632</td>
#     </tr>
#     <tr>
#       <th id="T_a3d93_level0_row3" class="row_heading level0 row3" >130</th>
#       <td id="T_a3d93_row3_col0" class="data row3 col0" >DA Warner</td>
#       <td id="T_a3d93_row3_col1" class="data row3 col1" >4313</td>
#     </tr>
#     <tr>
#       <th id="T_a3d93_level0_row4" class="row_heading level0 row4" >493</th>
#       <td id="T_a3d93_row4_col0" class="data row4 col0" >SK Raina</td>
#       <td id="T_a3d93_row4_col1" class="data row4 col1" >4177</td>
#     </tr>
#     <tr>
#       <th id="T_a3d93_level0_row5" class="row_heading level0 row5" >452</th>
#       <td id="T_a3d93_row5_col0" class="data row5 col0" >RV Uthappa</td>
#       <td id="T_a3d93_row5_col1" class="data row5 col1" >3927</td>
#     </tr>
#     <tr>
#       <th id="T_a3d93_level0_row6" class="row_heading level0 row6" >339</th>
#       <td id="T_a3d93_row6_col0" class="data row6 col0" >MS Dhoni</td>
#       <td id="T_a3d93_row6_col1" class="data row6 col1" >3802</td>
#     </tr>
#     <tr>
#       <th id="T_a3d93_level0_row7" class="row_heading level0 row7" >174</th>
#       <td id="T_a3d93_row7_col0" class="data row7 col0" >G Gambhir</td>
#       <td id="T_a3d93_row7_col1" class="data row7 col1" >3524</td>
#     </tr>
#     <tr>
#       <th id="T_a3d93_level0_row8" class="row_heading level0 row8" >108</th>
#       <td id="T_a3d93_row8_col0" class="data row8 col0" >CH Gayle</td>
#       <td id="T_a3d93_row8_col1" class="data row8 col1" >3516</td>
#     </tr>
#     <tr>
#       <th id="T_a3d93_level0_row9" class="row_heading level0 row9" >27</th>
#       <td id="T_a3d93_row9_col0" class="data row9 col0" >AB de Villiers</td>
#       <td id="T_a3d93_row9_col1" class="data row9 col1" >3487</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Virat kohli had played the most balls.
# David Warner and Chris Gayle are the only two foreign players in this top 10 list.

# %% [markdown]
# #### 22) Who are the leading run-scorers of all time?

# %%
runs=deliveries_data.groupby(['batter'])['batsman_run'].sum().reset_index()
runs.columns=['Batsman','runs']
y=runs.sort_values(by='runs',ascending=False).head(10).reset_index().drop('index',axis=1)
y.style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_11927_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_11927_row1_col1 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_11927_row2_col1, #T_11927_row3_col1 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_11927_row4_col1 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_11927_row5_col1 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_11927_row6_col1 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_11927_row7_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_11927_row8_col1 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_11927_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_11927">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11927_level0_col0" class="col_heading level0 col0" >Batsman</th>
#       <th id="T_11927_level0_col1" class="col_heading level0 col1" >runs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11927_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11927_row0_col0" class="data row0 col0" >V Kohli</td>
#       <td id="T_11927_row0_col1" class="data row0 col1" >6634</td>
#     </tr>
#     <tr>
#       <th id="T_11927_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11927_row1_col0" class="data row1 col0" >S Dhawan</td>
#       <td id="T_11927_row1_col1" class="data row1 col1" >6244</td>
#     </tr>
#     <tr>
#       <th id="T_11927_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_11927_row2_col0" class="data row2 col0" >DA Warner</td>
#       <td id="T_11927_row2_col1" class="data row2 col1" >5883</td>
#     </tr>
#     <tr>
#       <th id="T_11927_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_11927_row3_col0" class="data row3 col0" >RG Sharma</td>
#       <td id="T_11927_row3_col1" class="data row3 col1" >5881</td>
#     </tr>
#     <tr>
#       <th id="T_11927_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_11927_row4_col0" class="data row4 col0" >SK Raina</td>
#       <td id="T_11927_row4_col1" class="data row4 col1" >5536</td>
#     </tr>
#     <tr>
#       <th id="T_11927_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_11927_row5_col0" class="data row5 col0" >AB de Villiers</td>
#       <td id="T_11927_row5_col1" class="data row5 col1" >5181</td>
#     </tr>
#     <tr>
#       <th id="T_11927_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_11927_row6_col0" class="data row6 col0" >CH Gayle</td>
#       <td id="T_11927_row6_col1" class="data row6 col1" >4997</td>
#     </tr>
#     <tr>
#       <th id="T_11927_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_11927_row7_col0" class="data row7 col0" >MS Dhoni</td>
#       <td id="T_11927_row7_col1" class="data row7 col1" >4978</td>
#     </tr>
#     <tr>
#       <th id="T_11927_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_11927_row8_col0" class="data row8 col0" >RV Uthappa</td>
#       <td id="T_11927_row8_col1" class="data row8 col1" >4954</td>
#     </tr>
#     <tr>
#       <th id="T_11927_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_11927_row9_col0" class="data row9 col0" >KD Karthik</td>
#       <td id="T_11927_row9_col1" class="data row9 col1" >4377</td>
#     </tr>
#   </tbody>
# </table>

# %%
colors = sns.color_palette("pastel")[:13]
colors[0] = "crimson"
sns.barplot(x=y['Batsman'][:10], y=y['runs'][:10], palette=colors)
plt.title("Top 10 leading run-scorers", fontsize=20)
plt.xlabel("Player",fontsize=14)
plt.ylabel("Total Runs",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Virat Kohli is the leading run scorer in IPL.
# One interesting thing to notice that MS Dhoni is the only player in this list who bats down the order.

# %% [markdown]
# #### 23) Who has hit the most number of 4's?

# %% [markdown]
# Most number of 4's

# %%
balls_played=balls_played.merge(runs,left_on='batter',right_on='Batsman',how='outer')
four=deliveries_data[deliveries_data['batsman_run']==4]
runs_4=four.groupby('batter')['batsman_run'].count().reset_index()
runs_4.columns=['Batsman','4s']
runs_4.sort_values(by='4s',ascending=False).head(10).reset_index().drop('index',axis=1).style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_44a64_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_44a64_row1_col1 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_44a64_row2_col1 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_44a64_row3_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_44a64_row4_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_44a64_row5_col1 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_44a64_row6_col1 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_44a64_row7_col1 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_44a64_row8_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_44a64_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_44a64">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44a64_level0_col0" class="col_heading level0 col0" >Batsman</th>
#       <th id="T_44a64_level0_col1" class="col_heading level0 col1" >4s</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44a64_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44a64_row0_col0" class="data row0 col0" >S Dhawan</td>
#       <td id="T_44a64_row0_col1" class="data row0 col1" >701</td>
#     </tr>
#     <tr>
#       <th id="T_44a64_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44a64_row1_col0" class="data row1 col0" >V Kohli</td>
#       <td id="T_44a64_row1_col1" class="data row1 col1" >581</td>
#     </tr>
#     <tr>
#       <th id="T_44a64_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_44a64_row2_col0" class="data row2 col0" >DA Warner</td>
#       <td id="T_44a64_row2_col1" class="data row2 col1" >577</td>
#     </tr>
#     <tr>
#       <th id="T_44a64_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_44a64_row3_col0" class="data row3 col0" >RG Sharma</td>
#       <td id="T_44a64_row3_col1" class="data row3 col1" >519</td>
#     </tr>
#     <tr>
#       <th id="T_44a64_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_44a64_row4_col0" class="data row4 col0" >SK Raina</td>
#       <td id="T_44a64_row4_col1" class="data row4 col1" >506</td>
#     </tr>
#     <tr>
#       <th id="T_44a64_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_44a64_row5_col0" class="data row5 col0" >G Gambhir</td>
#       <td id="T_44a64_row5_col1" class="data row5 col1" >492</td>
#     </tr>
#     <tr>
#       <th id="T_44a64_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_44a64_row6_col0" class="data row6 col0" >RV Uthappa</td>
#       <td id="T_44a64_row6_col1" class="data row6 col1" >481</td>
#     </tr>
#     <tr>
#       <th id="T_44a64_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_44a64_row7_col0" class="data row7 col0" >AM Rahane</td>
#       <td id="T_44a64_row7_col1" class="data row7 col1" >431</td>
#     </tr>
#     <tr>
#       <th id="T_44a64_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_44a64_row8_col0" class="data row8 col0" >KD Karthik</td>
#       <td id="T_44a64_row8_col1" class="data row8 col1" >426</td>
#     </tr>
#     <tr>
#       <th id="T_44a64_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_44a64_row9_col0" class="data row9 col0" >AB de Villiers</td>
#       <td id="T_44a64_row9_col1" class="data row9 col1" >414</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#  Shikhar Dhawan holds the record for most number of 4's

# %% [markdown]
# #### 24) Who has hit the most number of 6's?

# %% [markdown]
# Most number of 6's

# %%
six=deliveries_data.groupby('batter')['batsman_run'].agg(lambda x: (x==6).sum()).reset_index()
six.columns=['Batsman','6s']
six.sort_values(by='6s',ascending=False).head(10).reset_index().drop('index',axis=1).style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_e19ca_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e19ca_row1_col1 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_e19ca_row2_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_e19ca_row3_col1 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_e19ca_row4_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_e19ca_row5_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_e19ca_row6_col1 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_e19ca_row7_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_e19ca_row8_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_e19ca_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_e19ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e19ca_level0_col0" class="col_heading level0 col0" >Batsman</th>
#       <th id="T_e19ca_level0_col1" class="col_heading level0 col1" >6s</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e19ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e19ca_row0_col0" class="data row0 col0" >CH Gayle</td>
#       <td id="T_e19ca_row0_col1" class="data row0 col1" >359</td>
#     </tr>
#     <tr>
#       <th id="T_e19ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e19ca_row1_col0" class="data row1 col0" >AB de Villiers</td>
#       <td id="T_e19ca_row1_col1" class="data row1 col1" >253</td>
#     </tr>
#     <tr>
#       <th id="T_e19ca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e19ca_row2_col0" class="data row2 col0" >RG Sharma</td>
#       <td id="T_e19ca_row2_col1" class="data row2 col1" >241</td>
#     </tr>
#     <tr>
#       <th id="T_e19ca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e19ca_row3_col0" class="data row3 col0" >MS Dhoni</td>
#       <td id="T_e19ca_row3_col1" class="data row3 col1" >229</td>
#     </tr>
#     <tr>
#       <th id="T_e19ca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e19ca_row4_col0" class="data row4 col0" >KA Pollard</td>
#       <td id="T_e19ca_row4_col1" class="data row4 col1" >224</td>
#     </tr>
#     <tr>
#       <th id="T_e19ca_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e19ca_row5_col0" class="data row5 col0" >V Kohli</td>
#       <td id="T_e19ca_row5_col1" class="data row5 col1" >219</td>
#     </tr>
#     <tr>
#       <th id="T_e19ca_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e19ca_row6_col0" class="data row6 col0" >DA Warner</td>
#       <td id="T_e19ca_row6_col1" class="data row6 col1" >216</td>
#     </tr>
#     <tr>
#       <th id="T_e19ca_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e19ca_row7_col0" class="data row7 col0" >SK Raina</td>
#       <td id="T_e19ca_row7_col1" class="data row7 col1" >204</td>
#     </tr>
#     <tr>
#       <th id="T_e19ca_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e19ca_row8_col0" class="data row8 col0" >SR Watson</td>
#       <td id="T_e19ca_row8_col1" class="data row8 col1" >190</td>
#     </tr>
#     <tr>
#       <th id="T_e19ca_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e19ca_row9_col0" class="data row9 col0" >RV Uthappa</td>
#       <td id="T_e19ca_row9_col1" class="data row9 col1" >182</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# "The Universe Boss" Chris Gayle had smashed 359 sixes, most by any batsman.

# %% [markdown]
# #### 25) Who has the highest strike rate?

# %%
player=pd.concat([runs,balls_played.iloc[:,1],runs_4.iloc[:,1],six.iloc[:,1]],axis=1)
player['strike_rate']=player['runs']/player['ballnumber']*100
player['4s'].fillna(0,inplace=True)
player.isnull().values.any()
# Out:
# False

# %%
player.sort_values(by='strike_rate',ascending=False).head(10)
# Out:
#            Batsman  runs  ballnumber     4s   6s  strike_rate
# 393      PN Mankad     4           1    1.0    0   400.000000
# 83      B Stanlake     5           2   19.0    0   250.000000
# 567       Umar Gul    39          19    0.0    5   205.263158
# 448       RS Sodhi     4           2  140.0    0   200.000000
# 551       TH David   187          94    0.0   16   198.936170
# 526  Shahid Afridi    81          46    0.0    6   176.086957
# 560   TU Deshpande    21          12    0.0    1   175.000000
# 200     I Malhotra     7           4    1.0    0   175.000000
# 287      LJ Wright   106          63   16.0    3   168.253968
# 36      AD Russell  2039        1212   37.0  175   168.234323

# %%
sr=player[player.ballnumber > 100]
sr.sort_values(by='strike_rate',ascending=False).head(10)
reqsr=sr.drop(columns=['runs','ballnumber','4s','6s'],axis=1)
reqsr.sort_values(by='strike_rate',ascending=False).head(10).style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_c5d44_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c5d44_row1_col1 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_c5d44_row2_col1 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_c5d44_row3_col1 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_c5d44_row4_col1 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_c5d44_row5_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_c5d44_row6_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_c5d44_row7_col1, #T_c5d44_row8_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_c5d44_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_c5d44">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5d44_level0_col0" class="col_heading level0 col0" >Batsman</th>
#       <th id="T_c5d44_level0_col1" class="col_heading level0 col1" >strike_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5d44_level0_row0" class="row_heading level0 row0" >36</th>
#       <td id="T_c5d44_row0_col0" class="data row0 col0" >AD Russell</td>
#       <td id="T_c5d44_row0_col1" class="data row0 col1" >168.234323</td>
#     </tr>
#     <tr>
#       <th id="T_c5d44_level0_row1" class="row_heading level0 row1" >91</th>
#       <td id="T_c5d44_row1_col0" class="data row1 col0" >BCJ Cutting</td>
#       <td id="T_c5d44_row1_col1" class="data row1 col1" >163.013699</td>
#     </tr>
#     <tr>
#       <th id="T_c5d44_level0_row2" class="row_heading level0 row2" >245</th>
#       <td id="T_c5d44_row2_col0" class="data row2 col0" >K Gowtham</td>
#       <td id="T_c5d44_row2_col1" class="data row2 col1" >161.739130</td>
#     </tr>
#     <tr>
#       <th id="T_c5d44_level0_row3" class="row_heading level0 row3" >234</th>
#       <td id="T_c5d44_row3_col0" class="data row3 col0" >JM Sharma</td>
#       <td id="T_c5d44_row3_col1" class="data row3 col1" >157.046980</td>
#     </tr>
#     <tr>
#       <th id="T_c5d44_level0_row4" class="row_heading level0 row4" >292</th>
#       <td id="T_c5d44_row4_col0" class="data row4 col0" >LS Livingstone</td>
#       <td id="T_c5d44_row4_col1" class="data row4 col1" >155.965909</td>
#     </tr>
#     <tr>
#       <th id="T_c5d44_level0_row5" class="row_heading level0 row5" >508</th>
#       <td id="T_c5d44_row5_col0" class="data row5 col0" >SP Narine</td>
#       <td id="T_c5d44_row5_col1" class="data row5 col1" >154.367470</td>
#     </tr>
#     <tr>
#       <th id="T_c5d44_level0_row6" class="row_heading level0 row6" >218</th>
#       <td id="T_c5d44_row6_col0" class="data row6 col0" >JC Archer</td>
#       <td id="T_c5d44_row6_col1" class="data row6 col1" >152.343750</td>
#     </tr>
#     <tr>
#       <th id="T_c5d44_level0_row7" class="row_heading level0 row7" >118</th>
#       <td id="T_c5d44_row7_col0" class="data row7 col0" >CR Brathwaite</td>
#       <td id="T_c5d44_row7_col1" class="data row7 col1" >150.833333</td>
#     </tr>
#     <tr>
#       <th id="T_c5d44_level0_row8" class="row_heading level0 row8" >99</th>
#       <td id="T_c5d44_row8_col0" class="data row8 col0" >Bipul Sharma</td>
#       <td id="T_c5d44_row8_col1" class="data row8 col1" >150.806452</td>
#     </tr>
#     <tr>
#       <th id="T_c5d44_level0_row9" class="row_heading level0 row9" >386</th>
#       <td id="T_c5d44_row9_col0" class="data row9 col0" >PBB Rajapaksa</td>
#       <td id="T_c5d44_row9_col1" class="data row9 col1" >150.364964</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#  Andre Russel has the highest strike rate, followed by K. Gowtham and B. Cutting.

# %% [markdown]
# #### 26) Who is the leading wicket-taker?

# %% [markdown]
# Highest wicket-taker

# %%
dismissal_kinds = ['caught', 'bowled', 'lbw', 'caught and bowled', 'stumped', 'hit wicket']
bowler = deliveries_data[deliveries_data["kind"].isin(dismissal_kinds)]['bowler'].value_counts().head(10)
bowler
# Out:
# bowler
# DJ Bravo           183
# SL Malinga         170
# A Mishra           166
# YS Chahal          166
# R Ashwin           157
# PP Chawla          157
# B Kumar            154
# SP Narine          152
# Harbhajan Singh    150
# JJ Bumrah          148
# Name: count, dtype: int64

# %%
colors = sns.color_palette("pastel")[:13]
colors[0] = "crimson"
sns.barplot(x=bowler[:10].index, y=bowler[:10], palette=colors)
plt.title("Leading wicket-takers", fontsize=26)
plt.xlabel("Bowler",fontsize=14)
plt.ylabel("Total Wickets",fontsize=14
          )
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - DJ Bravo is the leading wicket taker in IPL.
# - 6 out of top 10 are spin bowlers.

# %% [markdown]
# #### 27) What is the count of fours hit in each season?

# %% [markdown]
# Total number of fours in each season

# %%
fours_list = deliveries_data[deliveries_data['batsman_run'] == 4].groupby(deliveries_data['ID'].map(match_data.set_index('ID')['Season'])).size()
sns.barplot(x=fours_list.index, y=fours_list.values, color='turquoise')
plt.title("Total number of Fours in each season", fontsize=20)
plt.xlabel("Season", fontsize=14)
plt.ylabel("Total Fours", fontsize=14)
plt.xticks(rotation=90)
plt.gca().patches[5].set_facecolor('crimson')
plt.show()

# %% [markdown]
#  Highest number of four in a season was is 2013 season while season 2009 had the lowest count of 4's.

# %% [markdown]
# #### 28) What is the count of sixes hit in each season?

# %% [markdown]
# Total number of sixes in each season

# %%
data_6 = match_data['Season'].unique()
sixes_list = deliveries_data[deliveries_data['batsman_run'] == 6].groupby(deliveries_data['ID'].map(match_data.set_index('ID')['Season'])).size()

colors = ['turquoise'] * len(data_6)
colors[-4] = 'crimson'

plt.figure(figsize=(12, 8))
sns.barplot(x=sixes_list.index, y=sixes_list.values, palette=colors)
plt.title('Total number of Sixes in each season', fontsize=20)
plt.xlabel('Season', fontsize=16)
plt.ylabel('Total Sixes', fontsize=16)
plt.show()

# %% [markdown]
#  In season 2022, the maximum number of sixes were hit while the lowest was observed in season 2009.

# %% [markdown]
# #### 29) What is the run contribution from boundaries in each season?

# %% [markdown]
#  Total contribution of runs from boundaries in each season

# %%
totruns=np.array(season['total_run'])
res=(k/totruns)*100

# %%
res
# Out:
# array([58.81697051, 50.95089586, 54.853572  , 54.35378652, 53.63203135,
#        54.42881161, 55.68644023, 57.73443034, 54.95705652, 56.87213883,
#        59.49449776, 58.33076052, 55.48001648, 55.40591297, 59.24164788])

# %%
plt.subplots(figsize=(12, 6))
sns.barplot(x=Y, y=res, palette=['turquoise']*14)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
sns.despine()
plt.title('Total contribution of runs from boundaries in each season', fontsize=22)
plt.xlabel('Season', fontsize=16)
plt.xticks( fontsize=10)
plt.ylabel('Percentage', fontsize=16)
plt.show()

# %% [markdown]
# In season 2022, most runs of the total runs came from boundaries while most runs came from boundaries in season 2021 which is lowest till now.

# %% [markdown]
# #### 30) Which team has scored the most runs in the first 6 overs?

# %% [markdown]
# Total runs scored by teams in first 6 overs

# %%
team = deliveries_data['BattingTeam'].unique()
team_runs = []
for var in team:
    temp_df = deliveries_data[deliveries_data['BattingTeam']==var]
    temp_df = temp_df[temp_df['overs'].isin([0,1,2,3,4,5])]
    runs = temp_df['total_run'].sum()
    team_runs.append(runs)
team = pd.DataFrame(data=team_runs, index=team,columns=['Runs In First 6 Overs'])
#team.sort_values('Runs In First 6 Overs', ascending=False, inplace=True)
team.index.name = 'Team'

colors = ['turquoise',] * 15
colors[6] = 'crimson'

plt.figure(figsize=(10,6))
sns.barplot(x=team.index, y=team['Runs In First 6 Overs'], palette=colors)
plt.title('Total runs scored by teams in their first 6 overs', fontsize=20)
plt.xlabel('Team Name', fontsize=14)
plt.ylabel('Total runs', fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Mumbai Indians had scored the most runs in first 6 overs, followed by Kings XI Punjab.

# %% [markdown]
# #### 31) Which team has scored the most runs in the last 4 overs?

# %% [markdown]
# Total runs scored by teams in last 4 overs

# %%
team1 = deliveries_data['BattingTeam'].unique()
team_runs1 = []
for var in team1:
    temp_df = deliveries_data[deliveries_data['BattingTeam']==var]
    temp_df = temp_df[temp_df['overs'].isin([19,18,17,16])]
    runs1 = temp_df['total_run'].sum()
    team_runs1.append(runs1)
team1 = pd.DataFrame(data=team_runs1, index=team1,columns=['Runs In Last 4 Overs'])
# team.sort_values('Runs In First 6 Overs', ascending=False, inplace=True)
team1.index.name = 'Team'
colors = ['turquoise'] * 15
colors[6] = 'crimson'
sns.barplot(x=team1.index, y=team1['Runs In Last 4 Overs'], palette=colors)
plt.title('Total runs scored by teams in their last 4 overs', fontsize=18)
plt.xlabel('Team Name', fontsize=14)
plt.ylabel('Total runs', fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Mumbai Indians had scored most runs in last 4 overs, followed by Royal Challengers Bangalore.

# %% [markdown]
# #### 32) Which team has the best scoring run-rate in the first 6 overs?

# %% [markdown]
# Highest scoring run-rate in first 6 overs

# %%
played1=played.merge(team,left_on='Team Name',right_on='Team',how='inner')
played3=played1.merge(team1,left_on='Team Name',right_on='Team',how='inner')
mintoover=np.dot(played3['Total Matches played'],6)
mintoover1=np.dot(played3['Total Matches played'],4)
played3['RR in first 6 overs']=(played3['Runs In First 6 Overs']/mintoover)
played3['RR in last 4 overs']=(played3['Runs In Last 4 Overs']/mintoover1)
played3
# Out:
#                       Team Name  Total Matches played  Wins      % Win  \
# 0                Mumbai Indians                   231   131  56.709957
# 1   Royal Challengers Bangalore                   226   109  48.230088
# 2         Kolkata Knight Riders                   223   114  51.121076
# 3           Chennai Super Kings                   208   121  58.173077
# 4              Rajasthan Royals                   192    96  50.000000
# 5               Kings XI Punjab                   190    88  46.315789
# 6              Delhi Daredevils                   161    67  41.614907
# 7           Sunrisers Hyderabad                   152    75  49.342105
# 8               Deccan Chargers                    75    29  38.666667
# 9                Delhi Capitals                    63    36  57.142857
# 10                Pune Warriors                    46    12  26.086957
# 11                Gujarat Lions                    30    13  43.333333
# 12                 Punjab Kings                    28    13  46.428571
# 13               Gujarat Titans                    16    12  75.000000
# 14       Rising Pune Supergiant                    16    10  62.500000
# 15         Lucknow Super Giants                    15     9  60.000000
# 16      Rising Pune Supergiants                    14     5  35.714286
# 17         Kochi Tuskers Kerala                    14     6  42.857143
#
#     Runs In First 6 Overs  Runs In Last 4 Overs  RR in first 6 overs  \
# 0                   10549                  8506             7.611111
# 1                   10142                  7918             7.479351
# 2                   10311                  7091             7.706278
# 3                    9415                  7871             7.544071
# 4                    8663                  6191             7.519965
# 5                    8954                  6227             7.854386
# 6                    7360                  5043             7.619048
# 7                    7199                  5083             7.893640
# 8                    3417                  2539             7.593333
# 9                    3120                  2175             8.253968
# 10                   1895                  1360             6.865942
# 11                   1559                   921             8.661111
# 12                   1368                   905             8.142857
# 13                    740                   648             7.708333
# 14                    785                   555             8.177083
# 15                    670                   643             7.444444
# 16                    638                   443             7.595238
# 17                    680                   337             8.095238
#
#     RR in last 4 overs
# 0             9.205628
# 1             8.758850
# 2             7.949552
# 3             9.460337
# 4             8.061198
# 5             8.193421
# 6             7.830745
# 7             8.360197
# 8             8.463333
# 9             8.630952
# 10            7.391304
# 11            7.675000
# 12            8.080357
# 13           10.125000
# 14            8.671875
# 15           10.716667
# 16            7.910714
# 17            6.017857

# %%
colors = ['turquoise',] * 15
colors[4] = 'crimson'

sns.barplot(x=played3['Team Name'], y=played3['RR in first 6 overs'], palette=colors)
plt.xlabel('Team Name',fontsize=14)
plt.ylabel('Run Rate',fontsize=14)
plt.title('Run Rate in first 6 overs',  fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Gujarat Lions has the highest scoring run-rate in first 6 overs, followed by Delhi Capital.

# %% [markdown]
# #### 33) Which team has the best scoring run-rate in the last 4 overs?

# %% [markdown]
# Highest scoring rate in last 4 overs

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(x=played3['Team Name'], height=played3['RR in last 4 overs'], color=colors)

# set the title and axis labels
ax.set_title('Run Rate in last 4 overs', fontsize=26)
ax.set_xlabel('Team Name',fontsize=14)
ax.set_ylabel('Run Rate',fontsize=14)
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# Lucknow super Giants has the highest scoring run-rate in last 4 overs, followed by Gujrat Titans.

# %% [markdown]
# # END
