# %% [markdown]
# # Detailed Analysis of IPL data (2008-2024)

# %% [markdown]
# The Indian Premier League (IPL) is a professional Twenty20 cricket league in India usually contested between March and May of every year by eight teams representing eight different cities or states in India. The league was founded by the Board of Control for Cricket in India (BCCI) in 2007. The IPL is the most-attended cricket league in the world and the brand value of the IPL in 2019 was ₹475 billion (US$6.7 billion) in 2023 (US$15.4 billion)

# %% [markdown]
# ![ipl-auction-scaled.jpg](attachment:ipl-auction-scaled.jpg)

# %% [markdown]
# #### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ##### Let us import the data sets called IPL Matches 2008-2020 and IPL Ball-by-Ball 2008-2020 into python environment

# %%
deliveries_data = pd.read_csv(r'C:\Users\Admin\Downloads\IPL 2008-2024\deliveries.csv')
match_data=pd.read_csv(r"C:\Users\Admin\Downloads\IPL 2008-2024\matches.csv")
print("Data ready for exploration")
# Out:
# Data ready for exploration

# %% [markdown]
# ##### Basic data exploration

# %%
#looking at the top 5 rows
print('Below are the first 5 rows of the IPL Matches 2008-2020 dataset')
match_data.head()
# Out:
# Below are the first 5 rows of the IPL Matches 2008-2020 dataset
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %%
#match_data[['Team1','Team2', 'TossWinner','WinningTeam']].replace('Rising Pune Supergiant', 'Rising Pune Supergiants')

# %%
match_data['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
#looking at the top 5 rows
print('Below are the first 5 rows of the IPL Ball-by-Ball 2008-2020 dataset')
deliveries_data.tail()
# Out:
# Below are the first 5 rows of the IPL Ball-by-Ball 2008-2020 dataset
#         match_id  inning           batting_team         bowling_team  over  \
# 260915   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     9
# 260916   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     9
# 260917   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
# 260918   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
# 260919   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
#
#         ball   batter         bowler non_striker  batsman_runs  extra_runs  \
# 260915     5  SS Iyer     AK Markram     VR Iyer             1           0
# 260916     6  VR Iyer     AK Markram     SS Iyer             1           0
# 260917     1  VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
# 260918     2  SS Iyer  Shahbaz Ahmed     VR Iyer             1           0
# 260919     3  VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
#
#         total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# 260915           1         NaN          0              NaN            NaN
# 260916           1         NaN          0              NaN            NaN
# 260917           1         NaN          0              NaN            NaN
# 260918           1         NaN          0              NaN            NaN
# 260919           1         NaN          0              NaN            NaN
#
#        fielder
# 260915     NaN
# 260916     NaN
# 260917     NaN
# 260918     NaN
# 260919     NaN

# %%
#looking at bottom 5 rows
print('Below are the bottom 5 rows of the dataset')
match_data.tail()
# Out:
# Below are the bottom 5 rows of the dataset
#            id season       city        date   match_type  player_of_match  \
# 1090  1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311   2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                  team2          toss_winner  \
# 1090                 Punjab Kings    Sunrisers Hyderabad         Punjab Kings
# 1091          Sunrisers Hyderabad  Kolkata Knight Riders  Sunrisers Hyderabad
# 1092  Royal Challengers Bengaluru       Rajasthan Royals     Rajasthan Royals
# 1093          Sunrisers Hyderabad       Rajasthan Royals     Rajasthan Royals
# 1094          Sunrisers Hyderabad  Kolkata Knight Riders  Sunrisers Hyderabad
#
#      toss_decision                 winner   result  result_margin  \
# 1090           bat    Sunrisers Hyderabad  wickets            4.0
# 1091           bat  Kolkata Knight Riders  wickets            8.0
# 1092         field       Rajasthan Royals  wickets            4.0
# 1093         field    Sunrisers Hyderabad     runs           36.0
# 1094           bat  Kolkata Knight Riders  wickets            8.0
#
#       target_runs  target_overs super_over method                umpire1  \
# 1090        215.0          20.0          N    NaN            Nitin Menon
# 1091        160.0          20.0          N    NaN           AK Chaudhary
# 1092        173.0          20.0          N    NaN  KN Ananthapadmanabhan
# 1093        176.0          20.0          N    NaN            Nitin Menon
# 1094        114.0          20.0          N    NaN          J Madanagopal
#
#                    umpire2
# 1090             VK Sharma
# 1091              R Pandit
# 1092  MV Saidharshan Kumar
# 1093             VK Sharma
# 1094           Nitin Menon

# %%
#checking number of rows and columns
print(match_data.shape)
print(deliveries_data.shape)
# Out:
# (1095, 20)
# (260920, 17)

# %%
#checking the which are the columns
match_data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
deliveries_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
#  16  fielder           9354 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.8+ MB

# %%
match_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           21 non-null     object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 171.2+ KB

# %%
deliveries_data.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# is_wicket                0
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# dtype: int64

# %%
match_data.isna().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
match_data.method.unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
deliveries_data.duplicated().sum()
# Out:
# 0

# %%
match_data.duplicated().sum()
# Out:
# 0

# %%
deliveries_data.describe().T
# Out:
#                  count           mean            std       min       25%  \
# match_id      260920.0  907066.506086  367991.278255  335982.0  548334.0
# inning        260920.0       1.483531       0.502643       1.0       1.0
# over          260920.0       9.197677       5.683484       0.0       4.0
# ball          260920.0       3.624486       1.814920       1.0       2.0
# batsman_runs  260920.0       1.265001       1.639298       0.0       0.0
# extra_runs    260920.0       0.067806       0.343265       0.0       0.0
# total_runs    260920.0       1.332807       1.626416       0.0       0.0
# is_wicket     260920.0       0.049632       0.217184       0.0       0.0
#
#                    50%        75%        max
# match_id      980967.0  1254066.0  1426312.0
# inning             1.0        2.0        6.0
# over               9.0       14.0       19.0
# ball               4.0        5.0       11.0
# batsman_runs       1.0        1.0        6.0
# extra_runs         0.0        0.0        7.0
# total_runs         1.0        1.0        7.0
# is_wicket          0.0        0.0        1.0

# %%
deliveries_data.describe(include='object').T
# Out:
#                    count unique             top   freq
# batting_team      260920     19  Mumbai Indians  31437
# bowling_team      260920     19  Mumbai Indians  31505
# batter            260920    673         V Kohli   6236
# bowler            260920    530        R Ashwin   4679
# non_striker       260920    663         V Kohli   6067
# extras_type        14125      5           wides   8380
# player_dismissed   12950    629       RG Sharma    223
# dismissal_kind     12950     10          caught   8063
# fielder             9354    607        MS Dhoni    220

# %%
match_data.describe().T
# Out:
#                 count           mean            std       min       25%  \
# id             1095.0  904828.319635  367740.242299  335982.0  548331.5
# result_margin  1076.0      17.259294      21.787444       1.0       6.0
# target_runs    1092.0     165.684066      33.427048      43.0     146.0
# target_overs   1092.0      19.759341       1.581108       5.0      20.0
#
#                     50%        75%        max
# id             980961.0  1254062.5  1426312.0
# result_margin       8.0       20.0      146.0
# target_runs       166.0      187.0      288.0
# target_overs       20.0       20.0       20.0

# %%
match_data.describe(include='object').T
# Out:
#                 count unique                          top  freq
# season           1095     17                         2013    76
# city             1044     36                       Mumbai   173
# date             1095    823                   2017-04-09     2
# match_type       1095      8                       League  1029
# player_of_match  1090    291               AB de Villiers    25
# venue            1095     58                 Eden Gardens    77
# team1            1095     19  Royal Challengers Bangalore   135
# team2            1095     19               Mumbai Indians   138
# toss_winner      1095     19               Mumbai Indians   143
# toss_decision    1095      2                        field   704
# winner           1090     19               Mumbai Indians   144
# result           1095      4                      wickets   578
# super_over       1095      2                            N  1081
# method             21      1                          D/L    21
# umpire1          1095     62                 AK Chaudhary   115
# umpire2          1095     62                       S Ravi    83

# %% [markdown]
# #### **Data Cleaning**
#
# **Names Manuplualtion**

# %%
deliveries_data['batting_team'].replace({'Rising Pune Supergiant':'Rising Pune Supergiants'}, inplace=True)

# %%
match_data['team1'].replace({'Rising Pune Supergiant':'Rising Pune Supergiants'}, inplace=True)
match_data['team2'].replace({'Rising Pune Supergiant':'Rising Pune Supergiants'}, inplace=True)
match_data['toss_winner'].replace({'Rising Pune Supergiant':'Rising Pune Supergiants'}, inplace=True)
match_data['winner'].replace({'Rising Pune Supergiant':'Rising Pune Supergiants'}, inplace=True)

# %%
match_data['team1'].replace({'Royal Challengers Bangalore':'Royal Challengers Bengaluru'}, inplace=True)
match_data['team2'].replace({'Royal Challengers Bangalore':'Royal Challengers Bengaluru'}, inplace=True)
match_data['toss_winner'].replace({'Royal Challengers Bangalore':'Royal Challengers Bengaluru'}, inplace=True)
match_data['winner'].replace({'Royal Challengers Bangalore':'Royal Challengers Bengaluru'}, inplace=True)

# %%
match_data['venue'].replace({
    'Eden Gardens':'Eden Gardens, Kolkata', 
    'Wankhede Stadium':'Wankhede Stadium, Mumbai',
    'M.Chinnaswamy Stadium':'M Chinnaswamy Stadium',
    'Punjab Cricket Association IS Bindra Stadium':'Punjab Cricket Association IS Bindra Stadium, Mohali',
    'Rajiv Gandhi International Stadium':'Rajiv Gandhi International Stadium, Uppal',
    'Dr DY Patil Sports Academy':'Dr DY Patil Sports Academy, Mumbai',
    'Arun Jaitley Stadium':'Arun Jaitley Stadium, Delhi',
    'Maharashtra Cricket Association Stadium':'Maharashtra Cricket Association Stadium, Pune',
    'MA Chidambaram Stadium':'MA Chidambaram Stadium, Chepauk, Chennai',
    'MA Chidambaram Stadium, Chepauk':'MA Chidambaram Stadium, Chepauk, Chennai',
    'Brabourne Stadium':'Brabourne Stadium, Mumbai',
    }, inplace=True)

# %%
print('Total Matches Played:',match_data.shape[0])
# Out:
# Total Matches Played: 1095

# %%
print('venues Played At:',match_data['city'].unique())
# Out:
# venues Played At: ['Bangalore' 'Chandigarh' 'Delhi' 'Mumbai' 'Kolkata' 'Jaipur' 'Hyderabad'
#  'Chennai' 'Cape Town' 'Port Elizabeth' 'Durban' 'Centurion' 'East London'
#  'Johannesburg' 'Kimberley' 'Bloemfontein' 'Ahmedabad' 'Cuttack' 'Nagpur'
#  'Dharamsala' 'Kochi' 'Indore' 'Visakhapatnam' 'Pune' 'Raipur' 'Ranchi'
#  'Abu Dhabi' nan 'Rajkot' 'Kanpur' 'Bengaluru' 'Dubai' 'Sharjah'
#  'Navi Mumbai' 'Lucknow' 'Guwahati' 'Mohali']

# %%
print('Teams : ',match_data['team1'].unique())
# Out:
# Teams :  ['Royal Challengers Bengaluru' 'Kings XI Punjab' 'Delhi Daredevils'
#  'Mumbai Indians' 'Kolkata Knight Riders' 'Rajasthan Royals'
#  'Deccan Chargers' 'Chennai Super Kings' 'Kochi Tuskers Kerala'
#  'Pune Warriors' 'Sunrisers Hyderabad' 'Gujarat Lions'
#  'Rising Pune Supergiants' 'Delhi Capitals' 'Punjab Kings'
#  'Lucknow Super Giants' 'Gujarat Titans']

# %% [markdown]
# ### 1) What is the count of matches played in each season?

# %% [markdown]
# Number of matches played in various seasons :

# %%
match_data['Season'] = pd.DatetimeIndex(match_data['date']).year
match_data.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                    Wankhede Stadium, Mumbai               Mumbai Indians
# 4                       Eden Gardens, Kolkata        Kolkata Knight Riders
#
#                          team2                  toss_winner  ...  \
# 0        Kolkata Knight Riders  Royal Challengers Bengaluru  ...
# 1          Chennai Super Kings          Chennai Super Kings  ...
# 2             Rajasthan Royals             Rajasthan Royals  ...
# 3  Royal Challengers Bengaluru               Mumbai Indians  ...
# 4              Deccan Chargers              Deccan Chargers  ...
#
#                         winner   result result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs         140.0        223.0
# 1          Chennai Super Kings     runs          33.0        241.0
# 2             Delhi Daredevils  wickets           9.0        130.0
# 3  Royal Challengers Bengaluru  wickets           5.0        166.0
# 4        Kolkata Knight Riders  wickets           5.0        111.0
#
#    target_overs  super_over method    umpire1         umpire2 Season
# 0          20.0           N    NaN  Asad Rauf     RE Koertzen   2008
# 1          20.0           N    NaN  MR Benson      SL Shastri   2008
# 2          20.0           N    NaN  Aleem Dar  GA Pratapkumar   2008
# 3          20.0           N    NaN   SJ Davis       DJ Harper   2008
# 4          20.0           N    NaN  BF Bowden     K Hariharan   2008
#
# [5 rows x 21 columns]

# %%
match_data.groupby(['Season'])['id'].count()
match_data.groupby(['Season'])['id'].count().reset_index()
match_data.groupby(['Season'])['id'].count().reset_index().rename(columns={'id':'Matches'})
# Out:
#     Season  Matches
# 0     2008       58
# 1     2009       57
# 2     2010       60
# 3     2011       73
# 4     2012       74
# 5     2013       76
# 6     2014       60
# 7     2015       59
# 8     2016       60
# 9     2017       59
# 10    2018       60
# 11    2019       60
# 12    2020       60
# 13    2021       60
# 14    2022       74
# 15    2023       74
# 16    2024       71

# %%
match_per_season = match_data.groupby(['Season'])['id'].count().reset_index().rename(columns={'id':'matches'})
print(match_per_season)
print(match_per_season.nsmallest(1,'matches'))
print(match_per_season.nlargest(1,'matches'))
# Out:
#     Season  matches
# 0     2008       58
# 1     2009       57
# 2     2010       60
# 3     2011       73
# 4     2012       74
# 5     2013       76
# 6     2014       60
# 7     2015       59
# 8     2016       60
# 9     2017       59
# 10    2018       60
# 11    2019       60
# 12    2020       60
# 13    2021       60
# 14    2022       74
# 15    2023       74
# 16    2024       71
#    Season  matches
# 1    2009       57
#    Season  matches
# 5    2013       76

# %%
plt.figure(figsize=(9, 6))
sns.barplot(x="Season", y="matches", data=match_per_season, palette="rocket_r")
plt.xlabel("Seasons",fontsize=14)
plt.ylabel("matches",fontsize=14)
plt.title("Number of matches played in various seasons ",fontsize= 20, fontweight="bold")
plt.show()

# %% [markdown]
# The number of games played per season is close to 60. But between 2011, 2013 & 2022, we are seaing slite increase in the number of matches. it is because there are now 10 teams, thanks to the addition of two new teams, the Pune Warriors and Kochi Tuskers Kerala.

# %% [markdown]
# ### 2) How many runs were scored in each season?

# %% [markdown]
# Total number of runs scored across seasons

# %%
season_data = match_data[['id','Season']].merge(deliveries_data, left_on = 'id', right_on = 'match_id', how = 'left').drop(columns=['id','match_id'], axis = 1)
season_data.head()
# Out:
#    Season  inning           batting_team                 bowling_team  over  \
# 0    2008       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    2008       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    2008       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    2008       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    2008       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN
# 4           0         NaN          0              NaN            NaN     NaN

# %%
season = season_data.groupby(['Season'])['total_runs'].sum().reset_index()
print(season)
print(season.nsmallest(1,'total_runs'))
print(season.nlargest(1,'total_runs'))
# Out:
#     Season  total_runs
# 0     2008       17937
# 1     2009       16353
# 2     2010       18883
# 3     2011       21154
# 4     2012       22453
# 5     2013       22602
# 6     2014       18931
# 7     2015       18353
# 8     2016       18862
# 9     2017       18786
# 10    2018       19901
# 11    2019       19434
# 12    2020       19416
# 13    2021       18637
# 14    2022       24395
# 15    2023       25688
# 16    2024       25971
#    Season  total_runs
# 1    2009       16353
#     Season  total_runs
# 16    2024       25971

# %% [markdown]
# ### 3) What were the total number of matches played and the total runs scored in each season?

# %%
runs_per_season=pd.concat([match_per_season,season.loc[:,'total_runs']],axis=1)
print(runs_per_season)
# Out:
#     Season  matches  total_runs
# 0     2008       58       17937
# 1     2009       57       16353
# 2     2010       60       18883
# 3     2011       73       21154
# 4     2012       74       22453
# 5     2013       76       22602
# 6     2014       60       18931
# 7     2015       59       18353
# 8     2016       60       18862
# 9     2017       59       18786
# 10    2018       60       19901
# 11    2019       60       19434
# 12    2020       60       19416
# 13    2021       60       18637
# 14    2022       74       24395
# 15    2023       74       25688
# 16    2024       71       25971

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(runs_per_season['Season'], runs_per_season['total_runs'], marker='o', linestyle='-.', color='green')
plt.xticks([2009,2013, 2024])
plt.title('Total Runs Scored per Season')
plt.xlabel('Season')
plt.ylabel('Total Runs')
#plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
#plt.tight_layout()
plt.show()

# %% [markdown]
# - IN Season 2022 the highest scoring season is (24,395 runs),
# - IN Season 2009 the lowest scoring season is (16,353 runs).

# %% [markdown]
# # MATCH DATA

# %% [markdown]
# #### 4) Who has umpired the most?

# %% [markdown]
# Count of matches by umpires

# %%
ump=pd.concat([match_data['umpire1'],match_data['umpire2']])
ump=ump.value_counts()
umps=ump.to_frame().reset_index()
umps.head(10)
# Out:
#                    index  count
# 0                 S Ravi    131
# 1           AK Chaudhary    131
# 2            Nitin Menon    104
# 3        HDPK Dharmasena     98
# 4          C Shamshuddin     88
# 5            CB Gaffaney     77
# 6  KN Ananthapadmanabhan     72
# 7              M Erasmus     67
# 8              VK Sharma     65
# 9           BNJ Oxenford     64

# %% [markdown]
# S Ravi is  umpired in 131 matches, followed by AK Chaudhary who is umpired in 111 matches.

# %% [markdown]
# #### 5) Which team has won the most tosses?

# %% [markdown]
# Number of tosses won by teams

# %%
match_data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'Season'],
#       dtype='object')

# %%
toss=match_data['toss_winner'].value_counts()
toss
# Out:
# toss_winner
# Mumbai Indians                 143
# Kolkata Knight Riders          122
# Chennai Super Kings            122
# Royal Challengers Bengaluru    121
# Rajasthan Royals               120
# Sunrisers Hyderabad             88
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Delhi Capitals                  50
# Deccan Chargers                 43
# Punjab Kings                    24
# Gujarat Titans                  22
# Pune Warriors                   20
# Lucknow Super Giants            19
# Gujarat Lions                   15
# Rising Pune Supergiants         13
# Kochi Tuskers Kerala             8
# Name: count, dtype: int64

# %%
plt.bar(toss.index, toss, color=sns.color_palette('Set1'))
plt.title("No. of tosses won by each team",fontsize=16)
plt.xlabel("Team",fontsize=14)
plt.ylabel("Tosses won",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Mumbai Indians have won the most tosses, followed by Kolkata Knight Riders.

# %% [markdown]
# #### 6) What does the team decide after winning the toss?

# %% [markdown]
# Decision made after winning the toss

# %%
temp_series = match_data.toss_decision.value_counts()
temp_series
# Out:
# toss_decision
# field    704
# bat      391
# Name: count, dtype: int64

# %%
labels = temp_series.index
values = (temp_series / temp_series.sum()) * 100
plt.figure(figsize=(8, 6))
plt.pie(values, labels=labels, autopct='%1.f%%', textprops={'fontsize': 14}, radius=0.7)
plt.title("Toss decision percentage", fontsize=20)
plt.show()

# %% [markdown]
# After winning the toss, team take to field first

# %% [markdown]
# #### 7) How toss decision varies across seasons?

# %% [markdown]
# Toss decision across seasons

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=match_data, x='Season', hue='toss_decision', multiple='stack')
plt.title("Toss decision in different seasons", fontsize=20)
plt.xlabel("Season", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.show()

# %% [markdown]
# In 2020 most of the teams are choosing field first,
# In 2008,2009 most of the teams are choosing bat first,
# In 2016 to 2018 most of the teams are choosing field first

# %% [markdown]
# #### 8) Does winning the toss implies winning the game?

# %%
match_data['toss_win_game_win'] = np.where((match_data.toss_winner == match_data.winner),'Yes','No')
match_data.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                    Wankhede Stadium, Mumbai               Mumbai Indians
# 4                       Eden Gardens, Kolkata        Kolkata Knight Riders
#
#                          team2                  toss_winner  ...   result  \
# 0        Kolkata Knight Riders  Royal Challengers Bengaluru  ...     runs
# 1          Chennai Super Kings          Chennai Super Kings  ...     runs
# 2             Rajasthan Royals             Rajasthan Royals  ...  wickets
# 3  Royal Challengers Bengaluru               Mumbai Indians  ...  wickets
# 4              Deccan Chargers              Deccan Chargers  ...  wickets
#
#   result_margin target_runs  target_overs  super_over  method    umpire1  \
# 0         140.0       223.0          20.0           N     NaN  Asad Rauf
# 1          33.0       241.0          20.0           N     NaN  MR Benson
# 2           9.0       130.0          20.0           N     NaN  Aleem Dar
# 3           5.0       166.0          20.0           N     NaN   SJ Davis
# 4           5.0       111.0          20.0           N     NaN  BF Bowden
#
#           umpire2 Season toss_win_game_win
# 0     RE Koertzen   2008                No
# 1      SL Shastri   2008               Yes
# 2  GA Pratapkumar   2008                No
# 3       DJ Harper   2008                No
# 4     K Hariharan   2008                No
#
# [5 rows x 22 columns]

# %%
match_data.groupby('toss_winner')['toss_win_game_win'].value_counts()
# Out:
# toss_winner                  toss_win_game_win
# Chennai Super Kings          Yes                  75
#                              No                   47
# Deccan Chargers              No                   24
#                              Yes                  19
# Delhi Capitals               Yes                  26
#                              No                   24
# Delhi Daredevils             No                   45
#                              Yes                  35
# Gujarat Lions                Yes                  10
#                              No                    5
# Gujarat Titans               Yes                  14
#                              No                    8
# Kings XI Punjab              No                   49
#                              Yes                  36
# Kochi Tuskers Kerala         No                    4
#                              Yes                   4
# Kolkata Knight Riders        Yes                  68
#                              No                   54
# Lucknow Super Giants         Yes                  10
#                              No                    9
# Mumbai Indians               Yes                  78
#                              No                   65
# Pune Warriors                No                   17
#                              Yes                   3
# Punjab Kings                 No                   15
#                              Yes                   9
# Rajasthan Royals             No                   60
#                              Yes                  60
# Rising Pune Supergiants      Yes                   8
#                              No                    5
# Royal Challengers Bengaluru  Yes                  61
#                              No                   60
# Sunrisers Hyderabad          No                   50
#                              Yes                  38
# Name: count, dtype: int64

# %%
values = match_data["toss_win_game_win"].value_counts()
values
# Out:
# toss_win_game_win
# Yes    554
# No     541
# Name: count, dtype: int64

# %%
labels = ["Yes", "No"] #values.index
values = match_data["toss_win_game_win"].value_counts()
plt.figure()
plt.title("Winning toss implies winning matches?", fontsize=20)
plt.pie(values, labels=labels, autopct="%1.f%%", colors = ['cyan', 'green'], radius=0.7)
plt.legend(title="Toss win = Game win", loc="best") #right_upper
plt.show()

# %% [markdown]
# Winning the toss may be beneficial, but it does not always determine the outcome of the game.

# %% [markdown]
# #### 9) How many times chasing team has won the match?

# %% [markdown]
# Match win result

# %%
match_data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'Season', 'toss_win_game_win'],
#       dtype='object')

# %%
match_data['method'].value_counts()
# Out:
# method
# D/L    21
# Name: count, dtype: int64

# %% [markdown]
# #### 10) Which team has won the tournament the most number of times?

# %% [markdown]
# Number of times team have won the tournament

# %%
winners_of_IPL = match_data.groupby('Season').agg({'winner': 'last'})
winners_of_IPL
# Out:
#                        winner
# Season
# 2008         Rajasthan Royals
# 2009          Deccan Chargers
# 2010      Chennai Super Kings
# 2011      Chennai Super Kings
# 2012    Kolkata Knight Riders
# 2013           Mumbai Indians
# 2014    Kolkata Knight Riders
# 2015           Mumbai Indians
# 2016      Sunrisers Hyderabad
# 2017           Mumbai Indians
# 2018      Chennai Super Kings
# 2019           Mumbai Indians
# 2020           Mumbai Indians
# 2021      Chennai Super Kings
# 2022           Gujarat Titans
# 2023      Chennai Super Kings
# 2024    Kolkata Knight Riders

# %%
winners_of_IPL.value_counts()
# Out:
# winner
# Chennai Super Kings      5
# Mumbai Indians           5
# Kolkata Knight Riders    3
# Deccan Chargers          1
# Gujarat Titans           1
# Rajasthan Royals         1
# Sunrisers Hyderabad      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=winners_of_IPL['winner'].value_counts().index, y=winners_of_IPL['winner'].value_counts(), palette='Set2')
plt.title("Winners of IPL", fontsize=26)
plt.xlabel("Team Name",fontsize=14)
plt.ylabel("Count",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  Mumbai Indians had won the IPL 5 times while Chennai Super Kings had won it 4 times.

# %% [markdown]
# #### 11) Which team has played the most number of matches?

# %%
teams = pd.concat([match_data['team1'], match_data['team2']]).value_counts().reset_index()
teams.columns = ['Team Name', 'Total Matches played']
teams.style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_d5a8f_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d5a8f_row1_col1 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_d5a8f_row2_col1 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_d5a8f_row3_col1 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_d5a8f_row4_col1 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_d5a8f_row5_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_d5a8f_row6_col1 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_d5a8f_row7_col1 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_d5a8f_row8_col1 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_d5a8f_row9_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_d5a8f_row10_col1 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_d5a8f_row11_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_d5a8f_row12_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_d5a8f_row13_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_d5a8f_row14_col1, #T_d5a8f_row15_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_d5a8f_row16_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_d5a8f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5a8f_level0_col0" class="col_heading level0 col0" >Team Name</th>
#       <th id="T_d5a8f_level0_col1" class="col_heading level0 col1" >Total Matches played</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5a8f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5a8f_row0_col0" class="data row0 col0" >Mumbai Indians</td>
#       <td id="T_d5a8f_row0_col1" class="data row0 col1" >261</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d5a8f_row1_col0" class="data row1 col0" >Royal Challengers Bengaluru</td>
#       <td id="T_d5a8f_row1_col1" class="data row1 col1" >255</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d5a8f_row2_col0" class="data row2 col0" >Kolkata Knight Riders</td>
#       <td id="T_d5a8f_row2_col1" class="data row2 col1" >251</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d5a8f_row3_col0" class="data row3 col0" >Chennai Super Kings</td>
#       <td id="T_d5a8f_row3_col1" class="data row3 col1" >238</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d5a8f_row4_col0" class="data row4 col0" >Rajasthan Royals</td>
#       <td id="T_d5a8f_row4_col1" class="data row4 col1" >221</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d5a8f_row5_col0" class="data row5 col0" >Kings XI Punjab</td>
#       <td id="T_d5a8f_row5_col1" class="data row5 col1" >190</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d5a8f_row6_col0" class="data row6 col0" >Sunrisers Hyderabad</td>
#       <td id="T_d5a8f_row6_col1" class="data row6 col1" >182</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d5a8f_row7_col0" class="data row7 col0" >Delhi Daredevils</td>
#       <td id="T_d5a8f_row7_col1" class="data row7 col1" >161</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d5a8f_row8_col0" class="data row8 col0" >Delhi Capitals</td>
#       <td id="T_d5a8f_row8_col1" class="data row8 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d5a8f_row9_col0" class="data row9 col0" >Deccan Chargers</td>
#       <td id="T_d5a8f_row9_col1" class="data row9 col1" >75</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d5a8f_row10_col0" class="data row10 col0" >Punjab Kings</td>
#       <td id="T_d5a8f_row10_col1" class="data row10 col1" >56</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d5a8f_row11_col0" class="data row11 col0" >Pune Warriors</td>
#       <td id="T_d5a8f_row11_col1" class="data row11 col1" >46</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d5a8f_row12_col0" class="data row12 col0" >Gujarat Titans</td>
#       <td id="T_d5a8f_row12_col1" class="data row12 col1" >45</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d5a8f_row13_col0" class="data row13 col0" >Lucknow Super Giants</td>
#       <td id="T_d5a8f_row13_col1" class="data row13 col1" >44</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d5a8f_row14_col0" class="data row14 col0" >Rising Pune Supergiants</td>
#       <td id="T_d5a8f_row14_col1" class="data row14 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d5a8f_row15_col0" class="data row15 col0" >Gujarat Lions</td>
#       <td id="T_d5a8f_row15_col1" class="data row15 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d5a8f_row16_col0" class="data row16 col0" >Kochi Tuskers Kerala</td>
#       <td id="T_d5a8f_row16_col1" class="data row16 col1" >14</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.subplots(figsize=(10,6))
sns.barplot(x="Team Name", y="Total Matches played", data=teams.sort_values(by='Total Matches played', ascending=False), palette='Set1')
plt.title("Total number of matches played", fontsize=26)
plt.xlabel("Team Name",fontsize=14)
plt.ylabel("Count",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Mumbai Indians have played the most matches(231), followed by Royal Challengers Bangalore (226)

# %% [markdown]
# #### 12) Which team has won the most number of times?

# %%
wins=pd.DataFrame(match_data['winner'].value_counts()).reset_index()
wins.columns=['Team Name','Wins']
wins.style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_302c0_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_302c0_row1_col1 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_302c0_row2_col1 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_302c0_row3_col1 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_302c0_row4_col1 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_302c0_row5_col1, #T_302c0_row6_col1 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_302c0_row7_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_302c0_row8_col1 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_302c0_row9_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_302c0_row10_col1 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_302c0_row11_col1, #T_302c0_row12_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_302c0_row13_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_302c0_row14_col1, #T_302c0_row15_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_302c0_row16_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_302c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_302c0_level0_col0" class="col_heading level0 col0" >Team Name</th>
#       <th id="T_302c0_level0_col1" class="col_heading level0 col1" >Wins</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_302c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_302c0_row0_col0" class="data row0 col0" >Mumbai Indians</td>
#       <td id="T_302c0_row0_col1" class="data row0 col1" >144</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_302c0_row1_col0" class="data row1 col0" >Chennai Super Kings</td>
#       <td id="T_302c0_row1_col1" class="data row1 col1" >138</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_302c0_row2_col0" class="data row2 col0" >Kolkata Knight Riders</td>
#       <td id="T_302c0_row2_col1" class="data row2 col1" >131</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_302c0_row3_col0" class="data row3 col0" >Royal Challengers Bengaluru</td>
#       <td id="T_302c0_row3_col1" class="data row3 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_302c0_row4_col0" class="data row4 col0" >Rajasthan Royals</td>
#       <td id="T_302c0_row4_col1" class="data row4 col1" >112</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_302c0_row5_col0" class="data row5 col0" >Kings XI Punjab</td>
#       <td id="T_302c0_row5_col1" class="data row5 col1" >88</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_302c0_row6_col0" class="data row6 col0" >Sunrisers Hyderabad</td>
#       <td id="T_302c0_row6_col1" class="data row6 col1" >88</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_302c0_row7_col0" class="data row7 col0" >Delhi Daredevils</td>
#       <td id="T_302c0_row7_col1" class="data row7 col1" >67</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_302c0_row8_col0" class="data row8 col0" >Delhi Capitals</td>
#       <td id="T_302c0_row8_col1" class="data row8 col1" >48</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_302c0_row9_col0" class="data row9 col0" >Deccan Chargers</td>
#       <td id="T_302c0_row9_col1" class="data row9 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_302c0_row10_col0" class="data row10 col0" >Gujarat Titans</td>
#       <td id="T_302c0_row10_col1" class="data row10 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_302c0_row11_col0" class="data row11 col0" >Punjab Kings</td>
#       <td id="T_302c0_row11_col1" class="data row11 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_302c0_row12_col0" class="data row12 col0" >Lucknow Super Giants</td>
#       <td id="T_302c0_row12_col1" class="data row12 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_302c0_row13_col0" class="data row13 col0" >Rising Pune Supergiants</td>
#       <td id="T_302c0_row13_col1" class="data row13 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_302c0_row14_col0" class="data row14 col0" >Gujarat Lions</td>
#       <td id="T_302c0_row14_col1" class="data row14 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_302c0_row15_col0" class="data row15 col0" >Pune Warriors</td>
#       <td id="T_302c0_row15_col1" class="data row15 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_302c0_row16_col0" class="data row16 col0" >Kochi Tuskers Kerala</td>
#       <td id="T_302c0_row16_col1" class="data row16 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Most number of wins

# %%
plt.subplots(figsize=(10,6))
sns.barplot(x="Team Name", y="Wins", data=wins.sort_values(by='Wins', ascending=False), palette='Set2')
plt.title("Total Win by teams", fontsize=26)
plt.xlabel("Team Name",fontsize=14)
plt.ylabel("Count",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Mumbai Indians had won the most matches(131), followed by Chennai Super Kings (121)

# %% [markdown]
# #### 13) Which team has the highest winning percentage?

# %%
played=teams.merge(wins,left_on='Team Name',right_on='Team Name',how='inner')
played['% Win']=(played['Wins']/played['Total Matches played'])*100 # total win / no of played match * 100
played.sort_values(by=['% Win'],ascending=False).reset_index().drop('index',axis=1).style.background_gradient(cmap='PuBu',subset=['% Win'])
# Out:
# <style type="text/css">
# #T_44575_row0_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_44575_row1_col3 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_44575_row2_col3 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_44575_row3_col3 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_44575_row4_col3 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_44575_row5_col3 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_44575_row6_col3 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_44575_row7_col3 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_44575_row8_col3 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_44575_row9_col3 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_44575_row10_col3 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_44575_row11_col3 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_44575_row12_col3, #T_44575_row13_col3 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_44575_row14_col3 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_44575_row15_col3 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_44575_row16_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_44575">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44575_level0_col0" class="col_heading level0 col0" >Team Name</th>
#       <th id="T_44575_level0_col1" class="col_heading level0 col1" >Total Matches played</th>
#       <th id="T_44575_level0_col2" class="col_heading level0 col2" >Wins</th>
#       <th id="T_44575_level0_col3" class="col_heading level0 col3" >% Win</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44575_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44575_row0_col0" class="data row0 col0" >Gujarat Titans</td>
#       <td id="T_44575_row0_col1" class="data row0 col1" >45</td>
#       <td id="T_44575_row0_col2" class="data row0 col2" >28</td>
#       <td id="T_44575_row0_col3" class="data row0 col3" >62.222222</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44575_row1_col0" class="data row1 col0" >Chennai Super Kings</td>
#       <td id="T_44575_row1_col1" class="data row1 col1" >238</td>
#       <td id="T_44575_row1_col2" class="data row1 col2" >138</td>
#       <td id="T_44575_row1_col3" class="data row1 col3" >57.983193</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_44575_row2_col0" class="data row2 col0" >Mumbai Indians</td>
#       <td id="T_44575_row2_col1" class="data row2 col1" >261</td>
#       <td id="T_44575_row2_col2" class="data row2 col2" >144</td>
#       <td id="T_44575_row2_col3" class="data row2 col3" >55.172414</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_44575_row3_col0" class="data row3 col0" >Lucknow Super Giants</td>
#       <td id="T_44575_row3_col1" class="data row3 col1" >44</td>
#       <td id="T_44575_row3_col2" class="data row3 col2" >24</td>
#       <td id="T_44575_row3_col3" class="data row3 col3" >54.545455</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_44575_row4_col0" class="data row4 col0" >Delhi Capitals</td>
#       <td id="T_44575_row4_col1" class="data row4 col1" >91</td>
#       <td id="T_44575_row4_col2" class="data row4 col2" >48</td>
#       <td id="T_44575_row4_col3" class="data row4 col3" >52.747253</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_44575_row5_col0" class="data row5 col0" >Kolkata Knight Riders</td>
#       <td id="T_44575_row5_col1" class="data row5 col1" >251</td>
#       <td id="T_44575_row5_col2" class="data row5 col2" >131</td>
#       <td id="T_44575_row5_col3" class="data row5 col3" >52.191235</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_44575_row6_col0" class="data row6 col0" >Rajasthan Royals</td>
#       <td id="T_44575_row6_col1" class="data row6 col1" >221</td>
#       <td id="T_44575_row6_col2" class="data row6 col2" >112</td>
#       <td id="T_44575_row6_col3" class="data row6 col3" >50.678733</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_44575_row7_col0" class="data row7 col0" >Rising Pune Supergiants</td>
#       <td id="T_44575_row7_col1" class="data row7 col1" >30</td>
#       <td id="T_44575_row7_col2" class="data row7 col2" >15</td>
#       <td id="T_44575_row7_col3" class="data row7 col3" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_44575_row8_col0" class="data row8 col0" >Sunrisers Hyderabad</td>
#       <td id="T_44575_row8_col1" class="data row8 col1" >182</td>
#       <td id="T_44575_row8_col2" class="data row8 col2" >88</td>
#       <td id="T_44575_row8_col3" class="data row8 col3" >48.351648</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_44575_row9_col0" class="data row9 col0" >Royal Challengers Bengaluru</td>
#       <td id="T_44575_row9_col1" class="data row9 col1" >255</td>
#       <td id="T_44575_row9_col2" class="data row9 col2" >123</td>
#       <td id="T_44575_row9_col3" class="data row9 col3" >48.235294</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_44575_row10_col0" class="data row10 col0" >Kings XI Punjab</td>
#       <td id="T_44575_row10_col1" class="data row10 col1" >190</td>
#       <td id="T_44575_row10_col2" class="data row10 col2" >88</td>
#       <td id="T_44575_row10_col3" class="data row10 col3" >46.315789</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_44575_row11_col0" class="data row11 col0" >Gujarat Lions</td>
#       <td id="T_44575_row11_col1" class="data row11 col1" >30</td>
#       <td id="T_44575_row11_col2" class="data row11 col2" >13</td>
#       <td id="T_44575_row11_col3" class="data row11 col3" >43.333333</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_44575_row12_col0" class="data row12 col0" >Punjab Kings</td>
#       <td id="T_44575_row12_col1" class="data row12 col1" >56</td>
#       <td id="T_44575_row12_col2" class="data row12 col2" >24</td>
#       <td id="T_44575_row12_col3" class="data row12 col3" >42.857143</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_44575_row13_col0" class="data row13 col0" >Kochi Tuskers Kerala</td>
#       <td id="T_44575_row13_col1" class="data row13 col1" >14</td>
#       <td id="T_44575_row13_col2" class="data row13 col2" >6</td>
#       <td id="T_44575_row13_col3" class="data row13 col3" >42.857143</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_44575_row14_col0" class="data row14 col0" >Delhi Daredevils</td>
#       <td id="T_44575_row14_col1" class="data row14 col1" >161</td>
#       <td id="T_44575_row14_col2" class="data row14 col2" >67</td>
#       <td id="T_44575_row14_col3" class="data row14 col3" >41.614907</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_44575_row15_col0" class="data row15 col0" >Deccan Chargers</td>
#       <td id="T_44575_row15_col1" class="data row15 col1" >75</td>
#       <td id="T_44575_row15_col2" class="data row15 col2" >29</td>
#       <td id="T_44575_row15_col3" class="data row15 col3" >38.666667</td>
#     </tr>
#     <tr>
#       <th id="T_44575_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_44575_row16_col0" class="data row16 col0" >Pune Warriors</td>
#       <td id="T_44575_row16_col1" class="data row16 col1" >46</td>
#       <td id="T_44575_row16_col2" class

# %% [markdown]
# Win % by teams

# %%
plt.subplots(figsize=(10,6))
sns.barplot(x='Team Name', y='% Win',data=played.sort_values(by='% Win', ascending=False), palette='Set3' )
plt.title("Win % by teams", fontsize=26)
plt.xlabel("Team Name",fontsize=14)
plt.ylabel("Count",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The Gujarat Titans have the highest win % of 75.00

# %% [markdown]
# #### 14) Is there any lucky venue for a particular team?

# %% [markdown]
# Lucky Venues for a team

# %%
def lucky(match_data,team_name):
    return match_data[match_data['winner']==team_name]['venue'].value_counts().nlargest(10)

# %%
csk = lucky(match_data, 'Chennai Super Kings')
csk
# Out:
# venue
# MA Chidambaram Stadium, Chepauk, Chennai         50
# Wankhede Stadium, Mumbai                         13
# Dubai International Cricket Stadium               9
# Dr DY Patil Sports Academy, Mumbai                6
# Eden Gardens, Kolkata                             6
# Maharashtra Cricket Association Stadium, Pune     6
# M Chinnaswamy Stadium                             5
# Feroz Shah Kotla                                  5
# Arun Jaitley Stadium, Delhi                       3
# JSCA International Stadium Complex                3
# Name: count, dtype: int64

# %%
rcb = lucky(match_data, 'Royal Challengers Bengaluru')
rcb
# Out:
# venue
# M Chinnaswamy Stadium                            37
# Wankhede Stadium, Mumbai                          8
# Dubai International Cricket Stadium               8
# M Chinnaswamy Stadium, Bengaluru                  7
# Feroz Shah Kotla                                  5
# Eden Gardens, Kolkata                             5
# MA Chidambaram Stadium, Chepauk, Chennai          5
# Maharashtra Cricket Association Stadium, Pune     4
# Sharjah Cricket Stadium                           3
# Kingsmead                                         3
# Name: count, dtype: int64

# %%
rcb = lucky(match_data, 'Royal Challengers Bangalore')
values = rcb
labels = rcb.index

plt.pie(values, labels=labels, autopct='%1.1f%%', )
plt.title('Wins at different Venues for RCB', fontsize=30)
plt.show()

# %%
mi = lucky(match_data, 'Royal Challengers Bangalore')
values = mi
labels = mi.index
fig, ax = plt.subplots(figsize=(10, 6))
wedges, texts, autotexts = ax.pie(values, labels=labels, autopct='%1.1f%%', pctdistance=0.85,textprops=dict(color="black"), wedgeprops=dict(width=0.6, edgecolor='w'))

for w in wedges:
    w.set_edgecolor('w')
ax.legend(wedges, labels, title="Venues", loc="best", bbox_to_anchor=(1, 0, 0.5, 1))
ax.set_title('Wins at different Venues for RCB', fontsize=30)
plt.show()

# %% [markdown]
# #### 15) Which is the biggest win in terms of run margin?

# %%
match_data[match_data['result_margin']==match_data['result_margin'].max()]
# Out:
#           id season   city        date match_type player_of_match  \
# 620  1082635   2017  Delhi  2017-05-06     League     LMP Simmons
#
#                 venue             team1           team2       toss_winner  \
# 620  Feroz Shah Kotla  Delhi Daredevils  Mumbai Indians  Delhi Daredevils
#
#      ... result result_margin target_runs  target_overs  super_over  method  \
# 620  ...   runs         146.0       213.0          20.0           N     NaN
#
#          umpire1    umpire2 Season toss_win_game_win
# 620  Nitin Menon  CK Nandan   2017                No
#
# [1 rows x 22 columns]

# %% [markdown]
# #### 16) What is the count of runs scored from boundaries in each season?

# %% [markdown]
#  Total runs scored from boundaries in each season

# %%
fours_list = deliveries_data[deliveries_data['batsman_runs'] == 4].groupby(deliveries_data['match_id'].map(match_data.set_index('id')['Season'])).size()
sixes_list = deliveries_data[deliveries_data['batsman_runs'] == 6].groupby(deliveries_data['match_id'].map(match_data.set_index('id')['Season'])).size()

# %%
runs4=np.dot(fours_list,4)
runs6=np.dot(sixes_list,6)

# %%
k = runs4 + runs6
Y = match_data['Season'].unique()
#colors = ['turquoise'] * 14
#colors[0] = 'crimson'
sns.set_style('whitegrid')
plt.figure(figsize=(12, 8))
sns.barplot(x=Y, y=k, palette=('Set3'))
plt.title('Total number of runs scored from boundaries in each season', fontsize=22)
plt.xlabel('Season', fontsize=16)
plt.ylabel('Total runs', fontsize=16)
plt.show()

# %% [markdown]
# #### 17) Which stadium has hosted the most number of matches?

# %% [markdown]
#  Total count of matches played in differnt stadiums

# %%
match_data['venue'].value_counts()[:10]
# Out:
# venue
# Wankhede Stadium, Mumbai                      118
# Eden Gardens, Kolkata                          93
# MA Chidambaram Stadium, Chepauk, Chennai       85
# M Chinnaswamy Stadium                          80
# Rajiv Gandhi International Stadium, Uppal      64
# Feroz Shah Kotla                               60
# Sawai Mansingh Stadium                         47
# Dubai International Cricket Stadium            46
# Dr DY Patil Sports Academy, Mumbai             37
# Punjab Cricket Association Stadium, Mohali     35
# Name: count, dtype: int64

# %%
sns.barplot(x=match_data['venue'].value_counts()[:10].index, y=match_data['venue'].value_counts()[:10], palette='Set1')
plt.title("Matches played at different stadiums", fontsize=20)
plt.xlabel("Venue",fontsize=14)
plt.ylabel("Match count",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Eden Gardens has hosted most number of matches.

# %% [markdown]
# #### 18) Who has won the most MOM awards?

# %% [markdown]
# Man of the Match award

# %%
match_data.player_of_match.value_counts()[:10]
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# AD Russell        15
# Name: count, dtype: int64

# %%
sns.barplot(x=match_data.player_of_match.value_counts()[:10].index, y=match_data.player_of_match.value_counts()[:10], palette='Set3')
plt.title("Top 10 MOM awardee", fontsize=20)
plt.xlabel("Players",fontsize=14)
plt.ylabel("Count",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# AB de Villiers (23) had won the most MOM awards, followed by Chris Gayle (22)

# %% [markdown]
# Total run scored from boundaries is lowest in season 2009 and highest in season 2013.

# %% [markdown]
# # Deliveries Data

# %% [markdown]
# #### 19) Particular Batsmen analysis

# %% [markdown]
# Lets see some stats of highest run scorer of IPL : Virat Kohli

# %%
filt=(deliveries_data['batter']=='V Kohli')
df_kohli=deliveries_data[filt]
df_kohli.head()
# Out:
#      match_id  inning                 batting_team           bowling_team  \
# 132    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 133    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 134    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 137    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 138    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
#
#      over  ball   batter    bowler non_striker  batsman_runs  extra_runs  \
# 132     1     2  V Kohli  I Sharma    W Jaffer             0           0
# 133     1     3  V Kohli  I Sharma    W Jaffer             0           4
# 134     1     4  V Kohli  I Sharma    W Jaffer             1           0
# 137     2     1  V Kohli  AB Dinda    W Jaffer             0           0
# 138     2     2  V Kohli  AB Dinda    W Jaffer             0           0
#
#      total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 132           0         NaN          0              NaN            NaN     NaN
# 133           4     legbyes          0              NaN            NaN     NaN
# 134           1         NaN          0              NaN            NaN     NaN
# 137           0         NaN          0              NaN            NaN     NaN
# 138           0         NaN          1          V Kohli         bowled     NaN

# %%
df_kohli['batsman_runs'].sum()
# Out:
# 8014

# %%
# how many sixs
len(df_kohli[df_kohli['batsman_runs']==6])
# Out:
# 273

# %%
# Grouping data by innings and summing up the runs
runs_by_position = df_kohli.groupby('inning')['batsman_runs'].sum()

print(runs_by_position)
# Out:
# inning
# 1    4400
# 2    3604
# 4      10
# Name: batsman_runs, dtype: int64

# %%
# how many fours
len(df_kohli[df_kohli['batsman_runs']==4])
# Out:
# 708

# %%
# Get the value counts of runs scored
runs_counts = df_kohli['batsman_runs'].value_counts()
print(runs_counts)

# Plotting the pie chart
plt.pie(runs_counts, labels=runs_counts.index, autopct='%1.1f%%')
plt.title('Virat Kohli total runs contribution', fontsize=20)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# batsman_runs
# 1    2591
# 0    2198
# 4     708
# 2     445
# 6     273
# 3      21
# Name: count, dtype: int64

# %% [markdown]
#  Interesting fact is that Virat Kohli has scored more runs by taking singles than by hitting 6

# %%
plt.figure(figsize=(10, 6))

values = df_kohli['dismissal_kind'].value_counts()
colors = ['turquoise', 'crimson', 'lime', 'orange', 'blue', 'green']

plt.pie(values, labels=values.index, colors=colors, autopct='%1.1f%%', pctdistance=0.85,textprops=dict(color="w"), wedgeprops=dict(width=0.6, edgecolor='w'))

plt.title('Dismissal Type', fontsize=30)
plt.legend(title="Dismissal Type", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# #### 20) Innings wise comparison between teams

# %% [markdown]
# Innings wise comparision

# %%
runs=deliveries_data.groupby(['inning','batting_team'])['total_runs'].sum().reset_index()
runs1 = runs[runs['inning'] == 1].sort_values(by='total_runs', ascending=False)
runs1
# Out:
#     inning                 batting_team  total_runs
# 10       1               Mumbai Indians       22340
# 0        1          Chennai Super Kings       22092
# 15       1  Royal Challengers Bangalore       20178
# 8        1        Kolkata Knight Riders       19713
# 13       1             Rajasthan Royals       16860
# 17       1          Sunrisers Hyderabad       15760
# 6        1              Kings XI Punjab       15710
# 3        1             Delhi Daredevils       11247
# 2        1               Delhi Capitals        7056
# 1        1              Deccan Chargers        6765
# 12       1                 Punjab Kings        5249
# 9        1         Lucknow Super Giants        4115
# 5        1               Gujarat Titans        3755
# 11       1                Pune Warriors        2973
# 14       1      Rising Pune Supergiants        2427
# 4        1                Gujarat Lions        2267
# 16       1  Royal Challengers Bengaluru        1758
# 7        1         Kochi Tuskers Kerala        1009

# %%
runs2 = runs[runs['inning'] == 2].sort_values(by='total_runs', ascending=False)
runs2
# Out:
#     inning                 batting_team  total_runs
# 28       2               Mumbai Indians       19793
# 26       2        Kolkata Knight Riders       19582
# 31       2             Rajasthan Royals       17852
# 33       2  Royal Challengers Bangalore       17473
# 18       2          Chennai Super Kings       16528
# 24       2              Kings XI Punjab       14307
# 35       2          Sunrisers Hyderabad       13274
# 21       2             Delhi Daredevils       13038
# 20       2               Delhi Capitals        7823
# 19       2              Deccan Chargers        4698
# 30       2                 Punjab Kings        4287
# 23       2               Gujarat Titans        4002
# 27       2         Lucknow Super Giants        3395
# 29       2                Pune Warriors        3385
# 22       2                Gujarat Lions        2589
# 32       2      Rising Pune Supergiants        2106
# 34       2  Royal Challengers Bengaluru        1172
# 25       2         Kochi Tuskers Kerala         892

# %% [markdown]
# ## Batting first :

# %%
sns.barplot(x='batting_team', y= 'total_runs', data=runs1, palette='summer')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Royal Challengers Bangalore and Mumbai Indians median value is better than other teams while batting first.
# Royal Challengers Bangalore had scored 250+ in a single match and is the only team to achieve that feat.

# %% [markdown]
# ## Batting second :

# %%
sns.barplot(x='batting_team', y= 'total_runs', data=runs2, palette='summer')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### 21) Which batsmen have played the most number of balls?

# %% [markdown]
#  Most balls played by a batsman

# %%
balls_played=deliveries_data.groupby(['batter'])['ball'].count().reset_index()
balls_played.sort_values(by='ball',ascending=False).head(10).style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_b931e_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b931e_row1_col1 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_b931e_row2_col1 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_b931e_row3_col1 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_b931e_row4_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_b931e_row5_col1 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_b931e_row6_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_b931e_row7_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_b931e_row8_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_b931e_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_b931e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b931e_level0_col0" class="col_heading level0 col0" >batter</th>
#       <th id="T_b931e_level0_col1" class="col_heading level0 col1" >ball</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b931e_level0_row0" class="row_heading level0 row0" >631</th>
#       <td id="T_b931e_row0_col0" class="data row0 col0" >V Kohli</td>
#       <td id="T_b931e_row0_col1" class="data row0 col1" >6236</td>
#     </tr>
#     <tr>
#       <th id="T_b931e_level0_row1" class="row_heading level0 row1" >512</th>
#       <td id="T_b931e_row1_col0" class="data row1 col0" >S Dhawan</td>
#       <td id="T_b931e_row1_col1" class="data row1 col1" >5483</td>
#     </tr>
#     <tr>
#       <th id="T_b931e_level0_row2" class="row_heading level0 row2" >477</th>
#       <td id="T_b931e_row2_col0" class="data row2 col0" >RG Sharma</td>
#       <td id="T_b931e_row2_col1" class="data row2 col1" >5183</td>
#     </tr>
#     <tr>
#       <th id="T_b931e_level0_row3" class="row_heading level0 row3" >147</th>
#       <td id="T_b931e_row3_col0" class="data row3 col0" >DA Warner</td>
#       <td id="T_b931e_row3_col1" class="data row3 col1" >4849</td>
#     </tr>
#     <tr>
#       <th id="T_b931e_level0_row4" class="row_heading level0 row4" >546</th>
#       <td id="T_b931e_row4_col0" class="data row4 col0" >SK Raina</td>
#       <td id="T_b931e_row4_col1" class="data row4 col1" >4177</td>
#     </tr>
#     <tr>
#       <th id="T_b931e_level0_row5" class="row_heading level0 row5" >374</th>
#       <td id="T_b931e_row5_col0" class="data row5 col0" >MS Dhoni</td>
#       <td id="T_b931e_row5_col1" class="data row5 col1" >3947</td>
#     </tr>
#     <tr>
#       <th id="T_b931e_level0_row6" class="row_heading level0 row6" >501</th>
#       <td id="T_b931e_row6_col0" class="data row6 col0" >RV Uthappa</td>
#       <td id="T_b931e_row6_col1" class="data row6 col1" >3927</td>
#     </tr>
#     <tr>
#       <th id="T_b931e_level0_row7" class="row_heading level0 row7" >50</th>
#       <td id="T_b931e_row7_col0" class="data row7 col0" >AM Rahane</td>
#       <td id="T_b931e_row7_col1" class="data row7 col1" >3858</td>
#     </tr>
#     <tr>
#       <th id="T_b931e_level0_row8" class="row_heading level0 row8" >282</th>
#       <td id="T_b931e_row8_col0" class="data row8 col0" >KD Karthik</td>
#       <td id="T_b931e_row8_col1" class="data row8 col1" >3687</td>
#     </tr>
#     <tr>
#       <th id="T_b931e_level0_row9" class="row_heading level0 row9" >289</th>
#       <td id="T_b931e_row9_col0" class="data row9 col0" >KL Rahul</td>
#       <td id="T_b931e_row9_col1" class="data row9 col1" >3578</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Virat kohli had played the most balls.
# David Warner and Chris Gayle are the only two foreign players in this top 10 list.

# %% [markdown]
# #### 22) Who are the leading run-scorers of all time?

# %%
runs=deliveries_data.groupby(['batter'])['batsman_runs'].sum().reset_index()
runs.columns=['Batsman','runs']
y=runs.sort_values(by='runs',ascending=False).head(10).reset_index().drop('index',axis=1)
y.style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_39063_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_39063_row1_col1 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_39063_row2_col1 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_39063_row3_col1 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_39063_row4_col1 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_39063_row5_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_39063_row6_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_39063_row7_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_39063_row8_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_39063_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_39063">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39063_level0_col0" class="col_heading level0 col0" >Batsman</th>
#       <th id="T_39063_level0_col1" class="col_heading level0 col1" >runs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39063_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_39063_row0_col0" class="data row0 col0" >V Kohli</td>
#       <td id="T_39063_row0_col1" class="data row0 col1" >8014</td>
#     </tr>
#     <tr>
#       <th id="T_39063_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_39063_row1_col0" class="data row1 col0" >S Dhawan</td>
#       <td id="T_39063_row1_col1" class="data row1 col1" >6769</td>
#     </tr>
#     <tr>
#       <th id="T_39063_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_39063_row2_col0" class="data row2 col0" >RG Sharma</td>
#       <td id="T_39063_row2_col1" class="data row2 col1" >6630</td>
#     </tr>
#     <tr>
#       <th id="T_39063_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_39063_row3_col0" class="data row3 col0" >DA Warner</td>
#       <td id="T_39063_row3_col1" class="data row3 col1" >6567</td>
#     </tr>
#     <tr>
#       <th id="T_39063_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_39063_row4_col0" class="data row4 col0" >SK Raina</td>
#       <td id="T_39063_row4_col1" class="data row4 col1" >5536</td>
#     </tr>
#     <tr>
#       <th id="T_39063_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_39063_row5_col0" class="data row5 col0" >MS Dhoni</td>
#       <td id="T_39063_row5_col1" class="data row5 col1" >5243</td>
#     </tr>
#     <tr>
#       <th id="T_39063_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_39063_row6_col0" class="data row6 col0" >AB de Villiers</td>
#       <td id="T_39063_row6_col1" class="data row6 col1" >5181</td>
#     </tr>
#     <tr>
#       <th id="T_39063_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_39063_row7_col0" class="data row7 col0" >CH Gayle</td>
#       <td id="T_39063_row7_col1" class="data row7 col1" >4997</td>
#     </tr>
#     <tr>
#       <th id="T_39063_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_39063_row8_col0" class="data row8 col0" >RV Uthappa</td>
#       <td id="T_39063_row8_col1" class="data row8 col1" >4954</td>
#     </tr>
#     <tr>
#       <th id="T_39063_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_39063_row9_col0" class="data row9 col0" >KD Karthik</td>
#       <td id="T_39063_row9_col1" class="data row9 col1" >4843</td>
#     </tr>
#   </tbody>
# </table>

# %%
colors = sns.color_palette("pastel")[:13]
colors[0] = "crimson"
sns.barplot(x=y['Batsman'][:10], y=y['runs'][:10], palette=colors)
plt.title("Top 10 leading run-scorers", fontsize=20)
plt.xlabel("Player",fontsize=14)
plt.ylabel("Total Runs",fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Virat Kohli is the leading run scorer in IPL.
# One interesting thing to notice that MS Dhoni is the only player in this list who bats down the order.

# %% [markdown]
# #### 23) Who has hit the most number of 4's?

# %% [markdown]
# Most number of 4's

# %%
balls_played=balls_played.merge(runs,left_on='batter',right_on='Batsman',how='outer')
four=deliveries_data[deliveries_data['batsman_runs']==4]
runs_4=four.groupby('batter')['batsman_runs'].count().reset_index()
runs_4.columns=['Batsman','4s']
runs_4.sort_values(by='4s',ascending=False).head(10).reset_index().drop('index',axis=1).style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_1ac7c_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1ac7c_row1_col1 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_1ac7c_row2_col1 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_1ac7c_row3_col1 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_1ac7c_row4_col1 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_1ac7c_row5_col1 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_1ac7c_row6_col1 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_1ac7c_row7_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_1ac7c_row8_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_1ac7c_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_1ac7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ac7c_level0_col0" class="col_heading level0 col0" >Batsman</th>
#       <th id="T_1ac7c_level0_col1" class="col_heading level0 col1" >4s</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ac7c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ac7c_row0_col0" class="data row0 col0" >S Dhawan</td>
#       <td id="T_1ac7c_row0_col1" class="data row0 col1" >768</td>
#     </tr>
#     <tr>
#       <th id="T_1ac7c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1ac7c_row1_col0" class="data row1 col0" >V Kohli</td>
#       <td id="T_1ac7c_row1_col1" class="data row1 col1" >708</td>
#     </tr>
#     <tr>
#       <th id="T_1ac7c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1ac7c_row2_col0" class="data row2 col0" >DA Warner</td>
#       <td id="T_1ac7c_row2_col1" class="data row2 col1" >663</td>
#     </tr>
#     <tr>
#       <th id="T_1ac7c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1ac7c_row3_col0" class="data row3 col0" >RG Sharma</td>
#       <td id="T_1ac7c_row3_col1" class="data row3 col1" >599</td>
#     </tr>
#     <tr>
#       <th id="T_1ac7c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1ac7c_row4_col0" class="data row4 col0" >SK Raina</td>
#       <td id="T_1ac7c_row4_col1" class="data row4 col1" >506</td>
#     </tr>
#     <tr>
#       <th id="T_1ac7c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1ac7c_row5_col0" class="data row5 col0" >G Gambhir</td>
#       <td id="T_1ac7c_row5_col1" class="data row5 col1" >492</td>
#     </tr>
#     <tr>
#       <th id="T_1ac7c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1ac7c_row6_col0" class="data row6 col0" >RV Uthappa</td>
#       <td id="T_1ac7c_row6_col1" class="data row6 col1" >481</td>
#     </tr>
#     <tr>
#       <th id="T_1ac7c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1ac7c_row7_col0" class="data row7 col0" >AM Rahane</td>
#       <td id="T_1ac7c_row7_col1" class="data row7 col1" >479</td>
#     </tr>
#     <tr>
#       <th id="T_1ac7c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1ac7c_row8_col0" class="data row8 col0" >KD Karthik</td>
#       <td id="T_1ac7c_row8_col1" class="data row8 col1" >466</td>
#     </tr>
#     <tr>
#       <th id="T_1ac7c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1ac7c_row9_col0" class="data row9 col0" >F du Plessis</td>
#       <td id="T_1ac7c_row9_col1" class="data row9 col1" >422</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#  Shikhar Dhawan holds the record for most number of 4's

# %% [markdown]
# #### 24) Who has hit the most number of 6's?

# %% [markdown]
# Most number of 6's

# %%
six=deliveries_data.groupby('batter')['batsman_runs'].agg(lambda x: (x==6).sum()).reset_index()
six.columns=['Batsman','6s']
six.sort_values(by='6s',ascending=False).head(10).reset_index().drop('index',axis=1).style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_4aaee_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_4aaee_row1_col1 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_4aaee_row2_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_4aaee_row3_col1 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_4aaee_row4_col1 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_4aaee_row5_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_4aaee_row6_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_4aaee_row7_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_4aaee_row8_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_4aaee_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_4aaee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4aaee_level0_col0" class="col_heading level0 col0" >Batsman</th>
#       <th id="T_4aaee_level0_col1" class="col_heading level0 col1" >6s</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4aaee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4aaee_row0_col0" class="data row0 col0" >CH Gayle</td>
#       <td id="T_4aaee_row0_col1" class="data row0 col1" >359</td>
#     </tr>
#     <tr>
#       <th id="T_4aaee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4aaee_row1_col0" class="data row1 col0" >RG Sharma</td>
#       <td id="T_4aaee_row1_col1" class="data row1 col1" >281</td>
#     </tr>
#     <tr>
#       <th id="T_4aaee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4aaee_row2_col0" class="data row2 col0" >V Kohli</td>
#       <td id="T_4aaee_row2_col1" class="data row2 col1" >273</td>
#     </tr>
#     <tr>
#       <th id="T_4aaee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4aaee_row3_col0" class="data row3 col0" >AB de Villiers</td>
#       <td id="T_4aaee_row3_col1" class="data row3 col1" >253</td>
#     </tr>
#     <tr>
#       <th id="T_4aaee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4aaee_row4_col0" class="data row4 col0" >MS Dhoni</td>
#       <td id="T_4aaee_row4_col1" class="data row4 col1" >252</td>
#     </tr>
#     <tr>
#       <th id="T_4aaee_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4aaee_row5_col0" class="data row5 col0" >DA Warner</td>
#       <td id="T_4aaee_row5_col1" class="data row5 col1" >236</td>
#     </tr>
#     <tr>
#       <th id="T_4aaee_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4aaee_row6_col0" class="data row6 col0" >KA Pollard</td>
#       <td id="T_4aaee_row6_col1" class="data row6 col1" >224</td>
#     </tr>
#     <tr>
#       <th id="T_4aaee_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4aaee_row7_col0" class="data row7 col0" >AD Russell</td>
#       <td id="T_4aaee_row7_col1" class="data row7 col1" >209</td>
#     </tr>
#     <tr>
#       <th id="T_4aaee_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4aaee_row8_col0" class="data row8 col0" >SV Samson</td>
#       <td id="T_4aaee_row8_col1" class="data row8 col1" >206</td>
#     </tr>
#     <tr>
#       <th id="T_4aaee_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4aaee_row9_col0" class="data row9 col0" >SK Raina</td>
#       <td id="T_4aaee_row9_col1" class="data row9 col1" >204</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# "The Universe Boss" Chris Gayle had smashed 359 sixes, most by any batsman.

# %% [markdown]
# #### 25) Who has the highest strike rate?

# %%
player=pd.concat([runs,balls_played.iloc[:,1],runs_4.iloc[:,1],six.iloc[:,1]],axis=1)
player['strike_rate']=player['runs']/player['ball']*100
player['4s'].fillna(0,inplace=True)
player.isnull().values.any()
# Out:
# False

# %%
player.sort_values(by='strike_rate',ascending=False).head(10)

# %%
sr=player[player.ball > 100]
sr.sort_values(by='strike_rate',ascending=False).head(10)
reqsr=sr.drop(columns=['runs','ball','4s','6s'],axis=1)
reqsr.sort_values(by='strike_rate',ascending=False).head(10).style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_8cab7_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_8cab7_row1_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_8cab7_row2_col1 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_8cab7_row3_col1 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_8cab7_row4_col1 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_8cab7_row5_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_8cab7_row6_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_8cab7_row7_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_8cab7_row8_col1, #T_8cab7_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_8cab7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8cab7_level0_col0" class="col_heading level0 col0" >Batsman</th>
#       <th id="T_8cab7_level0_col1" class="col_heading level0 col1" >strike_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8cab7_level0_row0" class="row_heading level0 row0" >234</th>
#       <td id="T_8cab7_row0_col0" class="data row0 col0" >J Fraser-McGurk</td>
#       <td id="T_8cab7_row0_col1" class="data row0 col1" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8cab7_level0_row1" class="row_heading level0 row1" >652</th>
#       <td id="T_8cab7_row1_col0" class="data row1 col0" >WG Jacks</td>
#       <td id="T_8cab7_row1_col1" class="data row1 col1" >172.932331</td>
#     </tr>
#     <tr>
#       <th id="T_8cab7_level0_row2" class="row_heading level0 row2" >433</th>
#       <td id="T_8cab7_row2_col0" class="data row2 col0" >PD Salt</td>
#       <td id="T_8cab7_row2_col1" class="data row2 col1" >169.610390</td>
#     </tr>
#     <tr>
#       <th id="T_8cab7_level0_row3" class="row_heading level0 row3" >606</th>
#       <td id="T_8cab7_row3_col0" class="data row3 col0" >T Stubbs</td>
#       <td id="T_8cab7_row3_col1" class="data row3 col1" >169.456067</td>
#     </tr>
#     <tr>
#       <th id="T_8cab7_level0_row4" class="row_heading level0 row4" >617</th>
#       <td id="T_8cab7_row4_col0" class="data row4 col0" >TM Head</td>
#       <td id="T_8cab7_row4_col1" class="data row4 col1" >168.558952</td>
#     </tr>
#     <tr>
#       <th id="T_8cab7_level0_row5" class="row_heading level0 row5" >39</th>
#       <td id="T_8cab7_row5_col0" class="data row5 col0" >AD Russell</td>
#       <td id="T_8cab7_row5_col1" class="data row5 col1" >164.224422</td>
#     </tr>
#     <tr>
#       <th id="T_8cab7_level0_row6" class="row_heading level0 row6" >105</th>
#       <td id="T_8cab7_row6_col0" class="data row6 col0" >BCJ Cutting</td>
#       <td id="T_8cab7_row6_col1" class="data row6 col1" >163.013699</td>
#     </tr>
#     <tr>
#       <th id="T_8cab7_level0_row7" class="row_heading level0 row7" >208</th>
#       <td id="T_8cab7_row7_col0" class="data row7 col0" >H Klaasen</td>
#       <td id="T_8cab7_row7_col1" class="data row7 col1" >161.990212</td>
#     </tr>
#     <tr>
#       <th id="T_8cab7_level0_row8" class="row_heading level0 row8" >503</th>
#       <td id="T_8cab7_row8_col0" class="data row8 col0" >Ramandeep Singh</td>
#       <td id="T_8cab7_row8_col1" class="data row8 col1" >160.377358</td>
#     </tr>
#     <tr>
#       <th id="T_8cab7_level0_row9" class="row_heading level0 row9" >85</th>
#       <td id="T_8cab7_row9_col0" class="data row9 col0" >Ashutosh Sharma</td>
#       <td id="T_8cab7_row9_col1" class="data row9 col1" >160.169492</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#  Andre Russel has the highest strike rate, followed by K. Gowtham and B. Cutting.

# %% [markdown]
# #### 26) Who is the leading wicket-taker?

# %% [markdown]
# Highest wicket-taker

# %%
dismissal_kinds = ['caught', 'bowled', 'lbw', 'caught and bowled', 'stumped', 'hit wicket']
bowler = deliveries_data[deliveries_data["dismissal_kind"].isin(dismissal_kinds)]['bowler'].value_counts().head(10)
bowler
# Out:
# bowler
# YS Chahal     205
# PP Chawla     192
# DJ Bravo      183
# B Kumar       181
# SP Narine     180
# R Ashwin      180
# A Mishra      174
# SL Malinga    170
# JJ Bumrah     168
# RA Jadeja     160
# Name: count, dtype: int64

# %%
colors = sns.color_palette("pastel")[:13]
colors[0] = "crimson"
sns.barplot(x=bowler[:10].index, y=bowler[:10], palette=colors)
plt.title("Leading wicket-takers", fontsize=26)
plt.xlabel("Bowler",fontsize=14)
plt.ylabel("Total Wickets",fontsize=14
          )
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - DJ Bravo is the leading wicket taker in IPL.
# - 6 out of top 10 are spin bowlers.

# %% [markdown]
# #### 27) What is the count of fours hit in each season?

# %% [markdown]
# Total number of fours in each season

# %%
fours_list = deliveries_data[deliveries_data['batsman_runs'] == 4].groupby(deliveries_data['match_id'].map(match_data.set_index('id')['Season'])).size()
sns.barplot(x=fours_list.index, y=fours_list.values, color='turquoise')
plt.title("Total number of Fours in each season", fontsize=20)
plt.xlabel("Season", fontsize=14)
plt.ylabel("Total Fours", fontsize=14)
plt.xticks(rotation=90)
plt.gca().patches[15].set_facecolor('crimson')
plt.show()

# %% [markdown]
#  Highest number of four in a season was is 2013 season while season 2009 had the lowest count of 4's.

# %% [markdown]
# #### 28) What is the count of sixes hit in each season?

# %% [markdown]
# Total number of sixes in each season

# %%
data_6 = match_data['Season'].unique()
sixes_list = deliveries_data[deliveries_data['batsman_runs'] == 6].groupby(deliveries_data['match_id'].map(match_data.set_index('id')['Season'])).size()

colors = ['turquoise'] * len(data_6)
colors[-1] = 'crimson'

plt.figure(figsize=(12, 8))
sns.barplot(x=sixes_list.index, y=sixes_list.values, palette=colors)
plt.title('Total number of Sixes in each season', fontsize=20)
plt.xlabel('Season', fontsize=16)
plt.ylabel('Total Sixes', fontsize=16)
plt.show()

# %% [markdown]
#  In season 2022, the maximum number of sixes were hit while the lowest was observed in season 2009.

# %% [markdown]
# #### 29) What is the run contribution from boundaries in each season?

# %% [markdown]
#  Total contribution of runs from boundaries in each season

# %%
totruns=np.array(season['total_runs'])
res=(k/totruns)*100

# %%
Y = match_data['Season'].unique()
res
# Out:
# array([58.81697051, 50.95089586, 54.853572  , 54.35378652, 53.63203135,
#        54.42881161, 55.68644023, 57.73443034, 54.95705652, 56.87213883,
#        59.49449776, 58.33076052, 55.48001648, 55.40591297, 59.24164788,
#        60.12145749, 62.63139656])

# %%
plt.subplots(figsize=(12, 6))
sns.barplot(x=Y, y=res, palette=['turquoise']*14)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.title('Total contribution of runs from boundaries in each season', fontsize=22)
plt.xlabel('Season', fontsize=16)
plt.xticks( fontsize=10)
plt.ylabel('Percentage', fontsize=16)
plt.show()

# %% [markdown]
# In season 2022, most runs of the total runs came from boundaries while most runs came from boundaries in season 2021 which is lowest till now.

# %% [markdown]
# #### 30) Which team has scored the most runs in the first 6 overs?

# %% [markdown]
# Total runs scored by teams in first 6 overs

# %%
team = deliveries_data['batting_team'].unique()
team_runs = []
for var in team:
    temp_df = deliveries_data[deliveries_data['batting_team']==var]
    temp_df = temp_df[temp_df['over'].isin([0,1,2,3,4,5])]
    runs = temp_df['total_runs'].sum()
    team_runs.append(runs)
team = pd.DataFrame(data=team_runs, index=team,columns=['Runs In First 6 Overs'])
#team.sort_values('Runs In First 6 Overs', ascending=False, inplace=True)
team.index.name = 'Team'

colors = ['turquoise',] * 15
colors[6] = 'crimson'

plt.figure(figsize=(10,6))
sns.barplot(x=team.index, y=team['Runs In First 6 Overs'], palette=colors)
plt.title('Total runs scored by teams in their first 6 overs', fontsize=20)
plt.xlabel('Team Name', fontsize=14)
plt.ylabel('Total runs', fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Mumbai Indians had scored the most runs in first 6 overs, followed by Kings XI Punjab.

# %% [markdown]
# #### 31) Which team has scored the most runs in the last 4 overs?

# %% [markdown]
# Total runs scored by teams in last 4 overs

# %%
team1 = deliveries_data['batting_team'].unique()
team_runs1 = []
for var in team1:
    temp_df = deliveries_data[deliveries_data['batting_team']==var]
    temp_df = temp_df[temp_df['over'].isin([19,18,17,16])]
    runs1 = temp_df['total_runs'].sum()
    team_runs1.append(runs1)
team1 = pd.DataFrame(data=team_runs1, index=team1,columns=['Runs In Last 4 Overs'])
# team.sort_values('Runs In First 6 Overs', ascending=False, inplace=True)
team1.index.name = 'Team'
colors = ['turquoise'] * 15
colors[6] = 'crimson'
sns.barplot(x=team1.index, y=team1['Runs In Last 4 Overs'], palette=colors)
plt.title('Total runs scored by teams in their last 4 overs', fontsize=18)
plt.xlabel('Team Name', fontsize=14)
plt.ylabel('Total runs', fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Mumbai Indians had scored most runs in last 4 overs, followed by Royal Challengers Bangalore.

# %% [markdown]
# #### 32) Which team has the best scoring run-rate in the first 6 overs?

# %% [markdown]
# Highest scoring run-rate in first 6 overs

# %%
played1=played.merge(team,left_on='Team Name',right_on='Team',how='inner')
played3=played1.merge(team1,left_on='Team Name',right_on='Team',how='inner')
mintoover=np.dot(played3['Total Matches played'],6)
mintoover1=np.dot(played3['Total Matches played'],4)
played3['RR in first 6 overs']=(played3['Runs In First 6 Overs']/mintoover)
played3['RR in last 4 overs']=(played3['Runs In Last 4 Overs']/mintoover1)
played3
# Out:
#                       Team Name  Total Matches played  Wins      % Win  \
# 0                Mumbai Indians                   261   144  55.172414
# 1   Royal Challengers Bengaluru                   255   123  48.235294
# 2         Kolkata Knight Riders                   251   131  52.191235
# 3           Chennai Super Kings                   238   138  57.983193
# 4              Rajasthan Royals                   221   112  50.678733
# 5               Kings XI Punjab                   190    88  46.315789
# 6           Sunrisers Hyderabad                   182    88  48.351648
# 7              Delhi Daredevils                   161    67  41.614907
# 8                Delhi Capitals                    91    48  52.747253
# 9               Deccan Chargers                    75    29  38.666667
# 10                 Punjab Kings                    56    24  42.857143
# 11                Pune Warriors                    46    12  26.086957
# 12               Gujarat Titans                    45    28  62.222222
# 13         Lucknow Super Giants                    44    24  54.545455
# 14      Rising Pune Supergiants                    30    15  50.000000
# 15                Gujarat Lions                    30    13  43.333333
# 16         Kochi Tuskers Kerala                    14     6  42.857143
#
#     Runs In First 6 Overs  Runs In Last 4 Overs  RR in first 6 overs  \
# 0                   12225                  9598             7.806513
# 1                     876                   611             0.572549
# 2                   11941                  8053             7.928951
# 3                   10991                  9061             7.696779
# 4                   10226                  7281             7.711916
# 5                    8954                  6227             7.854386
# 6                    8937                  6237             8.184066
# 7                    7360                  5043             7.619048
# 8                    4709                  3141             8.624542
# 9                    3417                  2539             7.593333
# 10                   2841                  2047             8.455357
# 11                   1895                  1360             6.865942
# 12                   2184                  1823             8.088889
# 13                   2080                  1718             7.878788
# 14                   1423                   998             7.905556
# 15                   1559                   921             8.661111
# 16                    680                   337             8.095238
#
#     RR in last 4 overs
# 0             9.193487
# 1             0.599020
# 2             8.020916
# 3             9.517857
# 4             8.236425
# 5             8.193421
# 6             8.567308
# 7             7.830745
# 8             8.629121
# 9             8.463333
# 10            9.138393
# 11            7.391304
# 12           10.127778
# 13            9.761364
# 14            8.316667
# 15            7.675000
# 16            6.017857

# %%
colors = ['turquoise',] * 15
colors[4] = 'crimson'

sns.barplot(x=played3['Team Name'], y=played3['RR in first 6 overs'], palette=colors)
plt.xlabel('Team Name',fontsize=14)
plt.ylabel('Run Rate',fontsize=14)
plt.title('Run Rate in first 6 overs',  fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Gujarat Lions has the highest scoring run-rate in first 6 overs, followed by Delhi Capital.

# %% [markdown]
# #### 33) Which team has the best scoring run-rate in the last 4 overs?

# %% [markdown]
# Highest scoring rate in last 4 overs

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(x=played3['Team Name'], height=played3['RR in last 4 overs'], color=colors)

# set the title and axis labels
ax.set_title('Run Rate in last 4 overs', fontsize=26)
ax.set_xlabel('Team Name',fontsize=14)
ax.set_ylabel('Run Rate',fontsize=14)
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# Lucknow super Giants has the highest scoring run-rate in last 4 overs, followed by Gujrat Titans.

# %% [markdown]
# # END
