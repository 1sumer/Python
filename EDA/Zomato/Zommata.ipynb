# %% [markdown]
# # <p style="background-color:#B0766D;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Zomato Dataset Exploratory Data analysis</p>
# <img src="https://raw.githubusercontent.com/chiragsamal/Zomato/master/Images/zomato.jpg">

# %% [markdown]
# # <p style="background-color:#B0766D;font-family:newtimeroman;color:#FFF9ED;font-size:100%;text-align:center;border-radius:10px 10px;">Importing Important Libraries</p>

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# # <p style="background-color:#B0766D;font-family:newtimeroman;color:#FFF9ED;font-size:100%;text-align:center;border-radius:10px 10px;">Improve our domain Knowledge about Zomato</p>
# ### Lets Talks about Zomato and Familiar more about it:

# %% [markdown]
# * Zomato has Launched in 2010, its technology platform connects customers, restaurant partners and delivery partners, serving their multiple needs.
# * Customers use its platform to search and discover restaurants, read and write customer generated reviews and view and upload photos, order food delivery, book a table and make payments while dining-out at restaurants.
# * On the other hand, it provides restaurant partners with industry-specific marketing tools which enable them to engage and acquire customers to grow their business while also providing a reliable and efficient last mile delivery service.
# * Its team also operate a one-stop procurement solution, Hyperpure, which supplies high quality ingredients and kitchen products to restaurant partners. Zomato' team also provide our delivery partners with transparent and flexible earning opportunities.

# %%
df = pd.read_csv(r"D:\Python\EDA\Zomato\Zomato_df.csv")
df
# Out:
#        Unnamed: 0  online_order  book_table  rate  votes  location  rest_type  \
# 0               0             1           1   4.1    775         1         20
# 1               1             1           0   4.1    787         1         20
# 2               2             1           0   3.8    918         1         16
# 3               3             0           0   3.7     88         1         62
# 4               4             0           0   3.8    166         4         20
# ...           ...           ...         ...   ...    ...       ...        ...
# 23243       23243             1           1   3.8    128        84          5
# 23244       23244             0           0   3.9     77        84         38
# 23245       23245             0           0   2.8    161        84         21
# 23246       23246             0           0   2.5     81        84         21
# 23247       23247             0           1   4.3    236        25          4
#
#        cuisines    cost  menu_item
# 0          1386   800.0       5047
# 1           594   800.0       5047
# 2           484   800.0       5047
# 3          1587   300.0       5047
# 4          1406   600.0       5047
# ...         ...     ...        ...
# 23243      1318  1200.0       5047
# 23244       878  2000.0       5047
# 23245       539  1200.0       5047
# 23246        80   800.0       5047
# 23247       878  2500.0       5047
#
# [23248 rows x 10 columns]

# %%
df.shape
# Out:
# (23248, 10)

# %%
df.head(10)
# Out:
#    Unnamed: 0  online_order  book_table  rate  votes  location  rest_type  \
# 0           0             1           1   4.1    775         1         20
# 1           1             1           0   4.1    787         1         20
# 2           2             1           0   3.8    918         1         16
# 3           3             0           0   3.7     88         1         62
# 4           4             0           0   3.8    166         4         20
# 5           5             1           0   3.8    286         4         20
# 6           6             1           1   4.6   2556         1         22
# 7           7             1           0   4.0    324         1         13
# 8           8             1           0   4.2    504         1         13
# 9           9             1           0   4.1    402         1         13
#
#    cuisines   cost  menu_item
# 0      1386  800.0       5047
# 1       594  800.0       5047
# 2       484  800.0       5047
# 3      1587  300.0       5047
# 4      1406  600.0       5047
# 5      1156  600.0       5047
# 6      1468  600.0       5047
# 7       462  700.0       5047
# 8       485  550.0       5047
# 9       332  500.0       5047

# %%
df.tail()
# Out:
#        Unnamed: 0  online_order  book_table  rate  votes  location  rest_type  \
# 23243       23243             1           1   3.8    128        84          5
# 23244       23244             0           0   3.9     77        84         38
# 23245       23245             0           0   2.8    161        84         21
# 23246       23246             0           0   2.5     81        84         21
# 23247       23247             0           1   4.3    236        25          4
#
#        cuisines    cost  menu_item
# 23243      1318  1200.0       5047
# 23244       878  2000.0       5047
# 23245       539  1200.0       5047
# 23246        80   800.0       5047
# 23247       878  2500.0       5047

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'online_order', 'book_table', 'rate', 'votes', 'location',
#        'rest_type', 'cuisines', 'cost', 'menu_item'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23248 entries, 0 to 23247
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    23248 non-null  int64
#  1   online_order  23248 non-null  int64
#  2   book_table    23248 non-null  int64
#  3   rate          23248 non-null  float64
#  4   votes         23248 non-null  int64
#  5   location      23248 non-null  int64
#  6   rest_type     23248 non-null  int64
#  7   cuisines      23248 non-null  int64
#  8   cost          23248 non-null  float64
#  9   menu_item     23248 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 1.8 MB

# %%
df.describe().T
# Out:
#                 count          mean          std   min      25%      50%  \
# Unnamed: 0    23248.0  11623.500000  6711.263865   0.0  5811.75  11623.5
# online_order  23248.0      0.704491     0.456281   0.0     0.00      1.0
# book_table    23248.0      0.260539     0.438938   0.0     0.00      0.0
# rate          23248.0      3.905781     0.426153   1.8     3.80      4.0
# votes         23248.0    605.461674  1113.706789   0.0   104.00    225.0
# location      23248.0     35.525680    23.260984   0.0    19.00     34.0
# rest_type     23248.0     32.933672    20.506963   0.0    20.00     21.0
# cuisines      23248.0    862.081168   473.466781   0.0   429.00    879.0
# cost          23248.0    753.500946   520.472169  40.0   400.00    600.0
# menu_item     23248.0   4308.031487  1394.280280   0.0  4320.75   5047.0
#
#                    75%      max
# Unnamed: 0    17435.25  23247.0
# online_order      1.00      1.0
# book_table        1.00      1.0
# rate              4.20      4.9
# votes           597.00  16832.0
# location         49.00     87.0
# rest_type        62.00     72.0
# cuisines       1218.00   1680.0
# cost           1000.00   6000.0
# menu_item      5047.00   5047.0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# online_order    0
# book_table      0
# rate            0
# votes           0
# location        0
# rest_type       0
# cuisines        0
# cost            0
# menu_item       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop('Unnamed: 0',axis=1, inplace=True)

# %%
columns_lst=list(df.columns)
for i in columns_lst:
    print('Number of unique values in',i, 'is',df[i].nunique())
# Out:
# Number of unique values in online_order is 2
# Number of unique values in book_table is 2
# Number of unique values in rate is 31
# Number of unique values in votes is 2303
# Number of unique values in location is 88
# Number of unique values in rest_type is 73
# Number of unique values in cuisines is 1681
# Number of unique values in cost is 57
# Number of unique values in menu_item is 5048

# %%
plt.figure(figsize=(10,20))
for i in range(len(columns_lst)):
    plt.subplot(5,3,i+1)
    plt.title(columns_lst[i])
    plt.xticks(rotation=45)
    plt.hist(df[columns_lst[i]])
    
plt.tight_layout()

# %%
RATING = df['rate'].value_counts().head()
RATING
# Out:
# rate
# 3.9    3246
# 4.0    2902
# 4.1    2827
# 3.8    2483
# 4.2    2124
# Name: count, dtype: int64

# %%
RATING.plot(kind='pie',autopct='%1.f%%')
plt.title('rating')
plt.show()

# %%
PLT = df[df['rate']==3.9].value_counts()[:20]
sns.set_style(style='whitegrid')
plt.figure(figsize=(5,5))
sns.distplot(PLT, label='Rate', color='tomato', kde=True)
plt.title('RATING')
plt.legend(loc=1)
plt.grid()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3380\3844715.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(PLT, label='Rate', color='tomato', kde=True)

# %%
df['rate'][df['rate']==3.9].count()
# Out:
# 3246

# %%
df_su = pd.DataFrame(df.groupby('votes')['votes'].count())
df_su.head()
# Out:
#        votes
# votes
# 0          4
# 8         10
# 9          4
# 10        11
# 25         7

# %%
df_hu = df.groupby('votes')['votes'].count()[:50]
sns.countplot(df_hu,label='Votes', color='tomato')
plt.title('Votes')
plt.legend(loc=1)
plt.grid()

# %%
sns.set_style(style='whitegrid')
plt.figure(figsize=(5,5))
sns.histplot(df['votes'], label='Votes', color='tomato', kde=True)
plt.title('Votes')
plt.legend(loc=1)
plt.grid()

# %%
plt.figure(figsize=(5,5))
sns.histplot(df['rate'], color='greenyellow', label='RATE',kde=True)
plt.legend()
plt.grid()

# %%
df['cuisines']
# Out:
# 0        1386
# 1         594
# 2         484
# 3        1587
# 4        1406
#          ...
# 23243    1318
# 23244     878
# 23245     539
# 23246      80
# 23247     878
# Name: cuisines, Length: 23248, dtype: int64

# %%
sns.histplot(data=df, x='cost', hue='online_order')
# Out:
# <Axes: xlabel='cost', ylabel='Count'>
