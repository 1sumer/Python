# %% [markdown]
# ## **Python Conditional Statements:**
# Conditional statements in Python are used to execute different blocks of code based on whether a specified condition evaluates to True or False. They are fundamental to programming as they enable the implementation of decision-making logic within programs. Python provides several conditional statements to facilitate this, namely if, else, elif, and nested conditionals.

# %% [markdown]
# ### **1.if Statement:**
# The if statement is the most basic conditional statement in Python. It allows you to execute a block of code only if a specified condition is true.
#
# **Syntax**
#
# <pre><code>if condition:
#     # block of code to be executed if condition is true </code></pre>

# %%
x = int(input("Enter a number: "))
if x > 5:
    print(f"{x} is greater than 5")
else:
    print(f"{x} is not greater than 5")
# Out:
# 4 is not greater than 5

# %%
x = 10
if x < 5:
    print("x is Less Than 5")
else:
    x+=1
    x = x+1
    print(x)
    print("x is Not Less than 5")
# Out:
# 12
# x is Not Less than 5

# %%
a = False #try assigning False to a
if a:
    print('Hello') #try removing the indentation
else:
    print('Bye')
# Out:
# Bye

# %%
a = [1,2,3,4,5,6]
if 10 in a:
    print("True")
else:
    print("False")
# Out:
# False

# %%
a = [1,2,3,4,5,6]
if type(a) == tuple:
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# ### **2.else Statement:**
# The else statement provides an alternative action for when the condition in the if statement is not met.
# - If the condition is true: Python runs the code inside the if block.
# - If the condition is false: Python skips the code inside the if block and moves to the else block, running the code inside it.
#
#
# **Syntax :**
#
# <pre><code>if condition:
#     # block of code to be executed if condition is true
# else:
#     # block of code to be executed if condition is false</code></pre>
#
# #### FLOW CHART:
# ![image.png](attachment:image.png)
#
# Conditional expression should only be of the form of Boolean. The output of the conditional expression can only either be TRUE or FALSE.

# %%
x = 4
if x % 2 != 0:
    print("x is odd")
else:
    print("x is even")
# Out:
# x is even

# %%
x = int(input('enter a numer: '))
if (x % 5 ==0):
    print('its divisible by 5')
else:
    print('its not divisible by 5')
# Out:
# its divisible by 5

# %%
x = int(input("Enter a number: "))
if x % 3 == 0:
    print("Divisible by 3")
else:
    print("Not Divisible by 3")
# Out:
# Divisible by 3

# %%
s = "Kayak"
s = s.lower()

if s == s[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Palindrome

# %%
list = ['p','y','t','h','o','n']
# Output : "python" 
string = ''.join(list)
print(string)
# Out:
# python

# %%
a = 'Listen'.lower()
b = 'Silent'.lower()
if sorted(a) == sorted(b):
    print("Anagram")
else:
    print("Not Anagram")
# Out:
# Anagram

# %%
a = 'List  en'.lower()
b = 'Sile nt'.lower()
a = a.replace(" ", "").lower()
b = b.replace(" ", "").lower()
if sorted(a) == sorted(b):
    print("Anagram")
else:
    print("Not Anagram")
# Out:
# Anagram

# %% [markdown]
# It's not always necessary to define the 'else' part for every 'if'
#
# We use comparison operators to form conditional expressions. Comparison operators can be clubbed with logical operators(and, or...) and bitwise operators(&, |...) to define complex expressions in simple forms.

# %%
#'a==4' is the conditional expression
a = 4
if a>=3: 
    print('Hello')
else:
    print('Bye')
# Out:
# Hello

# %%
a = int(input("enter a no:"))   
if a%2==0:
    print(f"{a} is even")
else:
    print(f"{a} is odd")
# Out:
# 16 is even

# %%
#Checking if a year is a leap year
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(year,"is a leap year.")
else:
    print(year,"is not a leap year.")
# Out:
# 2028 is a leap year.

# %%
a = int(input('Tell a number: '))

if a % 3 == 0 and a % 5 == 0:
    print(a, ' is divisible by both 3 and 5')
else:
    print(a, ' is not divisible by 3 or 5 or both')

print('We understood if-else')
# Out:
# 40  is not divisible by 3 itself, hence I won't check if it is divisible by 5
# We understood if-else

# %% [markdown]
# ### **3.elif Statement:**
# The elif statement, short for "else if", allows you to check multiple conditions sequentially. It is used when you have more than two possible outcomes.
#
# <pre><code>if condition1:
#     # block of code to be executed if condition1 is true
# elif condition2:
#     # block of code to be executed if condition1 is false and condition2 is true
# else:
#     # block of code to be executed if all conditions are false</code></pre>

# %%
#let's find if a number is divisible by both 3 and 5
a = int(input("Enter the value of a: "))

if a % 3 == 0 and a % 5 == 0:
    print(f"{a} is divisible by both 3 and 5")
elif a % 3 == 0:
    print(f"{a} is divisible by 3")
elif a % 5 == 0:
    print(f"{a} is divisible by 5")
else:
    print(f"{a} is not divisible by both 3 and 5")
# Out:
# 15 is divisible by both 3 and 5

# %%
a=5
b=4
if a == b:
    print("How did that happen?")
elif a > b:
    print("Yikes")
else:
    print("All is well with the world")
# Out:
# Yikes

# %%
d = [1,2,3,"true"]
if d[-3]>2:
    print("hay i am here")
elif d[-3]>=2:
    print("dont ask")
else:
    print("i am outside")
# Out:
# dont ask

# %%
a = int(input("Enter the value of a: "))

if a > 0:
    print(f"{a} is a positive number")
elif a < 0:
    print(f"{a} is a negative number")
else:
    print(f"{a} is zero")
# Out:
# 0 is zero

# %%
sub1=int(input("enter a marks sub1 "))
sub2=int(input("enter a marks sub2 "))
sub3=int(input("enter a marks sub3 "))
sub4=int(input("enter a marks sub4 "))
print(sub1,sub2,sub3,sub4)

totalmarks=sub1+sub2+sub3+sub4
print(f"{totalmarks} / 400")

percent=(totalmarks/400)*100
print(f"{percent} %")

if percent>=90:
    print("E")
elif percent<90 and percent>=80:
    print("A+")
elif percent<80 and percent>=70:
    print("A")
elif percent<70 and percent>=60:
    print("B+")
elif percent<60 and percent>=50:
    print("B")
else:
    print("Better luck next time")
# Out:
# 75 85 65 70
# 295 / 400
# 73.75 %
# A

# %% [markdown]
# ### **4.Nested if Statements:**
# Python allows you to nest conditional statements within one another, creating more complex decision-making logic.
#
# Nested if statements in Python are like opening a series of boxes inside another box. Each box (or if statement) contains its own instructions, and you can have one box inside another.
# ```
# if condition1:
#     # block of code
#     if condition2:
#         # block of code
#     else:
#         # block of code
# else:
#     # block of code
# ```

# %%
t = int(input('enter a number'))
if t % 3 ==0 and t % 5 ==0:
    print('divisible by 3 & 5') 
elif t % 5 ==0:
    print('divisible by 5')
else:
    print('not divisible by 3 & 5')

# %%
t = int(input('enter a number'))
if t % 3 ==0:
    if t % 5 ==0:
        print('divisible by 3 & 5')
    else:
        print('Only divisible by 3')
elif t % 5 ==0:
    print('divisible by 5')
else:
    print('not divisible by 3 & 5')
# Out:
# divisible by 5

# %%
x = 10
if x > 5:
    if x == 10:
        print("x is Greater Than 5 and equal to 10")
    else:
        print("x is greater than 5")
else:
    print("x is less than or equal to 5")
# Out:
# x is Greater Than 5 and equal to 10

# %%
x = int(input("Enter a number: "))

if x>0:
    if x%2==0:
        print(x,"is +ve even number")
    else:
        print(x,"is +ve odd number")
elif x < 0:
    if x%2==0:
        print(x,"is -ve even number")
    else:
        print(x,"is -ve odd number")
else:
    print(x,"is zero")
# Out:
# -12 is -ve even number

# %%
a = float(input("Enter the length of side a: "))
b = float(input("Enter the length of side b: "))
c = float(input("Enter the length of side c: "))

if a + b > c and a + c > b and b + c > a:
    if a == b == c:
        print("Equilateral triangle")
    elif a == b or b == c or a == c:
        print("Isosceles triangle")
    else:
        print("Scalene triangle")
else:
    print("Not a valid triangle")
# Out:
# Equilateral triangle

# %%
print("Simple Calculator")
print("1. Add")
print("2. Subtract")
print("3. Multiply")
print("4. Divide")

choice = input("Enter choice (1/2/3/4): ")

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if choice == '1':
    result = num1 + num2
    print("Result:", result)
elif choice == '2':
    result = num1 - num2
    print("Result:", result)
elif choice == '3':
    result = num1 * num2
    print("Result:", result)
elif choice == '4':
    if num2 != 0:
        result = num1 / num2
        print("Result:", result)
    else:
        print("Error: Division by zero")
else:
    print("Invalid choice")
# Out:
# Simple Calculator
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# Result: 2.0

# %%
s = input("Enter a text: ")
print(s)
if s == s[::-1]:
    print('string is a palindrome')
else:
    print('string is not a palindrome')
# Out:
# madam
# string is a palindrome

# %% [markdown]
# ### **5. Conditional Expressions (Ternary Operator)**
# - You can write simple if-else statements in a single line using the ternary operator

# %%
if a % 2 == 0:
    f"{a} is Even"
else:
    f"{a} is Odd"

# %%
a = int(input("Enter the first number: "))

even = f"{a} is Even" if a % 2 == 0 else f"{a} is Odd"
print(even)
# Out:
# 10 is Even

# %%
a = int(input("Enter the first number: "))

num = f"{a} is +ve number" if a > 0 else f"{a} is -ve number" if a < 0 else "Number is zero"
print(num)
# Out:
# Number is zero

# %%
b = int(input("Enter the number: "))

div = f"{b} is divisible by 3 & 5" if b%3==0 and b%5==0 else f"{b} is divisible by 3" if b%3==0 else f"{b } is divisible by 5" if b%5==0 else f"{b} is not divisible by 3 & 5"
print(div)
# Out:
# 23 is not divisible by 3 & 5

# %%
string = input("Enter a string: ")
Palindrome = "string is a palindrome" if string == string[::-1] else "string is not a palindrome"
print(Palindrome)
# Out:
# string is a palindrome

# %%
a = 'Listen'.lower()
b = 'Silent'.lower()

if sorted(a) == sorted(b): # sorted(a) == sorted(b)
    print("Anagram")
else:
    print("Not A anagram")
# Out:
# Anagram

# %%
c = "Anagram" if sorted(a) == sorted(b) else "Not Anagram"
c
# Out:
# 'Anagram'

# %% [markdown]
# ### **6. match-case Statement**
# - This is a more advanced conditional construct similar to a switch-case in other languages. It allows matching complex patterns.

# %%
a = 'start'

match a:
    case 'start':
        print('starts the Engine')
    case 'end':
        print('Stop the Engine')
    case _:
        print('Not Started')
# Out:
# starts the Engine

# %%
t = input("Enter a text")

match t:
    case _ if t == t[::-1]:
        print(f"{t} Palindrome")
    case _:
        print(f"{t} Not Palindrome")
# Out:
# madam Palindrome

# %%
num = int(input("Enter a number: "))

match num:
    case _ if num > 0:
        print(f"{num} is Positive number")
    case _ if num < 0:
        print(f"{num} Negative number")
    case _:
        print("Zero")
# Out:
# Zero

# %%
num = int(input("Enter a number: "))

match num:
    case _ if num % 2 == 0:  # Check if divisible by 2
        print(f"{num} is divisible by 2")
    case _:
        print(f"{num} is not divisible by 2")
# Out:
# 12 is divisible by 2

# %%
x = [10,12,14,16,18,20]

match x:
    case _ if 10 in x and 20 in x:
        print("10, 20 is present in the list")
    case _ if 20 in x:
        print("20 is present in the list")
    case _:
        print("Number not found")
# Out:
# 10, 20 is present in the list

# %% [markdown]
# **Notes:**
#
# - **Indentation:** In Python, indentation is used to define blocks of code. All statements within the same block must be indented consistently.
# - **Logical Operators:** You can use logical operators (and, or, not) to combine multiple conditions within a conditional statement.
# - **Multiple Conditions:** You can have as many elif clauses as needed to handle various conditions.
# - **Execution Flow:** Python evaluates the conditions sequentially, executing the block of code associated with the first true condition encountered.
