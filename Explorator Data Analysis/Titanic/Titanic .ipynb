# %% [markdown]
# # <p style="background-color:#B0766D;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Titanic Dataset Exploratory Data analysis</p>
# <img src="https://wallpapercave.com/wp/8OJhYbl.jpg" style="display: block; margin: 0 auto;">

# %% [markdown]
# **The objective of this study is to analyze the Titanic dataset to identify and understand the factors influencing survival outcomes among passengers.**
#
# - Investigate the impact of gender, age group, passenger class, and travel companionship on survival probabilities.
# - Identify potential patterns or trends in survival outcomes across different demographic and socio-economic groups.
# - Explore the underlying factors contributing to disparities in survival rates among passengers.
# - Provide insights and recommendations for improving disaster preparedness, safety measures, and emergency response protocols in transportation systems.

# %% [markdown]
# **Survived:** This column indicates whether the passenger survived the Titanic disaster (1) or not (0).
#
# **Pclass:** This column represents the passenger's socio-economic status or class, where 1 = Upper class, 2 = Middle class, and 3 = Lower class.
#
# **Name:** This column contains the name of the passenger.
#
# **Sex:** This column specifies the gender of the passenger, either male or female.
#
# **Age:** This column denotes the age of the passenger. Missing values are denoted as NaN.
#
# **SibSp:** This column indicates the number of siblings or spouses the passenger had aboard the Titanic.
#
# **Parch:** This column indicates the number of parents or children the passenger had aboard the Titanic.
#
# **Ticket:** This column contains the ticket number of the passenger.
#
# **Fare:** This column represents the fare paid by the passenger.
#
# **Embarked:** This column indicates the port of embarkation for the passenger, with C = Cherbourg, Q = Queenstown, and S = Southampton.
#
# **Age_group:** This column appears to be a categorical grouping of ages, likely created for analysis purposes. Categories include "Adult", "Middle Age", "Seniors", etc.

# %% [markdown]
# ### **Import Python Libraries**
#
# Import all libraries which are required for our analysis, such as Data Loading, Statistical analysis, Visualizations, Data Transformations, Merge and Joins, etc.
#
# Pandas and Numpy have been used for Data Manipulation and numerical Calculations
#
# Matplotlib and Seaborn have been used for Data visualizations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
#sns.load_dataset('titanic')

# %% [markdown]
# ### **Reading Dataset**
#
# The Pandas library offers a wide range of possibilities for loading data into the pandas DataFrame from files like JSON, .csv, .xlsx, .sql, .pickle, .html, .txt, images etc.
#
# Most of the data are available in a tabular format of CSV files. It is trendy and easy to access. Using the read_csv() function, data can be converted to a pandas DataFrame.
#
# In this article, the data to predict Used car price is being used as an example. In this dataset, we are trying to analyze the used car’s price and how EDA focuses on identifying the factors influencing the car price. We have stored the data in the DataFrame data.

# %%
df = pd.read_csv(r'D:\Python\EDA\Titanic\Titanic.csv')
df.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# #### **Understanding the Data:**
#
# Display basic information about the dataset such as the number of rows and columns, data types, and missing values.

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.shape
# Out:
# (891, 15)

# %% [markdown]
# There are 891 observations and 12 variables in our dataset

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# **data.info()**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %% [markdown]
# Calculate summary statistics for numerical variables (mean, median, min, max, etc.).

# %%
df.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
df.describe(include='object').T
# Out:
#             count unique          top freq
# sex           891      2         male  577
# embarked      889      3            S  644
# who           891      3          man  537
# embark_town   889      3  Southampton  644
# alive         891      2           no  549

# %% [markdown]
# ### **Finding The Missing Values**

# %% [markdown]
# **Missing Values Calculation**
#
# isnull() is widely been in all pre-processing steps to identify null values in the data
#
# In our example, data.isnull().sum() is used to get the number of missing records in each column

# %%
df['deck'].unique()
# Out:
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# - age: There are 177 missing values in the age column. This suggests that we need to handle these missing values before performing any analysis. You might consider imputing missing ages using techniques like mean, median.
# - embarked and embark_town: Both columns have 2 missing values each. These columns represent the port of embarkation. You could explore the distribution of the existing values to decide how to handle these missing entries. Common approaches include imputing with the mode or creating a new category for missing values.
# - deck: The deck column has a whopping 688 missing values. This column likely represents the deck or cabin number where passengers stayed. Given the high number of missing values, you might consider dropping this column from your analysis unless it serves a critical purpose.
# - Other columns: The remaining columns (survived, pclass, sex, sibsp, parch, fare, class, who, adult_male, alive, and alone) have no missing values. You can proceed with analyzing these columns without any imputation.

# %%
df.duplicated().sum()
# Out:
# 107

# %% [markdown]
# The number of duplicated rows in your DataFrame is 107. These duplicates might impact the accuracy of your analysis, so it’s essential to handle them appropriately. You can consider removing these duplicate rows using the drop_duplicates() method

# %% [markdown]
# ### **Data Reduction or Handling Missing Values**

# %% [markdown]
# ### **Data Cleaning:**
#
# - Handle missing values in the dataset (e.g., impute missing values, remove rows or columns with missing values).
# - Check for and handle duplicate rows, if any.
# - Check for and handle outliers in numerical variables.
#
# Some columns or variables can be dropped if they do not add value to our analysis.
#
# In our dataset, the column PassengerId and Cabin. have only ID values, assuming they don’t have any predictive power to predict the dependent variable.

# %%
columns_remove = ['deck', 'embarked','alive', 'pclass'] #remove deck, embarked, alive, pclass becouse deck has most null values other 3 columns are repeated columns
df.drop(columns = columns_remove, inplace=True)

# %%
df.head()
# Out:
#    survived     sex   age  sibsp  parch     fare  class    who  adult_male  \
# 0         0    male  22.0      1      0   7.2500  Third    man        True
# 1         1  female  38.0      1      0  71.2833  First  woman       False
# 2         1  female  26.0      0      0   7.9250  Third  woman       False
# 3         1  female  35.0      1      0  53.1000  First  woman       False
# 4         0    male  35.0      0      0   8.0500  Third    man        True
#
#    embark_town  alone
# 0  Southampton  False
# 1    Cherbourg  False
# 2  Southampton   True
# 3  Southampton  False
# 4  Southampton   True

# %% [markdown]
# ### **Handle missing values in the dataset**
#
# impute missing values

# %%
df['age'].fillna(round(df['age'].mean()), inplace=True)

# %%
df['embark_town'].mode()[0]
# Out:
# 'Southampton'

# %%
df['embark_town'].fillna(df['embark_town'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# survived       0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alone          0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (773, 11)

# %% [markdown]
# We start our Feature Engineering as we need to add some columns required for analysis.
#
# ### **Feature Engineering**
#
# Feature engineering refers to the process of using domain knowledge to select and transform the most relevant variables from raw data when creating a predictive model using machine learning or statistical modeling. The main goal of Feature engineering is to create meaningful data from raw data.
#
# ### **Creating Features**
#
# We will manipulate the variables related to age in our dataset. Upon examining the sample data, the 'Age' column represents the age of a person.
#
# However, it might be challenging to understand how age relates to survival.
#
# To address this, we will introduce a new column, 'Age_group', to categorize the ages of individuals.

# %%
def categorize(age):
    if age < 17.0:
        return 'Young'
    elif age<34.0:
        return 'Adult'
    elif age< 54.0:
        return 'Middle age'
    else:
        return 'Seniors'

# %%
df['Age_group'] = df['age'].apply(categorize)

# %%
df.head()
# Out:
#    survived     sex   age  sibsp  parch     fare  class    who  adult_male  \
# 0         0    male  22.0      1      0   7.2500  Third    man        True
# 1         1  female  38.0      1      0  71.2833  First  woman       False
# 2         1  female  26.0      0      0   7.9250  Third  woman       False
# 3         1  female  35.0      1      0  53.1000  First  woman       False
# 4         0    male  35.0      0      0   8.0500  Third    man        True
#
#    embark_town  alone   Age_group
# 0  Southampton  False       Adult
# 1    Cherbourg  False  Middle age
# 2  Southampton   True       Adult
# 3  Southampton  False  Middle age
# 4  Southampton   True  Middle age

# %%
df['Age_group'].unique()
# Out:
# array(['Adult', 'Middle age', 'Seniors', 'Young'], dtype=object)

# %%
for col in df.columns:
    print(col, df[col].unique())
# Out:
# survived [0 1]
# sex ['male' 'female']
# age [22.   38.   26.   35.   30.   54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 33.   23.   24.   46.   59.   71.   37.   47.   14.5
#  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.   56.
#  50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.   60.
#  10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.    0.67
#  30.5   0.42 34.5  74.  ]
# sibsp [1 0 3 4 2 5 8]
# parch [0 1 2 5 3 4 6]
# fare [  7.25    71.2833   7.925   53.1      8.05     8.4583  51.8625  21.075
#   11.1333  30.0708  16.7     26.55    31.275    7.8542  16.      29.125
#   13.      18.       7.225   26.       8.0292  35.5     31.3875 263.
#    7.8792   7.8958  27.7208 146.5208   7.75    10.5     82.1708  52.
#    7.2292  11.2417   9.475   21.      41.5792  15.5     21.6792  17.8
#   39.6875   7.8     76.7292  61.9792  27.75    46.9     80.      83.475
#   27.9     15.2458   8.1583   8.6625  73.5     14.4542  56.4958   7.65
#   29.      12.475    9.       9.5      7.7875  47.1     15.85    34.375
#   61.175   20.575   34.6542  63.3583  23.      77.2875   8.6542   7.775
#   24.15     9.825   14.4583 247.5208   7.1417  22.3583   6.975    7.05
#   14.5     15.0458  26.2833   9.2167  79.2      6.75    11.5     36.75
#    7.7958  12.525   66.6      7.3125  61.3792   7.7333  69.55    16.1
#   15.75    20.525   55.      25.925   33.5     30.6958  25.4667  28.7125
#    0.      15.05    39.      22.025   50.       8.4042   6.4958  10.4625
#   18.7875  31.     113.275   27.      76.2917  90.       9.35    13.5
#    7.55    26.25    12.275    7.125   52.5542  20.2125  86.5    512.3292
#   79.65   153.4625 135.6333  19.5     29.7     77.9583  20.25    78.85
#   91.0792  12.875    8.85   151.55    30.5     23.25    12.35   110.8833
#  108.9     24.      56.9292  83.1583 262.375   14.     164.8667 134.5
#    6.2375  57.9792  28.5    133.65    15.9      9.225   35.      75.25
#   69.3     55.4417 211.5      4.0125 227.525   15.7417   7.7292  12.
#  120.      12.65    18.75     6.8583  32.5      7.875   14.4     55.9
#    8.1125  81.8583  19.2583  19.9667  89.1042  38.5      7.725   13.7917
#    9.8375   7.0458   7.5208  12.2875   9.5875  49.5042  78.2667  15.1
#    7.6292  22.525   26.2875  59.4      7.4958  34.0208  93.5    221.7792
#  106.425   49.5     71.      13.8625   7.8292  39.6     17.4     51.4792
#   26.3875  30.      40.125    8.7125  15.      33.      42.4     15.55
#   65.      32.3208   7.0542   8.4333  25.5875   9.8417   8.1375  10.1708
#  211.3375  57.      13.4167   7.7417   9.4833   7.7375   8.3625  23.45
#   25.9292   8.6833   8.5167   7.8875  37.0042   6.45     6.95     8.3
#    6.4375  39.4     14.1083  13.8583  50.4958   5.       9.8458  10.5167]
# class ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']
# who ['man' 'woman' 'child']
# adult_male [ True False]
# embark_town ['Southampton' 'Cherbourg' 'Queenstown']
# alone [False  True]
# Age_group ['Adult' 'Middle age' 'Seniors' 'Young']

# %%
df.describe().T
# Out:
#           count       mean        std   min    25%   50%     75%       max
# survived  773.0   0.415265   0.493087  0.00   0.00   0.0   1.000    1.0000
# age       773.0  29.836248  13.770979  0.42  21.00  30.0  36.000   80.0000
# sibsp     773.0   0.529107   0.991280  0.00   0.00   0.0   1.000    8.0000
# parch     773.0   0.421734   0.841380  0.00   0.00   0.0   1.000    6.0000
# fare      773.0  35.058996  52.442778  0.00   8.05  16.1  34.375  512.3292

# %%
df.describe(include='object').T
# Out:
#             count unique          top freq
# sex           773      2         male  482
# who           773      3          man  442
# embark_town   773      3  Southampton  563
# Age_group     773      4        Adult  432

# %% [markdown]
# ### **Data Visulization**

# %% [markdown]
# Sapareting the Columns into Categorical and Numarical columns

# %%
cat_col = df.select_dtypes(include='object').columns
num_col = df.select_dtypes(include = np.number).columns.tolist() #exclude = 'object'

print(cat_col)
print(num_col)
# Out:
# Index(['sex', 'who', 'embark_town', 'Age_group'], dtype='object')
# ['survived', 'age', 'sibsp', 'parch', 'fare']

# %% [markdown]
# ### **EDA Univariate Analysis**
#
# Analyzing/visualizing the dataset by taking one variable at a time:
#
# Data visualization is essential; we must decide what charts to plot to better understand the data. In this article, we visualize our data using Matplotlib and Seaborn libraries.
#
# Matplotlib is a Python 2D plotting library used to draw basic charts we use Matplotlib.
#
# Seaborn is also a python library built on top of Matplotlib that uses short lines of code to create and style statistical plots from Pandas and Numpy
#
# Univariate analysis can be done for both Categorical and Numerical variables.
#
# Categorical variables can be visualized using a Count plot, Bar Chart, Pie Plot, etc.
#
# Numerical Variables can be visualized using Histogram, Box Plot, Density Plot, etc.
#
# In our example, we have done a Univariate analysis using Histogram and  Box Plot for continuous Variables.
#
# In the below fig, a histogram and box plot is used to show the pattern of the variables, as some variables have skewness and outliers.

# %%
df.survived.value_counts()
# Out:
# survived
# 0    452
# 1    321
# Name: count, dtype: int64

# %%
# Univeriate analysis
for col in num_col:
    print(col)
    plt.subplot(1,1,1)
    df[col].plot(kind = 'hist', alpha=0.5, bins=20, color='r') 
    plt.ylabel('frequency')
    plt.show()
# Out:
# survived
# age
# sibsp
# parch
# fare

# %% [markdown]
# - The proportion of individuals who did not survive is higher than those who did.
# - The age group between 20 and 40 had the highest number of travelers.
# - Travelers with 1 sibling/spouse were more common.
# - Travelers with 1 or 2 parents/children were more prevalent.

# %%
df['sex'].value_counts()
# Out:
# sex
# male      482
# female    291
# Name: count, dtype: int64

# %%
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    563
# Cherbourg      153
# Queenstown      57
# Name: count, dtype: int64

# %%
df['Age_group'].value_counts()
# Out:
# Age_group
# Adult         432
# Middle age    193
# Young          99
# Seniors        49
# Name: count, dtype: int64

# %%
df['who'].value_counts()
# Out:
# who
# man      442
# woman    249
# child     82
# Name: count, dtype: int64

# %% [markdown]
# Analyze the distribution of categorical variables using Countplot.

# %%
for col in cat_col:
    plt.figure()
    plt.subplot(1,1,1)
    sns.countplot(x=col, data=df, order=df[col].value_counts().index, palette='viridis')
    plt.show()

# %%
# Suppress the palette warning
warnings.filterwarnings("ignore")

plt.figure(figsize= (10,14))
plt.subplot(3,2,1)
sns.countplot( x='sex', data=df, order = df['sex'].value_counts().index, palette='Set1')

plt.subplot(3,2,2)
sns.countplot( x='embark_town', data=df, order = df['embark_town'].value_counts().index, palette='Set2')

plt.subplot(3,2,3)
sns.countplot( x='Age_group', data=df, order = df['Age_group'].value_counts().index, palette='Set3')

plt.subplot(3,2,4)
sns.countplot( x='class', data=df, order = df['class'].value_counts().index, palette='Set1')

plt.subplot(3,2,5)
sns.countplot( x='who', data=df, order = df['who'].value_counts().index, palette='Set2')

plt.tight_layout()
plt.show()

# %% [markdown]
# - Gender Distribution: More males than females. Red bars represent males, blue bars represent females.
# - Embarkation Towns: Southampton (S) had the highest number of passengers, followed by Cherbourg (C), and Queenstown (Q) had the fewest.
# - Age Groups: Majority are adults (17 to 33 years), followed by middle-aged passengers (34 to 53 years). Young passengers (less than 17 years) and seniors (54 years and above) have lower representation.
# - Passenger Classes (Pclass): Third class (3rd) has the highest count, followed by first class (1st) and then second class (2nd).
# - Who (Man, Woman, Child): Men are the most numerous, followed by women, with children being the least represented.

# %% [markdown]
# ### **Multivariate Analysis**

# %%
corr = df[num_col].corr()
sns.heatmap(corr,annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# **Correlation between Variables:**
#
# - Heatmap displays correlation coefficients between survived, age, sibsp, parch, and fare.
# - Positive values indicate positive correlation, negative values indicate inverse correlation.

# %% [markdown]
# ### **EDA Bivariate Analysis**
#
# Now, let’s move ahead with bivariate analysis. Bivariate Analysis helps to understand how variables are related to each other and the relationship between dependent and independent variables present in the dataset.
#
# For Numerical variables, Pair plots and Scatter plots are widely been used to do Bivariate Analysis.
#
# A Stacked bar chart can be used for categorical variables if the output variable is a classifier. Bar plots can be used if the output variable is continuous
#
# In our example, a pair plot has been used to show the relationship between two Categorical variables.
#
# Analyze relationships between multiple variables simultaneously

# %% [markdown]
# Use appropriate visualizations to present key findings and insights from your analysis.

# %%
plt.figure(figsize=(12,6))

ax = plt.subplot(1,2,1)
ax = sns.countplot(x='survived', data=df)
ax.set_xticklabels(['Unsurvived', 'Survived'])
ax.bar_label(ax.containers[0])
plt.title("Survived", fontsize=20, fontweight= 'bold')

ax = plt.subplot(1,2,2)
ax=df['survived'].value_counts().plot.pie(labels = ['Unsurvived','Survived'],explode=[0, 0.1],autopct='%1.f%%',shadow=True);
ax.set_title(label = "Survived", fontsize = 20,color='Red',font='Lucida Calligraphy', fontweight= 'bold')
# Out:
# Text(0.5, 1.0, 'Survived')

# %% [markdown]
# - It shows that 455 individuals did not survive, while 320 individuals survived.
#     - Approximately 59% of passengers did not survive (represented by the larger blue section).
#     - Approximately 41% of passengers unsurvived (represented by the smaller orange section).

# %%
plt.figure(figsize=(12,6))

ax = plt.subplot(1,2,1)
ax = sns.countplot(x='sex', data=df)
ax.bar_label(ax.containers[0])
plt.title("Gender", fontsize=20)
ax =plt.subplot(1,2,2)
ax=df['sex'].value_counts().plot.pie(explode=[0, 0.1],autopct='%1.2f%%',shadow=True);
ax.set_title(label = "Gender", fontsize = 20,color='Red',font='Lucida Calligraphy');

# %% [markdown]
# - It shows that 483 individuals are male, while 292 individuals are female.
#     - Approximately 62.32% of individuals are male (represented by the larger blue section).
#     - Approximately 37.68% of individuals are female (represented by the smaller orange section).

# %%
plt.figure(figsize=(12,6))

ax = plt.subplot(1,2,1)
ax = sns.countplot(x='who', data=df)
ax.bar_label(ax.containers[0])
plt.title("Gender", fontsize=20)
ax =plt.subplot(1,2,2)
ax=df['who'].value_counts().plot.pie(explode=[0, 0.1 , 0.2],autopct='%1.f%%',shadow=True);
ax.set_title(label = "Gender", fontsize = 20,color='Red',font='Lucida Calligraphy');

# %% [markdown]
# - It shows that 443 individuals are male, while 250 individuals are female, and 82 individuals are children.
#     - Approximately 57.16% of individuals are male (represented by the larger blue section).
#     - Approximately 32.26% of individuals are female (represented by the smaller orange section).
#     - Approximately 10.58% of individuals are children (represented by the green section).

# %%
df.groupby(['sex', 'survived'])['survived'].count()
# Out:
# sex     survived
# female  0            76
#         1           215
# male    0           376
#         1           106
# Name: survived, dtype: int64

# %%
df.groupby(['class','survived'])['survived'].count()
# Out:
# class   survived
# First   0            77
#         1           135
# Second  0            81
#         1            82
# Third   0           294
#         1           104
# Name: survived, dtype: int64

# %%
df.groupby(['who','survived'])['survived'].count()
# Out:
# who    survived
# child  0            34
#        1            48
# man    0           357
#        1            85
# woman  0            61
#        1           188
# Name: survived, dtype: int64

# %%
df.groupby(['adult_male', 'survived'])['survived'].count()
# Out:
# adult_male  survived
# False       0            95
#             1           236
# True        0           357
#             1            85
# Name: survived, dtype: int64

# %%
df.groupby(['embark_town', 'survived'])['survived'].count()
# Out:
# embark_town  survived
# Cherbourg    0            63
#              1            90
# Queenstown   0            38
#              1            19
# Southampton  0           351
#              1           212
# Name: survived, dtype: int64

# %%
df.groupby(['alone', 'survived'])['survived'].count()
# Out:
# alone  survived
# False  0           164
#        1           173
# True   0           288
#        1           148
# Name: survived, dtype: int64

# %%
df.groupby(['sibsp','survived'])['survived'].count()
# Out:
# sibsp  survived
# 0      0           312
#        1           195
# 1      0            93
#        1           107
# 2      0            15
#        1            12
# 3      0            10
#        1             4
# 4      0            15
#        1             3
# 5      0             5
# 8      0             2
# Name: survived, dtype: int64

# %%
df.groupby(['parch','survived'])['survived'].count()
# Out:
# parch  survived
# 0      0           355
#        1           214
# 1      0            51
#        1            63
# 2      0            35
#        1            40
# 3      0             2
#        1             3
# 4      0             4
# 5      0             4
#        1             1
# 6      0             1
# Name: survived, dtype: int64

# %%
df.groupby(['Age_group','survived'])['survived'].count()
# Out:
# Age_group   survived
# Adult       0           263
#             1           169
# Middle age  0           111
#             1            82
# Seniors     0            33
#             1            16
# Young       0            45
#             1            54
# Name: survived, dtype: int64

# %%
plt.figure(figsize=(14,18))

plt.subplot(3, 2, 1)
sns.countplot(x='sex', hue='survived', data=df, palette='Set1')
plt.legend(title='Survived', loc='upper right')
plt.title('Survivor by gender')

plt.subplot(3,2,2)
sns.countplot(x='class', hue='survived', data=df, palette='Set2')
plt.legend(title='Survived', loc=1)#'upper right'
plt.title('survivor by class')

plt.subplot(3,2,3)
sns.countplot(x='who', hue='survived', data=df, palette='Set3')
plt.legend(title='Survived', loc=1)#'upper right'
plt.title('survivor by Type of Gender')

plt.subplot(3,2,4)
sns.countplot(x='embark_town', hue='survived', data=df, palette='Greens')
plt.legend(title='Survived', loc=1)#'upper right'
plt.title('survivor by embark_town')

plt.subplot(3,2,5)
sns.countplot(x='alone', hue='survived', data=df, palette='colorblind')
plt.legend(title='Survived', loc=1)#'upper right'
plt.title('survivor by alone')

plt.show()

# %% [markdown]
# - A significant number of females survived compared to males.
# - The survival rate for females appears to be higher.
# - First-class passengers have the highest number of survivors.
# - Second-class passengers come next, followed by third-class passengers.
# - Women and children have significantly higher numbers of survivors compared to men.
# - The survival rate for children is also notable.
# - Passengers who embarked from Cherbourg have the highest number of survivors.
# - Southampton and Queenstown follow with fewer survivors.
# - Individuals who were not alone (i.e., accompanied) have a slightly higher number of survivors.

# %%
plt.figure(figsize=(14,14))

plt.subplot(2,2,1)
sns.countplot(x='adult_male', hue='survived', data=df, palette='Set1')
plt.legend(title='Survived', loc=1)#'upper right'
plt.title('survivor by adult_male')

plt.subplot(2,2,2)
sns.countplot(x='Age_group', hue='survived', data=df, palette='Greens')
plt.legend(title='Survived', loc=1)
plt.title('survivor by Age_group')

plt.subplot(2,2,3)
sns.countplot(x='sibsp', hue='survived', data=df, palette='Set2')
plt.legend(title='Survived', loc=1)#'upper right'
plt.title('survivor by sibsp')

plt.subplot(2,2,4)
sns.countplot(x='parch', hue='survived', data=df, palette='Set3')
plt.legend(title='Survived', loc=1)
plt.title('survivor by parch')

plt.show()

# %% [markdown]
# - A significant proportion of adult males did not survive (indicated by the taller red bar under “True”).
# - This suggests that adult males were less likely to survive.
# - The “Young” age group had a notably higher survival rate (as indicated by the taller green bar).
# - Middle-aged individuals had a lower survival rate.
# - Seniors also had a lower survival rate.
# - Overall, age played a crucial role in survival.
# - Individuals with one sibling/spouse onboard had a relatively higher survival rate (green bar).
# - The number of siblings/spouses seemed to impact survival.
# - Those with three parents/children onboard had a taller green bar, indicating more survivors.
# - The number of parents/children also influenced survival.

# %%
survival_rate_by_class_gender = df.groupby(['class', 'sex', 'survived'])['survived'].count()
survival_rate_by_class_gender.plot(kind='bar', color = ['blue', 'orange', 'green'], alpha = 0.7)
plt.title("Survival by class and grnder")
plt.xticks(rotation=90)
plt.show()

# %%
cross_tab = pd.crosstab(index=[df['survived'], # First factor to compare
                               df['sex']], # second factor to compare
                        columns=df['class']) # the factor we want as our "column"
cross_tab
# Out:
# class            First  Second  Third
# survived sex
# 0        female      3       6     67
#          male       74      75    227
# 1        female     90      65     60
#          male       45      17     44

# %%
survival_by_class = pd.crosstab(index=df['class'], columns=df['survived'])
survival_by_class.plot(kind='bar', stacked=True, title='Survival by Passenger Class')
# Out:
# <Axes: title={'center': 'Survival by Passenger Class'}, xlabel='class'>

# %%
cla = sns.FacetGrid(data = df, col='class')
cla = cla.map(plt.hist, 'age')

# %% [markdown]
# ### **Obsevation**
#
# - the dataset shows thet the survival rate is 62%indicating that the majoriy of passengersarenot survive the titanic disaster
# - Young passengers are survived compared to other agr group
# - female passengers are survived compared male passengers
# - travel with companionship are survied more
# - first class passengers are alived more than other class

# %% [markdown]
# **Survival Rate:** The dataset shows that the survival rate is 62%, indicating that the majority of passengers did not survive the Titanic disaster.
#
# **Gender Disparity:** Among the passengers, males had a higher mortality rate compared to females, with 65% of males not surviving compared to 35% of females.
#
# **Age Group Disparity:** Analysis based on age groups reveals that adults had the highest number of casualties, followed by middle-aged individuals. Conversely, young passengers had a higher likelihood of survival compared to other age groups. Seniors also faced high mortality rates.
#
# **Gender Disparity Across Survival:** While males experienced higher casualties overall, females exhibited a higher survival rate, indicating that gender played a significant role in determining survival outcomes.
#
# **Class Disparity:** Passengers in first class had the highest survival rate, followed by those in second class. However, passengers in third class faced the highest mortality rate, with a notable peak in casualties.
#
# **Sibling/Spouse Disparity:** Passengers traveling with no siblings or spouse had a higher chance of survival compared to those traveling with one or more siblings or spouse.

# %% [markdown]
# ### **Conclusion:**
#
# - The analysis of the Titanic dataset highlights significant disparities in survival outcomes based on gender, age group, passenger class, and travel companionship.
# - Females and young individuals were more likely to survive, while males, adults, and passengers in lower-class accommodations faced higher mortality rates.
# - These findings underscore the complex dynamics of disaster response and the impact of socio-demographic factors on survival probabilities.
# - Further investigation into the underlying factors driving these disparities may provide valuable insights into historical events and inform future disaster preparedness efforts.
