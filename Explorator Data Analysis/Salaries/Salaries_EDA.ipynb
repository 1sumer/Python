# %% [markdown]
# ### **Salaries EDA**
# This is the Salaries dataset which involves the details and information of a particular individual with their Job Title, BasePay, OvertimePay, OtherPay, Benefits, TotalPay etc.
#
# #### **Problem Statement**
# 1.Display Top 10 Rows of The Dataset
# 2. Check Last 10 Rows of The Dataset
# 3. Find Shape of Our Datset (Number of Rows And Number Of Columns)
# 4. Getting Information About Our Dataset Like Total Number Rows
# 5. Check Null Values In The Dataset
# 6. Drop ID, Notes,Benefits and Status Columns
# 7. Get Overall Statistics About The Dataframe
# 8. Find Occurence of The Employee Names (Top 5)
# 9. Find The Number of Unique Job Titles
# 10.Total Number of Job Titles Contain Captain
# 11. Displays All The Employee Names From Fire Department
# 12. Find Minimum, Maximum And Average BasePay
# 13. Replace 'Not Provided' in EmployeeName' Column to NaN
# 14. Drop THe Rows Having More Than 5 Missing Values
# 15. Find Job Title of NATHANIEL FORD
# 16. year-wise gain for the employee with the highest total pay and benefits?
# 17. Display Name of The Person Having The Highest BasePay
# 18. Find Average BasePay of All Employee Per Year
# 19. Find Average BasePay of All Employee Per Job Title
# 20. Find Average BasePAy of Employee HAving Job Title ACCOUNTANT
# 21. Find Top 5 Most Common Jobs
# 22. Visualize the distribution of BasePay, OvertimePay, and OtherPay using histograms or kernel density plots

# %% [markdown]
# #### **Importing Necessary Libraries**
# Importing the necessary libraries which are required for the analysis of the dataset. The Python libraries help in analysing and visualising the dataset and get the insights in the defined the way.
#
# - Numpy and Pandas are mainly used for numerical calculation and data manipulation.
# - Matplotlib and Seaborn and used for creating insightful visuals which gives clear picture of the data present in it.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'D:\Python\Explorator Data Analysis\Salaries\Salaries.csv')

# %% [markdown]
# 1. Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %% [markdown]
# 2. Check Last 10 Rows of The Dataset

# %%
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %% [markdown]
# 3. Find Shape of Our Datset (Number of Rows And Number Of Columns)

# %%
df.shape
# Out:
# (148654, 13)

# %% [markdown]
# The shape operation of Pandas finds out the number of rows and columns available in the dataset. It helps in knowing whether the dataset is small or large.

# %%
df.size
# Out:
# 1932502

# %% [markdown]
# The size operation gives the number of values or the data present in the whole dataset.

# %% [markdown]
# 4. Getting Information About Our Dataset Like Total Number Rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# The info() operation of Pandas is very helpful for the coders or the analysts as it gives the information of each and every column present in the dataset, which includes the Column Name, Count of Not Null values and the DataType of each column.

# %% [markdown]
# 5. Check Null Values In The Dataset

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# The isnull() operation is used to know the number of null values present in the whole dataset.

# %%
df.nunique()
# Out:
# Id                  148654
# EmployeeName        110811
# JobTitle              2159
# BasePay             109900
# OvertimePay          66555
# OtherPay             84968
# Benefits             99635
# TotalPay            138486
# TotalPayBenefits    142098
# Year                     4
# Notes                    0
# Agency                   1
# Status                   2
# dtype: int64

# %% [markdown]
# The nunique operation is used to findout the number of unique values in the dataset.

# %%
for col in df.columns:
    print(f"{col} : {df[col].unique()}")
# Out:
# Id : [     1      2      3 ... 148652 148653 148654]
# EmployeeName : ['NATHANIEL FORD' 'GARY JIMENEZ' 'ALBERT PARDINI' ... 'Charlene D Mccully'
#  'Not provided' 'Joe Lopez']
# JobTitle : ['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY'
#  'CAPTAIN III (POLICE DEPARTMENT)' 'WIRE ROPE CABLE MAINTENANCE MECHANIC'
#  ... 'Conversion' 'Cashier 3' 'Not provided']
# BasePay : [167411.18 155966.02 212739.13 ... '6.04' '15.50' 'Not Provided']
# OvertimePay : [0.0 245131.88 106088.18 ... '102.70' '56.77' 'Not Provided']
# OtherPay : [400184.25 137811.38 16452.6 ... '13.35' 'Not Provided' '-618.13']
# Benefits : [nan 44430.12 69810.19 ... '0.13' '1.24' 'Not Provided']
# TotalPay : [ 5.6759543e+05  5.3890928e+05  3.3527991e+05 ...  1.2890000e+01
#   6.0000000e+00 -6.1813000e+02]
# TotalPayBenefits : [ 5.6759543e+05  5.3890928e+05  3.3527991e+05 ...  1.2890000e+01
#   7.2400000e+00 -6.1813000e+02]
# Year : [2011 2012 2013 2014]
# Notes : [nan]
# Agency : ['San Francisco']
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 6. Drop ID, Notes,Benefits and Status Columns

# %%
df.drop(columns = ['Id', 'Status', 'Benefits', 'Notes'], inplace=True)

# %% [markdown]
# The Pandas drop operation removes the specified rows and columns from the dataset which are further not required for analysis.

# %%
df.head()
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay   TotalPay  TotalPayBenefits  Year  \
# 0  167411.18         0.0  400184.25  567595.43         567595.43  2011
# 1  155966.02   245131.88  137811.38  538909.28         538909.28  2011
# 2  212739.13   106088.18    16452.6  335279.91         335279.91  2011
# 3    77916.0    56120.71   198306.9  332343.61         332343.61  2011
# 4   134401.6      9737.0  182234.59  326373.19         326373.19  2011
#
#           Agency
# 0  San Francisco
# 1  San Francisco
# 2  San Francisco
# 3  San Francisco
# 4  San Francisco

# %%
df.shape
# Out:
# (148654, 9)

# %%
df.isnull().sum()
# Out:
# EmployeeName        2
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %%
# Replace non-numeric values in 'BasePay' with NaN
df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')
df['OvertimePay'] = pd.to_numeric(df['OvertimePay'], errors='coerce')
df['OtherPay'] = pd.to_numeric(df['OtherPay'], errors='coerce')

# %%
df['BasePay']
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148649         0.00
# 148650          NaN
# 148651          NaN
# 148652          NaN
# 148653         0.00
# Name: BasePay, Length: 148654, dtype: float64

# %% [markdown]
# 7. Drop THe Rows Having More Than 5 Missing Values

# %%
df.dropna(subset=['BasePay'], inplace=True)

# %% [markdown]
# 8. Replace 'Not Provided' in EmployeeName' Column to NaN

# %%
df['EmployeeName'].replace({'Not Provided': np.nan}, inplace=True)

# %% [markdown]
# 9. Get Overall Statistics About The Dataframe

# %%
df.describe().T
# Out:
#                      count          mean           std      min       25%  \
# BasePay           148045.0  66325.448840  42764.635495  -166.01  33588.20
# OvertimePay       148045.0   5086.740800  11473.181557    -0.01      0.00
# OtherPay          148045.0   3645.661408   8019.498636 -7058.59      0.00
# TotalPay          148045.0  75057.851048  50409.761170  -618.13  36958.16
# TotalPayBenefits  148045.0  94038.185067  62683.477905  -618.13  45077.41
# Year              148045.0   2012.520653      1.119390  2011.00   2012.00
#
#                        50%        75%        max
# BasePay           65007.45   94691.05  319275.01
# OvertimePay           0.00    4695.71  245131.88
# OtherPay            817.17    4242.90  400184.25
# TotalPay          71644.71  106028.00  567595.43
# TotalPayBenefits  92675.51  133085.41  567595.43
# Year               2013.00    2014.00    2014.00

# %%
df.describe(include='object').T
# Out:
#                count  unique               top    freq
# EmployeeName  148043  110312         Kevin Lee      13
# JobTitle      148045    2154  Transit Operator    6975
# Agency        148045       1     San Francisco  148045

# %% [markdown]
# The describe() operation of Pandas is very important as it gives the statistical description of every column in the dataset, which includes the Count, Mean, Standard Deviation, Minimum, Maximum, 1st quartile, 2nd quartile and 3rd quartile.
#
# **T :** It represents the transpose function which converts the rows into columns and columns into rows.

# %% [markdown]
# 10. Find Occurence of The Employee Names (Top 5)

# %%
# Find Occurence of The Employee Names (Top 5)

# Find the top 5 most common job titles.
top_5 = df['EmployeeName'].value_counts().head(5)

# Use a bar chart to display the data.
top_5.plot(kind='bar')
plt.show()

# %% [markdown]
# 11. Find The Number of Unique Job Titles

# %%
df['JobTitle'].unique().tolist()
# Out:
# ['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#  'CAPTAIN III (POLICE DEPARTMENT)',
#  'WIRE ROPE CABLE MAINTENANCE MECHANIC',
#  'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)',
#  'ASSISTANT DEPUTY CHIEF II',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'DEPUTY DIRECTOR OF INVESTMENTS',
#  'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#  'ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#  'EXECUTIVE CONTRACT EMPLOYEE',
#  'DEPARTMENT HEAD V',
#  'COMMANDER III, (POLICE DEPARTMENT)',
#  'CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#  'ASSISTANT MEDICAL EXAMINER',
#  'CAPTAIN, FIRE SUPPRESSION',
#  'CHIEF OF POLICE',
#  'DEPUTY CHIEF III (POLICE DEPARTMENT)',
#  'INSPECTOR III, (POLICE DEPARTMENT)',
#  'ELECTRONIC MAINTENANCE TECHNICIAN',
#  'ADMINISTRATOR, SFGH MEDICAL CENTER',
#  'LIEUTENANT III (POLICE DEPARTMENT)',
#  'FIREFIGHTER',
#  'NURSING SUPERVISOR PSYCHIATRIC',
#  'MAYOR',
#  'LIEUTENANT, FIRE DEPARTMENT',
#  'INCIDENT SUPPORT SPECIALIST',
#  'ANESTHETIST',
# ...

# %% [markdown]
# 12. Total Number of Job Titles Contain Captain

# %%
df[df['JobTitle'].str.contains('Captain')]['JobTitle']
# Out:
# 36167                     Captain 3
# 36180     Captain, Fire Suppression
# 36184     Captain, Fire Suppression
# 36186     Captain, Fire Suppression
# 36189     Captain, Fire Suppression
#                     ...
# 116604    Captain, Fire Suppression
# 120867                    Captain 3
# 122361    Captain, Fire Suppression
# 126588                    Captain 3
# 132232    Captain, Fire Suppression
# Name: JobTitle, Length: 410, dtype: object

# %% [markdown]
# 13. Displays All The Employee Names From Fire Department

# %%
df[df['JobTitle'].str.contains('FIRE DEPARTMENT')]['EmployeeName'].tolist()
# Out:
# ['PATRICK GARDNER',
#  'ALSON LEE',
#  'MICHAEL MORRIS',
#  'JOANNE HAYES-WHITE',
#  'ARTHUR KENNEY',
#  'DAVID FRANKLIN',
#  'MARTY ROSS',
#  'VICTOR WYRSCH',
#  'RAYMOND GUZMAN',
#  'MONICA FIELDS',
#  'JOSE VELO',
#  'BRENDAN WARD',
#  'MICHAEL THOMPSON',
#  'THOMAS ABBOTT',
#  'THOMAS SIRAGUSA',
#  'BRYAN RUBENSTEIN',
#  'KEN YEE',
#  'KIRK RICHARDSON',
#  'KENNETH SMITH',
#  'CHARLES CRANE',
#  'ROBERT POSTEL',
#  'RICHARD BUSALACCHI',
#  'KEVIN BURKE',
#  'EDUARDO GONZALEZ',
#  'ROBERT WINSLOW',
#  'LORRIE KALOS',
#  'MICHAEL BRYANT',
#  'MARK GONZALES',
#  'REX HALE',
#  'KEVIN SMITH',
#  'KEVIN TAYLOR',
#  'ERIKA HOO',
#  'SAMSON LAI',
#  'KHAIRUL ALI',
#  'JOHN HICKEY',
#  'EDWARD CHU',
#  'ZACHARY PUMPHREY',
#  'MARK CASTAGNOLA',
#  'LUIS IBARRA-RIVERA',
#  'MICHAEL KEARNEY',
#  'MATTHEW MCNAUGHTON',
#  'GEORGE LYSENKO',
#  'ALBERTO PEDRUCO',
#  'DWAYNE CURRY',
#  'DENNIS SUTTER',
#  'ROBERT SERRANO',
#  'JAMES VANNUCCHI',
#  'CANTREZ TRIPLETT',
#  'RYAN KENNEDY',
# ...

# %% [markdown]
# 14. Find Minimum, Maximum And Average BasePay

# %%
print(f"Maximum BasePay {df['BasePay'].max()}")
print(f"Minimum BasePay {df['BasePay'].min()}")
print(f"Average BasePay {df['BasePay'].mean()}")
# Out:
# Maximum BasePay 319275.01
# Minimum BasePay -166.01
# Average BasePay 66325.44884048768

# %% [markdown]
# 15. Find Job Title of NATHANIEL FORD

# %%
df['JobTitle'][df['EmployeeName'] == 'NATHANIEL FORD']
# Out:
# 0    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# Name: JobTitle, dtype: object

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'TotalPay', 'TotalPayBenefits', 'Year', 'Agency'],
#       dtype='object')

# %% [markdown]
# 16. year-wise gain for the employee with the highest total pay and benefits?

# %%
df.groupby(['Year']).agg({'TotalPay':'sum', 'TotalPayBenefits':'sum'})
# Out:
#           TotalPay  TotalPayBenefits
# Year
# 2011  2.594195e+09      2.594195e+09
# 2012  2.724848e+09      3.696940e+09
# 2013  2.915985e+09      3.808882e+09
# 2014  2.876911e+09      3.821866e+09

# %% [markdown]
# 17. Display Name of The Person Having The Highest BasePay

# %%
max_basepay = df['BasePay'].max()
df[df['BasePay'] == max_basepay]['EmployeeName']
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %% [markdown]
# 18. Find Average BasePay of All Employee Per Year

# %%
df.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# 19. Find Average BasePay of All Employee Per Job Title

# %%
df.groupby('JobTitle')['BasePay'].mean().to_frame().reset_index().sort_values('BasePay', ascending=False).head(5)
# Out:
#                                    JobTitle        BasePay
# 473                         Chief of Police  309767.683333
# 474                  Chief, Fire Department  304232.340000
# 836              Gen Mgr, Public Trnsp Dept  297769.413333
# 324  CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.000000
# 620            Dep Dir for Investments, Ret  276153.765000

# %% [markdown]
# 20. Find Average BasePAy of Employee HAving Job Title ACCOUNTANT

# %%
df[df['JobTitle'] == 'ACCOUNTANT'].groupby('JobTitle')['BasePay'].mean()
# Out:
# JobTitle
# ACCOUNTANT    46643.172
# Name: BasePay, dtype: float64

# %% [markdown]
# 21. Find Top 5 Most Common Jobs

# %%
df['JobTitle'].value_counts().head()
# Out:
# JobTitle
# Transit Operator                6975
# Special Nurse                   4382
# Registered Nurse                3725
# Public Svc Aide-Public Works    2514
# Police Officer 3                2411
# Name: count, dtype: int64

# %% [markdown]
# 22. Visualize the distribution of BasePay, OvertimePay, and OtherPay using histograms or kernel density plots

# %%
col = df[['BasePay', 'OvertimePay', 'OtherPay']]

for i in col:
    
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.hist(col[i], bins=10, color='red', edgecolor='black')
    plt.xlabel(i)
    plt.xticks(rotation=90)
    plt.ylabel('Frequency')
    plt.title('Distribution of ' + i)
    
    plt.subplot(1, 2, 2)
    df[i].plot(kind='kde', color='green')
    plt.xlabel(i)
    plt.xticks(rotation=90)
    plt.ylabel('Density')
    plt.title('Distribution of ' + i)
    
    plt.show()

# %% [markdown]
# 22) Display Name of The Person Having The Highest BasePay

# %%
highst_basepay = df['BasePay'].max()
df[df['BasePay'] == highst_basepay]
# Out:
#          EmployeeName         JobTitle    BasePay  OvertimePay  OtherPay  \
# 72925  Gregory P Suhr  Chief of Police  319275.01          0.0  20007.06
#
#         TotalPay  TotalPayBenefits  Year         Agency
# 72925  339282.07         425815.28  2013  San Francisco

# %%
# Set the overall figure size
plt.figure(figsize=(14, 7))

plt.subplot(1,3,1)
sns.countplot(x='EmployeeName',data=df, palette='Set1', order = df['EmployeeName'].value_counts().head(10).index)
plt.title('Employee Name')
plt.xticks(rotation=90)

plt.subplot(1,3,2)
sns.countplot(x='JobTitle',data=df, palette='Set2', order = df['JobTitle'].value_counts().head(10).index)
plt.title('JobTitle')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %%
num = df.select_dtypes(include=['int', 'float']).columns.tolist()

corr = df[num].corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True,cmap='Greens')
plt.show()
