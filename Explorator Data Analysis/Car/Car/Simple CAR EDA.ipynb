# %% [markdown]
# ## **Exploratory Data Analysis of Used Cars Dataset**
#
# **Analysis Goals**
#
# - **Descriptive Analysis:** Summarize the dataset to understand the distribution of various features such as year of manufacture, kilometers driven, fuel type, transmission, owner type, and seating capacity.
# - **Price Analysis:** Investigate the factors affecting the resale price of cars. Analyze the relationship between the price and other features such as year, kilometers driven, fuel type, engine capacity, and power.
# - **Geographical Insights:** Explore the geographical distribution of car sales and prices. Identify which locations have higher or lower average resale prices.
# - **Trend Analysis:** Examine trends over time, such as how car prices have changed over the years and the impact of the year of manufacture on resale prices.
# - **Missing Data Handling:** Address missing values in the dataset, particularly for the Mileage, Engine, Power, Seats, New_Price, and Price columns. Determine appropriate methods for handling or imputing these values, such as using mean, median, mode, or predictive modeling.
# - **Correlation Analysis:** Conduct a correlation analysis to identify the strength and direction of relationships between different numerical features and the resale price.

# %% [markdown]
# ### **Step 1: Import Python Libraries**
#
# The first step involved in ML using python is understanding and playing around with our data using libraries. Here is the link to the dataset.
#
# Import all libraries which are required for our analysis, such as Data Loading, Statistical analysis, Visualizations, Data Transformations, Merge and Joins, etc.
#
# Pandas and Numpy have been used for Data Manipulation and numerical Calculations
#
# Matplotlib and Seaborn have been used for Data visualizations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### **Step 2: Reading Dataset**
#
# The Pandas library offers a wide range of possibilities for loading data into the pandas DataFrame from files like JSON, .csv, .xlsx, .sql, .pickle, .html, .txt, images etc.
#
# Most of the data are available in a tabular format of CSV files. It is trendy and easy to access. Using the read_csv() function, data can be converted to a pandas DataFrame.
#
# In this article, the data to predict Used car price is being used as an example. In this dataset, we are trying to analyze the used car’s price and how EDA focuses on identifying the factors influencing the car price. We have stored the data in the DataFrame data.

# %%
data = pd.read_csv(r"D:\Python\EDA\Car\Car\Car.csv")

# %% [markdown]
# Analyzing the Data
#
# Before we make any inferences, we listen to our data by examining all variables in the data.
#
# The main goal of data understanding is to gain general insights about the data, which covers the number of rows and columns, values in the data, datatypes, and Missing values in the dataset.
#
# shape – shape will display the number of observations(rows) and features(columns) in the dataset
#
# There are 7253 observations and 14 variables in our dataset
#
#
# head() will display the top 5 observations of the dataset

# %% [markdown]
# data.head()

# %% [markdown]
# **tail()** will display the last 5 observations of the dataset

# %%
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# 3  88.76 bhp    7.0        NaN   6.00
# 4  140.8 bhp    5.0        NaN  17.74

# %% [markdown]
# **info()** helps to understand the data type and information about data, including the number of records in each column, data having null or not null, Data type, the memory usage of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
data.shape
# Out:
# (7253, 14)

# %%
data.nunique()
# Out:
# S.No.                7253
# Name                 2041
# Location               11
# Year                   23
# Kilometers_Driven    3660
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               450
# Engine                150
# Power                 386
# Seats                   9
# New_Price             625
# Price                1373
# dtype: int64

# %% [markdown]
# **Missing Values Calculation**
#
# isnull() is widely been in all pre-processing steps to identify null values in the data
#
# In our example, data.isnull().sum() is used to get the number of missing records in each column

# %%
data.isna().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# S.No.                 0.000000
# Name                  0.000000
# Location              0.000000
# Year                  0.000000
# Kilometers_Driven     0.000000
# Fuel_Type             0.000000
# Transmission          0.000000
# Owner_Type            0.000000
# Mileage               0.027575
# Engine                0.634220
# Power                 0.634220
# Seats                 0.730732
# New_Price            86.129877
# Price                17.013650
# dtype: float64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The percentage of missing values for the columns New_Price and Price is ~86% and ~17%, respectively.
#
# ### **Step 3: Data Reduction**
#
# Some columns or variables can be dropped if they do not add value to our analysis.
#
# In our dataset, the column S.No have only ID values, assuming they don’t have any predictive power to predict the dependent variable.

# %%
# Remove S.No. column from data
data.drop(['S.No.', 'New_Price'], axis = 1, inplace=True)

# %%
# Impute Price with median (or use predictive imputation if necessary)
data['Price'].fillna(data['Price'].median(), inplace=True)

# %%
data.dropna(subset=['Seats','Mileage'], inplace=True)

# %%
data.isna().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %% [markdown]
# We start our Feature Engineering as we need to add some columns required for analysis.
#
# ### **Step 4: Feature Engineering**
#
# Feature engineering refers to the process of using domain knowledge to select and transform the most relevant variables from raw data when creating a predictive model using machine learning or statistical modeling. The main goal of Feature engineering is to create meaningful data from raw data.
#
# ### **Step 4A: Creating Features**
#
# We will play around with the variables Year and Name in our dataset. If we see the sample data, the column “Year” shows the manufacturing year of the car.
#
# It would be difficult to find the car’s age if it is in year format as the Age of the car is a contributing factor to Car Price.
#
# Introducing a new column, “Car_Age” to know the age of the car

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %%
# Split the 'Power' column into two separate columns
data[['Power (Numeric)', 'Unit']] = data['Power'].str.split(' ', expand=True) #
data['Power (Numeric)'].replace({'null':'0'}, inplace=True) # Replace 'null' with '0' for numeric values
data['Power (Numeric)'] = data['Power (Numeric)'].astype('float') # Convert 'Power (Numeric)' to float

# %%
data[['Engine (Numeric)', 'Unit']] = data['Engine'].str.split(' ', expand=True)
data['Engine (Numeric)'] = data['Engine (Numeric)'].astype('int')

# %%
data[['Mileage (Numeric)', 'Unit']] = data['Mileage'].str.split(' ', expand=True)
data['Mileage (Numeric)'] = data['Mileage (Numeric)'].astype('float')

# %%
data.drop('Unit', axis=1, inplace=True)

# %%
data['Car_Age']= date.today().year-data['Year']

# %% [markdown]
# Since car names will not be great predictors of the price in our current data. But we can process this column to extract important information using brand and Model names. Let’s split the name and introduce new variables “Brand” and “Model”

# %%
data['Brand'] = data.Name.str.split().str.get(0)
data['Model'] = data.Name.str.split().str.get(1) + ' ' + data.Name.str.split().str.get(2)
data[['Name','Brand','Model']]
# Out:
#                                                    Name          Brand  \
# 0                                Maruti Wagon R LXI CNG         Maruti
# 1                      Hyundai Creta 1.6 CRDi SX Option        Hyundai
# 2                                          Honda Jazz V          Honda
# 3                                     Maruti Ertiga VDI         Maruti
# 4                       Audi A4 New 2.0 TDI Multitronic           Audi
# ...                                                 ...            ...
# 7248                  Volkswagen Vento Diesel Trendline     Volkswagen
# 7249                             Volkswagen Polo GT TSI     Volkswagen
# 7250                             Nissan Micra Diesel XV         Nissan
# 7251                             Volkswagen Polo GT TSI     Volkswagen
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...  Mercedes-Benz
#
#                   Model
# 0               Wagon R
# 1             Creta 1.6
# 2                Jazz V
# 3            Ertiga VDI
# 4                A4 New
# ...                 ...
# 7248       Vento Diesel
# 7249            Polo GT
# 7250       Micra Diesel
# 7251            Polo GT
# 7252  E-Class 2009-2013
#
# [7198 rows x 3 columns]

# %%
car_brands = data["Brand"].unique()
car_brands_lower = [brand.lower() for brand in car_brands]

# Find duplicates in the unique values
repeated_values = set([brand for brand in car_brands_lower if car_brands_lower.count(brand) > 1])

print(repeated_values)
# Out:
# {'isuzu'}

# %%
searchfor = ['Isuzu' ,'ISUZU','Mini','Land']
'|'.join(searchfor)
# Out:
# 'Isuzu|ISUZU|Mini|Land'

# %%
searchfor = ['Isuzu' ,'ISUZU','Mini','Land']
data[data.Brand.str.contains('|'.join(searchfor))].head()
# Out:
#                                     Name    Location  Year  Kilometers_Driven  \
# 13      Land Rover Range Rover 2.2L Pure       Delhi  2014              72000
# 14        Land Rover Freelander 2 TD4 SE        Pune  2012              85000
# 176             Mini Countryman Cooper D      Jaipur  2017               8525
# 191  Land Rover Range Rover 2.2L Dynamic  Coimbatore  2018              36091
# 228            Mini Cooper Convertible S       Kochi  2017              26327
#
#     Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 13     Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 14     Diesel    Automatic     Second    0.0 kmpl  2179 CC     115 bhp    5.0
# 176    Diesel    Automatic     Second   16.6 kmpl  1998 CC     112 bhp    5.0
# 191    Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 228    Petrol    Automatic      First  16.82 kmpl  1998 CC  189.08 bhp    4.0
#
#      Price  Power (Numeric)  Engine (Numeric)  Mileage (Numeric)  Car_Age  \
# 13   27.00           187.70              2179              12.70       10
# 14   17.50           115.00              2179               0.00       12
# 176  23.00           112.00              1998              16.60        7
# 191  55.76           187.70              2179              12.70        6
# 228  35.67           189.08              1998              16.82        7
#
#     Brand               Model
# 13   Land         Rover Range
# 14   Land    Rover Freelander
# 176  Mini   Countryman Cooper
# 191  Land         Rover Range
# 228  Mini  Cooper Convertible

# %%
data["Brand"].replace({"ISUZU": "Isuzu", "Mini": "Mini Cooper","Land":"Land Rover"}, inplace=True)

# %%
data['Model'].unique()
# Out:
# array(['Wagon R', 'Creta 1.6', 'Jazz V', 'Ertiga VDI', 'A4 New',
#        'EON LPG', 'Micra Diesel', 'Innova Crysta', 'Vento Diesel',
#        'Indica Vista', 'Ciaz Zeta', 'City 1.5', 'Swift VDI',
#        'Rover Range', 'Rover Freelander', 'Pajero Sport', 'Amaze S',
#        'Swift DDiS', 'Duster 85PS', 'New C-Class', '3 Series', 'S Cross',
#        'A6 2011-2015', 'i20 1.2', 'Vento Petrol', 'City Corporate',
#        'Alto K10', 'WRV i-VTEC', 'Innova 2.5', 'Duster 110PS',
#        'Corolla Altis', 'Ssangyong Rexton', 'A6 2.7', 'Vento 1.6',
#        'Vitara Brezza', 'KUV 100', 'M-Class ML', 'Polo Diesel',
#        'Alto LXi', 'Nano LX', 'i20 Magna', 'Elantra 2.0', 'Elantra CRDi',
#        'Xcent 1.1', 'Thar CRDe', 'A4 2.0', 'Swift LDI', 'Swift Ldi',
#        'Grand i10', 'Vento 2013-2015', 'KWID RXT', 'i10 Asta',
#        'X-Trail SLX', 'Zen Estilo', 'Figo Diesel', 'Indica V2', 'City ZX',
#        'C-Class Progressive', 'Ertiga SHVS', 'Creta 1.4',
#        'Cayenne 2009-2014', 'XUV500 W8', 'i10 Sportz', 'Terrano XV',
#        'Brio VX', 'A6 2.0', 'Fiesta 1.4', 'Innova 2.0', 'Santro Xing',
#        'Zest Revotron', 'Amaze SX', 'Ritz VDi', 'City i', '5 Series',
#        'Fortuner 4x2', 'Ecosport 1.5', 'Verna Transform', 'Polo Petrol',
#        'i20 1.4', 'i20 Asta', 'GO Plus', 'A4 3.0', 'i20 2015-2017',
#        'Omni 5', 'Etios Liva', 'XF 3.0', 'Verna 1.6', 'Eeco 5',
#        'Nano Twist', 'Civic 2006-2010', 'V40 Cross', 'Micra XV',
#        'B Class', 'Verna CRDi', 'Nano XTA', 'Scorpio VLX', 'CR-V 2.4',
#        'Vento 1.5', 'Ciaz VXi', 'XUV500 AT', 'Ritz VXI', 'SLC 43',
#        'Verna VTVT', '1 Series', 'Jazz 1.2', 'Swift VVT', 'Fortuner 3.0',
#        'Beat LT', 'Rapid 1.5', 'Ciaz 1.4', 'RS5 Coupe', 'S Class',
#        'Superb Elegance', 'EON Magna', 'GO NXT', 'Brio S', 'Swift VXI',
#        'X5 xDrive', 'Brio V', 'i10 Magna', 'GLC 220', 'Countryman Cooper',
#        'Beat Diesel', 'Optra Magnum', 'Lodgy 110PS', 'E-Class E250',
#        'Baleno Alpha', 'Scorpio 1.99', 'Ertiga ZDI', 'Laura Ambiente',
#        'NuvoSport N6', 'Fabia 1.4', 'Indigo eCS', 'Q3 2012-2015',
#        'Octavia Elegance', 'A8 L', 'Rapid 1.6', 'Superb Style',
#        'i20 Active', 'Amaze VX', 'Verito 1.5', 'Cooper Convertible',
#        'Swift ZDi', 'Santa Fe', 'City i-VTEC', 'i20 Sportz',
#        'X1 sDrive20d', 'Ciaz 1.3', 'Rapid Leisure', 'Accent CRDi',
#        'Polo GT', 'i10 Era', 'Tucson 2.0', 'Omni MPI', 'GLE 350d',
#        'Ritz ZDi', 'A-Star Vxi', 'Grande Punto', 'X3 xDrive30d',
#        'Zen VXI', 'Zest Quadrajet', 'EcoSport 1.0', 'Swift Dzire',
#        'Alto 800', 'Q7 3.0', 'Laura 1.9', 'Jazz VX', 'Jetta 2007-2011',
#        'Indigo LX', 'GLA Class', 'Celerio VXI', 'GLE 250d', 'Omni 8',
#        'Brio 1.2', 'Sumo Delux', 'Indigo LS', 'Ertiga Paseo',
#        'Accord 2.4', 'Fiesta EXi', '6 Series', 'Q7 45', 'Corolla H4',
#        'Manza ELAN', 'Octavia Ambition', 'EON D', 'Manza Club',
#        'Octavia RS', 'Spark 1.0', 'XF 2.0', 'CR-V RVi', 'Superb L&K',
#        'Fiesta Classic', 'Zen LX', 'Clubman Cooper', 'Etios GD',
#        'Alto VXi', 'X5 3.0d', 'Teana XV', '800 AC', 'BRV i-VTEC',
#        'E-Class 2009-2013', 'E-Class 2015-2017', 'XE Portfolio',
#        'Ritz LDi', 'Xenon XT', 'A3 35', 'GL-Class 2007', 'Alto LX',
#        'XF Diesel', 'Q3 35', 'Scorpio S10', 'BR-V i-VTEC',
#        'S80 2006-2013', 'Accent GLE', 'GLC 43', 'A6 35', 'Etios VD',
#        'EON Era', 'Captur 1.5', 'V40 D3', 'Enjoy 1.4', 'Bolero ZLX',
#        'Santro GLS', 'Q5 30', 'Ritz VXi', 'Cedia Sports', 'Celerio LDi',
#        'S-Cross Delta', 'Q7 4.2', 'Manza Aqua', 'Fortuner 4x4',
#        'Fiesta 1.6', 'E-Class E', 'Yeti Ambition', 'Figo 2015-2019',
#        'Endeavour Hurricane', 'GLS 350d', 'CR-V 2.4L', 'A Class',
#        'Ertiga VXI', 'Octavia Classic', 'Zen LXi', 'SX4 ZXI', 'Camry A/T',
#        'Beat LS', 'Swift Vdi', 'Mobilio S', 'Fabia 1.6', 'Etios G',
#        'E-Class 280', 'Linea T', 'Ertiga ZXI', 'Enjoy TCDi', 'X1 sDrive',
#        'Ciaz RS', 'XUV500 W6', 'TT 2.0', 'Polo 1.5', 'Renault Logan',
#        'Jazz 1.5', 'XF 2.2', 'Compass 2.0', 'Swift ZXI', 'Ikon 1.3',
#        'Bolero VLX', 'Sail Hatchback', 'Quanto C2', 'X5 2014-2019',
#        'Pajero 2.8', 'GLC 220d', 'XUV500 W10', 'Terrano XL', 'Scorpio S4',
#        'Aveo U-VA', 'Xcent 1.2', 'EON Sportz', 'Xylo E8', 'City V',
#        'Bolero DI', 'Esteem Vxi', 'Santro LS', 'Cooper 5',
#        'Safari Storme', 'BR-V i-DTEC', 'Jetta 2013-2015', 'Ignis 1.2',
#        'Beat Option', 'Indica DLS', 'Ciaz ZDi', 'XJ 2.0L',
#        'Corolla Executive', 'Vento IPL', 'Ciaz ZXi', 'Sunny XV',
#        'Ciaz VDI', 'Polo 1.2', 'Amaze EX', 'Superb 1.8', 'SLK-Class SLK',
#        'EcoSport 1.5', 'Passat Highline', 'Aveo 1.4', 'Ritz LXi',
#        'Endeavour 3.2', 'Q5 2008-2012', 'City 1.3', 'Dzire AMT',
#        'Cooper S', 'Yeti Elegance', 'Baleno Zeta', 'Accent GLS',
#        'Cruze LTZ', 'Nano Lx', 'Figo Titanium', 'Linea Emotion',
#        'Figo Aspire', 'Baleno LXI', 'Scorpio 2.6', 'Koleos 2.0', 'Omni E',
#        'Endeavour XLT', 'XUV500 W9', 'SX4 S', 'Qualis FS', 'Ameo 1.5',
#        'Xylo H4', 'Alto Green', 'A6 3.0', 'CR-V 2.0L', 'Mobilio RS',
#        'E-Class Facelift', 'KWID 1.0', 'Dzire VXI', 'Grand Vitara',
#        'TT 40', 'Sunny 2011-2014', 'Swift ZDI', 'Accent Executive',
#        'Scorpio LX', 'redi-GO T', 'Camry Hybrid', 'Jetta 2012-2014',
#        'Eeco 7', 'Q3 2.0', 'Fortwo CDI', 'Sumo DX', 'Vento TSI',
#        'Outlander 2.4', 'Cayman 2009-2012', 'Fabia 1.2', 'SX4 Vxi',
#        'Ameo 1.2', 'Baleno Delta', 'CLA 200', 'Endeavour 2.2',
#        'Civic 2010-2013', 'Baleno Vxi', 'XC60 D5', 'A-Star Lxi',
#        'Indigo CS', 'Ecosport Signature', 'Manza Aura', 'New Safari',
#        'GL-Class 350', 'Fortuner 2.8', 'Micra XE', 'Compass 1.4', 'A4 35',
#        'Indigo GLE', 'S-Cross Zeta', 'XUV500 W4', 'Laura Elegance',
#        'Boxster S', 'XUV300 W8', 'Hexa XT', 'Tiago 1.2', 'Swift LXI',
#        'Swift VDi', '7 Series', 'Superb 2009-2014', 'Ciaz VDi',
#        'Avventura MULTIJET', 'Swift VXi', 'SX4 ZDI', 'Tigor 1.2',
#        'Indica GLS', 'S60 D4', 'Polo 1.0', 'Q7 35', 'Classic Nova',
#        'Zen VX', '800 DX', 'Corolla 1.8', 'XE 2.0L', 'Xylo D4',
#        'Camry 2.5', 'Q5 3.0', 'Baleno Sigma', 'Figo Petrol', 'Swift Lxi',
#        'Rover Discovery', 'X1 M', 'Beetle 2.0', 'Linea Classic',
#        'Petra 1.2', 'Laura 1.8', 'SX4 Zxi', 'Micra XL', 'i20 Era',
#        'Getz 1.5', 'Ecosport 1.0', 'A7 2011-2015', 'Polo GTI',
#        'Micra Active', 'Fiesta Diesel', 'Elite i20', 'Optra 1.6',
#        'Q5 2.0', 'Scorpio S6', '800 Std', 'Cooper Countryman', 'Sail LT',
#        'XJ 3.0L', 'Accord VTi-L', 'X3 xDrive20d', 'Laura Ambition',
#        'Aspire Titanium', 'Cooper 3', 'Passat Diesel', 'Tiguan 2.0',
#        'Captiva LTZ', 'Scorpio 2009-2014', 'i10 Magna(O)', 'Mobilio V',
#        'A-Star AT', 'Octavia Rider', 'Duster Petrol', 'Punto EVO',
#        'TUV 300', 'Endeavour 4x2', 'Amaze V', 'Figo 1.5D', 'Sunny XL',
#        'Endeavour 3.0L', 'X6 xDrive', 'KWID Climber', 'Cayenne Diesel',
#        'GO T', 'EON 1.0', 'Ritz ZXi', 'Amaze E', 'Bolt Quadrajet',
#        'Elantra 1.6', 'X1 xDrive', 'Evalia 2013', 'Linea T-Jet',
#        'Santro DX', 'Enjoy 1.3', 'Scala Diesel', 'Corolla H2',
#        'E-Class 200', 'Dzire VDI', 'Dzire ZDI', 'Fabia 1.2L', 'Sumo EX',
#        'Linea 1.3', 'Figo 1.2P', 'E-Class 220', 'Octavia 1.9', 'Ikon 1.4',
#        'Xylo E4', 'Bolero SLE', 'Ritz AT', 'Jeep MM', 'Sonata Embera',
#        'Duster Adventure', 'Verna 1.4', 'Verna SX', 'Cayenne Turbo',
#        'Quanto C8', 'Corolla H5', 'Freestyle Titanium', 'Ciaz AT',
#        'Scorpio SLE', 'SX4 VDI', 'Fiesta Titanium', 'E-Class E270',
#        'Camry W4', 'Superb 2.5', 'Etios Cross', 'Celerio ZXI',
#        'City i-DTEC', 'Qualis RS', 'X6 xDrive30d', 'Logan Diesel',
#        'Ciaz Alpha', 'Safari DICOR', 'Tavera LT', 'Celerio LXI',
#        'Nano XT', 'Santro AT', 'Xylo D2', 'XC90 2007-2015', 'Scorpio S2',
#        'Sunny Diesel', 'Pulse RxL', 'Etios Petrol', 'Corolla DX',
#        'Hexa XTA', 'Accord 2001-2003', 'SX4 Green', 'Octavia 2.0',
#        'NuvoSport N8', 'Octavia Ambiente', 'S80 D5', 'Tavera LS',
#        'Montero 3.2', 'Tiago AMT', 'Nano Cx', 'Scala RxL', 'A4 1.8',
#        'Getz GLS', 'Panamera Diesel', 'A6 2.8', 'Bolero mHAWK',
#        'Mobilio E', 'Superb 3.6', 'S60 D3', 'Celerio CNG', 'Scorpio DX',
#        'Tucson CRDi', 'Swift AMT', 'Etios VX', 'CrossPolo 1.5',
#        'Celerio ZDi', 'Getz GLE', 'Brio E', 'Fluence Diesel', 'X5 X5',
#        'X3 xDrive', 'Tigor 1.05', 'Venture EX', 'Endeavour 2.5L',
#        'Nexon 1.5', 'MUX 4WD', 'Platinum Etios', 'Thar DI',
#        'Panamera 2010', 'Santro GS', 'Tiago Wizz', 'KWID RXL',
#        'Scorpio S8', 'Vento Sport', 'Cayenne Base', 'Zen LXI',
#        'Jazz Select', 'A4 30', 'Endeavour Titanium', 'Sail 1.2',
#        'Dzire LDI', 'Eeco CNG', 'XUV500 W7', 'Q3 30', 'Rapid 2013-2016',
#        'E-Class E400', 'Aspire Ambiente', 'Sonata Transform', 'Quanto C6',
#        'R-Class R350', 'Octavia L', 'Getz GVS', 'Bolero SLX', 'Indigo XL',
#        'CR-V 2.0', 'Passat 1.8', 'Quanto C4', 'Pajero 4X4', 'Brio EX',
#        'Teana 230jM', 'Swift LXi', 'CLS-Class 2006-2010', 'D-MAX V-Cross',
#        'CR-V Sport', 'S-Cross Alpha', 'Fluence 1.5', 'Captiva LT',
#        'S60 D5', 'E-Class 250', 'Baleno RS', 'Fluence 2.0', 'Alto Std',
#        'Dzire New', 'Sonata GOLD', 'Ertiga LXI', 'Ignis 1.3',
#        'S-Class 320', 'Jazz Exclusive', 'Lancer 1.5', 'Sunny XE',
#        'KWID AMT', 'Octavia Style', 'A4 3.2', 'Swift RS', 'Passat 2.0',
#        'E-Class E350', 'Classic 1.4', 'redi-GO S', 'S-Class 280',
#        'Eeco Smiles', 'Vento 1.2', 'Duster RXZ', 'Ikon 1.6',
#        'E-Class 230', 'Accord V6', 'Xylo E2', 'Jazz Mode', 'Esteem LX',
#        'Laura RS', 'Ritz LXI', 'Etios VXD', 'Superb 2.8', 'XC60 D4',
#        'Redi GO', 'Mustang V8', 'Fusion Plus', 'Jazz Active', 'Ritz ZXI',
#        'Fortuner TRD', 'Superb Ambition', 'Scorpio SLX', 'Siena 1.2',
#        'SLK-Class 55', 'XF Aero', '1000 AC', 'Fiesta 1.5', 'SL-Class SL',
#        'Verna Xi', 'S-Class S', 'Alto LXI', 'Lancer GLXD', 'Alto Vxi',
#        'Santro D', 'Nexon 1.2', 'Z4 2009-2013', 'Nano STD', 'One LX',
#        'Jazz S', 'Logan Petrol', 'Versa DX2', 'Sonata 2.4', 'XJ 5.0',
#        'Aveo 1.6', 'Zen VXi', 'Enjoy Petrol', 'Getz 1.3', 'Ritz VDI',
#        'Verna XXi', 'Pulse Petrol', 'Cayenne S', 'Laura L', 'WR-V Edge',
#        'Camry W2', 'Nano CX', 'Continental Flying', 'Santro LP',
#        'CR-V Petrol', 'Tigor XE', 'Etios 1.4', 'Qualis Fleet',
#        'Rapid Ultima', 'Vento Konekt', 'Gallardo Coupe', 'Vento Magnific',
#        'i20 Diesel', 'Etios V', 'F Type', 'Laura Classic', 'Indica LEI',
#        'Elantra SX', 'Polo IPL', 'Bolt Revotron', 'Celerio X', 'Teana XL',
#        'BRV i-DTEC', 'A-Star Zxi', 'Avventura FIRE', 'CR-V Diesel',
#        'Xylo E9', 'Motors Contessa', 'Linea Dynamic', 'Thar 4X4',
#        'Camry MT', 'Verito Vibe', 'Flying Spur', 'Land Cruiser',
#        'Polo ALLSTAR', 'MU 7', 'Elantra GT', 'X3 2.5si', 'Xylo H9',
#        'Pulse RxZ', 'WRV i-DTEC', 'Accent GLX', 'CrossPolo 1.2',
#        'Avventura Urban', '370Z AT', 'Koleos 4X2', 'Bolero Power',
#        'Scorpio VLS', 'Abarth 595', 'E-Class E240', 'Terrano XE', nan,
#        'CLA 45', 'Alto XCITE', 'Superb Petrol', 'Tiago 1.05'],
#       dtype=object)

# %%
# Lowercase all model names
all_models_lower = data["Model"].str.lower()

# Find duplicates in the original lowercase model names
repeated_values = set([model for model in all_models_lower if list(all_models_lower).count(model) > 1])

print(repeated_values)
# Out:
# {'octavia rider', 'scala diesel', 'outlander 2.4', 'omni 8', 'jazz v', 'kwid amt', 'scorpio 2.6', 'xe 2.0l', 'gl-class 350', 'duster adventure', 'xc60 d4', 'compass 1.4', 'xf 3.0', 'ertiga zxi', 's60 d4', 'zen lxi', 'br-v i-dtec', 'octavia 2.0', 'accent gls', 'scorpio vlx', 'i20 sportz', 'enjoy 1.3', 'ertiga zdi', 'etios vd', 'i10 sportz', 'x5 3.0d', 'a8 l', 'corolla h2', 'figo 1.2p', 'br-v i-vtec', 'kwid rxt', 'linea emotion', 's-class 280', 'r-class r350', 'q5 2.0', 'glc 220', 'x6 xdrive30d', 'new c-class', 'xuv500 w10', 'vento ipl', 'rover freelander', 'xenon xt', '7 series', 'baleno alpha', 'indica vista', 'quanto c2', 'terrano xv', 'ciaz 1.3', 'figo 1.5d', 'sx4 zxi', 'redi-go t', 'mobilio v', 'b class', 'octavia classic', 'alto green', 'micra diesel', 'ikon 1.3', 'a6 2011-2015', 'q5 2008-2012', 'fortuner 4x4', 'ameo 1.5', 'eeco 7', 'santro ls', 'i20 1.2', 'q5 3.0', 'sx4 vxi', 'koleos 2.0', 's class', 'x1 sdrive20d', 'clubman cooper', 'tigor 1.05', 'i20 asta', 'fortuner 4x2', 'optra magnum', 'optra 1.6', 's80 d5', 'accord 2001-2003', 'duster 110ps', 'i20 active', 'nano twist', 'one lx', 'omni 5', 'brio e', 'linea classic', 'accent crdi', 'cr-v 2.0l', 'e-class 200', 'safari storme', 'x5 2014-2019', 'qualis fs', 'verna vtvt', 'vento 1.5', 'brv i-vtec', 'city 1.5', 'etios vxd', 'ritz zdi', 'thar crde', 'brio s', 'e-class 2015-2017', 'scorpio lx', 'xuv500 w6', 'zen estilo', 'ignis 1.2', 'camry 2.5', 'slk-class slk', 'alto k10', 'eon sportz', 'ikon 1.4', 'ciaz alpha', 'swift amt', 'e-class e270', 'alto lxi', 'hexa xta', 'thar di', 'nexon 1.5', 'fabia 1.4', 'corolla executive', 'amaze e', 'c-class progressive', 'celerio cng', 'elantra 1.6', 'amaze s', 'pajero 2.8', 'eon 1.0', 'zest revotron', 'ameo 1.2', 'i20 magna', 'superb style', 'spark 1.0', '3 series', 'vento 1.6', 'indica dls', 'xcent 1.1', 'swift zxi', 'jetta 2013-2015', 'rover discovery', 'i10 asta', 'x1 sdrive', 'sx4 vdi', 'jetta 2012-2014', 'eon d', 'ertiga vdi', 'grand vitara', 'crosspolo 1.5', 'e-class 220', 'q7 3.0', 'a3 35', 'indigo lx', 'x1 m', 'figo aspire', 'gla class', 'eon magna', 's cross', 'polo 1.0', 'city zx', 'alto std', 'xylo e8', 'ritz zxi', 'xylo d2', 'etios g', 'pulse rxl', 'micra xl', 'ritz lxi', 'nano lx', '800 std', 'e-class 230', 'e-class facelift', 'i10 era', '1 series', 'ertiga paseo', 'laura l', 'swift zdi', 'xylo d4', 'octavia elegance', 'cooper 3', 'cr-v 2.4', 'e-class e250', 'beat ls', 'rapid 1.5', 'sonata embera', 'vitara brezza', 'superb elegance', 'q7 45', 'baleno sigma', 'accord vti-l', 'ritz ldi', 'sunny xl', 'indigo xl', 'celerio vxi', 'passat 1.8', 'celerio lxi', 'classic 1.4', 'bolero slx', 'x3 xdrive', 'duster petrol', 'panamera diesel', 'linea 1.3', 'santro gs', 'cayman 2009-2012', 'sumo ex', 'lodgy 110ps', 'alto lx', 'captiva lt', 'brv i-dtec', 'q5 30', 'cayenne diesel', 'endeavour 2.2', 'laura ambiente', 'verito 1.5', 'go t', 'gls 350d', 'amaze vx', 'amaze ex', 'q3 30', 'mobilio e', 'micra active', 'xuv500 at', 'wrv i-vtec', 'quanto c8', 'vento sport', 'jazz vx', 'kwid 1.0', 'bolero vlx', 'innova 2.0', 'm-class ml', 'jazz s', 'versa dx2', 'micra xv', 'fiesta diesel', 'accent gle', 'fortuner 3.0', 'pajero sport', 'mobilio s', 'cruze ltz', 'swift vxi', 'gle 250d', 'creta 1.4', 'baleno vxi', 'fluence diesel', 'laura 1.9', 'slc 43', 'santro xing', 'cr-v 2.0', 'q3 35', 'ertiga vxi', 'x5 xdrive', 'safari dicor', 'dzire ldi', 'ciaz 1.4', 'tavera ls', 'yeti elegance', 'scorpio slx', 'nano xta', 'indica gls', 'e-class 250', 'elantra sx', 'rover range', 'elantra 2.0', 'enjoy tcdi', 'fiesta classic', 'tuv 300', 'cedia sports', 'tt 2.0', 'swift vdi', 'captur 1.5', 'cr-v rvi', 'xylo e4', 'nuvosport n6', 'a6 35', 'elantra crdi', 'scorpio s6', 'eeco 5', 'x-trail slx', 'innova crysta', 'jazz 1.5', '800 ac', 'indigo cs', 'a-star at', 'a4 1.8', 'jetta 2007-2011', 'ikon 1.6', 'ciaz rs', 'aveo 1.4', 'brio vx', 'civic 2010-2013', 'xc90 2007-2015', 'sx4 s', 'e-class 280', 'ciaz vdi', 'corolla h5', 'cla 200', 'alto vxi', 'getz gls', 'x6 xdrive', 'zen v ...

# %%
data['Model'] = data["Model"].str.lower()

# %%
car_model = data["Model"].nunique()
car_model
# Out:
# 695

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price  Power (Numeric)  Engine (Numeric)  Mileage (Numeric)  Car_Age  \
# 0   1.75            58.16               998              26.60       14
# 1  12.50           126.20              1582              19.67        9
# 2   4.50            88.70              1199              18.20       13
# 3   6.00            88.76              1248              20.77       12
# 4  17.74           140.80              1968              15.20       11
#
#      Brand       Model
# 0   Maruti     wagon r
# 1  Hyundai   creta 1.6
# 2    Honda      jazz v
# 3   Maruti  ertiga vdi
# 4     Audi      a4 new

# %%
data.shape
# Out:
# (7198, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7198 entries, 0 to 7252
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7198 non-null   object
#  1   Location           7198 non-null   object
#  2   Year               7198 non-null   int64
#  3   Kilometers_Driven  7198 non-null   int64
#  4   Fuel_Type          7198 non-null   object
#  5   Transmission       7198 non-null   object
#  6   Owner_Type         7198 non-null   object
#  7   Mileage            7198 non-null   object
#  8   Engine             7198 non-null   object
#  9   Power              7198 non-null   object
#  10  Seats              7198 non-null   float64
#  11  Price              7198 non-null   float64
#  12  Power (Numeric)    7198 non-null   float64
#  13  Engine (Numeric)   7198 non-null   int32
#  14  Mileage (Numeric)  7198 non-null   float64
#  15  Car_Age            7198 non-null   int64
#  16  Brand              7198 non-null   object
#  17  Model              7197 non-null   object
# dtypes: float64(4), int32(1), int64(3), object(10)
# memory usage: 1.0+ MB

# %% [markdown]
# We have done the fundamental data analysis, Featuring, and data clean-up. Let’s move to the EDA process
#
# Voila!! Our Data is ready to perform EDA.
#
# ### **Step 5: EDA Exploratory Data Analysis**
#
# Exploratory Data Analysis refers to the crucial process of performing initial investigations on data to discover patterns to check assumptions with the help of summary statistics and graphical representations.
#
# - EDA can be leveraged to check for outliers, patterns, and trends in the given data.
# - EDA helps to find meaningful patterns in data.
# - EDA provides in-depth insights into the data sets to solve our business problems.
# - EDA gives a clue to impute missing values in the dataset
#
# ### **Step 6: Statistics Summary**
#
# The information gives a quick and simple description of the data.
#
# Can include Count, Mean, Standard Deviation, median, mode, minimum value, maximum value, range, standard deviation, etc.
#
# Statistics summary gives a high-level idea to identify whether the data has any outliers, data entry error, distribution of data such as the data is normally distributed or left/right skewed
#
# In python, this can be achieved using describe()
#
# describe() function gives all statistics summary of data
#
# describe()– Provide a statistics summary of data belonging to numerical datatype such as int, float

# %%
data.describe().T
# Out:
#                     count          mean           std      min         25%  \
# Year               7198.0   2013.391081      3.235298  1996.00   2011.0000
# Kilometers_Driven  7198.0  58631.777160  84694.798141   171.00  34000.0000
# Seats              7198.0      5.279800      0.811759     0.00      5.0000
# Price              7198.0      8.845521     10.311835     0.44      3.8725
# Power (Numeric)    7198.0    110.829464     55.044446     0.00     74.0000
# Engine (Numeric)   7198.0   1616.900389    595.034653   624.00   1198.0000
# Mileage (Numeric)  7198.0     18.184266      4.504070     0.00     15.2150
# Car_Age            7198.0     10.608919      3.235298     5.00      8.0000
#
#                         50%       75%         max
# Year                2014.00   2016.00     2019.00
# Kilometers_Driven  53253.00  73000.00  6500000.00
# Seats                  5.00      5.00       10.00
# Price                  5.64      8.41      160.00
# Power (Numeric)       91.72    138.03      616.00
# Engine (Numeric)    1493.00   1968.00     5998.00
# Mileage (Numeric)     18.19     21.10       33.54
# Car_Age               10.00     13.00       28.00

# %%
data.describe(include='object').T
# Out:
#              count unique                     top  freq
# Name          7198   2015  Mahindra XUV500 W8 2WD    55
# Location      7198     11                  Mumbai   943
# Fuel_Type     7198      4                  Diesel  3838
# Transmission  7198      2                  Manual  5163
# Owner_Type    7198      4                   First  5921
# Mileage       7198    450               17.0 kmpl   205
# Engine        7198    149                 1197 CC   732
# Power         7198    385                  74 bhp   280
# Brand         7198     32                  Maruti  1428
# Model         7197    695             swift dzire   189

# %% [markdown]
# From the statistics summary, we can infer the below findings :
#
# - Years range from 1996- 2019 and has a high in a range which shows used cars contain both latest models and old model cars.
# - On average of Kilometers-driven in Used cars are ~58k KM. The range shows a huge difference between min and max as max values show 650000 KM shows the evidence of an outlier. This record can be removed.
# - Min value of Mileage shows 0 cars won’t be sold with 0 mileage. This sounds like a data entry issue.
# - It looks like Engine and Power have outliers, and the data is right-skewed.
# - The average number of seats in a car is 5. car seat is an important feature in price contribution.
# - The max price of a used car is 160k which is quite weird, such a high price for used cars. There may be an outlier or data entry issue.
#
# describe(include=’all’) provides a statistics summary of all data, include object, category etc

# %%
cat_cols=data.select_dtypes(include=['object']).columns.tolist()
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# ['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Brand', 'Model']
# Numerical Variables:
# ['Year', 'Kilometers_Driven', 'Seats', 'Price', 'Power (Numeric)', 'Engine (Numeric)', 'Mileage (Numeric)', 'Car_Age']

# %% [markdown]
# ### **Step 7: EDA Univariate Analysis**
#
# Analyzing/visualizing the dataset by taking one variable at a time:
#
# Data visualization is essential; we must decide what charts to plot to better understand the data. In this article, we visualize our data using Matplotlib and Seaborn libraries.
#
# Matplotlib is a Python 2D plotting library used to draw basic charts we use Matplotlib.
#
# Seaborn is also a python library built on top of Matplotlib that uses short lines of code to create and style statistical plots from Pandas and Numpy
#
# Univariate analysis can be done for both Categorical and Numerical variables.
#
# Categorical variables can be visualized using a Count plot, Bar Chart, Pie Plot, etc.
#
# Numerical Variables can be visualized using Histogram, Box Plot, Density Plot, etc.
#
# In our example, we have done a Univariate analysis using Histogram and  Box Plot for continuous Variables.
#
# In the below fig, a histogram and box plot is used to show the pattern of the variables, as some variables have skewness and outliers.

# %%
for col in num_cols:
    print(col)
    plt.subplot(1, 1, 1)
    data[col].hist(grid=False, bins=20, edgecolor='black', alpha=0.7, color='red')
    plt.ylabel('count')
    plt.show()
# Out:
# Year
# Kilometers_Driven
# Seats
# Price
# Power (Numeric)
# Engine (Numeric)
# Mileage (Numeric)
# Car_Age

# %%
cat_col = ['Location', 'Fuel_Type', 'Transmission', 'Owner_Type','Brand', 'Model']

# %%
for col in cat_col:
    print(col)
    sns.countplot(x=col, data=data, order=data[col].value_counts().head(10).index, palette="Set2")
    plt.xticks(rotation=90)
    plt.show()
# Out:
# Location
# Fuel_Type
# Transmission
# Owner_Type
# Brand
# Model

# %% [markdown]
# ### **8: EDA Bivariate Analysis**

# %%
#plt.figure(figsize=(13,17))
#sns.pairplot(data=data.drop(['Kilometers_Driven','Price'],axis=1))
corr = data[num_cols].corr()
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# Pair Plot provides below insights:
#
# - The variable Year has a positive correlation with price and mileage
# - A year has a Negative correlation with kilometers-Driven
# - Mileage is negatively correlated with Power
# - As power increases, mileage decreases
# - Car with recent make is higher at prices. As the age of the car increases price decreases
# - Engine and Power increase, and the price of the car increases
#
# A bar plot can be used to show the relationship between Categorical variables and continuous variables

# %% [markdown]
# From the count plot, we can have below observations
#
# - Mumbai has the highest number of cars available for purchase, followed by Hyderabad and Coimbatore
# - ~53% of cars have fuel type as Diesel this shows diesel cars provide higher performance
# - ~72% of cars have manual transmission
# - ~82 % of cars are First owned cars. This shows most of the buyers prefer to purchase first-owner cars
# - ~20% of cars belong to the brand Maruti followed by 19% of cars belonging to Hyundai
# - WagonR ranks first among all models which are available for purchase
#
#
#
# ### **9: EDA Bivariate Analysis**
#
# Now, let’s move ahead with bivariate analysis. Bivariate Analysis helps to understand how variables are related to each other and the relationship between dependent and independent variables present in the dataset.
#
# For Numerical variables, Pair plots and Scatter plots are widely been used to do Bivariate Analysis.
#
# A Stacked bar chart can be used for categorical variables if the output variable is a classifier. Bar plots can be used if the output variable is continuous
#
# In our example, a pair plot has been used to show the relationship between two Categorical variables.

# %%
# Group by Brand and find the maximum values for Power, Engine, and Mileage
power = data.groupby('Brand')['Power (Numeric)'].mean().sort_values(ascending=False)
engine = data.groupby('Brand')['Engine (Numeric)'].mean().sort_values(ascending=False)
mileage = data.groupby('Brand')['Mileage (Numeric)'].mean().sort_values(ascending=False)

# Plotting
fig, ax = plt.subplots(1, 3, figsize=(18, 6))

# Plot Power
power.plot(kind='bar', ax=ax[0], color='skyblue')
ax[0].set_title('Highest Power by Brand', fontweight='bold')
ax[0].set_ylabel('Power (Numeric)')
ax[0].set_xlabel('Brand', fontweight='bold')

# Plot Engine
engine.plot(kind='bar', ax=ax[1], color='lightcoral')
ax[1].set_title('Highest Engine Capacity by Brand', fontweight='bold')
ax[1].set_ylabel('Engine (Numeric)')
ax[1].set_xlabel('Brand', fontweight='bold')

# Plot Mileage
mileage.plot(kind='bar', ax=ax[2], color='lightgreen')
ax[2].set_title('Highest Mileage by Brand', fontweight='bold')
ax[2].set_ylabel('Mileage (Numeric)')
ax[2].set_xlabel('Brand', fontweight='bold')

plt.tight_layout() # Adjust spacing between subplots
plt.show()

# %%
# Define features and titles for plotting
features = [
    ('Location', 'Location Vs Price', 'skyblue'),
    ('Transmission', 'Transmission Vs Price', 'lightcoral'),
    ('Fuel_Type', 'Fuel_Type Vs Price', 'lightgreen'),
    ('Owner_Type', 'Owner_Type Vs Price', 'gold'),
    ('Brand', 'Brand Vs Price', 'lightblue'),
    ('Model', 'Model Vs Price', 'lightcoral'),
    ('Seats', 'Seats Vs Price', 'lightgreen'),
    ('Car_Age', 'Car_Age Vs Price', 'gold')
]

fig, axarr = plt.subplots(4, 2, figsize=(12, 18))

for i, (feature, title, color) in enumerate(features):
    row, col = divmod(i, 2)  # Calculate subplot indices
    if feature in ['Brand', 'Model', 'Car_Age']:  # Handle cases where we limit the number of bars
        data.groupby(feature)['Price'].mean().sort_values(ascending=False).head(10).plot.bar(
            ax=axarr[row][col], fontsize=12, color=color
        )
    else:
        data.groupby(feature)['Price'].mean().sort_values(ascending=False).plot.bar(
            ax=axarr[row][col], fontsize=12, color=color
        )
    axarr[row][col].set_title(title, fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# Observations
#
# - The price of cars is high in Coimbatore and less price in Kolkata and Jaipur
# - Automatic cars have more price than manual cars.
# - Diesel and Electric cars have almost the same price, which is maximum, and LPG cars have the lowest price
# - First-owner cars are higher in price, followed by a second
# - The third owner’s price is lesser than the Fourth and above
# - Lamborghini brand is the highest in price
# - Gallardocoupe Model is the highest in price
# - 2 Seater has the highest price followed by 4 Seater
# - The latest model cars are high in price

# %% [markdown]
# ### **Conclusion**
# Car prices are influenced by where you buy them, whether they're automatic or manual, the type of fuel they use, how many owners they've had, the brand and model, the number of seats, and how new they are. Knowing these trends can guide buyers in making smart choices based on their preferences and budget.
